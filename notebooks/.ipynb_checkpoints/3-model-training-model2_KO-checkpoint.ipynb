# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "KO"

# %%
NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 128
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 100
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization, Reshape
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 19:59:55.250893: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.048428  0.058512  0.059283  0.059831  0.103688  2020-10-15 00:00:00-04:00
# 1  0.065538  0.064916  0.076179  0.061010  0.159558  2020-10-16 00:00:00-04:00
# 2  0.066697  0.068700  0.064026  0.048926  0.103203  2020-10-19 00:00:00-04:00
# 3  0.062638  0.072776  0.073808  0.067495  0.119312  2020-10-20 00:00:00-04:00
# 4  0.064668  0.067245  0.073215  0.059831  0.143262  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.513142  0.517365  0.531784  0.526933  0.099551  2023-07-03 00:00:00-04:00
# 1  0.515663  0.532234  0.535972  0.541347  0.177316  2023-07-05 00:00:00-04:00
# 2  0.529845  0.529703  0.546925  0.526292  0.144602  2023-07-06 00:00:00-04:00
# 3  0.516609  0.513252  0.522120  0.500667  0.174976  2023-07-07 00:00:00-04:00
# 4  0.505893  0.502179  0.503113  0.486252  0.189146  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.498595  0.523871  0.518136  0.533169  0.202184  2024-01-02 00:00:00-05:00
# 1  0.534776  0.534157  0.553810  0.537725  0.179081  2024-01-03 00:00:00-05:00
# 2  0.538618  0.536085  0.550538  0.531217  0.149386  2024-01-04 00:00:00-05:00
# 3  0.530614  0.526121  0.531882  0.528288  0.110652  2024-01-05 00:00:00-05:00
# 4  0.526771  0.533514  0.542682  0.542607  0.128354  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        up_by_1_percent = 1.0 if data[i, target_attr_idx] / data[i-1, target_attr_idx] > 1.01 else 0.0
        data_y.append(up_by_1_percent)
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (254, 5)
# inside construct_lstm_data with shape: (168, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (552, 128, 5)
# > Data Train y: (552,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 128, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 128, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
class AppendParametersLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        inner_layer_output, extra_params = inputs
        return tf.concat([inner_layer_output, extra_params], axis=-1)

# %%
from tensorflow.keras.layers import Concatenate

input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

cnn = Conv1D(32, 6)(input_layer)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(32,6)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
# cnn = Conv1D(128,3, strides=2)(cnn)
# cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
# cnn = Conv1D(128,3)(cnn)
# cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
# cnn = Dense(256)(cnn)
# cnn = Reshape((64, 256))(cnn)  # Align shape with `input_denser`
from tensorflow.keras.layers import ZeroPadding1D, Cropping1D

# cnn = ZeroPadding1D(padding=(30))(cnn)
# cnn = Cropping1D(cropping=(0,1))(cnn)  # Remove 1 from the beginning

# input_denser = Dense(256, kernel_initializer=tf.keras.initializers.HeUniform())(input_layer)

# input_to_lstm = Concatenate()([cnn, input_denser])

# Add first LSTM layer and dropout regularization layer
lstm = LSTM(units = 800, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 800, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 200, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 100)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = Dense(1)(lstm)
# Out:
# 2024-12-31 19:59:57.044094: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 19:59:57.044140: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-31 19:59:57.725866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:57.726767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:57.727310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:58.200440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:58.201465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:58.202061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:58.381426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:58.382004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:58.382681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:58.518881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:58.519721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:58.520356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:58.647704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:58.648441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:58.648990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# # # Add input layer
# regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add second LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 400, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add third LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 200, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add forth LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# %%
from tensorflow.keras.models import Model

# # Add last dense layer/output layer
# regressor.add(Dense(1))
# regressor.summary()
regressor = Model(input_layer,lstm)
regressor.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 5)]          0
#  conv1d (Conv1D)             (None, 123, 32)           992
#  p_re_lu (PReLU)             (None, 123, 32)           32
#  conv1d_1 (Conv1D)           (None, 118, 32)           6176
#  p_re_lu_1 (PReLU)           (None, 118, 32)           32
#  conv1d_2 (Conv1D)           (None, 58, 64)            6208
#  p_re_lu_2 (PReLU)           (None, 58, 64)            64
#  conv1d_3 (Conv1D)           (None, 56, 64)            12352
#  p_re_lu_3 (PReLU)           (None, 56, 64)            64
#  lstm (LSTM)                 (None, 56, 800)           2768000
#  dropout (Dropout)           (None, 56, 800)           0
#  lstm_1 (LSTM)               (None, 56, 800)           5123200
#  dropout_1 (Dropout)         (None, 56, 800)           0
#  lstm_2 (LSTM)               (None, 56, 400)           1921600
#  dropout_2 (Dropout)         (None, 56, 400)           0
#  lstm_3 (LSTM)               (None, 56, 200)           480800
#  dropout_3 (Dropout)         (None, 56, 200)           0
#  lstm_4 (LSTM)               (None, 100)               120400
#  dropout_4 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 10,440,021
# Trainable params: 10,440,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K


optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(optimizer=optimizer, loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-16             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
try:
    best_model = load_model(model_location + model_name)
    regressor = best_model
    print(f"Using already trained model")
except:
    print(f"Building brand new model")
# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 19:59:59.384066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:59.384842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:59.385552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:59.832760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:59.833868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:59.834558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:59:59.977406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:59:59.977970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:59:59.978574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:00.083513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.084203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.084985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:00.177825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.178487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.179086: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 20:00:00.715754: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.716831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.717514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:00.809937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.810591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.811266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:00.902475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.903103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.903728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:00.995593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:00.996597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:00.997203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:01.088394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:01.089043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:01.089656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:01.758499: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.323746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.433435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.502672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.575213: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.649560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:02.835042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:03.013736: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:03.133168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:03.248433: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:03.355226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/18 [>.............................] - ETA: 51s - loss: 0.2637
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2929
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2777
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2773
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2843
#  6/18 [=========>....................] - ETA: 1s - loss: 0.2857
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2826
#  8/18 [============>.................] - ETA: 0s - loss: 0.2868
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2830
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2804
# 11/18 [=================>............] - ETA: 0s - loss: 0.2782
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2756
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2710
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2685
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2665
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2655
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2644
# 18/18 [==============================] - ETA: 0s - loss: 0.2642
# 2024-12-31 20:00:05.495069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:05.495996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:05.496564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:05.582176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:05.582745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:05.583298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:05.668151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:05.668729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:05.669323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:05.774783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:05.775590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:05.776231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:05.862210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 20:00:05.862858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 20:00:05.863489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 20:00:05.909022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:06.132409: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:06.187928: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:06.251522: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:06.317851: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 20:00:06.401217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 18/18 [==============================] - 6s 192ms/step - loss: 0.2642 - val_loss: 0.2484 - lr: 3.3300e-04
# Epoch 2/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2469
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2586
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2530
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2439
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2481
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2458
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2538
#  8/18 [============>.................] - ETA: 0s - loss: 0.2509
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2502
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2486
# 11/18 [=================>............] - ETA: 0s - loss: 0.2492
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2488
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2481
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2467
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2477
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2466
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2460
# 18/18 [==============================] - ETA: 0s - loss: 0.2460
# 18/18 [==============================] - 2s 93ms/step - loss: 0.2460 - val_loss: 0.2419 - lr: 3.3300e-04
# Epoch 3/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2187
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2403
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2421
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2440
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2410
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2417
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2379
#  8/18 [============>.................] - ETA: 0s - loss: 0.2387
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2392
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2383
# 11/18 [=================>............] - ETA: 0s - loss: 0.2389
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2387
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2411
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2394
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2396
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2413
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2423
# 18/18 [==============================] - ETA: 0s - loss: 0.2417
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2417 - val_loss: 0.2421 - lr: 3.3300e-04
# Epoch 4/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2257
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2224
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2529
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2581
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2453
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2493
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2464
#  8/18 [============>.................] - ETA: 0s - loss: 0.2444
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2446
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2462
# 11/18 [=================>............] - ETA: 0s - loss: 0.2461
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2456
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2457
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2444
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2462
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2448
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2458
# 18/18 [==============================] - ETA: 0s - loss: 0.2458
# 18/18 [==============================] - 2s 95ms/step - loss: 0.2458 - val_loss: 0.2413 - lr: 3.3300e-04
# Epoch 5/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2105
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2118
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2169
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2220
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2221
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2252
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2307
#  8/18 [============>.................] - ETA: 0s - loss: 0.2390
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2391
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2439
# 11/18 [=================>............] - ETA: 0s - loss: 0.2433
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2456
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2468
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2452
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2432
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2424
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2416
# 18/18 [==============================] - ETA: 0s - loss: 0.2420
# 18/18 [==============================] - 2s 94ms/step - loss: 0.2420 - val_loss: 0.2412 - lr: 3.3300e-04
# Epoch 6/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2465
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2517
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2482
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2412
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2375
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2296
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2350
#  8/18 [============>.................] - ETA: 0s - loss: 0.2354
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2392
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2378
# 11/18 [=================>............] - ETA: 0s - loss: 0.2382
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2365
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2353
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2370
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2406
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2431
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2434
# 18/18 [==============================] - ETA: 0s - loss: 0.2438
# 18/18 [==============================] - 2s 84ms/step - loss: 0.2438 - val_loss: 0.2425 - lr: 3.3300e-04
# Epoch 7/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2359
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2350
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2261
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2290
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2335
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2351
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2422
#  8/18 [============>.................] - ETA: 0s - loss: 0.2455
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2454
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2434
# 11/18 [=================>............] - ETA: 0s - loss: 0.2413
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2430
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2436
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2425
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2421
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2413
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2415
# 18/18 [==============================] - ETA: 0s - loss: 0.2416
# 18/18 [==============================] - 1s 82ms/step - loss: 0.2416 - val_loss: 0.2414 - lr: 3.3300e-04
# Epoch 8/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2591
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2313
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2416
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2402
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2516
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2485
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2444
#  8/18 [============>.................] - ETA: 0s - loss: 0.2397
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2414
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2427
# 11/18 [=================>............] - ETA: 0s - loss: 0.2405
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2429
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2422
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2417
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2430
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2416
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2396
# 18/18 [==============================] - ETA: 0s - loss: 0.2405
# 18/18 [==============================] - 1s 82ms/step - loss: 0.2405 - val_loss: 0.2415 - lr: 3.3300e-04
# Epoch 9/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2631
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2529
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2404
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2321
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2317
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2313
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2334
#  8/18 [============>.................] - ETA: 0s - loss: 0.2329
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2367
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2358
# 11/18 [=================>............] - ETA: 0s - loss: 0.2383
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2366
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2367
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2367
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2360
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2366
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2374
# 18/18 [==============================] - ETA: 0s - loss: 0.2380
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2380 - val_loss: 0.2413 - lr: 3.3300e-04
# Epoch 10/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2365
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2333
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2325
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2323
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2307
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2323
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2339
#  8/18 [============>.................] - ETA: 0s - loss: 0.2351
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2325
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2330
# 11/18 [=================>............] - ETA: 0s - loss: 0.2344
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2355
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2345
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2345
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2356
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2362
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2363
# 18/18 [==============================] - ETA: 0s - loss: 0.2372
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2372 - val_loss: 0.2431 - lr: 3.3300e-04
# Epoch 11/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2145
#  2/18 [==>...........................] - ETA: 1s - loss: 0.1987
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2203
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2266
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2280
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2338
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2296
#  8/18 [============>.................] - ETA: 0s - loss: 0.2329
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2339
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2378
# 11/18 [=================>............] - ETA: 0s - loss: 0.2372
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2381
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2380
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2404
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2409
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2410
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2400
# 18/18 [==============================] - ETA: 0s - loss: 0.2405
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2405 - val_loss: 0.2417 - lr: 3.3300e-04
# Epoch 12/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2501
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2448
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2377
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2387
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2369
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2370
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2392
#  8/18 [============>.................] - ETA: 0s - loss: 0.2404
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2405
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2429
# 11/18 [=================>............] - ETA: 0s - loss: 0.2386
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2360
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2364
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2354
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2343
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2342
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2350
# 18/18 [==============================] - ETA: 0s - loss: 0.2346
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2346 - val_loss: 0.2449 - lr: 3.3300e-04
# Epoch 13/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2304
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2360
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2299
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2354
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2327
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2377
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2346
#  8/18 [============>.................] - ETA: 0s - loss: 0.2320
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2309
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2332
# 11/18 [=================>............] - ETA: 0s - loss: 0.2358
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2337
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2350
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2361
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2366
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2349
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2346
# 18/18 [==============================] - ETA: 0s - loss: 0.2346
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2346 - val_loss: 0.2461 - lr: 3.3300e-04
# Epoch 14/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2542
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2422
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2520
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2481
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2450
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2414
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2403
#  8/18 [============>.................] - ETA: 0s - loss: 0.2371
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2363
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2345
# 11/18 [=================>............] - ETA: 0s - loss: 0.2317
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2341
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2332
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2329
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2318
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2312
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2339
# 18/18 [==============================] - ETA: 0s - loss: 0.2344
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2344 - val_loss: 0.2466 - lr: 3.3300e-04
# Epoch 15/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2126
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2065
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2173
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2134
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2177
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2192
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2216
#  8/18 [============>.................] - ETA: 0s - loss: 0.2293
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2303
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2303
# 11/18 [=================>............] - ETA: 0s - loss: 0.2273
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2253
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2254
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2263
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2275
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2279
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2293
# 18/18 [==============================] - ETA: 0s - loss: 0.2295
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2295 - val_loss: 0.2547 - lr: 3.3300e-04
# Epoch 16/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2777
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2322
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2346
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2312
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2317
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2337
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2300
#  8/18 [============>.................] - ETA: 0s - loss: 0.2301
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2282
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2316
# 11/18 [=================>............] - ETA: 0s - loss: 0.2297
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2319
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2322
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2333
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2344
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2351
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2331
# 18/18 [==============================] - ETA: 0s - loss: 0.2339
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2339 - val_loss: 0.2536 - lr: 3.3300e-04
# Epoch 17/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2510
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2307
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2280
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2335
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2381
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2345
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2338
#  8/18 [============>.................] - ETA: 0s - loss: 0.2326
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2377
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2385
# 11/18 [=================>............] - ETA: 0s - loss: 0.2387
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2384
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2374
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2358
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2338
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2323
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2314
# 18/18 [==============================] - ETA: 0s - loss: 0.2315
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2315 - val_loss: 0.2465 - lr: 3.3300e-04
# Epoch 18/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2302
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2120
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2159
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2207
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2303
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2311
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2266
#  8/18 [============>.................] - ETA: 0s - loss: 0.2227
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2208
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2236
# 11/18 [=================>............] - ETA: 0s - loss: 0.2243
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2265
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2244
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2258
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2302
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2305
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2279
# 18/18 [==============================] - ETA: 0s - loss: 0.2282
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2282 - val_loss: 0.2522 - lr: 3.3300e-04
# Epoch 19/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2314
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2187
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2372
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2257
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2186
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2139
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2143
#  8/18 [============>.................] - ETA: 0s - loss: 0.2222
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2257
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2266
# 11/18 [=================>............] - ETA: 0s - loss: 0.2288
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2325
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2307
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2303
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2308
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2313
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2312
# 18/18 [==============================] - ETA: 0s - loss: 0.2320
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2320 - val_loss: 0.2512 - lr: 3.3300e-04
# Epoch 20/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2393
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2440
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2290
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2359
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2293
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2282
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2309
#  8/18 [============>.................] - ETA: 0s - loss: 0.2289
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2324
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2312
# 11/18 [=================>............] - ETA: 0s - loss: 0.2291
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2314
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2299
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2288
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2298
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2312
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2307
# 18/18 [==============================] - ETA: 0s - loss: 0.2304
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2304 - val_loss: 0.2534 - lr: 3.3300e-04
# Epoch 21/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2082
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2025
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2204
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2199
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2197
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2185
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2289
#  8/18 [============>.................] - ETA: 0s - loss: 0.2261
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2242
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2241
# 11/18 [=================>............] - ETA: 0s - loss: 0.2295
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2335
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2356
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2368
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2335
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2327
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2334
# 18/18 [==============================] - ETA: 0s - loss: 0.2320
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2320 - val_loss: 0.2537 - lr: 3.3300e-04
# Epoch 22/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.1759
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2035
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2091
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2120
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2125
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2135
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2081
#  8/18 [============>.................] - ETA: 0s - loss: 0.2157
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2176
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2172
# 11/18 [=================>............] - ETA: 0s - loss: 0.2223
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2197
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2221
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2246
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2268
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2282
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2297
# ...
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2263
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2254
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2289
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2323
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2299
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2298
# 18/18 [==============================] - ETA: 0s - loss: 0.2306
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2306 - val_loss: 0.2574 - lr: 3.3300e-04
# Epoch 24/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2083
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2004
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2038
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2115
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2164
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2194
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2240
#  8/18 [============>.................] - ETA: 0s - loss: 0.2207
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2167
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2195
# 11/18 [=================>............] - ETA: 0s - loss: 0.2195
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2215
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2220
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2215
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2219
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2184
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2193
# 18/18 [==============================] - ETA: 0s - loss: 0.2182
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2182 - val_loss: 0.2626 - lr: 3.3300e-04
# Epoch 25/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.1895
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2238
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2088
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2115
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2105
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2113
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2099
#  8/18 [============>.................] - ETA: 0s - loss: 0.2120
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2124
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2142
# 11/18 [=================>............] - ETA: 0s - loss: 0.2134
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2162
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2183
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2217
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2219
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2243
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2230
# 18/18 [==============================] - ETA: 0s - loss: 0.2223
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2223 - val_loss: 0.2550 - lr: 3.3300e-04
# Epoch 26/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2840
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2872
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2551
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2485
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2499
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2472
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2432
#  8/18 [============>.................] - ETA: 0s - loss: 0.2416
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2422
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2423
# 11/18 [=================>............] - ETA: 0s - loss: 0.2395
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2394
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2372
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2359
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2371
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2367
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2364
# 18/18 [==============================] - ETA: 0s - loss: 0.2364
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2364 - val_loss: 0.2470 - lr: 3.3300e-04
# Epoch 27/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2349
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2304
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2264
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2314
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2297
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2285
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2266
#  8/18 [============>.................] - ETA: 0s - loss: 0.2237
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2290
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2290
# 11/18 [=================>............] - ETA: 0s - loss: 0.2318
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2291
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2296
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2281
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2285
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2284
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2329
# 18/18 [==============================] - ETA: 0s - loss: 0.2338
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2338 - val_loss: 0.2472 - lr: 3.3300e-04
# Epoch 28/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2231
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2205
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2272
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2290
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2265
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2301
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2318
#  8/18 [============>.................] - ETA: 0s - loss: 0.2261
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2218
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2256
# 11/18 [=================>............] - ETA: 0s - loss: 0.2224
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2220
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2232
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2204
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2179
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2182
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2186
# 18/18 [==============================] - ETA: 0s - loss: 0.2210
# 18/18 [==============================] - 2s 88ms/step - loss: 0.2210 - val_loss: 0.2523 - lr: 3.3300e-04
# Epoch 29/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2326
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2328
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2215
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2123
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2157
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2189
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2255
#  8/18 [============>.................] - ETA: 0s - loss: 0.2238
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2215
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2246
# 11/18 [=================>............] - ETA: 0s - loss: 0.2259
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2223
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2224
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2210
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2229
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2211
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2226
# 18/18 [==============================] - ETA: 0s - loss: 0.2234
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2234 - val_loss: 0.2646 - lr: 3.3300e-04
# Epoch 30/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2235
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2072
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2081
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2065
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2052
#  6/18 [=========>....................] - ETA: 0s - loss: 0.1989
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2029
#  8/18 [============>.................] - ETA: 0s - loss: 0.2098
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2133
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2169
# 11/18 [=================>............] - ETA: 0s - loss: 0.2164
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2178
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2176
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2260
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2242
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2236
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2231
# 18/18 [==============================] - ETA: 0s - loss: 0.2247
# 18/18 [==============================] - 2s 86ms/step - loss: 0.2247 - val_loss: 0.2537 - lr: 3.3300e-04
# Epoch 31/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2237
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2105
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2068
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2203
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2210
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2152
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2147
#  8/18 [============>.................] - ETA: 0s - loss: 0.2150
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2199
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2226
# 11/18 [=================>............] - ETA: 0s - loss: 0.2222
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2214
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2196
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2187
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2205
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2221
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2227
# 18/18 [==============================] - ETA: 0s - loss: 0.2227
# 18/18 [==============================] - 2s 85ms/step - loss: 0.2227 - val_loss: 0.2536 - lr: 3.3300e-04
# Epoch 32/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2229
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2354
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2304
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2182
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2136
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2226
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2268
#  8/18 [============>.................] - ETA: 0s - loss: 0.2258
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2245
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2214
# 11/18 [=================>............] - ETA: 0s - loss: 0.2239
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2222
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2192
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2198
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2193
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2217
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2247
# 18/18 [==============================] - ETA: 0s - loss: 0.2244
# 18/18 [==============================] - 1s 83ms/step - loss: 0.2244 - val_loss: 0.2489 - lr: 3.3300e-04
# Epoch 33/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2660
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2375
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2420
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2358
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2369
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2336
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2327
#  8/18 [============>.................] - ETA: 0s - loss: 0.2339
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2304
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2329
# 11/18 [=================>............] - ETA: 0s - loss: 0.2338
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2333
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2336
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2335
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2304
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2296
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2269
# 18/18 [==============================] - ETA: 0s - loss: 0.2271
# 18/18 [==============================] - 2s 91ms/step - loss: 0.2271 - val_loss: 0.2506 - lr: 3.3300e-04
# Epoch 34/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2034
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2062
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2234
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2233
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2289
#  6/18 [=========>....................] - ETA: 1s - loss: 0.2223
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2171
#  8/18 [============>.................] - ETA: 0s - loss: 0.2192
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2158
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2116
# 11/18 [=================>............] - ETA: 0s - loss: 0.2107
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2126
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2147
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2155
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2126
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2089
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2158
# 18/18 [==============================] - ETA: 0s - loss: 0.2171
# 18/18 [==============================] - 2s 89ms/step - loss: 0.2171 - val_loss: 0.2637 - lr: 3.3300e-04
# Epoch 35/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.1681
#  2/18 [==>...........................] - ETA: 1s - loss: 0.1740
#  3/18 [====>.........................] - ETA: 1s - loss: 0.1978
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2016
#  5/18 [=======>......................] - ETA: 1s - loss: 0.2128
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2148
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2204
#  8/18 [============>.................] - ETA: 0s - loss: 0.2184
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2176
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2174
# 11/18 [=================>............] - ETA: 0s - loss: 0.2142
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2134
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2152
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2180
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2163
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2165
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2159
# 18/18 [==============================] - ETA: 0s - loss: 0.2156
# 18/18 [==============================] - 2s 89ms/step - loss: 0.2156 - val_loss: 0.2547 - lr: 3.3300e-04
# Epoch 36/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2283
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2133

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
