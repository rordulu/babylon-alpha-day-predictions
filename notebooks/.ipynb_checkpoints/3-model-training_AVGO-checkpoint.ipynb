# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "AVGO"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:43:11.474554: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.011667  0.011280  0.013331  0.013504  0.080117  2020-10-15 00:00:00-04:00
# 1  0.015123  0.012424  0.014695  0.012976  0.048299  2020-10-16 00:00:00-04:00
# 2  0.014266  0.012560  0.013388  0.011787  0.083576  2020-10-19 00:00:00-04:00
# 3  0.012490  0.011546  0.013566  0.012291  0.071791  2020-10-20 00:00:00-04:00
# 4  0.011970  0.009791  0.011279  0.010252  0.060828  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.250006  0.245511  0.258914  0.249292  0.038462  2023-07-03 00:00:00-04:00
# 1  0.249450  0.245587  0.257415  0.242761  0.080736  2023-07-05 00:00:00-04:00
# 2  0.239243  0.235348  0.249178  0.236553  0.155070  2023-07-06 00:00:00-04:00
# 3  0.241718  0.237169  0.249334  0.235993  0.119621  2023-07-07 00:00:00-04:00
# 4  0.240738  0.246598  0.251046  0.249870  0.207368  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.356858  0.350736  0.364363  0.347781  0.193352  2024-01-02 00:00:00-05:00
# 1  0.346770  0.338595  0.353961  0.335655  0.239554  2024-01-03 00:00:00-05:00
# 2  0.341136  0.336122  0.350169  0.331325  0.168522  2024-01-04 00:00:00-05:00
# 3  0.338209  0.329809  0.347370  0.331447  0.143614  2024-01-05 00:00:00-05:00
# 4  0.340464  0.339944  0.352380  0.343016  0.226838  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:43:13.343586: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:43:13.343628: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:43:13.668008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:13.669062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:13.669742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:43:13.839823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:13.840873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:13.841494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:43:13.991922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:13.993007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:13.993642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:43:14.136817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.137735: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.138260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:43:14.456290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.457420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.458021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:14.560666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.561234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.561780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:43:14.663402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.664251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.664778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:14.906721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.907584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.908176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:14.998088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:14.998726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:14.999336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:15.088924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:15.089626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:15.090314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:15.508925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:15.820805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:15.928131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:15.997486: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:16.159597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:16.339552: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 34s - loss: 5.5923e-04
# 2024-12-31 05:43:16.475828: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  3/20 [===>..........................] - ETA: 1s - loss: 2.1810e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4482e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.1114e-04
#  9/20 [============>.................] - ETA: 0s - loss: 9.4774e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.1952e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 7.2831e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 7.0325e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 6.5150e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 6.1649e-05
# 20/20 [==============================] - ETA: 0s - loss: 6.1208e-05
# 2024-12-31 05:43:17.636670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:17.637588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:17.638201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:17.731787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:17.732396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:17.733002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:17.821881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:43:17.822497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:43:17.823125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:43:17.860013: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:17.952608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:18.005766: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:43:18.063092: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 3s 87ms/step - loss: 6.1208e-05 - val_loss: 8.3391e-05 - lr: 3.3300e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.2976e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.1400e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.0437e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.1422e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.0018e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.7161e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1987e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.1393e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0353e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9900e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.9967e-05 - val_loss: 8.0654e-05 - lr: 3.3300e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.3165e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.2715e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.9785e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.8422e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.8121e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.2117e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.0661e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0570e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9983e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9203e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.9562e-05 - val_loss: 7.7648e-05 - lr: 3.3300e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.7778e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.6203e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.5886e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6289e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.1572e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.2007e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.2787e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.1905e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0915e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9416e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 2.9432e-05 - val_loss: 8.6772e-05 - lr: 3.3300e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6249e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.6028e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.4912e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.5037e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.4659e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.5182e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.4208e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.5577e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8994e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8692e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.8660e-05 - val_loss: 9.7134e-05 - lr: 3.3300e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.0856e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.1229e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.6565e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.5696e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.5917e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.7114e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.7328e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.7651e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0802e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 3.0040e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 2.9759e-05 - val_loss: 9.1292e-05 - lr: 3.3300e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.9496e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.4723e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.6250e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.7617e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.4757e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.4751e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.3104e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.2167e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.1045e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9968e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9905e-05 - val_loss: 8.9726e-05 - lr: 3.3300e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.5434e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.6518e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.5209e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.3016e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.1480e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.9625e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8245e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8299e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8257e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9271e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 2.9265e-05 - val_loss: 1.0365e-04 - lr: 3.3300e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8265e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.4095e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4453e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.9393e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.6662e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.4650e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.2488e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.1408e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0026e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9017e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 2.8962e-05 - val_loss: 8.2813e-05 - lr: 3.3300e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.2344e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6206e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.7749e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.2378e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.1098e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.9317e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8305e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8942e-05
# 16/20 [=======================>......] - ETA: 0s - loss: 2.8626e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 2.9573e-05
# 20/20 [==============================] - ETA: 0s - loss: 2.9354e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 2.9354e-05 - val_loss: 8.6680e-05 - lr: 3.3300e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.9077e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.2190e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.3293e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6293e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.6053e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.6637e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.6422e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.7058e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.7024e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9753e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 2.9482e-05 - val_loss: 8.7270e-05 - lr: 3.3300e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3657e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.4719e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.7611e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.5266e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.5358e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.7360e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1424e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0248e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9475e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8872e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 2.9414e-05 - val_loss: 8.2234e-05 - lr: 3.3300e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8734e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.7680e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.7218e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6028e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.6189e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.4504e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.4469e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.9437e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0420e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9986e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 2.9830e-05 - val_loss: 9.2941e-05 - lr: 3.3300e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0133e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.7140e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.5609e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.0796e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.9380e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.9017e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.7649e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8011e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9007e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9156e-05
# 20/20 [==============================] - 1s 41ms/step - loss: 2.8901e-05 - val_loss: 8.9766e-05 - lr: 3.3300e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2374e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.5703e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.1803e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.8755e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.5391e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.3836e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.2033e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0818e-05
# 16/20 [=======================>......] - ETA: 0s - loss: 3.0142e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9595e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 2.9327e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8695e-05
# 20/20 [==============================] - 1s 48ms/step - loss: 2.8602e-05 - val_loss: 9.9266e-05 - lr: 3.3300e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4103e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.4552e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.3919e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.4110e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.0987e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.8360e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8611e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8263e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8633e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8888e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.8817e-05 - val_loss: 9.3810e-05 - lr: 3.3300e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5593e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1864e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.8167e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.4182e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.0231e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.8775e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.9178e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8492e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9040e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8794e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 2.8508e-05 - val_loss: 8.7537e-05 - lr: 3.3300e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8027e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8576e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.4831e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.4515e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.5369e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.5129e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.7561e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.7454e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0145e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9415e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9188e-05 - val_loss: 8.9067e-05 - lr: 3.3300e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0566e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.5415e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.6172e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6432e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.2409e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.0003e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1457e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.1613e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0243e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9029e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9082e-05 - val_loss: 9.6847e-05 - lr: 3.3300e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.9825e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.6638e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.4427e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.2057e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.2717e-05
# 10/20 [==============>...............] - ETA: 0s - loss: 2.8368e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.8629e-05
# 12/20 [=================>............] - ETA: 0s - loss: 2.8360e-05
# 14/20 [====================>.........] - ETA: 0s - loss: 2.9711e-05
# 16/20 [=======================>......] - ETA: 0s - loss: 2.9450e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 2.9047e-05
# 20/20 [==============================] - ETA: 0s - loss: 2.9111e-05
# 20/20 [==============================] - 1s 50ms/step - loss: 2.9111e-05 - val_loss: 9.1096e-05 - lr: 3.3300e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.4027e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.6084e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.0579e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.0736e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.0884e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.2239e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1353e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0687e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0291e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9518e-05
# 20/20 [==============================] - 1s 41ms/step - loss: 2.9530e-05 - val_loss: 1.1579e-04 - lr: 3.3300e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0600e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.0711e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.0283e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.3434e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.1156e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.9405e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8698e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8193e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9003e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8883e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 2.8777e-05 - val_loss: 9.5719e-05 - lr: 3.3300e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.6114e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.3976e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.3168e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.2518e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.2559e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.3917e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.4095e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.9358e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8645e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9089e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 2.9111e-05 - val_loss: 8.2441e-05 - lr: 3.3300e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.7359e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8553e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.5309e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.4574e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.2472e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.2526e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1949e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0932e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0569e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9254e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.9102e-05 - val_loss: 1.0518e-04 - lr: 3.3300e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1855e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8498e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.2568e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.2552e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.1044e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.0206e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.0026e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.9621e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9015e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8459e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.8932e-05 - val_loss: 8.8736e-05 - lr: 3.3300e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.5840e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.7962e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.9706e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.5819e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.5493e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.5972e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.5915e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.5743e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9553e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8786e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 2.8651e-05 - val_loss: 9.0490e-05 - lr: 3.3300e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5587e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.8405e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.7613e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6260e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.7817e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.7613e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.5891e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.5629e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.4954e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.5941e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.9186e-05 - val_loss: 7.7077e-05 - lr: 3.3300e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8742e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.5931e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.4449e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.8645e-05
#  9/20 [============>.................] - ETA: 0s - loss: 3.5396e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.3055e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1617e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0350e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 3.0016e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9847e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 3.0259e-05 - val_loss: 8.1925e-05 - lr: 3.3300e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.9901e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.8106e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.2313e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.9304e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.6701e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.8139e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.7062e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.8372e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9332e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9003e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.8988e-05 - val_loss: 9.5065e-05 - lr: 3.3300e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.1675e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.4860e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.7564e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.5904e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.4358e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.4350e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.5024e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.4736e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8216e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9323e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9281e-05 - val_loss: 9.8008e-05 - lr: 3.3300e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2698e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 4.3924e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.9238e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.3567e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.9942e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.1331e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8860e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.9772e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.9641e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.8731e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.8855e-05 - val_loss: 1.0065e-04 - lr: 3.3300e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1012e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.5961e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.5816e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.6604e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.4589e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.5921e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 3.1106e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 3.0033e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.8806e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9081e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9094e-05 - val_loss: 1.0896e-04 - lr: 3.3300e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6816e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.3959e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.3630e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.2310e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.2063e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.3326e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.4243e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.4860e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.5219e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.6214e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 2.8849e-05 - val_loss: 8.1413e-05 - lr: 3.3300e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8828e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 3.5757e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 3.2789e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 3.1757e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.8688e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 3.0647e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.8972e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 2.7517e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 2.7205e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 2.9672e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 2.9403e-05 - val_loss: 9.4478e-05 - lr: 1.1089e-04
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5440e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 2.3906e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 2.1764e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 2.2653e-05
#  9/20 [============>.................] - ETA: 0s - loss: 2.5647e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 2.8478e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 2.7594e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
