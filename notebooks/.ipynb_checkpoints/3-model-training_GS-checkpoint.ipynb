# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "GS"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:41:49.184389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.041279  0.041610  0.044104  0.040504  0.276347  2020-10-15 00:00:00-04:00
# 1  0.038688  0.040116  0.041855  0.035555  0.199053  2020-10-16 00:00:00-04:00
# 2  0.036775  0.035838  0.039339  0.034478  0.198396  2020-10-19 00:00:00-04:00
# 3  0.035356  0.042940  0.043217  0.039324  0.205559  2020-10-20 00:00:00-04:00
# 4  0.036775  0.035920  0.034016  0.028722  0.187551  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.316886  0.328765  0.326058  0.329288  0.046232  2023-07-03 00:00:00-04:00
# 1  0.320262  0.318317  0.319946  0.314812  0.150191  2023-07-05 00:00:00-04:00
# 2  0.307220  0.305296  0.305020  0.299254  0.174204  2023-07-06 00:00:00-04:00
# 3  0.296700  0.302526  0.304712  0.304043  0.174511  2023-07-07 00:00:00-04:00
# 4  0.304305  0.308437  0.311967  0.306911  0.094058  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.463638  0.473170  0.471435  0.479662  0.128894  2024-01-02 00:00:00-05:00
# 1  0.465599  0.464877  0.459300  0.465058  0.129052  2024-01-03 00:00:00-05:00
# 2  0.464864  0.468624  0.470899  0.467660  0.082798  2024-01-04 00:00:00-05:00
# 3  0.461232  0.473902  0.468954  0.475489  0.175419  2024-01-05 00:00:00-05:00
# 4  0.470256  0.473037  0.471078  0.480918  0.103123  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:41:50.982831: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:41:50.982869: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:41:51.298168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:51.299165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:51.299882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:41:51.466781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:51.467795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:51.468435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:41:51.614646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:51.615541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:51.616241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:41:51.753796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:51.754773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:51.755441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:41:52.071731: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.072468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.073197: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:52.175244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.175814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.176453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:41:52.274202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.275194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.276254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:52.522494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.523320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.523915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:52.613039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.613668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.614292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:52.703732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:52.704796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:52.705555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:53.122497: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:53.471832: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:53.577124: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:53.645407: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:53.802319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:53.983010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 34s - loss: 2.3506e-04
#  2/20 [==>...........................] - ETA: 0s - loss: 2.0816e-04
# 2024-12-31 05:41:54.116749: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  4/20 [=====>........................] - ETA: 0s - loss: 1.8715e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 1.7580e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 1.6808e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.6560e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.6229e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.7431e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.6918e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.7234e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.7407e-04
# 2024-12-31 05:41:55.290683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:55.291398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:55.292309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:55.380644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:55.381699: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:55.382300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:55.469286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:41:55.469873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:41:55.470488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:41:55.508489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:55.602943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:41:55.655336: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 3s 87ms/step - loss: 1.7407e-04 - val_loss: 2.6197e-04 - lr: 3.3300e-04
# Epoch 2/1000
# 2024-12-31 05:41:55.713210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 0s - loss: 1.9472e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8932e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6713e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7310e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7990e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6759e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5659e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5754e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6463e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6552e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6593e-04 - val_loss: 1.5786e-04 - lr: 3.3300e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1003e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4962e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5744e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4357e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5265e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5536e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6047e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6638e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6563e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6740e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6723e-04 - val_loss: 2.1660e-04 - lr: 3.3300e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2775e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8898e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 2.0135e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7939e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6403e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6538e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5753e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6259e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6614e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6701e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6654e-04 - val_loss: 1.6522e-04 - lr: 3.3300e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1331e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6275e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4631e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4825e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5369e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5871e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6428e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6608e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6137e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6317e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6274e-04 - val_loss: 2.1433e-04 - lr: 3.3300e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.9938e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2857e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4606e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5895e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5025e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4855e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5214e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6254e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5874e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.5930e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6006e-04 - val_loss: 2.5551e-04 - lr: 3.3300e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8941e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6501e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6313e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8833e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8535e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7390e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6206e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6799e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6212e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6383e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6342e-04 - val_loss: 1.7016e-04 - lr: 3.3300e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.1235e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2067e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.2182e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4915e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5658e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5440e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5219e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5729e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5930e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6082e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.5954e-04 - val_loss: 1.6353e-04 - lr: 3.3300e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3559e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5911e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4578e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5836e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6574e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6161e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6723e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6495e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6688e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6427e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6588e-04 - val_loss: 1.5754e-04 - lr: 3.3300e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4204e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9419e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6746e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5970e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7187e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6358e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6145e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6282e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6229e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6650e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6647e-04 - val_loss: 1.7370e-04 - lr: 3.3300e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5752e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6815e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5511e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5012e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6022e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6481e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6625e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6300e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6190e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6041e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6115e-04 - val_loss: 1.6167e-04 - lr: 3.3300e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4340e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5782e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4781e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4939e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 1.5198e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.5180e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.5027e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.5929e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.5971e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.6186e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6444e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6444e-04 - val_loss: 1.7128e-04 - lr: 3.3300e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2249e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3126e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3812e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4637e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4349e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.3892e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5225e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5746e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5710e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6638e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6595e-04 - val_loss: 1.6980e-04 - lr: 3.3300e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8401e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.1389e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9486e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8272e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8064e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7416e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7110e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6865e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6755e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6559e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6515e-04 - val_loss: 1.9453e-04 - lr: 3.3300e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3209e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7057e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6287e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6009e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5865e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6422e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7005e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6846e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6613e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6400e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6548e-04 - val_loss: 1.4649e-04 - lr: 3.3300e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.9064e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8340e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6500e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7293e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7367e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7473e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7217e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6872e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6698e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6378e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6210e-04 - val_loss: 1.8463e-04 - lr: 3.3300e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5506e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7765e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6287e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6006e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6182e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5803e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6950e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6917e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6447e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6468e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6367e-04 - val_loss: 1.9865e-04 - lr: 3.3300e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2627e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7267e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7105e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7455e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6877e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6185e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6318e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6745e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6324e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6287e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6351e-04 - val_loss: 2.3111e-04 - lr: 3.3300e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6129e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8874e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7245e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7309e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6211e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7178e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6824e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6649e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6367e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6533e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6537e-04 - val_loss: 1.7584e-04 - lr: 3.3300e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8760e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6395e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9444e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8540e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8483e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7834e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7161e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6883e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6726e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6304e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6249e-04 - val_loss: 1.9300e-04 - lr: 3.3300e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0236e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7212e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4907e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5694e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5826e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6065e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5981e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6119e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6550e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6457e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6408e-04 - val_loss: 1.7965e-04 - lr: 3.3300e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0559e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3069e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4223e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5846e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6844e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6685e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7240e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6892e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6232e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6131e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6083e-04 - val_loss: 1.9309e-04 - lr: 3.3300e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.9657e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5355e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6187e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7113e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6545e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6644e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6338e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6526e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6358e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6439e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6446e-04 - val_loss: 2.1570e-04 - lr: 3.3300e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5492e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7326e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6233e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7309e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6945e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6531e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6359e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6912e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7035e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6602e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6525e-04 - val_loss: 1.7478e-04 - lr: 3.3300e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1303e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7454e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6743e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5763e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6498e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7517e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7071e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6729e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6719e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6187e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6090e-04
# 20/20 [==============================] - 1s 49ms/step - loss: 1.6090e-04 - val_loss: 2.2457e-04 - lr: 3.3300e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 1s - loss: 9.1308e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2311e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4644e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4009e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5474e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5464e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5932e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5704e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6740e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6515e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 1.6382e-04 - val_loss: 1.6785e-04 - lr: 3.3300e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1946e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4180e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6620e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6298e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7955e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7721e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7666e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6729e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6520e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6436e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6457e-04 - val_loss: 2.0888e-04 - lr: 3.3300e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3997e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9491e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7483e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7787e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8350e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6841e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7007e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6183e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6500e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6265e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6537e-04 - val_loss: 2.0844e-04 - lr: 3.3300e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0953e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9306e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 2.0329e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8482e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6957e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7477e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7673e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7126e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6617e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6234e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6625e-04 - val_loss: 1.9058e-04 - lr: 3.3300e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.9447e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.0356e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7409e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7009e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6377e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6364e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6538e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6708e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6321e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6183e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6318e-04 - val_loss: 1.4231e-04 - lr: 3.3300e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6911e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5995e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4635e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6228e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5415e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6439e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6090e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5860e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5609e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.5972e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6029e-04 - val_loss: 1.7463e-04 - lr: 3.3300e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.9604e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.0269e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8355e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6284e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6941e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7065e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6886e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6471e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6478e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6230e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6226e-04 - val_loss: 1.9693e-04 - lr: 3.3300e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.6773e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.1168e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9298e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8912e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.9322e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7809e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6838e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6222e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6416e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6499e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6461e-04 - val_loss: 2.3190e-04 - lr: 3.3300e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2124e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7729e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8724e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8350e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8669e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.9067e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.8458e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.8083e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7344e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6595e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6543e-04 - val_loss: 2.2488e-04 - lr: 3.3300e-04
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3848e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7413e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8327e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7171e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6646e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5837e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5611e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5882e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5606e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
