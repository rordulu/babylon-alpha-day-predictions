# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "MSFT"

# %%
# Global parameters

TICKER = 'GOOGL'  # Default value, overwritten by papermill

NUM_EPOCH = 1000
STARTING_LR = 0.0001
SEQUENCE_SIZE = 128
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 100
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization, Reshape
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 19:15:49.245722: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.011252  0.007067  0.013574  0.018332  0.192277  2020-10-15 00:00:00-04:00
# 1  0.018348  0.009602  0.020447  0.023352  0.218478  2020-10-16 00:00:00-04:00
# 2  0.024121  0.012100  0.006004  0.007859  0.179317  2020-10-19 00:00:00-04:00
# 3  0.002494  0.008047  0.004997  0.016531  0.284121  2020-10-20 00:00:00-04:00
# 4  0.021631  0.024639  0.024388  0.030858  0.447896  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.355315  0.341472  0.360843  0.364105  0.045272  2023-07-03 00:00:00-04:00
# 1  0.355315  0.360916  0.364252  0.379290  0.160445  2023-07-05 00:00:00-04:00
# 2  0.359901  0.342356  0.357351  0.365829  0.135512  2023-07-06 00:00:00-04:00
# 3  0.362358  0.348382  0.365666  0.360658  0.108709  2023-07-07 00:00:00-04:00
# 4  0.347618  0.326367  0.338558  0.335788  0.228323  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.513446  0.496221  0.507688  0.514065  0.126433  2024-01-02 00:00:00-05:00
# 1  0.502800  0.497667  0.512677  0.520221  0.130831  2024-01-03 00:00:00-05:00
# 2  0.512382  0.493891  0.506607  0.499455  0.156520  2024-01-04 00:00:00-05:00
# 3  0.498706  0.477821  0.496629  0.494037  0.115851  2024-01-05 00:00:00-05:00
# 4  0.494939  0.492686  0.505859  0.519564  0.106174  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        up_by_1_percent = 1.0 if data[i, target_attr_idx] / data[i-1, target_attr_idx] > 1.01 else 0.0
        data_y.append(up_by_1_percent)
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (254, 5)
# inside construct_lstm_data with shape: (168, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (552, 128, 5)
# > Data Train y: (552,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 128, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 128, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
class AppendParametersLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        inner_layer_output, extra_params = inputs
        return tf.concat([inner_layer_output, extra_params], axis=-1)

# %%
from tensorflow.keras.layers import Concatenate

input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

cnn = Conv1D(32, 3)(input_layer)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(32,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Dense(256)(cnn)
# cnn = Reshape((64, 256))(cnn)  # Align shape with `input_denser`
from tensorflow.keras.layers import ZeroPadding1D, Cropping1D

# cnn = ZeroPadding1D(padding=(30))(cnn)
# cnn = Cropping1D(cropping=(0,1))(cnn)  # Remove 1 from the beginning

# input_denser = Dense(256, kernel_initializer=tf.keras.initializers.HeUniform())(input_layer)

# input_to_lstm = Concatenate()([cnn, input_denser])

# Add first LSTM layer and dropout regularization layer
lstm = LSTM(units = 800, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 800, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 200, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 100)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = Dense(1)(lstm)
# Out:
# 2024-12-31 19:15:51.129508: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 19:15:51.129549: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-31 19:15:51.879518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:51.880229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:51.881096: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:52.341856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:52.342792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:52.343451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:52.522689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:52.523256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:52.523887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:52.659988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:52.660686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:52.661536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:52.790523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:52.791267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:52.791789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# # # Add input layer
# regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add second LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 400, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add third LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 200, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add forth LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# %%
from tensorflow.keras.models import Model

# # Add last dense layer/output layer
# regressor.add(Dense(1))
# regressor.summary()
regressor = Model(input_layer,lstm)
regressor.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 5)]          0
#  conv1d (Conv1D)             (None, 126, 32)           512
#  p_re_lu (PReLU)             (None, 126, 32)           32
#  conv1d_1 (Conv1D)           (None, 124, 32)           3104
#  p_re_lu_1 (PReLU)           (None, 124, 32)           32
#  conv1d_2 (Conv1D)           (None, 61, 64)            6208
#  p_re_lu_2 (PReLU)           (None, 61, 64)            64
#  conv1d_3 (Conv1D)           (None, 59, 64)            12352
#  p_re_lu_3 (PReLU)           (None, 59, 64)            64
#  conv1d_4 (Conv1D)           (None, 29, 128)           24704
#  p_re_lu_4 (PReLU)           (None, 29, 128)           128
#  conv1d_5 (Conv1D)           (None, 27, 128)           49280
#  p_re_lu_5 (PReLU)           (None, 27, 128)           128
#  dense (Dense)               (None, 27, 256)           33024
#  lstm (LSTM)                 (None, 27, 800)           3382400
#  dropout (Dropout)           (None, 27, 800)           0
#  lstm_1 (LSTM)               (None, 27, 800)           5123200
#  dropout_1 (Dropout)         (None, 27, 800)           0
#  lstm_2 (LSTM)               (None, 27, 400)           1921600
#  dropout_2 (Dropout)         (None, 27, 400)           0
#  lstm_3 (LSTM)               (None, 27, 200)           480800
#  dropout_3 (Dropout)         (None, 27, 200)           0
#  lstm_4 (LSTM)               (None, 100)               120400
#  dropout_4 (Dropout)         (None, 100)               0
#  dense_1 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 11,158,133
# Trainable params: 11,158,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K


optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(optimizer=optimizer, loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-16             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
try:
    best_model = load_model(model_location + model_name)
    regressor = best_model
    print(f"Using already trained model")
except:
    print(f"Building brand new model")
# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 19:15:53.560055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:53.560761: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:53.561488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:54.007697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.008465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:54.009275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:54.150502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.151150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:54.151745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:54.251135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.251960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:54.252523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:54.344968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.345537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:54.346133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 19:15:54.908400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.909461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:54.910120: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:54.999304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:54.999920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:55.000557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:55.089433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:55.090053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:55.090711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:55.179828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:55.180731: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:55.181325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:55.270935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:55.271603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:55.272158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:55.957343: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:56.619084: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:56.726167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:56.793523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:56.887544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:56.958276: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:57.140965: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:57.315817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:57.435513: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:57.549466: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:15:57.657548: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/18 [>.............................] - ETA: 55s - loss: 0.2256
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2394
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2428
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2453
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2478
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2489
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2482
#  8/18 [============>.................] - ETA: 0s - loss: 0.2468
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2475
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2483
# 11/18 [=================>............] - ETA: 0s - loss: 0.2466
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2456
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2453
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2449
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2459
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2445
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2477
# 18/18 [==============================] - ETA: 0s - loss: 0.2477
# 2024-12-31 19:15:59.687989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:59.688700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:59.689486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:59.776269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:59.776888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:59.777525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:59.863332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:59.863904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:59.864492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:15:59.950484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:15:59.951243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:15:59.952002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:16:00.041368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:16:00.041986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:16:00.042565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:16:00.093141: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:16:00.383226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:16:00.436905: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:16:00.496635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:16:00.555773: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:16:00.613427: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 18/18 [==============================] - 6s 189ms/step - loss: 0.2477 - val_loss: 0.2671 - lr: 1.0000e-04
# Epoch 2/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2286
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2410
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2487
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2618
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2601
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2547
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2563
#  8/18 [============>.................] - ETA: 0s - loss: 0.2558
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2511
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2477
# 11/18 [=================>............] - ETA: 0s - loss: 0.2452
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2450
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2444
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2440
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2450
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2446
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2438
# 18/18 [==============================] - ETA: 0s - loss: 0.2431
# 18/18 [==============================] - 1s 82ms/step - loss: 0.2431 - val_loss: 0.2546 - lr: 1.0000e-04
# Epoch 3/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2314
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2319
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2347
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2244
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2221
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2250
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2336
#  8/18 [============>.................] - ETA: 0s - loss: 0.2358
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2384
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2369
# 11/18 [=================>............] - ETA: 0s - loss: 0.2370
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2377
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2380
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2386
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2365
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2394
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2414
# 18/18 [==============================] - ETA: 0s - loss: 0.2430
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2430 - val_loss: 0.2571 - lr: 1.0000e-04
# Epoch 4/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2376
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2283
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2329
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2354
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2359
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2429
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2437
#  8/18 [============>.................] - ETA: 0s - loss: 0.2444
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2440
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2431
# 11/18 [=================>............] - ETA: 0s - loss: 0.2435
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2435
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2442
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2439
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2437
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2413
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2427
# 18/18 [==============================] - ETA: 0s - loss: 0.2432
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2432 - val_loss: 0.2586 - lr: 1.0000e-04
# Epoch 5/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2790
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2667
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2654
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2657
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2631
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2557
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2519
#  8/18 [============>.................] - ETA: 0s - loss: 0.2492
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2474
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2484
# 11/18 [=================>............] - ETA: 0s - loss: 0.2449
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2441
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2441
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2440
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2431
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2435
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2426
# 18/18 [==============================] - ETA: 0s - loss: 0.2433
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2433 - val_loss: 0.2578 - lr: 1.0000e-04
# Epoch 6/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2653
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2727
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2636
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2573
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2557
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2529
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2515
#  8/18 [============>.................] - ETA: 0s - loss: 0.2474
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2470
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2487
# 11/18 [=================>............] - ETA: 0s - loss: 0.2496
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2485
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2465
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2468
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2450
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2442
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2435
# 18/18 [==============================] - ETA: 0s - loss: 0.2435
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2435 - val_loss: 0.2577 - lr: 1.0000e-04
# Epoch 7/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2322
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2332
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2280
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2304
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2353
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2320
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2279
#  8/18 [============>.................] - ETA: 0s - loss: 0.2323
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2294
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2353
# 11/18 [=================>............] - ETA: 0s - loss: 0.2351
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2390
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2391
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2386
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2418
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2426
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2422
# 18/18 [==============================] - ETA: 0s - loss: 0.2425
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2425 - val_loss: 0.2558 - lr: 1.0000e-04
# Epoch 8/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2282
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2327
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2437
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2419
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2395
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2403
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2414
#  8/18 [============>.................] - ETA: 0s - loss: 0.2401
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2399
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2393
# 11/18 [=================>............] - ETA: 0s - loss: 0.2387
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2389
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2413
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2409
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2409
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2414
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2400
# 18/18 [==============================] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2403 - val_loss: 0.2553 - lr: 1.0000e-04
# Epoch 9/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2701
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2411
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2424
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2419
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2354
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2412
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2442
#  8/18 [============>.................] - ETA: 0s - loss: 0.2421
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2431
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2424
# 11/18 [=================>............] - ETA: 0s - loss: 0.2428
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2410
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2419
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2397
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2392
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2395
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2391
# 18/18 [==============================] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2401 - val_loss: 0.2569 - lr: 1.0000e-04
# Epoch 10/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2349
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2386
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2479
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2467
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2494
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2442
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2416
#  8/18 [============>.................] - ETA: 0s - loss: 0.2446
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2418
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2420
# 11/18 [=================>............] - ETA: 0s - loss: 0.2435
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2424
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2424
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2423
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2424
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2405
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2403 - val_loss: 0.2574 - lr: 1.0000e-04
# Epoch 11/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2299
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2230
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2332
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2388
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2430
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2442
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2416
#  8/18 [============>.................] - ETA: 0s - loss: 0.2385
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2382
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2404
# 11/18 [=================>............] - ETA: 0s - loss: 0.2400
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2386
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2390
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2405
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2404
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2394
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - 1s 74ms/step - loss: 0.2403 - val_loss: 0.2543 - lr: 1.0000e-04
# Epoch 12/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2499
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2389
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2425
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2419
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2439
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2446
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2472
#  8/18 [============>.................] - ETA: 0s - loss: 0.2463
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2475
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2468
# 11/18 [=================>............] - ETA: 0s - loss: 0.2447
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2433
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2413
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2426
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2440
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2442
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2431
# 18/18 [==============================] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2429 - val_loss: 0.2567 - lr: 1.0000e-04
# Epoch 13/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2412
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2338
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2461
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2455
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2429
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2464
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2448
#  8/18 [============>.................] - ETA: 0s - loss: 0.2440
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2444
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2444
# 11/18 [=================>............] - ETA: 0s - loss: 0.2438
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2440
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2449
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2445
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2439
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2438
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2438
# 18/18 [==============================] - ETA: 0s - loss: 0.2437
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2437 - val_loss: 0.2586 - lr: 1.0000e-04
# Epoch 14/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2518
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2454
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2441
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2301
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2319
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2375
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2429
#  8/18 [============>.................] - ETA: 0s - loss: 0.2394
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2433
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2430
# 11/18 [=================>............] - ETA: 0s - loss: 0.2438
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2432
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2421
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2432
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2443
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2444
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2430
# 18/18 [==============================] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2429 - val_loss: 0.2547 - lr: 1.0000e-04
# Epoch 15/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2451
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2437
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2459
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2408
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2426
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2419
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2395
#  8/18 [============>.................] - ETA: 0s - loss: 0.2412
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2400
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2408
# 11/18 [=================>............] - ETA: 0s - loss: 0.2429
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2409
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2407
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2415
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2422
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2419
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2405
# 18/18 [==============================] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2403 - val_loss: 0.2573 - lr: 1.0000e-04
# Epoch 16/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2492
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2322
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2423
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2435
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2445
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2421
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2422
#  8/18 [============>.................] - ETA: 0s - loss: 0.2430
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2423
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2422
# 11/18 [=================>............] - ETA: 0s - loss: 0.2431
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2423
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2420
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2394
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2391
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2397
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2409
# 18/18 [==============================] - ETA: 0s - loss: 0.2407
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2407 - val_loss: 0.2568 - lr: 1.0000e-04
# Epoch 17/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2074
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2246
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2254
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2286
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2340
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2387
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2421
#  8/18 [============>.................] - ETA: 0s - loss: 0.2427
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2452
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2449
# 11/18 [=================>............] - ETA: 0s - loss: 0.2436
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2439
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2441
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2445
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2439
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2429
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2430
# 18/18 [==============================] - ETA: 0s - loss: 0.2427
# 18/18 [==============================] - 1s 71ms/step - loss: 0.2427 - val_loss: 0.2528 - lr: 1.0000e-04
# Epoch 18/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2743
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2619
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2531
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2488
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2473
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2456
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2461
#  8/18 [============>.................] - ETA: 0s - loss: 0.2464
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2444
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2438
# 11/18 [=================>............] - ETA: 0s - loss: 0.2394
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2426
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2429
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2428
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2398
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2410
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2407
# 18/18 [==============================] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2403 - val_loss: 0.2613 - lr: 1.0000e-04
# Epoch 19/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2812
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2664
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2527
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2497
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2478
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2456
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2457
#  8/18 [============>.................] - ETA: 0s - loss: 0.2416
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2409
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2424
# 11/18 [=================>............] - ETA: 0s - loss: 0.2423
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2403
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2385
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2412
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2410
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2413 - val_loss: 0.2582 - lr: 1.0000e-04
# Epoch 20/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2100
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2156
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2303
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2374
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2430
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2375
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2400
#  8/18 [============>.................] - ETA: 0s - loss: 0.2390
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2377
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2411
# 11/18 [=================>............] - ETA: 0s - loss: 0.2388
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2385
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2386
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2381
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2398
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2404
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2412 - val_loss: 0.2570 - lr: 1.0000e-04
# Epoch 21/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2439
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2408
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2441
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2482
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2454
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2431
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2430
#  8/18 [============>.................] - ETA: 0s - loss: 0.2404
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2439
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2443
# 11/18 [=================>............] - ETA: 0s - loss: 0.2422
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2424
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2398
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2396
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2384
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2388
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2406
# 18/18 [==============================] - ETA: 0s - loss: 0.2410
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2410 - val_loss: 0.2582 - lr: 1.0000e-04
# Epoch 22/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2200
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2512
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2558
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2501
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2436
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2420
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2410
#  8/18 [============>.................] - ETA: 0s - loss: 0.2384
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2401
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2398
# 11/18 [=================>............] - ETA: 0s - loss: 0.2424
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2431
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2427
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2432
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2425
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2417
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2419
# ...
# 11/18 [=================>............] - ETA: 0s - loss: 0.2417
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2416
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2404
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2411
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2404
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2386
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2416
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2412 - val_loss: 0.2560 - lr: 1.0000e-04
# Epoch 35/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2490
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2442
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2418
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2344
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2317
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2287
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2347
#  8/18 [============>.................] - ETA: 0s - loss: 0.2291
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2336
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2387
# 11/18 [=================>............] - ETA: 0s - loss: 0.2342
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2336
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2357
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2382
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2376
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2391
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2420
# 18/18 [==============================] - ETA: 0s - loss: 0.2418
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2418 - val_loss: 0.2545 - lr: 1.0000e-04
# Epoch 36/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2365
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2441
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2370
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2397
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2389
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2410
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2394
#  8/18 [============>.................] - ETA: 0s - loss: 0.2400
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2398
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2423
# 11/18 [=================>............] - ETA: 0s - loss: 0.2413
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2413
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2400
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2419
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2409
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2410
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2404
# 18/18 [==============================] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2401 - val_loss: 0.2573 - lr: 1.0000e-04
# Epoch 37/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2419
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2474
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2430
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2356
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2328
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2381
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2392
#  8/18 [============>.................] - ETA: 0s - loss: 0.2399
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2419
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2419
# 11/18 [=================>............] - ETA: 0s - loss: 0.2432
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2426
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2433
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2427
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2429
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2423
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2420
# 18/18 [==============================] - ETA: 0s - loss: 0.2421
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2421 - val_loss: 0.2551 - lr: 1.0000e-04
# Epoch 38/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2244
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2462
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2558
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2507
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2517
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2504
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2485
#  8/18 [============>.................] - ETA: 0s - loss: 0.2474
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2470
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2446
# 11/18 [=================>............] - ETA: 0s - loss: 0.2436
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2429
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2426
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2431
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2423
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2400
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2406
# 18/18 [==============================] - ETA: 0s - loss: 0.2409
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2409 - val_loss: 0.2617 - lr: 1.0000e-04
# Epoch 39/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2528
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2541
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2416
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2371
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2319
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2407
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2430
#  8/18 [============>.................] - ETA: 0s - loss: 0.2474
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2484
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2456
# 11/18 [=================>............] - ETA: 0s - loss: 0.2433
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2446
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2446
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2449
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2421
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2408
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2418
# 18/18 [==============================] - ETA: 0s - loss: 0.2419
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2419 - val_loss: 0.2550 - lr: 1.0000e-04
# Epoch 40/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2196
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2253
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2274
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2316
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2332
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2338
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2318
#  8/18 [============>.................] - ETA: 0s - loss: 0.2313
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2349
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2361
# 11/18 [=================>............] - ETA: 0s - loss: 0.2344
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2356
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2368
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2382
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2390
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2412
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2411 - val_loss: 0.2551 - lr: 1.0000e-04
# Epoch 41/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2314
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2476
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2491
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2477
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2475
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2440
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2425
#  8/18 [============>.................] - ETA: 0s - loss: 0.2383
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2397
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2398
# 11/18 [=================>............] - ETA: 0s - loss: 0.2381
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2368
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2400
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2405
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2409
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2418
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2419
# 18/18 [==============================] - ETA: 0s - loss: 0.2415
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2415 - val_loss: 0.2571 - lr: 1.0000e-04
# Epoch 42/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2343
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2307
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2368
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2364
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2387
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2335
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2334
#  8/18 [============>.................] - ETA: 0s - loss: 0.2311
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2348
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2382
# 11/18 [=================>............] - ETA: 0s - loss: 0.2366
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2354
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2371
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2392
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2400
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2405
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2407
# 18/18 [==============================] - ETA: 0s - loss: 0.2402
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2402 - val_loss: 0.2566 - lr: 1.0000e-04
# Epoch 43/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2637
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2472
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2442
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2419
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2419
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2406
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2398
#  8/18 [============>.................] - ETA: 0s - loss: 0.2380
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2376
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2375
# 11/18 [=================>............] - ETA: 0s - loss: 0.2377
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2388
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2380
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2394
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2429
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2425
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2406
# 18/18 [==============================] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2401 - val_loss: 0.2566 - lr: 1.0000e-04
# Epoch 44/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2240
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2261
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2231
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2291
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2273
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2372
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2366
#  8/18 [============>.................] - ETA: 0s - loss: 0.2349
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2390
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2391
# 11/18 [=================>............] - ETA: 0s - loss: 0.2394
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2425
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2423
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2427
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2428
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2426
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2433
# 18/18 [==============================] - ETA: 0s - loss: 0.2427
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2427 - val_loss: 0.2542 - lr: 1.0000e-04
# Epoch 45/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2064
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2271
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2400
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2368
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2349
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2385
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2381
#  8/18 [============>.................] - ETA: 0s - loss: 0.2364
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2406
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2411
# 11/18 [=================>............] - ETA: 0s - loss: 0.2434
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2424
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2441
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2436
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2434
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2430
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - ETA: 0s - loss: 0.2423
# 18/18 [==============================] - 1s 68ms/step - loss: 0.2423 - val_loss: 0.2552 - lr: 1.0000e-04
# Epoch 46/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2592
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2382
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2341
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2357
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2334
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2291
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2288
#  8/18 [============>.................] - ETA: 0s - loss: 0.2328
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2329
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2385
# 11/18 [=================>............] - ETA: 0s - loss: 0.2383
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2395
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2392
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2388
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2395
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - ETA: 0s - loss: 0.2410
# 18/18 [==============================] - 1s 70ms/step - loss: 0.2410 - val_loss: 0.2531 - lr: 1.0000e-04
# Epoch 47/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2369

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
