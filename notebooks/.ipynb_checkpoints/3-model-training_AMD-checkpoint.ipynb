# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "AMD"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:45:58.172330: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.176579  0.156232  0.181256  0.174923  0.084138  2020-10-15 00:00:00-04:00
# 1  0.177465  0.151911  0.181191  0.175180  0.073521  2020-10-16 00:00:00-04:00
# 2  0.177972  0.155817  0.175464  0.167653  0.098436  2020-10-19 00:00:00-04:00
# 3  0.168725  0.144218  0.169281  0.164822  0.105747  2020-10-20 00:00:00-04:00
# 4  0.165938  0.139721  0.160234  0.149640  0.097181  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.377731  0.345662  0.390107  0.385229  0.075364  2023-07-03 00:00:00-04:00
# 1  0.383685  0.351166  0.385877  0.373199  0.159649  2023-07-05 00:00:00-04:00
# 2  0.358161  0.328264  0.362773  0.370175  0.125443  2023-07-06 00:00:00-04:00
# 3  0.371398  0.337377  0.380540  0.368181  0.100566  2023-07-07 00:00:00-04:00
# 4  0.364051  0.327198  0.359974  0.370818  0.158830  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.562164  0.509409  0.539278  0.531652  0.233227  2024-01-02 00:00:00-05:00
# 1  0.507885  0.468162  0.515262  0.510679  0.219307  2024-01-03 00:00:00-05:00
# 2  0.498955  0.469760  0.516954  0.515118  0.203167  2024-01-04 00:00:00-05:00
# 3  0.514662  0.489348  0.532834  0.531652  0.255648  2024-01-05 00:00:00-05:00
# 4  0.537336  0.525683  0.556980  0.580545  0.265977  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:46:00.017264: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:46:00.017300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:46:00.334814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:00.336101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:00.336816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:46:00.502637: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:00.503444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:00.504090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:46:00.651979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:00.652846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:00.653505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:46:00.791031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:00.791993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:00.792717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:46:01.107250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.107951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.108806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:01.209963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.210536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.211172: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:01.305829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.306394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.307019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:46:01.544479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.545567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.546155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:01.635986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.636615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.637254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:01.726322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:01.726975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:01.727606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:02.140007: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:02.453972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:02.559867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:02.629447: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:02.812647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:02.994771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 34s - loss: 7.3762e-04
# 2024-12-31 05:46:03.130416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  2/20 [==>...........................] - ETA: 1s - loss: 5.8614e-04
#  4/20 [=====>........................] - ETA: 0s - loss: 5.3110e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 4.8682e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 4.9526e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 5.0032e-04
# 12/20 [=================>............] - ETA: 0s - loss: 5.1689e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 5.3960e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2477e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 5.0827e-04
# 20/20 [==============================] - ETA: 0s - loss: 5.0697e-04
# 2024-12-31 05:46:04.330063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:04.330965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:04.331593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:04.416347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:04.416944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:04.417537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:04.503424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:46:04.504020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:46:04.504637: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:46:04.538963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:04.635887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:04.686325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:46:04.740876: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 4s 88ms/step - loss: 5.0697e-04 - val_loss: 5.1475e-04 - lr: 1.1089e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.7215e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1279e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.9207e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7114e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7591e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8491e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8741e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9999e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8760e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8149e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7973e-04 - val_loss: 5.2273e-04 - lr: 1.1089e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3717e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0484e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8090e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3386e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6887e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8060e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9547e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9616e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0655e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 4.9676e-04
# 20/20 [==============================] - ETA: 0s - loss: 4.8324e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.8324e-04 - val_loss: 5.3428e-04 - lr: 1.1089e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.7878e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6169e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.5760e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5662e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8304e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7581e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8541e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7301e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7742e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8243e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.8250e-04 - val_loss: 4.6353e-04 - lr: 1.1089e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.9769e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2292e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6931e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7749e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9965e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9802e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8132e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6705e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7536e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7207e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7946e-04 - val_loss: 5.0196e-04 - lr: 1.1089e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.2480e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0103e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3553e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5526e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3647e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5202e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6107e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6720e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5665e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7215e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7699e-04 - val_loss: 4.6149e-04 - lr: 1.1089e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.7940e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.5964e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1850e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.6196e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1651e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8445e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8554e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7975e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9152e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8249e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.8182e-04 - val_loss: 4.5689e-04 - lr: 1.1089e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.0054e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.6997e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9587e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.8295e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3463e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8712e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0172e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8927e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9360e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8498e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.8393e-04 - val_loss: 4.8054e-04 - lr: 1.1089e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.8788e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.7055e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.7211e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.1372e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.4763e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6380e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9651e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0656e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8695e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8376e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7907e-04 - val_loss: 4.8265e-04 - lr: 1.1089e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3782e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6459e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7872e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3748e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9666e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8287e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7309e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7077e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0952e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8478e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.8379e-04 - val_loss: 4.8914e-04 - lr: 1.1089e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.8995e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1102e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3967e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3758e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3160e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8823e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9377e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6206e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6623e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7948e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 4.7706e-04 - val_loss: 4.8724e-04 - lr: 1.1089e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.3724e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.4987e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.5746e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.2853e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6768e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8659e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8871e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8083e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8050e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7807e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 4.7487e-04 - val_loss: 4.7465e-04 - lr: 1.1089e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.4955e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4200e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4711e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7327e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0231e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9827e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9592e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7124e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7884e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7882e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7772e-04 - val_loss: 4.6627e-04 - lr: 1.1089e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.8906e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1878e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.7824e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5045e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.2536e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5866e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5368e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.2490e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5677e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7883e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7935e-04 - val_loss: 4.5642e-04 - lr: 1.1089e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.0065e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0969e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.7637e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.1886e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1622e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1022e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7845e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6684e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8711e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8141e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7840e-04 - val_loss: 4.9381e-04 - lr: 1.1089e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8347e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.6489e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.6669e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 3.8658e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.0483e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.3900e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5677e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8305e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6866e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8211e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.8093e-04 - val_loss: 4.6834e-04 - lr: 1.1089e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3270e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.5618e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2571e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6695e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.4856e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.3924e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5158e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6444e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8255e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7901e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7878e-04 - val_loss: 4.5451e-04 - lr: 1.1089e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.7360e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.7166e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3306e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9218e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7354e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9523e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8850e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9928e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9815e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8019e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7748e-04 - val_loss: 4.7137e-04 - lr: 1.1089e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.5715e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0030e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7282e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7776e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5855e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 4.6025e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7134e-04
# 12/20 [=================>............] - ETA: 0s - loss: 4.8489e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9163e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8855e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7316e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8071e-04
# 20/20 [==============================] - 1s 53ms/step - loss: 4.8156e-04 - val_loss: 4.5011e-04 - lr: 1.1089e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.3856e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1260e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0757e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0024e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8012e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5366e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7946e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9435e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8144e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7188e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 4.7479e-04 - val_loss: 4.5069e-04 - lr: 1.1089e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.6044e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.1194e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.6288e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.5660e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1324e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0088e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0639e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0148e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9788e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8860e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.8400e-04 - val_loss: 4.5858e-04 - lr: 1.1089e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.5170e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4523e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1722e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3950e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1174e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8940e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9577e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8867e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8039e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7794e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7511e-04 - val_loss: 4.6760e-04 - lr: 1.1089e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.6945e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2404e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1314e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4239e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5393e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6791e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7288e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6171e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8128e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7775e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7509e-04 - val_loss: 4.6400e-04 - lr: 1.1089e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.1650e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.9924e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.6686e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8390e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6869e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8274e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6859e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5368e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6780e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7286e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7417e-04 - val_loss: 4.7866e-04 - lr: 1.1089e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.5768e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4830e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1149e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3373e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8208e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0909e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1537e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0417e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9271e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8391e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7979e-04 - val_loss: 4.8967e-04 - lr: 1.1089e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8584e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.8534e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6583e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7398e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7696e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7818e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6441e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.4978e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7533e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8287e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7906e-04 - val_loss: 4.5317e-04 - lr: 1.1089e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.0978e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0521e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1850e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.2248e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.2327e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5630e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6807e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7983e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6886e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8008e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7828e-04 - val_loss: 5.0750e-04 - lr: 1.1089e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.0530e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.9626e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0261e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3792e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0982e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8048e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6757e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6705e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7686e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7017e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7714e-04 - val_loss: 4.7050e-04 - lr: 1.1089e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.5051e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2640e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7623e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0198e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5229e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5908e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8633e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8369e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8332e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8017e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7665e-04 - val_loss: 4.5896e-04 - lr: 1.1089e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.0465e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2469e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.0227e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3945e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.2624e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.2217e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6953e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7426e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8071e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7353e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7687e-04 - val_loss: 4.5555e-04 - lr: 1.1089e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1814e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1523e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1483e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.5117e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0908e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.4536e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2034e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1928e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9575e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7829e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7859e-04 - val_loss: 4.6711e-04 - lr: 1.1089e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8470e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.9274e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.4560e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 3.8037e-04
#  9/20 [============>.................] - ETA: 0s - loss: 3.6756e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.1214e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.2213e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.2800e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5301e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7238e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7623e-04 - val_loss: 4.6387e-04 - lr: 1.1089e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.7769e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.6789e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4796e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5400e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6561e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8290e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0287e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0009e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8679e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8274e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7866e-04 - val_loss: 4.7447e-04 - lr: 1.1089e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3678e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.5099e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3596e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5956e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3646e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.5072e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.4297e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5743e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7194e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7974e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7655e-04 - val_loss: 4.6673e-04 - lr: 3.6926e-05
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.6552e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0713e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.8490e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 3.9487e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.0820e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.2039e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.3323e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.4709e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6033e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7508e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7591e-04 - val_loss: 4.6128e-04 - lr: 3.6926e-05
# Epoch 36/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.3071e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3210e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3918e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6375e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8405e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6835e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8625e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7410e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8162e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7240e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.6980e-04 - val_loss: 4.6852e-04 - lr: 3.6926e-05
# Epoch 37/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.4485e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.8368e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3473e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0704e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0994e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7505e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5146e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7011e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8975e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7778e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7387e-04 - val_loss: 4.6127e-04 - lr: 3.6926e-05
# Epoch 38/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.1451e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.8657e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4241e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3478e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6895e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9553e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9921e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9796e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8119e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7792e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7939e-04 - val_loss: 4.6613e-04 - lr: 3.6926e-05
# Epoch 39/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.2971e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.5564e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.5654e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4858e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1915e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0493e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8844e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9286e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8151e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7988e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7975e-04 - val_loss: 4.6572e-04 - lr: 3.6926e-05
# Epoch 40/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.5270e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.5958e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.9328e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7786e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7541e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8404e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8626e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7949e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7519e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7537e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7276e-04 - val_loss: 4.7043e-04 - lr: 3.6926e-05
# Epoch 41/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.2458e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.9722e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3445e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6199e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.1729e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.3891e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5636e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7041e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7915e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7071e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.6954e-04 - val_loss: 4.5701e-04 - lr: 3.6926e-05
# Epoch 42/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.0519e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.7407e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4099e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.2939e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1258e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9918e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0211e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8494e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6840e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7647e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7907e-04 - val_loss: 4.5641e-04 - lr: 3.6926e-05
# Epoch 43/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1727e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.2344e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7540e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8854e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9457e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9057e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8296e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7787e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8720e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7254e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 4.7632e-04 - val_loss: 4.6156e-04 - lr: 3.6926e-05
# Epoch 44/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1120e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.8501e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4925e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.5657e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1239e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1623e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1501e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8452e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8239e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7569e-04
# ...
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9638e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9395e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8467e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6559e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7572e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7086e-04 - val_loss: 4.6532e-04 - lr: 3.6926e-05
# Epoch 56/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.8595e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8148e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6046e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5291e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5003e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6136e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5466e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5663e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5615e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8311e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7884e-04 - val_loss: 4.6688e-04 - lr: 3.6926e-05
# Epoch 57/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5714e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0838e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1686e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 3.9103e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.1773e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4270e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8009e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9692e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7872e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7169e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7293e-04 - val_loss: 4.6864e-04 - lr: 3.6926e-05
# Epoch 58/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.0852e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0995e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0538e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3111e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3777e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3544e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1190e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8916e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6593e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7413e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7602e-04 - val_loss: 4.7292e-04 - lr: 3.6926e-05
# Epoch 59/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.4997e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3430e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6344e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4192e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3690e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.2591e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.3889e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5055e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6000e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7324e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7163e-04 - val_loss: 4.6642e-04 - lr: 3.6926e-05
# Epoch 60/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.2410e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6055e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1699e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5960e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.2993e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4081e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.3107e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5021e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5471e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6460e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7519e-04 - val_loss: 4.7532e-04 - lr: 3.6926e-05
# Epoch 61/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6344e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.1064e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 3.5243e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 3.8697e-04
#  9/20 [============>.................] - ETA: 0s - loss: 3.8132e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.1258e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.4136e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5014e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.5903e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6964e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7236e-04 - val_loss: 4.6504e-04 - lr: 3.6926e-05
# Epoch 62/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.1957e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.9435e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2633e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5269e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.4645e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4340e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5304e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7964e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7679e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6998e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 4.7099e-04 - val_loss: 4.6479e-04 - lr: 3.6926e-05
# Epoch 63/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.6101e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.3816e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.5041e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5842e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8712e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7480e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7220e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6967e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7022e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7083e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7050e-04 - val_loss: 4.5894e-04 - lr: 3.6926e-05
# Epoch 64/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.9738e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.3032e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1634e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7137e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9845e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7776e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7622e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9135e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8962e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7910e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7458e-04 - val_loss: 4.6136e-04 - lr: 3.6926e-05
# Epoch 65/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.1212e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0519e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2636e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4613e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5903e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7616e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6398e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6094e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6788e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6565e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7006e-04 - val_loss: 4.5253e-04 - lr: 3.6926e-05
# Epoch 66/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.6916e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.4624e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8879e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7438e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2701e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3502e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2848e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1385e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0406e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7861e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 4.7399e-04 - val_loss: 4.5504e-04 - lr: 1.2296e-05
# Epoch 67/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.7779e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.2753e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7811e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8651e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2265e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3324e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1010e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9744e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8000e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7822e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 4.7332e-04 - val_loss: 4.5692e-04 - lr: 1.2296e-05
# Epoch 68/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.6894e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6384e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4458e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6026e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8226e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8077e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5167e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7910e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7789e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7230e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7346e-04 - val_loss: 4.5769e-04 - lr: 1.2296e-05
# Epoch 69/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.1870e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.7213e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.5443e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9635e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0583e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1953e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1179e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1541e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9342e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7419e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7155e-04 - val_loss: 4.5964e-04 - lr: 1.2296e-05
# Epoch 70/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5008e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1217e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2036e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4975e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8042e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6090e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.5228e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5416e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6563e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7246e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.6880e-04 - val_loss: 4.6000e-04 - lr: 1.2296e-05
# Epoch 71/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.3542e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6752e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7042e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3313e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3612e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4791e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7124e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7484e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8073e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7646e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7654e-04 - val_loss: 4.6072e-04 - lr: 1.2296e-05
# Epoch 72/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.8773e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3395e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0663e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6148e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9329e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6445e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8582e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7574e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9173e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6656e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.6868e-04 - val_loss: 4.5995e-04 - lr: 1.2296e-05
# Epoch 73/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.4805e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.4773e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9939e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7131e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3108e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0639e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1836e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8536e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7002e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.6710e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7047e-04 - val_loss: 4.6217e-04 - lr: 1.2296e-05
# Epoch 74/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.2462e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.7416e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.9841e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8408e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8942e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8257e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9396e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8146e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7081e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.7601e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 4.7488e-04 - val_loss: 4.6237e-04 - lr: 1.2296e-05
# Epoch 75/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1379e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.5826e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
