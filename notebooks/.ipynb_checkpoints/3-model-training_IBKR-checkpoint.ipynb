# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "IBKR"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:50:14.708203: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.012303  0.016227  0.016591  0.016809  0.021004  2020-10-15 00:00:00-04:00
# 1  0.018355  0.019619  0.022459  0.019143  0.012430  2020-10-16 00:00:00-04:00
# 2  0.020683  0.018555  0.017333  0.011806  0.015188  2020-10-19 00:00:00-04:00
# 3  0.015230  0.019553  0.016793  0.014874  0.116009  2020-10-20 00:00:00-04:00
# 4  0.006185  0.018422  0.010386  0.012940  0.142312  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.246326  0.249905  0.249943  0.249930  0.025938  2023-07-03 00:00:00-04:00
# 1  0.248353  0.252406  0.251108  0.253996  0.100670  2023-07-05 00:00:00-04:00
# 2  0.253016  0.253825  0.255220  0.255894  0.101618  2023-07-06 00:00:00-04:00
# 3  0.259233  0.269841  0.266938  0.266332  0.183309  2023-07-07 00:00:00-04:00
# 4  0.266126  0.263219  0.265636  0.262333  0.064780  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.248494  0.254936  0.250070  0.257143  0.186303  2024-01-02 00:00:00-05:00
# 1  0.258045  0.274378  0.264497  0.271274  0.437429  2024-01-03 00:00:00-05:00
# 2  0.275522  0.283117  0.280228  0.275147  0.496693  2024-01-04 00:00:00-05:00
# 3  0.277216  0.289484  0.283457  0.280039  0.358539  2024-01-05 00:00:00-05:00
# 4  0.280332  0.279120  0.274183  0.278204  0.247830  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:50:16.620551: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:50:16.620594: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:50:17.097080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:17.098181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:17.099031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:50:17.288415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:17.289199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:17.290047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:50:17.458055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:17.459004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:17.459696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:50:17.606826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:17.607719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:17.608381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:50:17.950441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:17.951307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:17.952198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:18.067030: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:18.067655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:18.068310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:50:18.171709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:18.172512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:18.173063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:18.445037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:18.446297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:18.447398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:18.553541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:18.554280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:18.554961: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:18.659306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:18.660504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:18.661264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:19.143619: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:19.486347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:19.603312: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:19.684147: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:19.853707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:20.050665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 39s - loss: 2.9142e-04
# 2024-12-31 05:50:20.197867: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  2/20 [==>...........................] - ETA: 1s - loss: 1.9673e-04
#  4/20 [=====>........................] - ETA: 0s - loss: 1.5079e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4192e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.2353e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.2082e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.1188e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0804e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0485e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.0715e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.0577e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.0762e-04
# 2024-12-31 05:50:21.481575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:21.482418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:21.483098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:21.570025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:21.570604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:21.571227: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:21.659542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:50:21.660241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:50:21.660906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:50:21.700600: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:21.795199: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:21.848774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:50:21.908684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 4s 92ms/step - loss: 1.0762e-04 - val_loss: 8.0499e-05 - lr: 1.1089e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.1968e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0094e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.0518e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.6331e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.3127e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.7862e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.0672e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 8.9413e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.0638e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6257e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.6825e-05 - val_loss: 8.1470e-05 - lr: 1.1089e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.1059e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 7.7574e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.5932e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.3716e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0470e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.7057e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7837e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0089e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.0303e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 9.8225e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 9.7712e-05 - val_loss: 7.9241e-05 - lr: 1.1089e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1039e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0302e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0802e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.1162e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.1234e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.0885e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0431e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 9.8877e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.8925e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6181e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.6644e-05 - val_loss: 8.1063e-05 - lr: 1.1089e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4018e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 9.0365e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0236e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 9.4556e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.4490e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.9836e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7882e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.9643e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.7701e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.7470e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.6605e-05 - val_loss: 8.6855e-05 - lr: 1.1089e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0246e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1300e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.1382e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.1032e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.0326e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.0897e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.0371e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.0312e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 9.5621e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 9.5571e-05
# 20/20 [==============================] - ETA: 0s - loss: 9.6994e-05
# 20/20 [==============================] - 1s 43ms/step - loss: 9.6994e-05 - val_loss: 8.2429e-05 - lr: 1.1089e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.4294e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 7.3732e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0405e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.0504e-04
#  9/20 [============>.................] - ETA: 0s - loss: 9.9520e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.2707e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.1135e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.2848e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.4546e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4753e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.5675e-05 - val_loss: 8.1480e-05 - lr: 1.1089e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.5917e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 7.7648e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.9635e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 8.3369e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0343e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.0965e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 8.9244e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.1745e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.4059e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6018e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.7097e-05 - val_loss: 8.5369e-05 - lr: 1.1089e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0717e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 8.8996e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 9.2071e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.7040e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.3486e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.9214e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.0022e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.1670e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.7074e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.3598e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.4535e-05 - val_loss: 8.8380e-05 - lr: 1.1089e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.0402e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1291e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0606e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.0291e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.0673e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.0500e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0343e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0404e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 9.9004e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6271e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.5640e-05 - val_loss: 8.5739e-05 - lr: 1.1089e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1860e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2675e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.2130e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.1478e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.1153e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.0400e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0190e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0067e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 9.7747e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5866e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.5393e-05 - val_loss: 8.8412e-05 - lr: 1.1089e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.7220e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0092e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.2044e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.1281e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.0844e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.0542e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7533e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.8609e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.6740e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6681e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.6015e-05 - val_loss: 8.0740e-05 - lr: 1.1089e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.0511e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0575e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0514e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.0736e-04
#  9/20 [============>.................] - ETA: 0s - loss: 9.8333e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 1.0121e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0282e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 9.8443e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.8874e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.6297e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.5715e-05 - val_loss: 8.2461e-05 - lr: 1.1089e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1885e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 9.0253e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.8149e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.0522e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.3456e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.4512e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 8.7832e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 8.8332e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.3221e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4864e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.4665e-05 - val_loss: 8.7225e-05 - lr: 1.1089e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.1902e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 8.0265e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.7490e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.0835e-05
#  9/20 [============>.................] - ETA: 0s - loss: 8.3428e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.6548e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.0181e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.1149e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.4526e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5463e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.5323e-05 - val_loss: 8.8104e-05 - lr: 1.1089e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0220e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0942e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 8.5466e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.4568e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0738e-05
# 10/20 [==============>...............] - ETA: 0s - loss: 9.3139e-05
# 12/20 [=================>............] - ETA: 0s - loss: 9.3732e-05
# 14/20 [====================>.........] - ETA: 0s - loss: 9.5684e-05
# 16/20 [=======================>......] - ETA: 0s - loss: 9.4263e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 9.6752e-05
# 20/20 [==============================] - ETA: 0s - loss: 9.5626e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 9.5626e-05 - val_loss: 8.9049e-05 - lr: 1.1089e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.2276e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 8.9810e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.7884e-05
#  6/20 [========>.....................] - ETA: 0s - loss: 8.7770e-05
#  8/20 [===========>..................] - ETA: 0s - loss: 8.8357e-05
# 10/20 [==============>...............] - ETA: 0s - loss: 8.5441e-05
# 12/20 [=================>............] - ETA: 0s - loss: 9.1619e-05
# 14/20 [====================>.........] - ETA: 0s - loss: 9.2392e-05
# 16/20 [=======================>......] - ETA: 0s - loss: 9.5526e-05
# 18/20 [==========================>...] - ETA: 0s - loss: 9.6386e-05
# 20/20 [==============================] - ETA: 0s - loss: 9.5609e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.5609e-05 - val_loss: 8.7334e-05 - lr: 1.1089e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1623e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2216e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.9113e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.0564e-05
#  9/20 [============>.................] - ETA: 0s - loss: 1.0215e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 9.9491e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 1.0323e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0079e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 9.8044e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5927e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.6258e-05 - val_loss: 9.0923e-05 - lr: 1.1089e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1143e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0198e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.2056e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.0189e-05
#  9/20 [============>.................] - ETA: 0s - loss: 8.5922e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.7660e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.1496e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 8.9147e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.2389e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.2648e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4093e-05 - val_loss: 8.2366e-05 - lr: 1.1089e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.6784e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 8.1202e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.7552e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.6895e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.3257e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.9051e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7387e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.3332e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 1.0020e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5495e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.5301e-05 - val_loss: 8.6280e-05 - lr: 1.1089e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1563e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1245e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.2557e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 8.3793e-05
#  9/20 [============>.................] - ETA: 0s - loss: 8.6362e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.2035e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.2088e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.2758e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.3309e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5310e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4696e-05 - val_loss: 8.4807e-05 - lr: 1.1089e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0298e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1805e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.8375e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.7465e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.5071e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.4202e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.6327e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.6477e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.6592e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4335e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.4518e-05 - val_loss: 8.6529e-05 - lr: 1.1089e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.2937e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 8.8151e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.6769e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.0535e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.6887e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.5953e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7209e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.5953e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.7973e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4499e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4229e-05 - val_loss: 9.2627e-05 - lr: 1.1089e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.2936e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 8.9155e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.2857e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.3681e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0564e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.5481e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.2902e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.1626e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.2316e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4417e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.3976e-05 - val_loss: 8.7502e-05 - lr: 1.1089e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.4026e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 9.8872e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0165e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.0330e-04
#  9/20 [============>.................] - ETA: 0s - loss: 9.7996e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.4575e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.0432e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 8.9697e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.4036e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4627e-05
# 20/20 [==============================] - 1s 36ms/step - loss: 9.4750e-05 - val_loss: 9.0235e-05 - lr: 1.1089e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2348e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1297e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0055e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 9.8659e-05
#  9/20 [============>.................] - ETA: 0s - loss: 8.8818e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.2202e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.3000e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 8.8517e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.1773e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4283e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4228e-05 - val_loss: 9.0492e-05 - lr: 1.1089e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.3361e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1114e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.6546e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.4477e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0484e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.8476e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.2988e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.0355e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.0254e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4151e-05
# 20/20 [==============================] - 1s 38ms/step - loss: 9.6117e-05 - val_loss: 9.3000e-05 - lr: 1.1089e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.5689e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1829e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.0698e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 9.8063e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.9599e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.7046e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.5252e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.3095e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.5408e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4167e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4036e-05 - val_loss: 9.2320e-05 - lr: 1.1089e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1455e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0214e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.9882e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.6379e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.9487e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.5615e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.8211e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.5035e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.3530e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.3229e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4341e-05 - val_loss: 9.4905e-05 - lr: 1.1089e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.7402e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 9.6043e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.6877e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 8.6752e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.5867e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.6833e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7059e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.5111e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.7800e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5852e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.5257e-05 - val_loss: 8.3378e-05 - lr: 1.1089e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0526e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 8.6333e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.5482e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.5877e-05
#  9/20 [============>.................] - ETA: 0s - loss: 8.7477e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.7400e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.7519e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 1.0001e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 9.8003e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.4694e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.4607e-05 - val_loss: 8.5427e-05 - lr: 1.1089e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.3887e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 7.5545e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.6028e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.2914e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.6763e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.7116e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.4499e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.5300e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.6006e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5256e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 9.5070e-05 - val_loss: 8.9186e-05 - lr: 1.1089e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3153e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.0365e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 9.4209e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.1542e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.0235e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.2850e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.3668e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.3082e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.5889e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5101e-05
# 20/20 [==============================] - 1s 40ms/step - loss: 9.4575e-05 - val_loss: 8.9055e-05 - lr: 1.1089e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.5702e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 6.7824e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 7.1458e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 8.4495e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.2336e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 8.7689e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.0297e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.2750e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.5368e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.5510e-05
# 20/20 [==============================] - 1s 37ms/step - loss: 9.5329e-05 - val_loss: 8.8475e-05 - lr: 3.6926e-05
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.7759e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 7.8971e-05
#  5/20 [======>.......................] - ETA: 0s - loss: 8.8557e-05
#  7/20 [=========>....................] - ETA: 0s - loss: 9.1238e-05
#  9/20 [============>.................] - ETA: 0s - loss: 9.3073e-05
# 11/20 [===============>..............] - ETA: 0s - loss: 9.2753e-05
# 13/20 [==================>...........] - ETA: 0s - loss: 9.1239e-05
# 15/20 [=====================>........] - ETA: 0s - loss: 9.2065e-05
# 17/20 [========================>.....] - ETA: 0s - loss: 9.0378e-05
# 19/20 [===========================>..] - ETA: 0s - loss: 9.1363e-05
# 20/20 [==============================] - 1s 39ms/step - loss: 9.4190e-05 - val_loss: 9.0901e-05 - lr: 3.6926e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
