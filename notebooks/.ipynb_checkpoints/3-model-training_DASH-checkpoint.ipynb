# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "DASH"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:48:32.417476: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (442, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.856034  0.821942  0.857755  0.855897  0.022172  2021-09-27 00:00:00-04:00
# 1  0.832891  0.798577  0.816558  0.804593  0.033459  2021-09-28 00:00:00-04:00
# 2  0.803312  0.777427  0.820711  0.802178  0.016303  2021-09-29 00:00:00-04:00
# 3  0.795941  0.770314  0.810003  0.802918  0.019908  2021-09-30 00:00:00-04:00
# 4  0.808078  0.776344  0.797193  0.793110  0.022067  2021-10-01 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.160869  0.159216  0.177012  0.175694  0.023854  2023-07-03 00:00:00-04:00
# 1  0.169123  0.161195  0.181566  0.177468  0.027543  2023-07-05 00:00:00-04:00
# 2  0.165438  0.158133  0.168631  0.167217  0.066291  2023-07-06 00:00:00-04:00
# 3  0.163915  0.159122  0.178513  0.171948  0.037803  2023-07-07 00:00:00-04:00
# 4  0.167109  0.157709  0.177463  0.170273  0.033364  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.264347  0.252391  0.270234  0.263171  0.061850  2024-01-02 00:00:00-05:00
# 1  0.252113  0.239625  0.260277  0.249914  0.080128  2024-01-03 00:00:00-05:00
# 2  0.243612  0.235621  0.260027  0.250554  0.034200  2024-01-04 00:00:00-05:00
# 3  0.243416  0.239295  0.261027  0.255039  0.038631  2024-01-05 00:00:00-05:00
# 4  0.270244  0.255829  0.277090  0.273323  0.087815  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (442, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (608, 5)
#
#  Data Train Scaled: (442, 5)
# > Data Train X: (378, 64, 5)
# > Data Train y: (378,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:48:34.299810: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:48:34.299843: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:48:34.661439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:34.662217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:34.663057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:48:34.835172: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:34.836157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:34.836822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:48:34.982623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:34.983572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:34.984121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:48:35.121489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.122176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.122960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:48:35.435947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.436781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.437382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:35.537716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.538281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.538831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:35.634444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.635094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.635622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:48:35.874261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.875297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.876195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:35.968328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:35.968946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:35.969574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:36.059365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:36.059986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:36.060644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:36.477586: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:36.790150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:36.898859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:36.968639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:37.134623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:37.318517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/12 [=>............................] - ETA: 20s - loss: 5.9652e-04
# 2024-12-31 05:48:37.453892: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  3/12 [======>.......................] - ETA: 0s - loss: 4.2030e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.5737e-04
#  7/12 [================>.............] - ETA: 0s - loss: 4.2909e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 4.1285e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 4.0753e-04
# 12/12 [==============================] - ETA: 0s - loss: 4.2388e-04
# 2024-12-31 05:48:38.348218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:38.349405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:38.350055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:38.458631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:38.459447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:38.460270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:38.587775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:48:38.590150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:48:38.591667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:48:38.637805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:38.802077: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:38.904886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:48:39.008442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 3s 149ms/step - loss: 4.2388e-04 - val_loss: 1.0859e-04 - lr: 1.1089e-04
# Epoch 2/1000
#  1/12 [=>............................] - ETA: 0s - loss: 5.0169e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.7394e-04
#  4/12 [=========>....................] - ETA: 0s - loss: 4.0211e-04
#  6/12 [==============>...............] - ETA: 0s - loss: 3.4785e-04
#  8/12 [===================>..........] - ETA: 0s - loss: 3.7991e-04
# 10/12 [========================>.....] - ETA: 0s - loss: 3.6979e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8720e-04
# 12/12 [==============================] - ETA: 0s - loss: 3.8756e-04
# 12/12 [==============================] - 1s 54ms/step - loss: 3.8756e-04 - val_loss: 1.1170e-04 - lr: 1.1089e-04
# Epoch 3/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.1849e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.2003e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.3387e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.8708e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.7408e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.9375e-04
# 12/12 [==============================] - 1s 49ms/step - loss: 3.8839e-04 - val_loss: 1.0959e-04 - lr: 1.1089e-04
# Epoch 4/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.6097e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.5926e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.9072e-04
#  7/12 [================>.............] - ETA: 0s - loss: 4.0034e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5565e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.5359e-04
# 12/12 [==============================] - ETA: 0s - loss: 3.7579e-04
# 12/12 [==============================] - 1s 47ms/step - loss: 3.7579e-04 - val_loss: 1.1250e-04 - lr: 1.1089e-04
# Epoch 5/1000
#  1/12 [=>............................] - ETA: 0s - loss: 4.3221e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.5059e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.9781e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.6263e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.6263e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.7198e-04
# 12/12 [==============================] - 1s 43ms/step - loss: 3.7611e-04 - val_loss: 1.1220e-04 - lr: 1.1089e-04
# Epoch 6/1000
#  1/12 [=>............................] - ETA: 0s - loss: 1.9942e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 2.9335e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 2.9955e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.6619e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5602e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.6488e-04
# 12/12 [==============================] - 1s 43ms/step - loss: 3.8174e-04 - val_loss: 1.1290e-04 - lr: 1.1089e-04
# Epoch 7/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.0501e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.5734e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.5449e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.5432e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.7081e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.6028e-04
# 12/12 [==============================] - 1s 44ms/step - loss: 3.7561e-04 - val_loss: 1.1708e-04 - lr: 1.1089e-04
# Epoch 8/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.1912e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 2.1403e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.1644e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.2110e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5604e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8670e-04
# 12/12 [==============================] - 0s 42ms/step - loss: 3.7421e-04 - val_loss: 1.1432e-04 - lr: 1.1089e-04
# Epoch 9/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.3679e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.2538e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.8612e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.8173e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.8653e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.9599e-04
# 12/12 [==============================] - 1s 43ms/step - loss: 3.8234e-04 - val_loss: 1.1692e-04 - lr: 1.1089e-04
# Epoch 10/1000
#  1/12 [=>............................] - ETA: 0s - loss: 5.8625e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.1970e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.8934e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.6748e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5108e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.5663e-04
# 12/12 [==============================] - 1s 43ms/step - loss: 3.7360e-04 - val_loss: 1.2166e-04 - lr: 1.1089e-04
# Epoch 11/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.7505e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.5121e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.4031e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.5906e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.6463e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.6074e-04
# 12/12 [==============================] - 1s 42ms/step - loss: 3.7421e-04 - val_loss: 1.2109e-04 - lr: 1.1089e-04
# Epoch 12/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.0352e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.1607e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.2385e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.4373e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.4066e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8022e-04
# 12/12 [==============================] - 1s 45ms/step - loss: 3.7597e-04 - val_loss: 1.1759e-04 - lr: 1.1089e-04
# Epoch 13/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.2956e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 2.5838e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.8413e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.9073e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 4.1053e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.7916e-04
# 12/12 [==============================] - 1s 43ms/step - loss: 3.6923e-04 - val_loss: 1.1786e-04 - lr: 1.1089e-04
# Epoch 14/1000
#  1/12 [=>............................] - ETA: 0s - loss: 4.1890e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.4573e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.3581e-04
#  7/12 [================>.............] - ETA: 0s - loss: 4.2804e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.9957e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8182e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.7513e-04 - val_loss: 1.1757e-04 - lr: 1.1089e-04
# Epoch 15/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.5625e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.0691e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.0573e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.9663e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 4.0210e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.7626e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.7486e-04 - val_loss: 1.2055e-04 - lr: 1.1089e-04
# Epoch 16/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.7590e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.4436e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.0431e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.9741e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5387e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3
-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.0531e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.1121e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.7472e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.8592e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8258e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.7636e-04 - val_loss: 1.2339e-04 - lr: 3.6926e-05
# Epoch 61/1000
#  1/12 [=>............................] - ETA: 0s - loss: 4.3460e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 3.6143e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.1936e-04
#  7/12 [================>.............] - ETA: 0s - loss: 4.3176e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.9957e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8850e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.7010e-04 - val_loss: 1.2444e-04 - lr: 3.6926e-05
# Epoch 62/1000
#  1/12 [=>............................] - ETA: 0s - loss: 1.2830e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 2.8502e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.5647e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.6258e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.5271e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.5523e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.6752e-04 - val_loss: 1.2424e-04 - lr: 3.6926e-05
# Epoch 63/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.8047e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.1075e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 4.4266e-04
#  7/12 [================>.............] - ETA: 0s - loss: 4.1863e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.8918e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.7153e-04
# 12/12 [==============================] - 0s 40ms/step - loss: 3.6738e-04 - val_loss: 1.2413e-04 - lr: 3.6926e-05
# Epoch 64/1000
#  1/12 [=>............................] - ETA: 0s - loss: 3.8530e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 2.5146e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.1222e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.6752e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.7684e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.8580e-04
# 12/12 [==============================] - 0s 40ms/step - loss: 3.7083e-04 - val_loss: 1.2450e-04 - lr: 3.6926e-05
# Epoch 65/1000
#  1/12 [=>............................] - ETA: 0s - loss: 2.4296e-04
#  3/12 [======>.......................] - ETA: 0s - loss: 4.4095e-04
#  5/12 [===========>..................] - ETA: 0s - loss: 3.8097e-04
#  7/12 [================>.............] - ETA: 0s - loss: 3.7229e-04
#  9/12 [=====================>........] - ETA: 0s - loss: 3.6019e-04
# 11/12 [==========================>...] - ETA: 0s - loss: 3.4681e-04
# 12/12 [==============================] - 0s 41ms/step - loss: 3.6428e-04 - val_loss: 1.2446e-04 - lr: 3.6926e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
