# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "AAPL"

# %%
# Global parameters

TICKER = 'GOOGL'  # Default value, overwritten by papermill

NUM_EPOCH = 1000
STARTING_LR = 0.0001
SEQUENCE_SIZE = 128
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 100
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization, Reshape
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 19:12:59.996998: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.011252  0.007067  0.013574  0.018332  0.192277  2020-10-15 00:00:00-04:00
# 1  0.018348  0.009602  0.020447  0.023352  0.218478  2020-10-16 00:00:00-04:00
# 2  0.024121  0.012100  0.006004  0.007859  0.179317  2020-10-19 00:00:00-04:00
# 3  0.002494  0.008047  0.004997  0.016531  0.284121  2020-10-20 00:00:00-04:00
# 4  0.021631  0.024639  0.024388  0.030858  0.447896  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.355315  0.341472  0.360843  0.364105  0.045272  2023-07-03 00:00:00-04:00
# 1  0.355315  0.360916  0.364252  0.379290  0.160445  2023-07-05 00:00:00-04:00
# 2  0.359901  0.342356  0.357351  0.365829  0.135512  2023-07-06 00:00:00-04:00
# 3  0.362358  0.348382  0.365666  0.360658  0.108709  2023-07-07 00:00:00-04:00
# 4  0.347618  0.326367  0.338558  0.335788  0.228323  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.513446  0.496221  0.507688  0.514065  0.126433  2024-01-02 00:00:00-05:00
# 1  0.502800  0.497667  0.512677  0.520221  0.130831  2024-01-03 00:00:00-05:00
# 2  0.512382  0.493891  0.506607  0.499455  0.156520  2024-01-04 00:00:00-05:00
# 3  0.498706  0.477821  0.496629  0.494037  0.115851  2024-01-05 00:00:00-05:00
# 4  0.494939  0.492686  0.505859  0.519564  0.106174  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        up_by_1_percent = 1.0 if data[i, target_attr_idx] / data[i-1, target_attr_idx] > 1.01 else 0.0
        data_y.append(up_by_1_percent)
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (254, 5)
# inside construct_lstm_data with shape: (168, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (552, 128, 5)
# > Data Train y: (552,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 128, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 128, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
class AppendParametersLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        inner_layer_output, extra_params = inputs
        return tf.concat([inner_layer_output, extra_params], axis=-1)

# %%
from tensorflow.keras.layers import Concatenate

input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

cnn = Conv1D(32, 3)(input_layer)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(32,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Dense(256)(cnn)
# cnn = Reshape((64, 256))(cnn)  # Align shape with `input_denser`
from tensorflow.keras.layers import ZeroPadding1D, Cropping1D

# cnn = ZeroPadding1D(padding=(30))(cnn)
# cnn = Cropping1D(cropping=(0,1))(cnn)  # Remove 1 from the beginning

# input_denser = Dense(256, kernel_initializer=tf.keras.initializers.HeUniform())(input_layer)

# input_to_lstm = Concatenate()([cnn, input_denser])

# Add first LSTM layer and dropout regularization layer
lstm = LSTM(units = 800, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 800, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 200, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 100)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = Dense(1)(lstm)
# Out:
# 2024-12-31 19:13:01.874155: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 19:13:01.874200: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-31 19:13:02.623889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:02.624605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:02.625316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:03.086003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:03.086974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:03.087509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:03.266184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:03.266761: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:03.267405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:03.402373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:03.403278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:03.403855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:03.533225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:03.533814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:03.534480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# # # Add input layer
# regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add second LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 400, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add third LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 200, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add forth LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# %%
from tensorflow.keras.models import Model

# # Add last dense layer/output layer
# regressor.add(Dense(1))
# regressor.summary()
regressor = Model(input_layer,lstm)
regressor.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 5)]          0
#  conv1d (Conv1D)             (None, 126, 32)           512
#  p_re_lu (PReLU)             (None, 126, 32)           32
#  conv1d_1 (Conv1D)           (None, 124, 32)           3104
#  p_re_lu_1 (PReLU)           (None, 124, 32)           32
#  conv1d_2 (Conv1D)           (None, 61, 64)            6208
#  p_re_lu_2 (PReLU)           (None, 61, 64)            64
#  conv1d_3 (Conv1D)           (None, 59, 64)            12352
#  p_re_lu_3 (PReLU)           (None, 59, 64)            64
#  conv1d_4 (Conv1D)           (None, 29, 128)           24704
#  p_re_lu_4 (PReLU)           (None, 29, 128)           128
#  conv1d_5 (Conv1D)           (None, 27, 128)           49280
#  p_re_lu_5 (PReLU)           (None, 27, 128)           128
#  dense (Dense)               (None, 27, 256)           33024
#  lstm (LSTM)                 (None, 27, 800)           3382400
#  dropout (Dropout)           (None, 27, 800)           0
#  lstm_1 (LSTM)               (None, 27, 800)           5123200
#  dropout_1 (Dropout)         (None, 27, 800)           0
#  lstm_2 (LSTM)               (None, 27, 400)           1921600
#  dropout_2 (Dropout)         (None, 27, 400)           0
#  lstm_3 (LSTM)               (None, 27, 200)           480800
#  dropout_3 (Dropout)         (None, 27, 200)           0
#  lstm_4 (LSTM)               (None, 100)               120400
#  dropout_4 (Dropout)         (None, 100)               0
#  dense_1 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 11,158,133
# Trainable params: 11,158,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K


optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(optimizer=optimizer, loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-16             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
try:
    best_model = load_model(model_location + model_name)
    regressor = best_model
    print(f"Using already trained model")
except:
    print(f"Building brand new model")
# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 19:13:04.306588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:04.307521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:04.308167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:04.756823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:04.757707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:04.758317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:04.900676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:04.901352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:04.901980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:05.005114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.005937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.006571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:05.101305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.101967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.102554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 19:13:05.667917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.668935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.669583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:05.759171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.759789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.760390: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:05.850533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.851166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.851792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:05.941368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:05.942143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:05.942957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:06.032098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:06.032714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:06.033344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:06.732703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.380477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.486277: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.551127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.621375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.689808: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:07.870845: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:08.062192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:08.181556: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:08.291753: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:08.400182: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/18 [>.............................] - ETA: 54s - loss: 0.2228
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2394
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2406
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2440
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2481
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2489
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2496
#  8/18 [============>.................] - ETA: 0s - loss: 0.2483
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2448
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2456
# 11/18 [=================>............] - ETA: 0s - loss: 0.2462
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2490
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2470
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2491
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2487
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2477
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2483
# 18/18 [==============================] - ETA: 0s - loss: 0.2476
# 2024-12-31 19:13:10.427511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:10.428555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:10.429192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:10.515901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:10.516533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:10.517191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:10.603151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:10.603727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:10.604364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:10.690508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:10.691257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:10.691889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:10.777641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:13:10.778226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:13:10.778787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:13:10.828695: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:11.142694: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:11.209074: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:11.270824: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:11.346963: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:13:11.405890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 18/18 [==============================] - 6s 194ms/step - loss: 0.2476 - val_loss: 0.2672 - lr: 1.0000e-04
# Epoch 2/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2292
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2307
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2291
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2375
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2369
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2392
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2445
#  8/18 [============>.................] - ETA: 0s - loss: 0.2494
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2471
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2475
# 11/18 [=================>............] - ETA: 0s - loss: 0.2486
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2476
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2471
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2459
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2452
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2448
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2446
# 18/18 [==============================] - ETA: 0s - loss: 0.2444
# 18/18 [==============================] - 1s 78ms/step - loss: 0.2444 - val_loss: 0.2536 - lr: 1.0000e-04
# Epoch 3/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2327
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2369
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2445
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2422
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2432
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2426
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2437
#  8/18 [============>.................] - ETA: 0s - loss: 0.2392
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2391
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2365
# 11/18 [=================>............] - ETA: 0s - loss: 0.2401
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2398
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2392
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2379
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2386
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2409
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 75ms/step - loss: 0.2412 - val_loss: 0.2529 - lr: 1.0000e-04
# Epoch 4/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2360
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2328
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2451
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2473
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2450
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2479
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2485
#  8/18 [============>.................] - ETA: 0s - loss: 0.2480
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2470
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2483
# 11/18 [=================>............] - ETA: 0s - loss: 0.2465
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2444
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2457
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2437
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2425
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2418
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2409
# 18/18 [==============================] - ETA: 0s - loss: 0.2398
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2398 - val_loss: 0.2687 - lr: 1.0000e-04
# Epoch 5/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2201
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2279
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2405
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2427
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2361
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2419
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2385
#  8/18 [============>.................] - ETA: 0s - loss: 0.2414
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2472
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2431
# 11/18 [=================>............] - ETA: 0s - loss: 0.2475
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2461
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2491
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2475
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2467
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2458
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2462
# 18/18 [==============================] - ETA: 0s - loss: 0.2466
# 18/18 [==============================] - 1s 75ms/step - loss: 0.2466 - val_loss: 0.2500 - lr: 1.0000e-04
# Epoch 6/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2273
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2337
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2421
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2441
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2443
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2452
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2433
#  8/18 [============>.................] - ETA: 0s - loss: 0.2437
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2437
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2440
# 11/18 [=================>............] - ETA: 0s - loss: 0.2430
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2426
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2425
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2413
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2424
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2420
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - ETA: 0s - loss: 0.2428
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2428 - val_loss: 0.2678 - lr: 1.0000e-04
# Epoch 7/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2270
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2325
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2490
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2562
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2502
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2515
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2583
#  8/18 [============>.................] - ETA: 0s - loss: 0.2588
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2565
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2561
# 11/18 [=================>............] - ETA: 0s - loss: 0.2527
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2515
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2509
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2515
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2503
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2495
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2489
# 18/18 [==============================] - ETA: 0s - loss: 0.2484
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2484 - val_loss: 0.2576 - lr: 1.0000e-04
# Epoch 8/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2493
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2459
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2354
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2396
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2399
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2443
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2512
#  8/18 [============>.................] - ETA: 0s - loss: 0.2498
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2466
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2483
# 11/18 [=================>............] - ETA: 0s - loss: 0.2475
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2472
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2458
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2443
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2439
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2466
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2459
# 18/18 [==============================] - ETA: 0s - loss: 0.2452
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2452 - val_loss: 0.2572 - lr: 1.0000e-04
# Epoch 9/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2518
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2527
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2485
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2380
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2343
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2353
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2411
#  8/18 [============>.................] - ETA: 0s - loss: 0.2408
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2426
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2404
# 11/18 [=================>............] - ETA: 0s - loss: 0.2384
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2394
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2394
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2399
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2424
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2422
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2425
# 18/18 [==============================] - ETA: 0s - loss: 0.2420
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2420 - val_loss: 0.2560 - lr: 1.0000e-04
# Epoch 10/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2658
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2497
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2430
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2449
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2502
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2467
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2471
#  8/18 [============>.................] - ETA: 0s - loss: 0.2486
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2469
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2444
# 11/18 [=================>............] - ETA: 0s - loss: 0.2446
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2428
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2405
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2394
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2403
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2404
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2403
# 18/18 [==============================] - ETA: 0s - loss: 0.2402
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2402 - val_loss: 0.2589 - lr: 1.0000e-04
# Epoch 11/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2267
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2357
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2337
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2329
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2318
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2356
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2393
#  8/18 [============>.................] - ETA: 0s - loss: 0.2367
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2419
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2406
# 11/18 [=================>............] - ETA: 0s - loss: 0.2418
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2410
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2410
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2420
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2412
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2417
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2419
# 18/18 [==============================] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2411 - val_loss: 0.2558 - lr: 1.0000e-04
# Epoch 12/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2293
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2380
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2360
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2394
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2468
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2474
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2510
#  8/18 [============>.................] - ETA: 0s - loss: 0.2512
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2483
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2453
# 11/18 [=================>............] - ETA: 0s - loss: 0.2465
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2453
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2467
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2476
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2468
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2450
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2443
# 18/18 [==============================] - ETA: 0s - loss: 0.2438
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2438 - val_loss: 0.2532 - lr: 1.0000e-04
# Epoch 13/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2815
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2733
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2627
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2605
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2580
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2571
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2563
#  8/18 [============>.................] - ETA: 0s - loss: 0.2551
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2547
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2531
# 11/18 [=================>............] - ETA: 0s - loss: 0.2529
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2522
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2509
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2487
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2469
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2430
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2414
# 18/18 [==============================] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2413 - val_loss: 0.2756 - lr: 1.0000e-04
# Epoch 14/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2535
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2506
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2745
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2640
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2590
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2511
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2598
#  8/18 [============>.................] - ETA: 0s - loss: 0.2615
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2614
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2617
# 11/18 [=================>............] - ETA: 0s - loss: 0.2572
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2578
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2565
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2550
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2527
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2510
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2505
# 18/18 [==============================] - ETA: 0s - loss: 0.2507
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2507 - val_loss: 0.2553 - lr: 1.0000e-04
# Epoch 15/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2305
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2219
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2330
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2314
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2360
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2342
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2316
#  8/18 [============>.................] - ETA: 0s - loss: 0.2377
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2374
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2413
# 11/18 [=================>............] - ETA: 0s - loss: 0.2422
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2399
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2412
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2432
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2453
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2440
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2439
# 18/18 [==============================] - ETA: 0s - loss: 0.2435
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2435 - val_loss: 0.2554 - lr: 1.0000e-04
# Epoch 16/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2583
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2486
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2516
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2517
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2511
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2473
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2442
#  8/18 [============>.................] - ETA: 0s - loss: 0.2451
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2452
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2429
# 11/18 [=================>............] - ETA: 0s - loss: 0.2421
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2404
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2392
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2391
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2410
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2438
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - ETA: 0s - loss: 0.2423
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2423 - val_loss: 0.2612 - lr: 1.0000e-04
# Epoch 17/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2285
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2281
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2366
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2394
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2332
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2316
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2374
#  8/18 [============>.................] - ETA: 0s - loss: 0.2365
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2399
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2376
# 11/18 [=================>............] - ETA: 0s - loss: 0.2367
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2379
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2371
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2368
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2379
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2383
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2405
# 18/18 [==============================] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2411 - val_loss: 0.2547 - lr: 1.0000e-04
# Epoch 18/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2593
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2514
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2445
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2463
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2495
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2486
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2473
#  8/18 [============>.................] - ETA: 0s - loss: 0.2450
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2459
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2474
# 11/18 [=================>............] - ETA: 0s - loss: 0.2472
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2467
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2454
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2459
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2443
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2443
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2462
# 18/18 [==============================] - ETA: 0s - loss: 0.2454
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2454 - val_loss: 0.2604 - lr: 1.0000e-04
# Epoch 19/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2152
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2216
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2275
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2197
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2296
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2298
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2367
#  8/18 [============>.................] - ETA: 0s - loss: 0.2355
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2424
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2431
# 11/18 [=================>............] - ETA: 0s - loss: 0.2405
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2438
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2424
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2418
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2420
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2404
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2424
# 18/18 [==============================] - ETA: 0s - loss: 0.2426
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2426 - val_loss: 0.2518 - lr: 1.0000e-04
# Epoch 20/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2521
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2428
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2418
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2430
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2445
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2419
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2413
#  8/18 [============>.................] - ETA: 0s - loss: 0.2413
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2423
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2412
# 11/18 [=================>............] - ETA: 0s - loss: 0.2426
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2423
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2432
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2434
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2425
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2419
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2435
# 18/18 [==============================] - ETA: 0s - loss: 0.2433
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2433 - val_loss: 0.2622 - lr: 1.0000e-04
# Epoch 21/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2341
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2313
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2247
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2382
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2392
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2432
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2424
#  8/18 [============>.................] - ETA: 0s - loss: 0.2439
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2494
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2464
# 11/18 [=================>............] - ETA: 0s - loss: 0.2440
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2419
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2414
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2404
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2404
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2404
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2409
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2412 - val_loss: 0.2548 - lr: 1.0000e-04
# Epoch 22/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2483
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2448
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2398
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2422
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2365
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2338
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2393
#  8/18 [============>.................] - ETA: 0s - loss: 0.2446
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2456
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2440
# 11/18 [=================>............] - ETA: 0s - loss: 0.2416
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2398
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2377
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2390
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2410
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2423
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2431
# ...
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2404
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2390
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2406
# 18/18 [==============================] - ETA: 0s - loss: 0.2398
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2398 - val_loss: 0.2588 - lr: 1.0000e-04
# Epoch 63/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2180
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2296
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2406
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2481
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2502
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2539
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2523
#  8/18 [============>.................] - ETA: 0s - loss: 0.2514
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2482
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2470
# 11/18 [=================>............] - ETA: 0s - loss: 0.2459
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2461
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2450
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2426
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2418
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2418
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - ETA: 0s - loss: 0.2418
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2418 - val_loss: 0.2578 - lr: 1.0000e-04
# Epoch 64/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2655
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2477
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2368
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2320
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2351
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2372
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2378
#  8/18 [============>.................] - ETA: 0s - loss: 0.2421
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2412
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2404
# 11/18 [=================>............] - ETA: 0s - loss: 0.2394
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2405
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2406
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2386
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2405
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2410
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2409
# 18/18 [==============================] - ETA: 0s - loss: 0.2414
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2414 - val_loss: 0.2568 - lr: 1.0000e-04
# Epoch 65/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2211
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2286
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2278
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2322
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2355
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2355
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2374
#  8/18 [============>.................] - ETA: 0s - loss: 0.2336
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2361
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2369
# 11/18 [=================>............] - ETA: 0s - loss: 0.2389
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2420
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2407
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2391
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2404
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2399
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2414
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2412 - val_loss: 0.2548 - lr: 1.0000e-04
# Epoch 66/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2166
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2275
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2301
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2311
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2326
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2353
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2335
#  8/18 [============>.................] - ETA: 0s - loss: 0.2358
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2365
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2387
# 11/18 [=================>............] - ETA: 0s - loss: 0.2391
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2399
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2385
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2380
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2382
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2398
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2408
# 18/18 [==============================] - ETA: 0s - loss: 0.2405
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2405 - val_loss: 0.2576 - lr: 1.0000e-04
# Epoch 67/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2331
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2347
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2431
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2435
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2450
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2435
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2400
#  8/18 [============>.................] - ETA: 0s - loss: 0.2438
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2423
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2425
# 11/18 [=================>............] - ETA: 0s - loss: 0.2433
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2425
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2416
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2420
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2421
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2418
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2410
# 18/18 [==============================] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2413 - val_loss: 0.2552 - lr: 1.0000e-04
# Epoch 68/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2485
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2509
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2436
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2498
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2487
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2454
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2463
#  8/18 [============>.................] - ETA: 0s - loss: 0.2448
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2461
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2439
# 11/18 [=================>............] - ETA: 0s - loss: 0.2435
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2424
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2430
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2405
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2402
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2411
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2420
# 18/18 [==============================] - ETA: 0s - loss: 0.2415
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2415 - val_loss: 0.2589 - lr: 1.0000e-04
# Epoch 69/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2237
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2331
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2316
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2321
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2334
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2391
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2411
#  8/18 [============>.................] - ETA: 0s - loss: 0.2380
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2415
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2446
# 11/18 [=================>............] - ETA: 0s - loss: 0.2459
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2455
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2449
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2451
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2459
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2434
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2440
# 18/18 [==============================] - ETA: 0s - loss: 0.2436
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2436 - val_loss: 0.2543 - lr: 1.0000e-04
# Epoch 70/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2656
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2607
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2533
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2480
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2516
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2491
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2462
#  8/18 [============>.................] - ETA: 0s - loss: 0.2459
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2436
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2423
# 11/18 [=================>............] - ETA: 0s - loss: 0.2395
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2385
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2382
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2379
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2363
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2383
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2386
# 18/18 [==============================] - ETA: 0s - loss: 0.2385
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2385 - val_loss: 0.2579 - lr: 3.3300e-05
# Epoch 71/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2098
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2253
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2408
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2404
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2334
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2398
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2335
#  8/18 [============>.................] - ETA: 0s - loss: 0.2324
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2312
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2329
# 11/18 [=================>............] - ETA: 0s - loss: 0.2339
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2371
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2381
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2399
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2386
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2389
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2397
# 18/18 [==============================] - ETA: 0s - loss: 0.2400
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2400 - val_loss: 0.2577 - lr: 3.3300e-05
# Epoch 72/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2371
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2593
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2534
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2484
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2409
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2415
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2458
#  8/18 [============>.................] - ETA: 0s - loss: 0.2457
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2480
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2466
# 11/18 [=================>............] - ETA: 0s - loss: 0.2438
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2429
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2422
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2427
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2413
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2405
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2404
# 18/18 [==============================] - ETA: 0s - loss: 0.2398
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2398 - val_loss: 0.2559 - lr: 3.3300e-05
# Epoch 73/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2384
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2393
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2439
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2381
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2367
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2389
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2401
#  8/18 [============>.................] - ETA: 0s - loss: 0.2397
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2388
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2402
# 11/18 [=================>............] - ETA: 0s - loss: 0.2436
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2427
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2424
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2418
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2405
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2406
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2394
# 18/18 [==============================] - ETA: 0s - loss: 0.2391
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2391 - val_loss: 0.2590 - lr: 3.3300e-05
# Epoch 74/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2161
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2350
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2398
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2407
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2405
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2436
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2407
#  8/18 [============>.................] - ETA: 0s - loss: 0.2411
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2393
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2384
# 11/18 [=================>............] - ETA: 0s - loss: 0.2431
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2426
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2421
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2396
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2407
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2406
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2407
# 18/18 [==============================] - ETA: 0s - loss: 0.2401
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2401 - val_loss: 0.2593 - lr: 3.3300e-05
# Epoch 75/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2353
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2387
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2436
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2472
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2520

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
