# %%
# Parameters
TICKER = "BAC"

# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 48
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 04:58:08.707310: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = "google_stock_price_processed_train"
data_file_name_validate = "google_stock_price_processed_validate"
data_file_name_test = "google_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

if TICKER is not None:
    data_train_df = data_train_df[data_train_df['TICKER'] == TICKER]
    data_validate_df = data_validate_df[data_validate_df['TICKER'] == TICKER]
    data_test_df = data_test_df[data_test_df['TICKER'] == TICKER]

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (932, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (41, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.095067  0.092815  0.114254  0.094749  0.133300  2019-10-17
# 1  0.096304  0.090671  0.109972  0.091093  0.221433  2019-10-18
# 2  0.095717  0.088612  0.109740  0.091411  0.149765  2019-10-21
# 3  0.093561  0.086664  0.110117  0.089795  0.149016  2019-10-22
# 4  0.090876  0.091155  0.110591  0.097671  0.124298  2019-10-23
# Validation Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.660064  0.652145  0.667228  0.653320  0.076514  2023-07-03
# 1  0.657521  0.674865  0.670659  0.673287  0.119899  2023-07-05
# 2  0.663193  0.653402  0.662830  0.656889  0.118822  2023-07-06
# 3  0.665638  0.659203  0.670949  0.649268  0.154589  2023-07-07
# 4  0.647839  0.633293  0.637602  0.617726  0.286412  2023-07-10
# Testing Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.848613  0.841590  0.841555  0.836595  0.144569  2024-01-02
# 1  0.838834  0.846182  0.848224  0.844312  0.132489  2024-01-03
# 2  0.851058  0.841783  0.844164  0.821933  0.124554  2024-01-04
# 3  0.836408  0.824139  0.832952  0.815663  0.093517  2024-01-05
# 4  0.832966  0.841831  0.842908  0.845952  0.117863  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (932, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (105, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (1099, 5)
#
#  Data Train Scaled: (932, 5)
# > Data Train X: (868, 64, 5)
# > Data Train y: (868,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (41, 5)
# > Data Test X: (41, 64, 5)
# > Data Test y: (41,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 04:58:10.707496: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 04:58:10.707545: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:58:11.042890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.043631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.044344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:58:11.194031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.194989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.195667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:58:11.334237: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.335020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.335537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 200)           480800
#  dropout_1 (Dropout)         (None, 64, 200)           0
#  lstm_2 (LSTM)               (None, 100)               120400
#  dropout_2 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 1,250,901
# Trainable params: 1,250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, early_stopping])
# Out:
# 2024-12-31 04:58:11.580459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.581354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.581897: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:11.684838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.685402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.685958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 04:58:11.847057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:11.847802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:11.848400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:12.084054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:12.084944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:12.085579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:12.173296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:12.173939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:12.174509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:12.262101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:12.262726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:12.263305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:12.673039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:12.986844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:13.094007: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:13.162418: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:13.326726: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:13.508703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/28 [>.............................] - ETA: 48s - loss: 0.0020
#  2/28 [=>............................] - ETA: 1s - loss: 0.0017
# 2024-12-31 04:58:13.645210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  4/28 [===>..........................] - ETA: 1s - loss: 0.0011
#  6/28 [=====>........................] - ETA: 0s - loss: 8.8529e-04
#  8/28 [=======>......................] - ETA: 0s - loss: 7.7901e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 7.2447e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 6.7945e-04
# 14/28 [==============>...............] - ETA: 0s - loss: 6.6207e-04
# 16/28 [================>.............] - ETA: 0s - loss: 6.4139e-04
# 18/28 [==================>...........] - ETA: 0s - loss: 6.1558e-04
# 20/28 [====================>.........] - ETA: 0s - loss: 6.1054e-04
# 22/28 [======================>.......] - ETA: 0s - loss: 6.1340e-04
# 24/28 [========================>.....] - ETA: 0s - loss: 5.9616e-04
# 26/28 [==========================>...] - ETA: 0s - loss: 6.0671e-04
# 28/28 [==============================] - ETA: 0s - loss: 6.0268e-04
# 2024-12-31 04:58:15.120525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:15.121162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:15.121857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:15.207648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:15.208229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:15.208858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:15.311062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:58:15.311740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:58:15.312709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:58:15.354333: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:15.456509: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:15.521553: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:58:15.609157: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 4s 78ms/step - loss: 6.0268e-04 - val_loss: 0.0013
# Epoch 2/1000
#  1/28 [>.............................] - ETA: 2s - loss: 7.4827e-04
#  2/28 [=>............................] - ETA: 1s - loss: 7.4977e-04
#  3/28 [==>...........................] - ETA: 1s - loss: 7.6584e-04
#  5/28 [====>.........................] - ETA: 1s - loss: 6.1773e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5897e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0827e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9784e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1954e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1251e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0731e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9768e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2343e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0875e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0027e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9279e-04
# 28/28 [==============================] - 1s 42ms/step - loss: 4.9398e-04 - val_loss: 0.0028
# Epoch 3/1000
#  1/28 [>.............................] - ETA: 1s - loss: 7.3464e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.3304e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.7358e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8799e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9688e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7934e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1506e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2322e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1729e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0667e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0295e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1351e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0888e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9721e-04
# 28/28 [==============================] - 1s 41ms/step - loss: 4.9793e-04 - val_loss: 9.7101e-04
# Epoch 4/1000
#  1/28 [>.............................] - ETA: 1s - loss: 3.7396e-04
#  3/28 [==>...........................] - ETA: 1s - loss: 4.6841e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.0403e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7747e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.6492e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7928e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8649e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2416e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5938e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4471e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3397e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1196e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0343e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9649e-04
# 28/28 [==============================] - 1s 42ms/step - loss: 4.9560e-04 - val_loss: 6.8732e-04
# Epoch 5/1000
#  1/28 [>.............................] - ETA: 1s - loss: 2.6516e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.9007e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8099e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7685e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7946e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2419e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9872e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8878e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8970e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0939e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8907e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7904e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8891e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8576e-04
# 28/28 [==============================] - 1s 40ms/step - loss: 4.8597e-04 - val_loss: 5.6784e-04
# Epoch 6/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0010
#  3/28 [==>...........................] - ETA: 0s - loss: 6.3086e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4439e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.2091e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4395e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1548e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9155e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9004e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9382e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9235e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8460e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9040e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8341e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0156e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0351e-04 - val_loss: 0.0032
# Epoch 7/1000
#  1/28 [>.............................] - ETA: 1s - loss: 8.7779e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.5213e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8156e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3793e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0489e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8529e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7664e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7097e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.6930e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6774e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.6911e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7630e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8018e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9973e-04
# 28/28 [==============================] - 1s 40ms/step - loss: 4.9975e-04 - val_loss: 5.2067e-04
# Epoch 8/1000
#  1/28 [>.............................] - ETA: 1s - loss: 8.7778e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7374e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4682e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8678e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2783e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1673e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1426e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9627e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8047e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9580e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0301e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9187e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0364e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0934e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.0997e-04 - val_loss: 0.0017
# Epoch 9/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.3146e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7670e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1666e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3078e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8870e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0696e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2303e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1689e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1615e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9754e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1124e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0642e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9506e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0798e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0625e-04 - val_loss: 0.0011
# Epoch 10/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.6344e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7983e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1950e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5860e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1819e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2144e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9544e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8565e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9127e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0971e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9109e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9914e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9687e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9177e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9005e-04 - val_loss: 0.0011
# Epoch 11/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.9127e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.3553e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2535e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6580e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1929e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9713e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0632e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9401e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9313e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0309e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9225e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9811e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0337e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8981e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8905e-04 - val_loss: 0.0025
# Epoch 12/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.5466e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9374e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.0687e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8617e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.4404e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6892e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7266e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9220e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0654e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0595e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3333e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2355e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2511e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2344e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2259e-04 - val_loss: 0.0026
# Epoch 13/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.7068e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.6356e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3604e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4412e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2532e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5461e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5057e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6207e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.6405e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.5765e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.6473e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7668e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.7829e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8843e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.8637e-04 - val_loss: 0.0016
# Epoch 14/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.1733e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4703e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.7140e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1077e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9600e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9602e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7744e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8216e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7099e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7483e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7145e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7256e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.7610e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8229e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8123e-04 - val_loss: 9.0643e-04
# Epoch 15/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.3417e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.2638e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.6813e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3524e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2719e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.1176e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.2474e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.2719e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5577e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7051e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9054e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8866e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9463e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9582e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9454e-04 - val_loss: 0.0013
# Epoch 16/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.6890e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7928e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9733e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8158e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9951e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1352e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3220e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1912e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9920e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9361e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9142e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9771e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8579e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9259e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9226e-04 - val_loss: 0.0012
# Epoch 17/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.2784e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.5189e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.7853e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0283e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8098e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7442e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5416e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2837e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2767e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1759e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1695e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0762e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0049e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8501e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0105e-04 - val_loss: 0.0011
# Epoch 18/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0029
#  3/28 [==>...........................] - ETA: 0s - loss: 0.0014
#  5/28 [====>.........................] - ETA: 0s - loss: 0.0011
#  7/28 [======>.......................] - ETA: 0s - loss: 8.9627e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 8.1294e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.3685e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.9838e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.5724e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.5810e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.4522e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2210e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1372e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9850e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.0231e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.0016e-04 - val_loss: 0.0012
# Epoch 19/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.4062e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.5275e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.0086e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.2994e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.0151e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.0080e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.2459e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.3967e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.3888e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.3624e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.6402e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7937e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9139e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9269e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9052e-04 - val_loss: 0.0012
# Epoch 20/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.4520e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.3138e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7341e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5518e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9908e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8579e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7242e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8880e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8272e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7643e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8278e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8836e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8129e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.7715e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.7704e-04 - val_loss: 0.0014
# Epoch 21/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.2789e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.7796e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.6465e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.1705e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2036e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.2363e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.3364e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.4462e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5503e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8064e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7392e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.6797e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.5665e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8041e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8515e-04 - val_loss: 0.0029
# Epoch 22/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.0398e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.6770e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.0305e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3716e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7350e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8448e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8345e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5766e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4260e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2797e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3075e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0730e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0185e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9107e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 4.8923e-04 - val_loss: 0.0014
# Epoch 23/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.3766e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9837e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.9972e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7321e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2568e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0214e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9309e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9423e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9074e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9537e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7552e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9522e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0113e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9848e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 5.0118e-04 - val_loss: 4.8042e-04
# Epoch 24/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.7775e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6787e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7303e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0069e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3953e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2638e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2363e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4619e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3432e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2808e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1476e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1020e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0156e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9098e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 4.8945e-04 - val_loss: 5.1400e-04
# Epoch 25/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.3255e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.5127e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.6520e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.2151e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.4516e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4470e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5911e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6201e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7436e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6693e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.6204e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7728e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9207e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9225e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9054e-04 - val_loss: 0.0016
# Epoch 26/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.4829e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
