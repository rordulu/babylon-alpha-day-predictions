# %%
# Parameters
TICKER = "MSFT"

# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 48
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 04:47:32.311644: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = "google_stock_price_processed_train"
data_file_name_validate = "google_stock_price_processed_validate"
data_file_name_test = "google_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

if TICKER is not None:
    data_train_df = data_train_df[data_train_df['TICKER'] == TICKER]
    data_validate_df = data_validate_df[data_validate_df['TICKER'] == TICKER]
    data_test_df = data_test_df[data_test_df['TICKER'] == TICKER]

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (932, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (41, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.095067  0.092815  0.114254  0.094749  0.133300  2019-10-17
# 1  0.096304  0.090671  0.109972  0.091093  0.221433  2019-10-18
# 2  0.095717  0.088612  0.109740  0.091411  0.149765  2019-10-21
# 3  0.093561  0.086664  0.110117  0.089795  0.149016  2019-10-22
# 4  0.090876  0.091155  0.110591  0.097671  0.124298  2019-10-23
# Validation Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.660064  0.652145  0.667228  0.653320  0.076514  2023-07-03
# 1  0.657521  0.674865  0.670659  0.673287  0.119899  2023-07-05
# 2  0.663193  0.653402  0.662830  0.656889  0.118822  2023-07-06
# 3  0.665638  0.659203  0.670949  0.649268  0.154589  2023-07-07
# 4  0.647839  0.633293  0.637602  0.617726  0.286412  2023-07-10
# Testing Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.848613  0.841590  0.841555  0.836595  0.144569  2024-01-02
# 1  0.838834  0.846182  0.848224  0.844312  0.132489  2024-01-03
# 2  0.851058  0.841783  0.844164  0.821933  0.124554  2024-01-04
# 3  0.836408  0.824139  0.832952  0.815663  0.093517  2024-01-05
# 4  0.832966  0.841831  0.842908  0.845952  0.117863  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (932, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (105, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (1099, 5)
#
#  Data Train Scaled: (932, 5)
# > Data Train X: (868, 64, 5)
# > Data Train y: (868,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (41, 5)
# > Data Test X: (41, 64, 5)
# > Data Test y: (41,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 04:47:34.143658: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 04:47:34.143693: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:47:34.469042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:34.469787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:34.470620: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:47:34.618090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:34.619088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:34.619656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:47:34.757494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:34.758339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:34.759093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 200)           480800
#  dropout_1 (Dropout)         (None, 64, 200)           0
#  lstm_2 (LSTM)               (None, 100)               120400
#  dropout_2 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 1,250,901
# Trainable params: 1,250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, early_stopping])
# Out:
# 2024-12-31 04:47:35.013652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.014473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.015218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:35.119742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.120314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.120935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 04:47:35.285256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.285953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.286796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:35.528590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.529599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.530211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:35.621816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.622504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.623119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:35.714611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:35.715353: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:35.715951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:36.134010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:36.427045: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:36.534402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:36.613669: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:36.775501: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:36.958076: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/28 [>.............................] - ETA: 48s - loss: 0.0013
# 2024-12-31 04:47:37.094028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  2/28 [=>............................] - ETA: 1s - loss: 0.0012
#  4/28 [===>..........................] - ETA: 1s - loss: 8.3383e-04
#  6/28 [=====>........................] - ETA: 0s - loss: 7.0150e-04
#  8/28 [=======>......................] - ETA: 0s - loss: 6.2343e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 6.2310e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 6.0492e-04
# 14/28 [==============>...............] - ETA: 0s - loss: 5.8698e-04
# 16/28 [================>.............] - ETA: 0s - loss: 5.8319e-04
# 18/28 [==================>...........] - ETA: 0s - loss: 5.7307e-04
# 20/28 [====================>.........] - ETA: 0s - loss: 5.7278e-04
# 22/28 [======================>.......] - ETA: 0s - loss: 5.8646e-04
# 24/28 [========================>.....] - ETA: 0s - loss: 5.9046e-04
# 26/28 [==========================>...] - ETA: 0s - loss: 5.8511e-04
# 28/28 [==============================] - ETA: 0s - loss: 5.7680e-04
# 2024-12-31 04:47:38.477686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:38.478608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:38.479260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:38.564800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:38.565375: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:38.565988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:38.650747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:47:38.651325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:47:38.651901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:47:38.685703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:38.788468: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:38.838854: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:47:38.891433: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 4s 69ms/step - loss: 5.7680e-04 - val_loss: 6.5697e-04
# Epoch 2/1000
#  1/28 [>.............................] - ETA: 1s - loss: 3.4416e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.1901e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4415e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7445e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5886e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8001e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7915e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6386e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8202e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2403e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3759e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2615e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3065e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3607e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.3426e-04 - val_loss: 0.0026
# Epoch 3/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.8744e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0226e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1496e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5370e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7024e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3838e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2138e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4396e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2689e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3416e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4961e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4276e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5208e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3847e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.3641e-04 - val_loss: 0.0024
# Epoch 4/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8130e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.2096e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8592e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6364e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3013e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0636e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9662e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0742e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8393e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9464e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1473e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1276e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0958e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0097e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.0009e-04 - val_loss: 0.0020
# Epoch 5/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.4737e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.2393e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6342e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.9179e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2886e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9630e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6681e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6637e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4284e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5054e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7224e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8811e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8475e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.6597e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.6691e-04 - val_loss: 0.0013
# Epoch 6/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.5783e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.8923e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.2941e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3655e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2438e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6397e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0578e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4206e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3517e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3091e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2369e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1748e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0972e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0542e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0342e-04 - val_loss: 0.0027
# Epoch 7/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.3335e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0247e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5829e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6095e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0396e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8163e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5067e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1832e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1329e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9285e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3329e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2711e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2404e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2304e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2539e-04 - val_loss: 0.0030
# Epoch 8/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.5963e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.7933e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4572e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.9201e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.8488e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.7846e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2884e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.2278e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1786e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8290e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7690e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7039e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6387e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5716e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.5786e-04 - val_loss: 5.3936e-04
# Epoch 9/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.5146e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.6234e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4753e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9602e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5899e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3370e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5780e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6435e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4198e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2475e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3210e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2964e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1826e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0996e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0953e-04 - val_loss: 0.0028
# Epoch 10/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.3129e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.9282e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1044e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7551e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9174e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6913e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7747e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6805e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0402e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2937e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2625e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2556e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1361e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2051e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2087e-04 - val_loss: 0.0029
# Epoch 11/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 8.4000e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.6472e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9596e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0804e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9714e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.9779e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9123e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6760e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4427e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3356e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3076e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1144e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2248e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2159e-04 - val_loss: 0.0028
# Epoch 12/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.5669e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0072e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0723e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.8106e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.1012e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9063e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7524e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8422e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7945e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.7806e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5570e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5228e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5314e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4340e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4241e-04 - val_loss: 9.6460e-04
# Epoch 13/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.4369e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.1541e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.1634e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.6919e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.6979e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0779e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2749e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3475e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3058e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3130e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2317e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0951e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2015e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2014e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1856e-04 - val_loss: 0.0018
# Epoch 14/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.0278e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1697e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1165e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9268e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1130e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9120e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9119e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1139e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5529e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5895e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4679e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3899e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3982e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2281e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2656e-04 - val_loss: 0.0047
# Epoch 15/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0016
#  3/28 [==>...........................] - ETA: 0s - loss: 8.5471e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1333e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5440e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4460e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.4027e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.7923e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.5145e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.2681e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0052e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9490e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8716e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6685e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5617e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.5718e-04 - val_loss: 8.5677e-04
# Epoch 16/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.7356e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.4228e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4162e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.8391e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.6233e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.5702e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.3727e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.3954e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.3041e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0014e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8394e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7628e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.7024e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5018e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4936e-04 - val_loss: 7.7039e-04
# Epoch 17/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.7912e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.4296e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5702e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.1889e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2337e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9577e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6576e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.0332e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.8174e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9004e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9473e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8707e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6425e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5796e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.5681e-04 - val_loss: 5.1932e-04
# Epoch 18/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.2891e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.3796e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6706e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5778e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5429e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2628e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9891e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2055e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0612e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8950e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0607e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2785e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2579e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3323e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.3179e-04 - val_loss: 6.6876e-04
# Epoch 19/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.3131e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.8021e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4699e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3139e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7239e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7649e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6875e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.5773e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.3880e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6528e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8919e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0288e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1072e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3278e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.3334e-04 - val_loss: 0.0031
# Epoch 20/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 7.8814e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.2642e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3838e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6703e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4701e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2226e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1036e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2982e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2673e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2836e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1866e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0856e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1441e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.1413e-04 - val_loss: 5.8730e-04
# Epoch 21/1000
#  1/28 [>.............................] - ETA: 1s - loss: 9.0614e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.9759e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.6010e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9341e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7222e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5191e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3511e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5438e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3812e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4437e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4441e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2591e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0740e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0866e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0665e-04 - val_loss: 0.0012
# Epoch 22/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.0953e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4565e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4138e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.1691e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.9080e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.8509e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.4792e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.3623e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0568e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0475e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8484e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6564e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6813e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4828e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.4695e-04 - val_loss: 0.0015
# Epoch 23/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.5596e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.0543e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4042e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5244e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2039e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9762e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6896e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3682e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3592e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2369e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2346e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1935e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1712e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1692e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1641e-04 - val_loss: 0.0016
# Epoch 24/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.7102e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.5095e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4717e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0821e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3161e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8063e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5255e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4431e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3777e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4838e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4140e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3390e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2461e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2610e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2506e-04 - val_loss: 0.0014
# Epoch 25/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.1601e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.9502e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.6036e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7674e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7771e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9183e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3973e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4827e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3677e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3481e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3376e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3863e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2676e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2165e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2395e-04 - val_loss: 0.0019
# Epoch 26/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 6.9898e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5312e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7485e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4979e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2164e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2313e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2625e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1465e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1529e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0734e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0625e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0010e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1449e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1663e-04 - val_loss: 0.0035
# Epoch 27/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.9533e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.0766e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4130e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9443e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4049e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0619e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9033e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1145e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2485e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3445e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3743e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3783e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2873e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2759e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2609e-04 - val_loss: 6.4035e-04
# Epoch 28/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.0320e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7706e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4046e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.6764e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7329e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7596e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7490e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7665e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7423e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0161e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1736e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5256e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9308e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7783e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.7906e-04 - val_loss: 0.0012
# Epoch 29/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.9001e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7792e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8949e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9660e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8834e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7317e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5910e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.5137e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5117e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.3340e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.4244e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.5374e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8360e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8560e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 4.8426e-04 - val_loss: 8.6496e-04
# Epoch 30/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.6065e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.2389e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.2026e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7212e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9930e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9106e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0974e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1732e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2385e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5234e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5433e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5005e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3443e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2852e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2993e-04 - val_loss: 0.0017
# Epoch 31/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.5232e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.5631e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2061e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0788e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8420e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4693e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2765e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0754e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1357e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1743e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2075e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2635e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3843e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2793e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2960e-04 - val_loss: 0.0031
# Epoch 32/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.6180e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6670e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8874e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2564e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3804e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2007e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4904e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3207e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3250e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3113e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2259e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3425e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4381e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3065e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.3225e-04 - val_loss: 0.0012
# Epoch 33/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.0121e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.7384e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1910e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6277e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5041e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3187e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1075e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9354e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9379e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1573e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2422e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1126e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0787e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0555e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.0591e-04 - val_loss: 0.0028
# Epoch 34/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.5257e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7476e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6172e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6539e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2408e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1670e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4499e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5436e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5219e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5082e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3013e-04
# ...
# 17/28 [=================>............] - ETA: 0s - loss: 4.7037e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6991e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.6035e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.6376e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.7348e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8960e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9194e-04 - val_loss: 4.9403e-04
# Epoch 163/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0017
#  3/28 [==>...........................] - ETA: 1s - loss: 9.0662e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.5517e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.7975e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9784e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0653e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7955e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7846e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7391e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6691e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5682e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3457e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3528e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3754e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.3869e-04 - val_loss: 0.0030
# Epoch 164/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.1305e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4272e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4427e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0152e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0624e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4867e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5955e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3911e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1966e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2229e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3909e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2825e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1948e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2570e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2901e-04 - val_loss: 4.9125e-04
# Epoch 165/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0012
#  3/28 [==>...........................] - ETA: 0s - loss: 6.3261e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6664e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9982e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2016e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3344e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2309e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3027e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1502e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0039e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3673e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4177e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3807e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2546e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2394e-04 - val_loss: 0.0030
# Epoch 166/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.0425e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.6986e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3836e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9270e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2496e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0412e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0652e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0752e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9253e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1015e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0484e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8604e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8696e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0557e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0747e-04 - val_loss: 0.0026
# Epoch 167/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.5426e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9813e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8093e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7838e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.3485e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.3044e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6785e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6987e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.6581e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0576e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2466e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1293e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1552e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3958e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.3818e-04 - val_loss: 0.0013
# Epoch 168/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.5556e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1348e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7169e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0005e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0758e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1729e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1437e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1601e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1676e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0274e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0842e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0550e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0547e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9300e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9310e-04 - val_loss: 0.0011
# Epoch 169/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.6392e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7877e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.5571e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1895e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8401e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3821e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3103e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4543e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4714e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3069e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1171e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0649e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9973e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8949e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9283e-04 - val_loss: 7.1912e-04
# Epoch 170/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.1678e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.1199e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2502e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.2147e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0637e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5028e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4782e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6072e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4336e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2350e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1034e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0709e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0100e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1360e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1535e-04 - val_loss: 0.0029
# Epoch 171/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.8575e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9176e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3859e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7705e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9667e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7778e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8767e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7139e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6274e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4515e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4776e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3569e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2922e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2636e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2697e-04 - val_loss: 0.0013
# Epoch 172/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.4457e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.9573e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3451e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9863e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9484e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3137e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4504e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4673e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4183e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3343e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2269e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1398e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9688e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9359e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9421e-04 - val_loss: 5.2889e-04
# Epoch 173/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.0528e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.3517e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3867e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9225e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7777e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8955e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0942e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8339e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7947e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7480e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8865e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7776e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0865e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1163e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1145e-04 - val_loss: 5.5878e-04
# Epoch 174/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.6500e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1723e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.9654e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.4626e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6043e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3090e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1092e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9324e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1176e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1830e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4402e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5920e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6224e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5044e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.5537e-04 - val_loss: 0.0048
# Epoch 175/1000
#  1/28 [>.............................] - ETA: 1s - loss: 7.1117e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6608e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9631e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8156e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8736e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2891e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1848e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0260e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9418e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3144e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4848e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2698e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2706e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1325e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.1213e-04 - val_loss: 5.5313e-04
# Epoch 176/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.0877e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.6493e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.2220e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 3.9485e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2396e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.3337e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.4518e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7485e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5938e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6357e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7416e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7870e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9547e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8882e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.8989e-04 - val_loss: 7.7369e-04
# Epoch 177/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.2664e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.2341e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8877e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1935e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9943e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4613e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3995e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4790e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6036e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
