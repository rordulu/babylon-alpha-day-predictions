# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "TSLA"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:40:37.317068: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.126316  0.107328  0.128451  0.111703  0.121850  2020-10-15 00:00:00-04:00
# 1  0.130008  0.106779  0.125030  0.103445  0.108208  2020-10-16 00:00:00-04:00
# 2  0.122678  0.098861  0.115678  0.095519  0.124748  2020-10-19 00:00:00-04:00
# 3  0.109726  0.085370  0.106476  0.087548  0.102935  2020-10-20 00:00:00-04:00
# 4  0.101636  0.086432  0.108537  0.088175  0.106299  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.465245  0.457815  0.487208  0.461911  0.141738  2023-07-03 00:00:00-04:00
# 1  0.471494  0.456753  0.494209  0.469066  0.160334  2023-07-05 00:00:00-04:00
# 2  0.469536  0.446456  0.480939  0.453088  0.142753  2023-07-06 00:00:00-04:00
# 3  0.470448  0.448605  0.483441  0.447412  0.132187  2023-07-07 00:00:00-04:00
# 4  0.465192  0.439953  0.459067  0.434447  0.141329  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.394422  0.370233  0.400900  0.377448  0.118140  2024-01-02 00:00:00-05:00
# 1  0.380746  0.355450  0.378156  0.350629  0.143931  2024-01-03 00:00:00-05:00
# 2  0.365379  0.347541  0.382120  0.349231  0.114961  2024-01-04 00:00:00-05:00
# 3  0.358970  0.340694  0.374164  0.348047  0.098870  2024-01-05 00:00:00-05:00
# 4  0.357039  0.343693  0.375288  0.356009  0.087546  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:40:39.225221: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:40:39.225261: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:40:39.557877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:39.558882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:39.559422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:40:39.730736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:39.731692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:39.732265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:40:39.881727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:39.882590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:39.883233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:40:40.019581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.020564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.021122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:40:40.338450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.339200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.339944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:40.444137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.444721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.445265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:40:40.556421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.557806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.558533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:40.825809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.827027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.827743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:40.933235: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:40.934001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:40.934656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:41.036666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:41.037973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:41.038715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:41.498645: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:41.859086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:41.978561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:42.052521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:42.229893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:42.415546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:42.567198: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 39s - loss: 0.0010
#  2/20 [==>...........................] - ETA: 1s - loss: 0.0011
#  4/20 [=====>........................] - ETA: 0s - loss: 8.7627e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 7.3984e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 7.5454e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 7.6763e-04
# 12/20 [=================>............] - ETA: 0s - loss: 7.7743e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 7.5260e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 7.5177e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 7.5179e-04
# 20/20 [==============================] - ETA: 0s - loss: 7.5160e-04
# 2024-12-31 05:40:43.897373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:43.898551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:43.899186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:43.997048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:43.997962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:43.998828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:44.097527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:40:44.098590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:40:44.099272: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:40:44.139522: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:44.242679: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:44.296817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:40:44.357649: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 4s 95ms/step - loss: 7.5160e-04 - val_loss: 4.5505e-04 - lr: 3.3300e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1636e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.3041e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.0791e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.7395e-04
#  9/20 [============>.................] - ETA: 0s - loss: 7.4164e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 7.4556e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 7.1548e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 6.9518e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.8016e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 7.0748e-04
# 20/20 [==============================] - 1s 46ms/step - loss: 7.0382e-04 - val_loss: 4.1690e-04 - lr: 3.3300e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.8909e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.5642e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.8757e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 7.9775e-04
#  9/20 [============>.................] - ETA: 0s - loss: 7.2851e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 7.4830e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 7.3953e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 7.1780e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.9744e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.9171e-04
# 20/20 [==============================] - 1s 43ms/step - loss: 7.0031e-04 - val_loss: 4.2364e-04 - lr: 3.3300e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.3586e-04
#  3/20 [===>..........................] - ETA: 0s - loss:
-04
# 13/20 [==================>...........] - ETA: 0s - loss: 6.5156e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 6.9794e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.8974e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8475e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.8227e-04 - val_loss: 4.5455e-04 - lr: 3.6926e-05
# Epoch 73/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.9146e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.2837e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.2999e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 7.1935e-04
#  9/20 [============>.................] - ETA: 0s - loss: 6.3260e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 6.3561e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 6.6031e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 6.5342e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.8723e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8208e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.8194e-04 - val_loss: 4.6010e-04 - lr: 3.6926e-05
# Epoch 74/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.4109e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.0832e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.8217e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.5360e-04
#  9/20 [============>.................] - ETA: 0s - loss: 6.8696e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 6.8463e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 7.3179e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 7.1115e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.8370e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8909e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.8723e-04 - val_loss: 4.5599e-04 - lr: 3.6926e-05
# Epoch 75/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.8398e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.4069e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 7.0342e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 7.2908e-04
#  9/20 [============>.................] - ETA: 0s - loss: 7.3822e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 7.7080e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 7.1756e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 7.1100e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 7.1449e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8700e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.9271e-04 - val_loss: 4.5757e-04 - lr: 3.6926e-05
# Epoch 76/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.5084e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.1104e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.1929e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.9794e-04
#  9/20 [============>.................] - ETA: 0s - loss: 6.1952e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.8393e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 6.1644e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 6.4376e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.3364e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8582e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.9328e-04 - val_loss: 4.4896e-04 - lr: 3.6926e-05
# Epoch 77/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.2329e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.4437e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4482e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.9659e-04
#  9/20 [============>.................] - ETA: 0s - loss: 7.0350e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 6.7245e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 6.8845e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 6.9431e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.7889e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.8939e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.8858e-04 - val_loss: 4.5086e-04 - lr: 3.6926e-05
# Epoch 78/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.9550e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.2887e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.5371e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.9895e-04
#  9/20 [============>.................] - ETA: 0s - loss: 6.5688e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 6.6151e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 6.7475e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 7.0634e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 6.7975e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 6.5959e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 6.7604e-04 - val_loss: 4.6078e-04 - lr: 3.6926e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
