# %%
# Parameters
TICKER = "GOOGL"

# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 48
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 04:39:00.915931: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = "google_stock_price_processed_train"
data_file_name_validate = "google_stock_price_processed_validate"
data_file_name_test = "google_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

if TICKER is not None:
    data_train_df = data_train_df[data_train_df['TICKER'] == TICKER]
    data_validate_df = data_validate_df[data_validate_df['TICKER'] == TICKER]
    data_test_df = data_test_df[data_test_df['TICKER'] == TICKER]

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (932, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (41, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.095067  0.092815  0.114254  0.094749  0.133300  2019-10-17
# 1  0.096304  0.090671  0.109972  0.091093  0.221433  2019-10-18
# 2  0.095717  0.088612  0.109740  0.091411  0.149765  2019-10-21
# 3  0.093561  0.086664  0.110117  0.089795  0.149016  2019-10-22
# 4  0.090876  0.091155  0.110591  0.097671  0.124298  2019-10-23
# Validation Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.660064  0.652145  0.667228  0.653320  0.076514  2023-07-03
# 1  0.657521  0.674865  0.670659  0.673287  0.119899  2023-07-05
# 2  0.663193  0.653402  0.662830  0.656889  0.118822  2023-07-06
# 3  0.665638  0.659203  0.670949  0.649268  0.154589  2023-07-07
# 4  0.647839  0.633293  0.637602  0.617726  0.286412  2023-07-10
# Testing Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.848613  0.841590  0.841555  0.836595  0.144569  2024-01-02
# 1  0.838834  0.846182  0.848224  0.844312  0.132489  2024-01-03
# 2  0.851058  0.841783  0.844164  0.821933  0.124554  2024-01-04
# 3  0.836408  0.824139  0.832952  0.815663  0.093517  2024-01-05
# 4  0.832966  0.841831  0.842908  0.845952  0.117863  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (932, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (105, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (1099, 5)
#
#  Data Train Scaled: (932, 5)
# > Data Train X: (868, 64, 5)
# > Data Train y: (868,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (41, 5)
# > Data Test X: (41, 64, 5)
# > Data Test y: (41,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 04:39:02.751633: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 04:39:02.751671: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:39:03.085409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.086343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.087004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:39:03.233194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.233958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.234601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:39:03.383566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.384368: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.385248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 200)           480800
#  dropout_1 (Dropout)         (None, 64, 200)           0
#  lstm_2 (LSTM)               (None, 100)               120400
#  dropout_2 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 1,250,901
# Trainable params: 1,250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, early_stopping])
# Out:
# 2024-12-31 04:39:03.642927: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.643610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.644501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:03.771360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.771999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.772583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 04:39:03.953397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:03.954375: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:03.955155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:04.200593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:04.201564: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:04.202221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:04.293563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:04.294192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:04.294844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:04.387005: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:04.388087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:04.388851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:04.844238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.168149: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.292467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.370117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.547413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.738989: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:05.880463: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/28 [>.............................] - ETA: 52s - loss: 0.0030
#  2/28 [=>............................] - ETA: 2s - loss: 0.0017
#  4/28 [===>..........................] - ETA: 1s - loss: 0.0011
#  6/28 [=====>........................] - ETA: 1s - loss: 9.1196e-04
#  8/28 [=======>......................] - ETA: 0s - loss: 8.3389e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 7.8842e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 7.6365e-04
# 14/28 [==============>...............] - ETA: 0s - loss: 7.9998e-04
# 16/28 [================>.............] - ETA: 0s - loss: 7.7008e-04
# 18/28 [==================>...........] - ETA: 0s - loss: 7.7263e-04
# 20/28 [====================>.........] - ETA: 0s - loss: 7.6367e-04
# 22/28 [======================>.......] - ETA: 0s - loss: 7.4473e-04
# 24/28 [========================>.....] - ETA: 0s - loss: 7.3099e-04
# 26/28 [==========================>...] - ETA: 0s - loss: 7.2123e-04
# 28/28 [==============================] - ETA: 0s - loss: 7.2253e-04
# 2024-12-31 04:39:07.389490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:07.390522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:07.391063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:07.476631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:07.477233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:07.477773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:07.563523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:39:07.564101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:39:07.564668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:39:07.599035: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:07.695696: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:07.746606: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:39:07.802790: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 4s 73ms/step - loss: 7.2253e-04 - val_loss: 5.4419e-04
# Epoch 2/1000
#  1/28 [>.............................] - ETA: 1s - loss: 9.0791e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.8844e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4390e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.6467e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.9728e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.3632e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.2586e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.9838e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.6207e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.6085e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.3808e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.3327e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.2939e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.5778e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 6.5585e-04 - val_loss: 0.0013
# Epoch 3/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8976e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.6618e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4216e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7521e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6228e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2913e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6652e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8801e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9111e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9872e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9451e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9941e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9472e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8843e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.8739e-04 - val_loss: 0.0015
# Epoch 4/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.1328e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4931e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4654e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1195e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5893e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6786e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.9184e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.0609e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1802e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.5690e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.4785e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.5249e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3370e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.2725e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3060e-04 - val_loss: 0.0056
# Epoch 5/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0022
#  3/28 [==>...........................] - ETA: 0s - loss: 0.0012
#  5/28 [====>.........................] - ETA: 0s - loss: 0.0010
#  7/28 [======>.......................] - ETA: 0s - loss: 8.6755e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.7943e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.2732e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.2183e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.8721e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.9317e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.9306e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.7149e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.5009e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.2700e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.2996e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3159e-04 - val_loss: 0.0042
# Epoch 6/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0012
#  3/28 [==>...........................] - ETA: 0s - loss: 7.5058e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.2336e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6607e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.8309e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.8390e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.9613e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.9590e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.7093e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.3944e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.1516e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0434e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1189e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3270e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.3187e-04 - val_loss: 6.5409e-04
# Epoch 7/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.2684e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.3696e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.2468e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5690e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2228e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2965e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.9304e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7955e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7799e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8477e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.5509e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.2855e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.2000e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1184e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.1236e-04 - val_loss: 0.0041
# Epoch 8/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0013
#  3/28 [==>...........................] - ETA: 0s - loss: 8.1308e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1010e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.0168e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.8069e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.5803e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2338e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.3580e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.3953e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.3084e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.4990e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.3262e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3155e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1616e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.1546e-04 - val_loss: 0.0015
# Epoch 9/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.9061e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.2781e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4567e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9882e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.5627e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3191e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.0664e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.8386e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.5716e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.4625e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.3196e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1811e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1267e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1383e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 6.1469e-04 - val_loss: 0.0011
# Epoch 10/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.5823e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.3395e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5360e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0678e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6816e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6812e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8543e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.0559e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.3152e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2913e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.5160e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.5072e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3766e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1807e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.1928e-04 - val_loss: 0.0012
# Epoch 11/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.8172e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.5247e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 8.3588e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.4000e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.1677e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.7357e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.5136e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.3157e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1430e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2309e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.1519e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1148e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3919e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.2847e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 6.3046e-04 - val_loss: 0.0039
# Epoch 12/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 9.2227e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3605e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 8.4177e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 8.1924e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.8830e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.6323e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 7.4076e-04
# 17/28 [=================>............] - ETA: 0s - loss: 7.0167e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.7593e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.5972e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.6706e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.4850e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3237e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3144e-04 - val_loss: 5.4290e-04
# Epoch 13/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0010
#  3/28 [==>...........................] - ETA: 0s - loss: 6.8588e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.0887e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5931e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3605e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.5076e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2548e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9871e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1226e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.3825e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2862e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.3175e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1662e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1528e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.1761e-04 - val_loss: 9.9005e-04
# Epoch 14/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.1277e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7914e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.6262e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2166e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4150e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7281e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8041e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7209e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5088e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6060e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.6705e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7015e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9805e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9442e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.9477e-04 - val_loss: 9.7480e-04
# Epoch 15/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.7668e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 9.7487e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 8.0219e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 8.0304e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.2753e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.9710e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.6412e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.2854e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1095e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0101e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.0675e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0749e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0306e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1475e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.1621e-04 - val_loss: 0.0021
# Epoch 16/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.9992e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8031e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2592e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7257e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2919e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4728e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7848e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6608e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6126e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8791e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9599e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9328e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8972e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9671e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.9444e-04 - val_loss: 0.0019
# Epoch 17/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.9126e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 0.0012
#  5/28 [====>.........................] - ETA: 0s - loss: 0.0011
#  7/28 [======>.......................] - ETA: 0s - loss: 9.1599e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 8.7252e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 8.1100e-04
# 13/28 [============>.................] - ETA: 0s - loss: 8.0098e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 7.4293e-04
# 17/28 [=================>............] - ETA: 0s - loss: 7.4113e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 7.3365e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 7.0968e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.9648e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.7379e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.6823e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.6702e-04 - val_loss: 8.8352e-04
# Epoch 18/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.5081e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.4778e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3261e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3208e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3169e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.1134e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7651e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6362e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4485e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5628e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9686e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1815e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3190e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1468e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.1482e-04 - val_loss: 0.0021
# Epoch 19/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8630e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4835e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2442e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7055e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7301e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8456e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7648e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7819e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6744e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8154e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8026e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8406e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0020e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.2150e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.2027e-04 - val_loss: 5.4740e-04
# Epoch 20/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.8517e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6994e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8682e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.4444e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6246e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6380e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5981e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6090e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7068e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9436e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8449e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7692e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6760e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7168e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.7348e-04 - val_loss: 8.3752e-04
# Epoch 21/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.3863e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7278e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.0695e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5498e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3674e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2917e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.3088e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.2863e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0922e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2351e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2119e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0898e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0098e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8373e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.8873e-04 - val_loss: 0.0021
# Epoch 22/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.1158e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.0347e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1379e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9221e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0252e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2663e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.1557e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.1924e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9679e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8629e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7372e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5450e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6688e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8377e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.8135e-04 - val_loss: 5.6969e-04
# Epoch 23/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.4071e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.2300e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3133e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.8215e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4393e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.4275e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.1239e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.1053e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0757e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0375e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9315e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0444e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0027e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9240e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.9410e-04 - val_loss: 5.7130e-04
# Epoch 24/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 8.6196e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.2840e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.4746e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4754e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3722e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.3746e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.1346e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9509e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.7696e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.8383e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.5822e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.3391e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3092e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.3471e-04 - val_loss: 5.5394e-04
# Epoch 25/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0015
#  3/28 [==>...........................] - ETA: 0s - loss: 8.9004e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3469e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.3941e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.5494e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.4151e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.9351e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.8055e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.5842e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.3259e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2642e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.3261e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.5050e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3766e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.3654e-04 - val_loss: 0.0017
# Epoch 26/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.4944e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1129e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4784e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6364e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4105e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.1048e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.6882e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.6708e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.4241e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.4854e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2710e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1064e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1101e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9298e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.9113e-04 - val_loss: 9.2708e-04
# Epoch 27/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.9342e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.4236e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1794e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6233e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4309e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0072e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8628e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5809e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0273e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9163e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9229e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9718e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9306e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8404e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.8968e-04 - val_loss: 9.9047e-04
# Epoch 28/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0016
#  3/28 [==>...........................] - ETA: 0s - loss: 0.0010
#  5/28 [====>.........................] - ETA: 0s - loss: 8.4059e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.5109e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.5289e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.2328e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.0840e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.8735e-04
# 17/28 [=================>............] - ETA: 0s - loss: 7.1983e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 7.1264e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.8227e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.6557e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.5419e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3671e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 6.3778e-04 - val_loss: 0.0012
# Epoch 29/1000
#  1/28 [>.............................] - ETA: 1s - loss: 7.8608e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.6527e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8988e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.4065e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.6757e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3099e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2017e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.1733e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1391e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0461e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2222e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1356e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.2239e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3179e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 6.3270e-04 - val_loss: 5.4011e-04
# Epoch 30/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.6151e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.2093e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8715e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2742e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2805e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4836e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3092e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6858e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9860e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0044e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2197e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.2112e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0734e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9734e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.9613e-04 - val_loss: 0.0036
# Epoch 31/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0012
#  3/28 [==>...........................] - ETA: 0s - loss: 8.3481e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1350e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6786e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.9485e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3061e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.4246e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.1952e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9201e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9053e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9163e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8027e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0919e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3705e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3568e-04 - val_loss: 0.0015
# Epoch 32/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0013
#  3/28 [==>...........................] - ETA: 0s - loss: 7.4655e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.7404e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0217e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8228e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7542e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6196e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6572e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6487e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5694e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9113e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9245e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9589e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9736e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 6.0297e-04 - val_loss: 5.9043e-04
# Epoch 33/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.3554e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8002e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5459e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.8099e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.5788e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3001e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.5563e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.4478e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.5123e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2719e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.3913e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.3261e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.2935e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3238e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3121e-04 - val_loss: 6.5798e-04
# Epoch 34/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.4488e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0266e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2013e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0691e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0865e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8229e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8965e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7260e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5567e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.1041e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.3502e-04
# ...
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7216e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7246e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9661e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8182e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7616e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.8638e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2700e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.1129e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0681e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9293e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.0349e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.0771e-04 - val_loss: 5.0411e-04
# Epoch 70/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0012
#  3/28 [==>...........................] - ETA: 0s - loss: 7.8469e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.0653e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6849e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.6547e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2424e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2150e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9923e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.8717e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6579e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8803e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9177e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1857e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.1663e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 6.1436e-04 - val_loss: 5.7886e-04
# Epoch 71/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.1440e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.6272e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2579e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3167e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7749e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4240e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1030e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2383e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5106e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8928e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8347e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8632e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9254e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9708e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.9515e-04 - val_loss: 0.0016
# Epoch 72/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.0544e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.5947e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4944e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6586e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0948e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.6628e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.6009e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.4177e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1920e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.1649e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9636e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9505e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8027e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8161e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.8072e-04 - val_loss: 5.4162e-04
# Epoch 73/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.4695e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0307e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.3076e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3003e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3391e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0461e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7264e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7406e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.8318e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.7576e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7966e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6070e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6261e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5650e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 5.5810e-04 - val_loss: 5.7179e-04
# Epoch 74/1000
#  1/28 [>.............................] - ETA: 1s - loss: 7.6983e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.3066e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0171e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7561e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9639e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8430e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7206e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6378e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4744e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2997e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2672e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3633e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3943e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4245e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.4353e-04 - val_loss: 0.0060
# Epoch 75/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0016
#  3/28 [==>...........................] - ETA: 0s - loss: 0.0011
#  5/28 [====>.........................] - ETA: 0s - loss: 8.8383e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 8.2758e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.6617e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.2036e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.7931e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.5648e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.7341e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.6041e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.6341e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.4895e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.5585e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.3670e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.3588e-04 - val_loss: 0.0024
# Epoch 76/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.7929e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1276e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.9157e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7069e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9141e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9412e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.0324e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.3551e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1570e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0389e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9413e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9094e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.7706e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7999e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.7969e-04 - val_loss: 5.0810e-04
# Epoch 77/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0013
#  3/28 [==>...........................] - ETA: 0s - loss: 9.0992e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1011e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.0662e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.6242e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0593e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8422e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8608e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9683e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9200e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9704e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.8861e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9484e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.9269e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.9098e-04 - val_loss: 5.0658e-04
# Epoch 78/1000
#  1/28 [>.............................] - ETA: 1s - loss: 9.3728e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.6862e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7649e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3854e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0903e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3278e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6829e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6273e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3982e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8428e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9787e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9494e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8455e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.0197e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 6.0053e-04 - val_loss: 0.0019
# Epoch 79/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.2845e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.0245e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3003e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0635e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4493e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6920e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7036e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7072e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6490e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5297e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5660e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6095e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6621e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.8769e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.8537e-04 - val_loss: 0.0010
# Epoch 80/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.0489e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.2681e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.0290e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6406e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2891e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0052e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8179e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7823e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6858e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6904e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5482e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7042e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8704e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7824e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.7637e-04 - val_loss: 0.0012
# Epoch 81/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.5617e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.0564e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3546e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.5870e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.6525e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8953e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1242e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4624e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4563e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6766e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5147e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6195e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5528e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.6538e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.7221e-04 - val_loss: 6.7540e-04
# Epoch 82/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0018
#  3/28 [==>...........................] - ETA: 0s - loss: 8.9644e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 8.0672e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.4336e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.0552e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.9624e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.5532e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.4018e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.1163e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0929e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.4119e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.1878e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.1264e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.2214e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 6.2037e-04 - val_loss: 0.0015
# Epoch 83/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.7006e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1886e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6892e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0031e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8467e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9756e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3161e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0324e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3628e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5375e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4006e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4643e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4435e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5138e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.4909e-04 - val_loss: 0.0011
# Epoch 84/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.1413e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.1094e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.5023e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.2133e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
