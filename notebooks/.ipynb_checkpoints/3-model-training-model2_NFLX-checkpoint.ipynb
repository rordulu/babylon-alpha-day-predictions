# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "NFLX"

# %%
# Global parameters

TICKER = 'GOOGL'  # Default value, overwritten by papermill

NUM_EPOCH = 1000
STARTING_LR = 0.0001
SEQUENCE_SIZE = 128
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 100
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization, Reshape
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 19:21:03.101996: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.011252  0.007067  0.013574  0.018332  0.192277  2020-10-15 00:00:00-04:00
# 1  0.018348  0.009602  0.020447  0.023352  0.218478  2020-10-16 00:00:00-04:00
# 2  0.024121  0.012100  0.006004  0.007859  0.179317  2020-10-19 00:00:00-04:00
# 3  0.002494  0.008047  0.004997  0.016531  0.284121  2020-10-20 00:00:00-04:00
# 4  0.021631  0.024639  0.024388  0.030858  0.447896  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.355315  0.341472  0.360843  0.364105  0.045272  2023-07-03 00:00:00-04:00
# 1  0.355315  0.360916  0.364252  0.379290  0.160445  2023-07-05 00:00:00-04:00
# 2  0.359901  0.342356  0.357351  0.365829  0.135512  2023-07-06 00:00:00-04:00
# 3  0.362358  0.348382  0.365666  0.360658  0.108709  2023-07-07 00:00:00-04:00
# 4  0.347618  0.326367  0.338558  0.335788  0.228323  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.513446  0.496221  0.507688  0.514065  0.126433  2024-01-02 00:00:00-05:00
# 1  0.502800  0.497667  0.512677  0.520221  0.130831  2024-01-03 00:00:00-05:00
# 2  0.512382  0.493891  0.506607  0.499455  0.156520  2024-01-04 00:00:00-05:00
# 3  0.498706  0.477821  0.496629  0.494037  0.115851  2024-01-05 00:00:00-05:00
# 4  0.494939  0.492686  0.505859  0.519564  0.106174  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        up_by_1_percent = 1.0 if data[i, target_attr_idx] / data[i-1, target_attr_idx] > 1.01 else 0.0
        data_y.append(up_by_1_percent)
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (254, 5)
# inside construct_lstm_data with shape: (168, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (552, 128, 5)
# > Data Train y: (552,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 128, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 128, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
class AppendParametersLayer(tf.keras.layers.Layer):
    def call(self, inputs):
        inner_layer_output, extra_params = inputs
        return tf.concat([inner_layer_output, extra_params], axis=-1)

# %%
from tensorflow.keras.layers import Concatenate

input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

cnn = Conv1D(32, 3)(input_layer)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(32,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(64,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3, strides=2)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3)(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Dense(256)(cnn)
# cnn = Reshape((64, 256))(cnn)  # Align shape with `input_denser`
from tensorflow.keras.layers import ZeroPadding1D, Cropping1D

# cnn = ZeroPadding1D(padding=(30))(cnn)
# cnn = Cropping1D(cropping=(0,1))(cnn)  # Remove 1 from the beginning

# input_denser = Dense(256, kernel_initializer=tf.keras.initializers.HeUniform())(input_layer)

# input_to_lstm = Concatenate()([cnn, input_denser])

# Add first LSTM layer and dropout regularization layer
lstm = LSTM(units = 800, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 800, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 200, return_sequences = True)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 100)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = Dense(1)(lstm)
# Out:
# 2024-12-31 19:21:04.963317: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 19:21:04.963357: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-12-31 19:21:05.725986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:05.726808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:05.727597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:06.187833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:06.188787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:06.189366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:06.369619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:06.370184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:06.370825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:06.527599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:06.528487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:06.529061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:06.656619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:06.657333: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:06.657864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# # # Add input layer
# regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add second LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 400, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add third LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 200, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# # Add forth LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 100))
# regressor.add(Dropout(rate = 0.2))

# %%
from tensorflow.keras.models import Model

# # Add last dense layer/output layer
# regressor.add(Dense(1))
# regressor.summary()
regressor = Model(input_layer,lstm)
regressor.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 5)]          0
#  conv1d (Conv1D)             (None, 126, 32)           512
#  p_re_lu (PReLU)             (None, 126, 32)           32
#  conv1d_1 (Conv1D)           (None, 124, 32)           3104
#  p_re_lu_1 (PReLU)           (None, 124, 32)           32
#  conv1d_2 (Conv1D)           (None, 61, 64)            6208
#  p_re_lu_2 (PReLU)           (None, 61, 64)            64
#  conv1d_3 (Conv1D)           (None, 59, 64)            12352
#  p_re_lu_3 (PReLU)           (None, 59, 64)            64
#  conv1d_4 (Conv1D)           (None, 29, 128)           24704
#  p_re_lu_4 (PReLU)           (None, 29, 128)           128
#  conv1d_5 (Conv1D)           (None, 27, 128)           49280
#  p_re_lu_5 (PReLU)           (None, 27, 128)           128
#  dense (Dense)               (None, 27, 256)           33024
#  lstm (LSTM)                 (None, 27, 800)           3382400
#  dropout (Dropout)           (None, 27, 800)           0
#  lstm_1 (LSTM)               (None, 27, 800)           5123200
#  dropout_1 (Dropout)         (None, 27, 800)           0
#  lstm_2 (LSTM)               (None, 27, 400)           1921600
#  dropout_2 (Dropout)         (None, 27, 400)           0
#  lstm_3 (LSTM)               (None, 27, 200)           480800
#  dropout_3 (Dropout)         (None, 27, 200)           0
#  lstm_4 (LSTM)               (None, 100)               120400
#  dropout_4 (Dropout)         (None, 100)               0
#  dense_1 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 11,158,133
# Trainable params: 11,158,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K


optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(optimizer=optimizer, loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-16             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
try:
    best_model = load_model(model_location + model_name)
    regressor = best_model
    print(f"Using already trained model")
except:
    print(f"Building brand new model")
# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 19:21:07.428676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:07.429656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:07.430261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:07.880522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:07.881413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:07.881988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:08.023176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.023820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.024420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:08.126631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.127550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.128127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:08.220947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.221593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.222176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 19:21:08.793082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.793925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.794630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:08.883842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.884689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.885319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:08.973966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:08.974651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:08.975221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:09.064853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:09.065691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:09.066337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:09.154763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:09.155380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:09.155991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:09.838906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:10.496788: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:10.603966: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:10.671546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:10.741705: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:10.814370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:11.007475: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:11.182815: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:11.300691: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:11.432335: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:11.541178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/18 [>.............................] - ETA: 54s - loss: 0.2255
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2191
#  3/18 [====>.........................] - ETA: 1s - loss: 0.2195
#  4/18 [=====>........................] - ETA: 1s - loss: 0.2240
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2282
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2342
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2334
#  8/18 [============>.................] - ETA: 0s - loss: 0.2329
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2360
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2367
# 11/18 [=================>............] - ETA: 0s - loss: 0.2387
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2390
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2401
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2387
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2394
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2384
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2398
# 18/18 [==============================] - ETA: 0s - loss: 0.2395
# 2024-12-31 19:21:13.712307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:13.713394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:13.714351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:13.827177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:13.828141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:13.829479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:13.976294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:13.977668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:13.978461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:14.101503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:14.102330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:14.103317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:14.219899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 19:21:14.221295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 19:21:14.221961: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 19:21:14.287416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:14.637828: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:14.695360: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:14.767171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:14.830114: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 19:21:14.894241: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 18/18 [==============================] - 7s 220ms/step - loss: 0.2395 - val_loss: 0.2539 - lr: 1.0000e-04
# Epoch 2/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2307
#  2/18 [==>...........................] - ETA: 1s - loss: 0.2263
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2323
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2422
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2393
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2401
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2409
#  8/18 [============>.................] - ETA: 0s - loss: 0.2429
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2419
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2429
# 11/18 [=================>............] - ETA: 0s - loss: 0.2410
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2403
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2390
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2389
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2405
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2419
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2417
# 18/18 [==============================] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - 2s 89ms/step - loss: 0.2413 - val_loss: 0.2515 - lr: 1.0000e-04
# Epoch 3/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2136
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2360
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2423
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2468
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2418
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2447
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2447
#  8/18 [============>.................] - ETA: 0s - loss: 0.2385
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2366
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2352
# 11/18 [=================>............] - ETA: 0s - loss: 0.2359
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2400
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2433
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2424
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2420
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2437
# 18/18 [==============================] - ETA: 0s - loss: 0.2433
# 18/18 [==============================] - 1s 67ms/step - loss: 0.2433 - val_loss: 0.2607 - lr: 1.0000e-04
# Epoch 4/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2558
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2652
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2659
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2615
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2574
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2525
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2516
#  8/18 [============>.................] - ETA: 0s - loss: 0.2465
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2434
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2437
# 11/18 [=================>............] - ETA: 0s - loss: 0.2445
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2441
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2450
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2444
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2446
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2440
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2427
# 18/18 [==============================] - ETA: 0s - loss: 0.2421
# 18/18 [==============================] - 1s 66ms/step - loss: 0.2421 - val_loss: 0.2617 - lr: 1.0000e-04
# Epoch 5/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2667
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2580
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2414
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2449
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2402
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2391
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2390
#  8/18 [============>.................] - ETA: 0s - loss: 0.2379
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2348
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2347
# 11/18 [=================>............] - ETA: 0s - loss: 0.2354
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2369
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2421
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2428
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2420
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2431
# 18/18 [==============================] - ETA: 0s - loss: 0.2433
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2433 - val_loss: 0.2575 - lr: 1.0000e-04
# Epoch 6/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2376
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2367
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2360
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2321
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2320
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2318
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2367
#  8/18 [============>.................] - ETA: 0s - loss: 0.2347
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2346
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2334
# 11/18 [=================>............] - ETA: 0s - loss: 0.2341
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2361
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2342
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2363
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2380
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2389
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2392
# 18/18 [==============================] - ETA: 0s - loss: 0.2394
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2394 - val_loss: 0.2530 - lr: 1.0000e-04
# Epoch 7/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2302
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2236
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2232
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2278
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2295
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2298
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2292
#  8/18 [============>.................] - ETA: 0s - loss: 0.2299
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2341
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2354
# 11/18 [=================>............] - ETA: 0s - loss: 0.2380
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2388
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2375
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2370
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2369
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - ETA: 0s - loss: 0.2418
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2418 - val_loss: 0.2535 - lr: 1.0000e-04
# Epoch 8/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2335
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2461
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2413
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2415
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2432
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2441
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2450
#  8/18 [============>.................] - ETA: 0s - loss: 0.2458
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2450
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2439
# 11/18 [=================>............] - ETA: 0s - loss: 0.2437
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2438
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2441
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2445
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2439
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2427
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2427
# 18/18 [==============================] - ETA: 0s - loss: 0.2426
# 18/18 [==============================] - 1s 64ms/step - loss: 0.2426 - val_loss: 0.2565 - lr: 1.0000e-04
# Epoch 9/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2632
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2479
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2484
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2469
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2445
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2440
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2405
#  8/18 [============>.................] - ETA: 0s - loss: 0.2404
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2381
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2353
# 11/18 [=================>............] - ETA: 0s - loss: 0.2354
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2368
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2358
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2369
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2396
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2394
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2404
# 18/18 [==============================] - ETA: 0s - loss: 0.2402
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2402 - val_loss: 0.2595 - lr: 1.0000e-04
# Epoch 10/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2532
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2486
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2458
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2454
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2446
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2403
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2384
#  8/18 [============>.................] - ETA: 0s - loss: 0.2398
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2389
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2392
# 11/18 [=================>............] - ETA: 0s - loss: 0.2389
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2405
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2396
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2405
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2394
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2406
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - ETA: 0s - loss: 0.2414
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2414 - val_loss: 0.2563 - lr: 1.0000e-04
# Epoch 11/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2206
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2272
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2411
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2316
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2280
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2304
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2355
#  8/18 [============>.................] - ETA: 0s - loss: 0.2316
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2372
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2399
# 11/18 [=================>............] - ETA: 0s - loss: 0.2344
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2368
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2374
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2371
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2386
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2382
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2380
# 18/18 [==============================] - ETA: 0s - loss: 0.2397
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2397 - val_loss: 0.2538 - lr: 1.0000e-04
# Epoch 12/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2471
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2560
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2495
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2415
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2391
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2386
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2417
#  8/18 [============>.................] - ETA: 0s - loss: 0.2436
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2430
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2422
# 11/18 [=================>............] - ETA: 0s - loss: 0.2450
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2448
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2441
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2437
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2434
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2430
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2426
# 18/18 [==============================] - ETA: 0s - loss: 0.2425
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2425 - val_loss: 0.2536 - lr: 1.0000e-04
# Epoch 13/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2344
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2454
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2512
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2433
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2395
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2418
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2425
#  8/18 [============>.................] - ETA: 0s - loss: 0.2428
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2414
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2393
# 11/18 [=================>............] - ETA: 0s - loss: 0.2378
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2361
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2332
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2330
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2353
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2383
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2398
# 18/18 [==============================] - ETA: 0s - loss: 0.2412
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2412 - val_loss: 0.2593 - lr: 1.0000e-04
# Epoch 14/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2211
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2199
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2269
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2256
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2333
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2338
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2366
#  8/18 [============>.................] - ETA: 0s - loss: 0.2383
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2402
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2407
# 11/18 [=================>............] - ETA: 0s - loss: 0.2416
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2405
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2415
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2420
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2430
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2429
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2416
# 18/18 [==============================] - ETA: 0s - loss: 0.2411
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2411 - val_loss: 0.2525 - lr: 1.0000e-04
# Epoch 15/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2500
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2482
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2457
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2453
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2423
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2400
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2398
#  8/18 [============>.................] - ETA: 0s - loss: 0.2412
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2387
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2365
# 11/18 [=================>............] - ETA: 0s - loss: 0.2383
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2415
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2383
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2405
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2411
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2395
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2400
# 18/18 [==============================] - ETA: 0s - loss: 0.2391
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2391 - val_loss: 0.2591 - lr: 1.0000e-04
# Epoch 16/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2142
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2239
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2295
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2293
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2307
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2312
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2340
#  8/18 [============>.................] - ETA: 0s - loss: 0.2354
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2360
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2375
# 11/18 [=================>............] - ETA: 0s - loss: 0.2366
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2387
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2384
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2378
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2381
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2383
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2392
# 18/18 [==============================] - ETA: 0s - loss: 0.2394
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2394 - val_loss: 0.2527 - lr: 1.0000e-04
# Epoch 17/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2681
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2558
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2481
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2452
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2442
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2435
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2407
#  8/18 [============>.................] - ETA: 0s - loss: 0.2429
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2395
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2405
# 11/18 [=================>............] - ETA: 0s - loss: 0.2394
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2406
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2389
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2400
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2412
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2406
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2410
# 18/18 [==============================] - ETA: 0s - loss: 0.2406
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2406 - val_loss: 0.2554 - lr: 1.0000e-04
# Epoch 18/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2232
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2459
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2455
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2478
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2499
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2484
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2483
#  8/18 [============>.................] - ETA: 0s - loss: 0.2475
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2476
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2459
# 11/18 [=================>............] - ETA: 0s - loss: 0.2448
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2453
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2447
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2445
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2444
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2446
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2432
# 18/18 [==============================] - ETA: 0s - loss: 0.2429
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2429 - val_loss: 0.2621 - lr: 1.0000e-04
# Epoch 19/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2494
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2355
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2443
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2457
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2415
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2425
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2397
#  8/18 [============>.................] - ETA: 0s - loss: 0.2396
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2437
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2432
# 11/18 [=================>............] - ETA: 0s - loss: 0.2422
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2435
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2443
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2434
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2437
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2424
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2419
# 18/18 [==============================] - ETA: 0s - loss: 0.2417
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2417 - val_loss: 0.2540 - lr: 1.0000e-04
# Epoch 20/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2584
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2393
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2377
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2331
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2326
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2343
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2344
#  8/18 [============>.................] - ETA: 0s - loss: 0.2379
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2402
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2418
# 11/18 [=================>............] - ETA: 0s - loss: 0.2412
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2407
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2427
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2425
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2405
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2408
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2408
# 18/18 [==============================] - ETA: 0s - loss: 0.2399
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2399 - val_loss: 0.2542 - lr: 1.0000e-04
# Epoch 21/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2731
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2683
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2498
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2473
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2435
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2499
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2552
#  8/18 [============>.................] - ETA: 0s - loss: 0.2532
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2543
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2491
# 11/18 [=================>............] - ETA: 0s - loss: 0.2452
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2482
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2471
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2461
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2451
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2431
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2415
# 18/18 [==============================] - ETA: 0s - loss: 0.2413
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2413 - val_loss: 0.2576 - lr: 1.0000e-04
# Epoch 22/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2217
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2282
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2348
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2368
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2483
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2465
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2438
#  8/18 [============>.................] - ETA: 0s - loss: 0.2441
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2436
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2420
# 11/18 [=================>............] - ETA: 0s - loss: 0.2426
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2426
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2398
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2412
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2398
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2412
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2412
# ...
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2309
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2311
# 18/18 [==============================] - ETA: 0s - loss: 0.2308
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2308 - val_loss: 0.2568 - lr: 3.3300e-05
# Epoch 61/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2218
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2235
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2410
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2326
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2264
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2243
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2192
#  8/18 [============>.................] - ETA: 0s - loss: 0.2239
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2241
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2279
# 11/18 [=================>............] - ETA: 0s - loss: 0.2253
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2249
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2268
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2282
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2270
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2261
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2298
# 18/18 [==============================] - ETA: 0s - loss: 0.2296
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2296 - val_loss: 0.2763 - lr: 3.3300e-05
# Epoch 62/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2277
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2091
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2223
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2203
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2281
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2279
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2265
#  8/18 [============>.................] - ETA: 0s - loss: 0.2341
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2321
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2290
# 11/18 [=================>............] - ETA: 0s - loss: 0.2269
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2253
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2260
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2278
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2275
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2271
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2272
# 18/18 [==============================] - ETA: 0s - loss: 0.2276
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2276 - val_loss: 0.2546 - lr: 3.3300e-05
# Epoch 63/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2549
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2560
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2363
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2297
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2347
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2314
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2339
#  8/18 [============>.................] - ETA: 0s - loss: 0.2321
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2334
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2355
# 11/18 [=================>............] - ETA: 0s - loss: 0.2320
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2289
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2288
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2272
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2272
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2288
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2295
# 18/18 [==============================] - ETA: 0s - loss: 0.2297
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2297 - val_loss: 0.2694 - lr: 3.3300e-05
# Epoch 64/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2074
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2179
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2166
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2163
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2231
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2239
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2255
#  8/18 [============>.................] - ETA: 0s - loss: 0.2281
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2259
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2270
# 11/18 [=================>............] - ETA: 0s - loss: 0.2265
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2284
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2279
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2273
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2267
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2259
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2264
# 18/18 [==============================] - ETA: 0s - loss: 0.2269
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2269 - val_loss: 0.2615 - lr: 3.3300e-05
# Epoch 65/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2083
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2337
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2242
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2295
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2419
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2371
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2342
#  8/18 [============>.................] - ETA: 0s - loss: 0.2316
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2297
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2277
# 11/18 [=================>............] - ETA: 0s - loss: 0.2275
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2248
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2241
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2274
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2309
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2323
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2295
# 18/18 [==============================] - ETA: 0s - loss: 0.2286
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2286 - val_loss: 0.2636 - lr: 3.3300e-05
# Epoch 66/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2379
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2229
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2296
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2230
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2246
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2225
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2200
#  8/18 [============>.................] - ETA: 0s - loss: 0.2249
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2273
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2300
# 11/18 [=================>............] - ETA: 0s - loss: 0.2327
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2304
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2281
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2258
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2283
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2260
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2262
# 18/18 [==============================] - ETA: 0s - loss: 0.2263
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2263 - val_loss: 0.2595 - lr: 3.3300e-05
# Epoch 67/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2097
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2176
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2208
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2190
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2187
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2173
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2181
#  8/18 [============>.................] - ETA: 0s - loss: 0.2189
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2198
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2190
# 11/18 [=================>............] - ETA: 0s - loss: 0.2210
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2222
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2218
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2229
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2240
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2243
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2237
# 18/18 [==============================] - ETA: 0s - loss: 0.2239
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2239 - val_loss: 0.2654 - lr: 1.1089e-05
# Epoch 68/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.1916
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2046
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2119
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2168
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2145
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2211
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2174
#  8/18 [============>.................] - ETA: 0s - loss: 0.2193
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2244
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2254
# 11/18 [=================>............] - ETA: 0s - loss: 0.2252
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2222
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2230
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2195
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2223
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2246
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2244
# 18/18 [==============================] - ETA: 0s - loss: 0.2245
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2245 - val_loss: 0.2690 - lr: 1.1089e-05
# Epoch 69/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.2267
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2392
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2254
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2234
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2286
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2219
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2187
#  8/18 [============>.................] - ETA: 0s - loss: 0.2228
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2240
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2239
# 11/18 [=================>............] - ETA: 0s - loss: 0.2242
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2243
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2241
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2259
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2237
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2229
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2209
# 18/18 [==============================] - ETA: 0s - loss: 0.2213
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2213 - val_loss: 0.2625 - lr: 1.1089e-05
# Epoch 70/1000
#  1/18 [>.............................] - ETA: 1s - loss: 0.1919
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2278
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2141
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2137
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2131
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2121
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2131
#  8/18 [============>.................] - ETA: 0s - loss: 0.2129
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2132
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2152
# 11/18 [=================>............] - ETA: 0s - loss: 0.2125
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2159
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2142
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2185
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2180
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2172
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2185
# 18/18 [==============================] - ETA: 0s - loss: 0.2196
# 18/18 [==============================] - 1s 62ms/step - loss: 0.2196 - val_loss: 0.2760 - lr: 1.1089e-05
# Epoch 71/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.1899
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2312
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2244
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2193
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2210
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2151
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2155
#  8/18 [============>.................] - ETA: 0s - loss: 0.2196
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2171
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2180
# 11/18 [=================>............] - ETA: 0s - loss: 0.2169
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2202
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2208
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2213
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2207
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2201
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2203
# 18/18 [==============================] - ETA: 0s - loss: 0.2206
# 18/18 [==============================] - 1s 61ms/step - loss: 0.2206 - val_loss: 0.2664 - lr: 1.1089e-05
# Epoch 72/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2390
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2404
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2441
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2313
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2346
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2310
#  7/18 [==========>...................] - ETA: 0s - loss: 0.2268
#  8/18 [============>.................] - ETA: 0s - loss: 0.2242
#  9/18 [==============>...............] - ETA: 0s - loss: 0.2232
# 10/18 [===============>..............] - ETA: 0s - loss: 0.2233
# 11/18 [=================>............] - ETA: 0s - loss: 0.2224
# 12/18 [===================>..........] - ETA: 0s - loss: 0.2216
# 13/18 [====================>.........] - ETA: 0s - loss: 0.2235
# 14/18 [======================>.......] - ETA: 0s - loss: 0.2196
# 15/18 [========================>.....] - ETA: 0s - loss: 0.2198
# 16/18 [=========================>....] - ETA: 0s - loss: 0.2188
# 17/18 [===========================>..] - ETA: 0s - loss: 0.2198
# 18/18 [==============================] - ETA: 0s - loss: 0.2187
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2187 - val_loss: 0.2736 - lr: 1.1089e-05
# Epoch 73/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2306
#  2/18 [==>...........................] - ETA: 0s - loss: 0.2255
#  3/18 [====>.........................] - ETA: 0s - loss: 0.2363
#  4/18 [=====>........................] - ETA: 0s - loss: 0.2312
#  5/18 [=======>......................] - ETA: 0s - loss: 0.2306
#  6/18 [=========>....................] - ETA: 0s - loss: 0.2329

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
