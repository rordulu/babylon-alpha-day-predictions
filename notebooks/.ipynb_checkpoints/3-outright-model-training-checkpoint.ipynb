# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
import sys
sys.path.append('/Users/rifatordulu/Developer/lstm-stock-price-prediction/custom_objects')
# %run "../helpers/data_manipulator.py"
# %run "../helpers/yfinance_data_fetcher.py"

from custom_objects import register_custom_objects, precision_with_threshold, recall_with_threshold, focal_loss, true_positives, all_positives, recall_mul_prediction, f1_score_metric, cubic_loss, gap_based_loss

# Register globally
register_custom_objects()

# %%
NUM_EPOCH = 200
STARTING_LR = 0.0001
SEQUENCE_SIZE = 16
REDUCE_LR_PATIENCE = 6
STOP_L_PATIENCE = 12
BATCH_SIZE = 64
LOSS_FUNCTION = "mse"
RELOAD_FROM_NUMPY_FILE = False
NORMALIZE_Y = True

SPEC_FILE_TAG = "last_trained_model"

# %%
# Import necessary libraries and modules
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization, Reshape, Lambda
from tensorflow.keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle
import math
import keras.backend as K
import os
import logging
import absl.logging
import joblib
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %%
stocks = my_stocks

# %%
# Let's create ML-ready dataset
data_frame = construct_values_for_model(sequence_size = SEQUENCE_SIZE,
                                        ticker_symbols=stocks,
                                        use_for_last_day_prediction=False,
                                        verbose=False,
                                        refresh=False,
                                        data_interval="5y",
                                        find_sectors=True,
                                        normalize_y=NORMALIZE_Y)
# Out:
# fetch_finance_data_for_tickers: just returning file name: MSFT for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:222: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, data], ignore_index=True)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: NVDA for interval: 5y
# fetch_finance_data_for_tickers: just returning file name: AMZN for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: GOOGL for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: META for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: TSLA for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: AMD for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: QCOM for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: JPM for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: GS for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: KO for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# fetch_finance_data_for_tickers: just returning file name: PEP for interval: 5y
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:58: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:172: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_frame = pd.concat([data_frame, to_concat])
# {'AMD': 0, 'AMZN': 1, 'GOOGL': 2, 'GS': 3, 'JPM': 4, 'KO': 5, 'META': 6, 'MSFT': 7, 'NVDA': 8, 'PEP': 9, 'QCOM': 10, 'TSLA': 11}
# {'Auto Tech': 0, 'Consumer Retail': 1, 'Financials': 2, 'Tech': 3}
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:258: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_frame["Ticker"] = data_frame["Ticker"].replace(stock_dict)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:273: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_frame["Sector"] = data_frame["Sector"].replace(sector_dict)

# %%
train_data, validation_data, test_data = split_data(data_frame,
                                                    train_cut_date = "2024-03-31",
                                                    validate_cut_date = "2024-09-30",
                                                    test_end_date = "2024-12-31")

# %%
print(train_data["y-value"])
print(train_data["y-value-original"])
# Out:
# 0        0.172995
# 1       -0.303361
# 2       -0.690723
# 3       -0.611903
# 4        1.015430
#            ...
# 14707   -0.657688
# 14708   -0.321469
# 14709   -0.358750
# 14710   -0.407407
# 14711   -0.261466
# Name: y-value, Length: 12600, dtype: float64
# 0        1.012089
# 1        1.005422
# 2        1.000000
# 3        1.001103
# 4        1.023881
#            ...
# 14707    1.000462
# 14708    1.005168
# 14709    1.004647
# 14710    1.003966
# 14711    1.006008
# Name: y-value-original, Length: 12600, dtype: float64

# %%
# BElow verifying the arr conversions work properly. check the values...
print(train_data.iloc[0]["LstmData"].iloc[0])
print(np.array(train_data["LstmData"].to_list())[0][0])


print(f"train data shape:{train_data.shape} and train data columns: {train_data.columns}")
print(f"validation_data shape:{validation_data.shape} and validation_data columns: {validation_data.columns}")
print(f"test_data shape:{test_data.shape} and test_data columns: {test_data.columns}")
# Out:
# Open                0.971743
# High                0.975710
# Low                 0.976776
# Close               0.973558
# Volume              0.869621
# High-Low-Ratio     -0.507806
# High-Open-Ratio     0.206473
# Close-Open-Ratio    0.061677
# Next-Day-Open       0.962117
# Name: 0, dtype: float64
# [ 0.97174302  0.97571021  0.97677568  0.97355816  0.86962068 -0.50780607
#   0.20647284  0.06167679  0.96211685]
# train data shape:(12600, 8) and train data columns: Index(['LstmData', 'Date', 'Ticker', 'Sector', 'y-value', 'y-value-original',
#        'Orig_Ticker', 'Orig_Sector'],
#       dtype='object')
# validation_data shape:(1524, 8) and validation_data columns: Index(['LstmData', 'Date', 'Ticker', 'Sector', 'y-value', 'y-value-original',
#        'Orig_Ticker', 'Orig_Sector'],
#       dtype='object')
# test_data shape:(768, 8) and test_data columns: Index(['LstmData', 'Date', 'Ticker', 'Sector', 'y-value', 'y-value-original',
#        'Orig_Ticker', 'Orig_Sector'],
#       dtype='object')

# %% [markdown]
# #### Building LSTM Model

# %%
### MODEL 1
from tensorflow.keras.layers import Concatenate, ZeroPadding1D, Cropping1D, Embedding, RepeatVector

input_data = train_data.iloc[0]["LstmData"]
print(input_data.shape)

input_layer = Input(shape=(input_data.shape[0], input_data.shape[1]), name="values")
stock_id_input = Input(shape=(1,), name="stock_id")  # Stock ID input
sector_input = Input(shape=(1,), name="sector_id")  # Sector ID input


# Stock Embedding Layer
num_of_unique_stocks = train_data["Ticker"].nunique()  # Adjust based on the number of unique stocks
num_of_unique_sectors = train_data["Sector"].nunique()  # Adjust based on the number of unique stocks

# Roll to the nearest higher integer
stock_embedding_dim = 512 #math.ceil(math.sqrt(num_of_unique_stocks)) * 2
sector_embedding_dim = 128 #math.ceil(math.sqrt(num_of_unique_sectors)) * 2

stock_embedding = Embedding(input_dim=num_of_unique_stocks, output_dim=stock_embedding_dim, name="stock_embedding")(stock_id_input)
sector_embedding = Embedding(input_dim=num_of_unique_sectors, output_dim=sector_embedding_dim, name="sector_embedding")(sector_input)

# Reshape to remove the sequence length dimension
stock_embedding = Reshape((stock_embedding_dim,))(stock_embedding)
sector_embedding = Reshape((sector_embedding_dim,))(sector_embedding)

cnn = Conv1D(128,3, kernel_regularizer=l2(0.00001))(input_layer)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(128,3, kernel_regularizer=l2(0.00001))(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(256,3, kernel_regularizer=l2(0.00001))(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(256,3, kernel_regularizer=l2(0.00001))(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)
cnn = Conv1D(512,3, kernel_regularizer=l2(0.00001))(cnn)
cnn = PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25))(cnn)

# Pass embeddings through a dense layer
stock_embedding = Dense(128, activation='relu', name="stock_dense")(stock_embedding)
sector_embedding = Dense(128, activation='relu', name="sector_dense")(sector_embedding)

stock_embedding = Dropout(0.2)(stock_embedding)
sector_embedding = Dropout(0.2)(sector_embedding)

expanded_stock_embedding = RepeatVector(cnn.shape[1])(stock_embedding)  # Match timesteps with input data
cnn = Concatenate(axis=-1)([cnn, expanded_stock_embedding])

expanded_sector_embedding = RepeatVector(cnn.shape[1])(sector_embedding)  # Match timesteps with input data
cnn = Concatenate(axis=-1)([cnn, expanded_sector_embedding])

b = 1.2
a = 0.90

lstm = LSTM(units = 800, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 400, return_sequences = True)(cnn)
lstm = Dropout(rate = 0.3)(lstm)
lstm = LSTM(units = 100)(lstm)
lstm = Dropout(rate = 0.3)(lstm)
lstm = Dense(1, activation='tanh')(lstm)
# Out:
# (16, 9)

# %%
regressor = Model([input_layer, stock_id_input, sector_input],lstm)
regressor.summary()

from tensorflow.keras.utils import plot_model
plot_model(regressor, to_file='regressor_tree.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ values (InputLayer) │ (None, 16, 9)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 14, 128)   │      3,584 │ values[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu (PReLU)     │ (None, 14, 128)   │        128 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 12, 128)   │     49,280 │ p_re_lu[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_1 (PReLU)   │ (None, 12, 128)   │        128 │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 10, 256)   │     98,560 │ p_re_lu_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_id            │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_2 (PReLU)   │ (None, 10, 256)   │        256 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_embedding     │ (None, 1, 512)    │      6,144 │ stock_id[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sector_id           │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 8, 256)    │    196,864 │ p_re_lu_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 512)       │          0 │ stock_embedding[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sector_embedding    │ (None, 1, 128)    │        512 │ sector_id[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_3 (PReLU)   │ (None, 8, 256)    │        256 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_dense (Dense) │ (None, 128)       │     65,664 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 128)       │          0 │ sector_embedding… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 6, 512)    │    393,728 │ p_re_lu_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ stock_dense[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sector_dense        │ (None, 128)       │     16,512 │ reshape_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_4 (PReLU)   │ (None, 6, 512)    │        512 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 6, 128)    │          0 │ dropout[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ sector_dense[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 6, 640)    │          0 │ p_re_lu_4[0][0],  │
# │ (Concatenate)       │                   │            │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_1     │ (None, 6, 128)    │          0 │ dropout_1[0][0]   │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 6, 768)    │          0 │ concatenate[0][0… │
# │ (Concatenate)       │                   │            │ repeat_vector_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 6, 400)    │  1,870,400 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 6, 400)    │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 100)       │    200,400 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 100)       │          0 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │        101 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,903,029 (11.07 MB)
#  Trainable params: 2,903,029 (11.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the model

# %%
optimizer = Adam(learning_rate=STARTING_LR)
loss = None
loss_name = None

if LOSS_FUNCTION == "mse":
    loss = "mse"
    loss_name = "mse"
elif LOSS_FUNCTION == "focal":
    loss = focal_loss(alpha=0.25, gamma=2.0)
    loss_name = "focal_loss"
elif LOSS_FUNCTION == "mae":
    loss = "mae"
    loss_name = "mae"
elif LOSS_FUNCTION == "cubic":
    loss = cubic_loss(power=3)
    loss_name="cubic"
elif LOSS_FUNCTION == "square":
    loss = cubic_loss(power=0.5)
    loss_name="square"
elif LOSS_FUNCTION == "custom":
    loss = gap_based_loss(normalize_val_for_y(1.02), normalize_val_for_y(1.036), power=2)
    loss_name="custom"
else:
    loss = "binary_crossentropy"
    loss_name = "binary_crossentropy"

regressor.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=[
        precision_with_threshold(0.7),  # Custom precision
        recall_with_threshold(0.7),    # Custom recall
        'AUC',                         # Built-in AUC
        'Precision',                   # Built-in Precision
        'Recall',                      # Built-in Recall
        f1_score_metric,                # Custom F1 score
        true_positives,
        all_positives,
        recall_mul_prediction
    ]
)

# %% [markdown]
# ### Adjust parameters for the training

# %%
file_name_variable = f"special_{SPEC_FILE_TAG}_epoch_{NUM_EPOCH}_lr{STARTING_LR}_batch{BATCH_SIZE}_seqsize{SEQUENCE_SIZE}_loss{loss_name}"

# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = f"model_{file_name_variable}.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-11,# Minimum learning rate
    verbose=1
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=STOP_L_PATIENCE,
    restore_best_weights=True,
    min_delta=0.00001
)

if NORMALIZE_Y is False:
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=train_data["y-value"].unique(),
        y=train_data["y-value"].to_list()
    )
    class_weights = dict(enumerate(class_weights))

# %%
import logging

# Configure logging
logging.basicConfig(
    filename=f"training_output_{file_name_variable}.log", 
    level=logging.INFO, 
    format='%(asctime)s - %(message)s'
)
logger = logging.getLogger()

# Define a custom callback to log training progress
class LogCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logger.info(f"Epoch {epoch + 1}: {logs}")

# %% [markdown]
# ### START THE TRAINING

# %%
### Let's convert all of our stuff to np arrays to avoid any indexing issues:

X_train = np.array(train_data["LstmData"].to_list())
X_train_ticker = np.array(train_data["Ticker"].to_list())
X_train_sector = np.array(train_data["Sector"].to_list())
y_train = np.array(train_data["y-value"].to_list())

X_validate = np.array(validation_data["LstmData"].to_list())
X_validate_ticker = np.array(validation_data["Ticker"].to_list())
X_validate_sector = np.array(validation_data["Sector"].to_list())
y_validate = np.array(validation_data["y-value"].to_list())


print(X_train.shape)
print(y_train.shape)
print(f"total number of positives in train data: {np.sum(y_train)}")

print(X_validate.shape)
print(y_validate.shape)
print(f"total number of positives in validate data: {np.sum(y_validate)}")
# Out:
# (12600, 16, 9)
# (12600,)
# total number of positives in train data: 4142.64265944705
# (1524, 16, 9)
# (1524,)
# total number of positives in validate data: 304.05494479115487

# %%
import datetime

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
import keras

keras.config.disable_traceback_filtering()

# Training the model
history = regressor.fit(
    [X_train, X_train_ticker, X_train_sector]
    ,y_train
    ,validation_data=([X_validate, X_validate_ticker, X_validate_sector], y_validate)
    ,epochs=NUM_EPOCH
    ,batch_size = BATCH_SIZE
    ,callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping, LogCallback(), tensorboard_callback]
    # ,class_weight=class_weights
)

regressor.load_weights(model_location + model_name)
# Out:
# Epoch 1/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5470 - f1_score_metric: 0.0000e+00 - loss: 0.2337 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1007 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 24s 124ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.8373 - f1_score_metric: 0.0000e+00 - loss: 0.2392 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1174 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 25s 125ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.1779 - f1_score_metric: 0.0000e+00 - loss: 0.2068 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0949 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 19.3022 - f1_score_metric: 0.0000e+00 - loss: 0.2094 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0975 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.9818 - f1_score_metric: 0.0000e+00 - loss: 0.2052 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1017 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.9864 - f1_score_metric: 0.0000e+00 - loss: 0.2148 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1230 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.9948 - f1_score_metric: 0.0000e+00 - loss: 0.2055 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0951 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 8/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.5137 - f1_score_metric: 0.0000e+00 - loss: 0.2355 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0936 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.7280 - f1_score_metric: 0.0000e+00 - loss: 0.1954 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0974 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 10/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.3130 - f1_score_metric: 0.0000e+00 - loss: 0.2149 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0953 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 11/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 130ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.1808 - f1_score_metric: 0.0000e+00 - loss: 0.1969 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1011 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 12/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.8178 - f1_score_metric: 0.0000e+00 - loss: 0.2058 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1009 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 13/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 19.6665 - f1_score_metric: 0.0000e+00 - loss: 0.2058 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0959 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 14/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 22.0677 - f1_score_metric: 0.0000e+00 - loss: 0.2416 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0872 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 15/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 19.6124 - f1_score_metric: 0.0000e+00 - loss: 0.2103 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0858 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 16/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.7570 - f1_score_metric: 0.0000e+00 - loss: 0.2097 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0918 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 17/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5323 - f1_score_metric: 0.0000e+00 - loss: 0.2081 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0905 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 18/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.8803 - f1_score_metric: 0.0000e+00 - loss: 0.1960 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0900 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 19/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 133ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.5063 - f1_score_metric: 0.0000e+00 - loss: 0.2065 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0894 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 20/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.9338 - f1_score_metric: 0.0000e+00 - loss: 0.1904 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0837 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 21/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.6200 - f1_score_metric: 0.0000e+00 - loss: 0.2028 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1126 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 22/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.1616 - f1_score_metric: 0.0000e+00 - loss: 0.2163 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0892 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 23/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 133ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5221 - f1_score_metric: 0.0000e+00 - loss: 0.2002 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0876 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 24/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.5456 - f1_score_metric: 0.0000e+00 - loss: 0.2048 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0831 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 25/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 133ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.1724 - f1_score_metric: 0.0000e+00 - loss: 0.2017 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0842 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 26/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.3143 - f1_score_metric: 0.0000e+00 - loss: 0.2388 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0836 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 27/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.4922 - f1_score_metric: 0.0000e+00 - loss: 0.1972 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0861 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 28/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 22.0580 - f1_score_metric: 0.0000e+00 - loss: 0.2079 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1042 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 29/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5840 - f1_score_metric: 0.0000e+00 - loss: 0.2189 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0910 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 30/200
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.3299999158771244e-05.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.6225 - f1_score_metric: 0.0000e+00 - loss: 0.2068 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0869 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 31/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.8198 - f1_score_metric: 0.0000e+00 - loss: 0.1875 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0874 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 32/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5024 - f1_score_metric: 0.0000e+00 - loss: 0.2038 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0862 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 33/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.8007 - f1_score_metric: 0.0000e+00 - loss: 0.2145 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0836 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 34/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 133ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.2980 - f1_score_metric: 0.0000e+00 - loss: 0.1905 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1060 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 35/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5116 - f1_score_metric: 0.0000e+00 - loss: 0.2098 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0867 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 36/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.2971 - f1_score_metric: 0.0000e+00 - loss: 0.2012 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0827 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 37/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.4706 - f1_score_metric: 0.0000e+00 - loss: 0.2327 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0832 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 38/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.2609 - f1_score_metric: 0.0000e+00 - loss: 0.1956 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0843 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 39/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.2423 - f1_score_metric: 0.0000e+00 - loss: 0.2354 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0865 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 40/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.8470 - f1_score_metric: 0.0000e+00 - loss: 0.2152 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.1154 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 41/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.0807 - f1_score_metric: 0.0000e+00 - loss: 0.2202 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0831 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 42/200
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.108889963506954e-05.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 134ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.7596 - f1_score_metric: 0.0000e+00 - loss: 0.1980 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0869 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 3.3300e-05
# Epoch 43/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.6784 - f1_score_metric: 0.0000e+00 - loss: 0.2026 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0863 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05
# Epoch 44/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 136ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.5098 - f1_score_metric: 0.0000e+00 - loss: 0.2226 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0853 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05
# Epoch 45/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.2552 - f1_score_metric: 0.0000e+00 - loss: 0.1908 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0910 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05
# Epoch 46/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.3119 - f1_score_metric: 0.0000e+00 - loss: 0.2028 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0988 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05
# Epoch 47/200
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 21.6415 - f1_score_metric: 0.0000e+00 - loss: 0.2241 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0851 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05
# Epoch 48/200
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.6926035518263237e-06.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 26s 132ms/step - AUC: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - all_positives: 20.3132 - f1_score_metric: 0.0000e+00 - loss: 0.2318 - precision_with_threshold_fixed: 0.0000e+00 - recall_mul_prediction: 0.0000e+00 - recall_with_threshold_fixed: 0.0000e+00 - true_positives: 0.0000e+00 - val_AUC: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_all_positives: 12.6690 - val_f1_score_metric: 0.0000e+00 - val_loss: 0.0861 - val_precision_with_threshold_fixed: 0.0000e+00 - val_recall_mul_prediction: 0.0000e+00 - val_recall_with_threshold_fixed: 0.0000e+00 - val_true_positives: 0.0000e+00 - learning_rate: 1.1089e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### LET'S TRY THIS ON THE TEST DATA NOW

# %%
# y_test_predict = regressor.predict([X_test, X_test_ticker, X_test_sector])

y_validate_predict = regressor.predict([X_validate, X_validate_ticker, X_validate_sector])
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step

# %% [markdown]
# ### SANITATION:

# %%
validation_data['y-predict'] = y_validate_predict
validation_data.loc[:,'y-predict-original'] = inverse_normalize_data_for_y(validation_data[['y-predict']], ["y-predict"])
# Out:
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/3424258028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data['y-predict'] = y_validate_predict
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/3424258028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'y-predict-original'] = inverse_normalize_data_for_y(validation_data[['y-predict']], ["y-predict"])

# %% [markdown]
# ### LET'S SHOW THESE FALSE POSITIVES AND CHECK FOR TRENDS

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Define chart colors
train_actual_color = "cornflowerblue"
validate_actual_color = "orange"
test_actual_color = "green"
train_predicted_color = "lightblue"
validate_predicted_color = "peru"
test_predicted_color = "limegreen"

# %%
ticker_to_show = 0
ticker_data = validation_data[validation_data['Ticker'] == ticker_to_show]

plt.figure(figsize=(18,6))
plt.plot(ticker_data['Date'], ticker_data['y-predict-original'], label=f"{ticker_to_show} Prediction Values", color=train_predicted_color, marker='o', linestyle='')
plt.plot(ticker_data['Date'], ticker_data['y-value-original'], label=f"{ticker_to_show} Real Values", color=train_predicted_color, marker='x', linestyle='')
plt.title("Test results")
plt.xlabel("Time")
plt.ylabel("Prediction")
plt.xticks(rotation=45)
plt.legend()
plt.grid(color="lightgray")

# %%
# Plot actual and predicted price
plt.figure(figsize=(18,6))
plt.plot(ticker_data['Date'], ticker_data['y-predict-original'] - ticker_data['y-value-original'], label=f"{ticker_to_show} Over-Prediction Values", color=train_predicted_color, marker='o', linestyle='')

plt.title("Test results")
plt.xlabel("Time")
plt.ylabel("Over-Prediction")
plt.xticks(rotation=45)
plt.legend()
plt.grid(color="lightgray")

# %%
def calculate_for(val):

    validation_data.loc[:,'y-predict-binary'] = validation_data['y-predict-original'].apply(lambda x: 1 if x > val else 0)
    validation_data.loc[:,'y-value-binary'] = validation_data['y-value-original'].apply(lambda x: 1 if x > val else 0)


    validation_data.loc[:,'true-positive'] = (validation_data["y-predict-binary"] == 1.0) & (validation_data["y-value-binary"] == 1.0)
    validation_data.loc[:,'false-positive'] = (validation_data["y-predict-binary"] == 1.0) & (validation_data["y-value-binary"] == 0.0)
    validation_data.loc[:,'false-negative'] = (validation_data["y-predict-binary"] == 0.0) & (validation_data["y-value-binary"] == 1.0)

    ticker_data = validation_data[validation_data['Ticker'] == ticker_to_show]
    
    # Plot actual and predicted price
    plt.figure(figsize=(18,6))
    plt.plot(ticker_data['y-predict-binary'], label=f"{ticker_to_show} Prediction Values", color=train_predicted_color, marker='o', linestyle='')
    plt.plot(ticker_data['y-value-binary'], label=f"{ticker_to_show} Real Values", color=train_predicted_color, marker='x', linestyle='')
    plt.title("Test results")
    plt.xlabel("Time")
    plt.ylabel("Binary Prediction - True/False positives")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(color="lightgray")

    tps = validation_data['true-positive'].sum()
    fps = validation_data['false-positive'].sum()
    fns = validation_data['false-negative'].sum()
    real_trues = validation_data['y-value-binary'].sum()
    all_values = len(validation_data)
    
    print(f"Number of true positives for the given ticker: {tps}")
    print(f"Number of false positives for the given ticker: {fps}")
    print(f"Precision score: {tps/ (tps+fps)}")
    print(f"Recall score: {tps/ (tps+fns)}")
    print(f"Random guess score: {real_trues/ all_values}")
    
    tp_per_ticker = validation_data.groupby('Orig_Ticker')['true-positive'].sum()
    fp_per_ticker = validation_data.groupby('Orig_Ticker')['false-positive'].sum()
    fn_per_ticker = validation_data.groupby('Orig_Ticker')['false-negative'].sum()
    
    print(f"true-positive per ticker: {tp_per_ticker}")
    print(f"false-positive per ticker: {fp_per_ticker}")
    print(f"false-negative per ticker: {fn_per_ticker}")
    print(f"precision per ticker: {tp_per_ticker / (tp_per_ticker + fp_per_ticker)}")
    print(f"recall per ticker: {tp_per_ticker / (tp_per_ticker + fn_per_ticker)}")
    print(f"rand guess per ticker: {(tp_per_ticker + fn_per_ticker) / len(ticker_data)}")

    print_true = validation_data[validation_data['true-positive'] == 1.0][["Date", "Orig_Ticker", "y-predict-original", "y-value-original"]]
    print_false = validation_data[validation_data['false-positive'] == 1.0][["Date", "Orig_Ticker", "y-predict-original", "y-value-original"]]
    
    print(f"Some true positives")
    print(print_true.sample(n=min(5, len(print_true)), random_state=42))

    print(f"Some false positives")
    print(print_false.sample(n=min(5, len(print_false)), random_state=42))

# %%
calculate_for(1.02)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.18044619422572178
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      43
# AMZN     14
# GOOGL    13
# GS       14
# JPM       8
# KO        3
# META     26
# MSFT      4
# NVDA     51
# PEP       8
# QCOM     31
# TSLA     60
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       0.0
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.338583
# AMZN     0.110236
# GOOGL    0.102362
# GS       0.110236
# JPM      0.062992
# KO       0.023622
# META     0.204724
# MSFT     0.031496
# NVDA     0.401575
# PEP      0.062992
# QCOM     0.244094
# TSLA     0.472441
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'y-predict-binary'] = validation_data['y-predict-original'].apply(lambda x: 1 if x > val else 0)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'y-value-binary'] = validation_data['y-value-original'].apply(lambda x: 1 if x > val else 0)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'true-positive'] = (validation_data["y-predict-binary"] == 1.0) & (validation_data["y-value-binary"] == 1.0)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'false-positive'] = (validation_data["y-predict-binary"] == 1.0) & (validation_data["y-value-binary"] == 0.0)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data.loc[:,'false-negative'] = (validation_data["y-predict-binary"] == 0.0) & (validation_data["y-value-binary"] == 1.0)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.021)
# Out:
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.16535433070866143
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      38
# AMZN     12
# GOOGL    12
# GS       11
# JPM       5
# KO        2
# META     22
# MSFT      3
# NVDA     51
# PEP       8
# QCOM     31
# TSLA     57
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       0.0
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.299213
# AMZN     0.094488
# GOOGL    0.094488
# GS       0.086614
# JPM      0.039370
# KO       0.015748
# META     0.173228
# MSFT     0.023622
# NVDA     0.401575
# PEP      0.062992
# QCOM     0.244094
# TSLA     0.448819
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []

# %%
calculate_for(1.022)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.1541994750656168
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      37
# AMZN     10
# GOOGL    10
# GS       11
# JPM       4
# KO        1
# META     21
# MSFT      3
# NVDA     47
# PEP       7
# QCOM     30
# TSLA     54
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       0.0
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.291339
# AMZN     0.078740
# GOOGL    0.078740
# GS       0.086614
# JPM      0.031496
# KO       0.007874
# META     0.165354
# MSFT     0.023622
# NVDA     0.370079
# PEP      0.055118
# QCOM     0.236220
# TSLA     0.425197
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.023)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.13648293963254593
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      34
# AMZN     10
# GOOGL     7
# GS        9
# JPM       2
# KO        0
# META     18
# MSFT      3
# NVDA     42
# PEP       7
# QCOM     27
# TSLA     49
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       NaN
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.267717
# AMZN     0.078740
# GOOGL    0.055118
# GS       0.070866
# JPM      0.015748
# KO       0.000000
# META     0.141732
# MSFT     0.023622
# NVDA     0.330709
# PEP      0.055118
# QCOM     0.212598
# TSLA     0.385827
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.024)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.12532808398950132
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      31
# AMZN      9
# GOOGL     6
# GS        8
# JPM       2
# KO        0
# META     16
# MSFT      2
# NVDA     41
# PEP       4
# QCOM     23
# TSLA     49
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       NaN
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.244094
# AMZN     0.070866
# GOOGL    0.047244
# GS       0.062992
# JPM      0.015748
# KO       0.000000
# META     0.125984
# MSFT     0.015748
# NVDA     0.322835
# PEP      0.031496
# QCOM     0.181102
# TSLA     0.385827
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.025)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.11614173228346457
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      29
# AMZN      6
# GOOGL     6
# GS        7
# JPM       2
# KO        0
# META     14
# MSFT      2
# NVDA     40
# PEP       3
# QCOM     22
# TSLA     46
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       NaN
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.228346
# AMZN     0.047244
# GOOGL    0.047244
# GS       0.055118
# JPM      0.015748
# KO       0.000000
# META     0.110236
# MSFT     0.015748
# NVDA     0.314961
# PEP      0.023622
# QCOM     0.173228
# TSLA     0.362205
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []

# %%
calculate_for(1.015)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.2992125984251969
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      62
# AMZN     28
# GOOGL    28
# GS       36
# JPM      20
# KO       13
# META     46
# MSFT     16
# NVDA     71
# PEP      19
# QCOM     43
# TSLA     74
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       0.0
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.488189
# AMZN     0.220472
# GOOGL    0.220472
# GS       0.283465
# JPM      0.157480
# KO       0.102362
# META     0.362205
# MSFT     0.125984
# NVDA     0.559055
# PEP      0.149606
# QCOM     0.338583
# TSLA     0.582677
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.026)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.10301837270341208
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      26
# AMZN      6
# GOOGL     5
# GS        6
# JPM       2
# KO        0
# META     11
# MSFT      1
# NVDA     34
# PEP       3
# QCOM     19
# TSLA     44
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       NaN
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.204724
# AMZN     0.047244
# GOOGL    0.039370
# GS       0.047244
# JPM      0.015748
# KO       0.000000
# META     0.086614
# MSFT     0.007874
# NVDA     0.267717
# PEP      0.023622
# QCOM     0.149606
# TSLA     0.346457
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")

# %%
calculate_for(1.027)
# Out:
# Number of true positives for the given ticker: 0
# Number of false positives for the given ticker: 0
# Precision score: nan
# Recall score: 0.0
# Random guess score: 0.09317585301837271
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_4207/1013321211.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"Precision score: {tps/ (tps+fps)}")
# true-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: true-positive, dtype: int64
# false-positive per ticker: Orig_Ticker
# AMD      0
# AMZN     0
# GOOGL    0
# GS       0
# JPM      0
# KO       0
# META     0
# MSFT     0
# NVDA     0
# PEP      0
# QCOM     0
# TSLA     0
# Name: false-positive, dtype: int64
# false-negative per ticker: Orig_Ticker
# AMD      23
# AMZN      6
# GOOGL     4
# GS        5
# JPM       2
# KO        0
# META      6
# MSFT      1
# NVDA     32
# PEP       3
# QCOM     17
# TSLA     43
# Name: false-negative, dtype: int64
# precision per ticker: Orig_Ticker
# AMD     NaN
# AMZN    NaN
# GOOGL   NaN
# GS      NaN
# JPM     NaN
# KO      NaN
# META    NaN
# MSFT    NaN
# NVDA    NaN
# PEP     NaN
# QCOM    NaN
# TSLA    NaN
# dtype: float64
# recall per ticker: Orig_Ticker
# AMD      0.0
# AMZN     0.0
# GOOGL    0.0
# GS       0.0
# JPM      0.0
# KO       NaN
# META     0.0
# MSFT     0.0
# NVDA     0.0
# PEP      0.0
# QCOM     0.0
# TSLA     0.0
# dtype: float64
# rand guess per ticker: Orig_Ticker
# AMD      0.181102
# AMZN     0.047244
# GOOGL    0.031496
# GS       0.039370
# JPM      0.015748
# KO       0.000000
# META     0.047244
# MSFT     0.007874
# NVDA     0.251969
# PEP      0.023622
# QCOM     0.133858
# TSLA     0.338583
# dtype: float64
# Some true positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
# Some false positives
# Empty DataFrame
# Columns: [Date, Orig_Ticker, y-predict-original, y-value-original]
# Index: []
