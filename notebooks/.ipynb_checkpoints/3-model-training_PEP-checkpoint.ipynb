# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "PEP"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:47:12.188437: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.130613  0.132216  0.140231  0.141988  0.115416  2020-10-15 00:00:00-04:00
# 1  0.137998  0.142909  0.146655  0.145734  0.199672  2020-10-16 00:00:00-04:00
# 2  0.132866  0.139261  0.122976  0.120134  0.111435  2020-10-19 00:00:00-04:00
# 3  0.128610  0.122781  0.124991  0.120508  0.088942  2020-10-20 00:00:00-04:00
# 4  0.112088  0.113472  0.121087  0.119135  0.079856  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.852713  0.865976  0.862374  0.876586  0.071707  2023-07-03 00:00:00-04:00
# 1  0.862166  0.880227  0.882757  0.889790  0.209249  2023-07-05 00:00:00-04:00
# 2  0.873105  0.881041  0.881670  0.890060  0.224251  2023-07-06 00:00:00-04:00
# 3  0.873240  0.869233  0.856394  0.842632  0.258435  2023-07-07 00:00:00-04:00
# 4  0.849607  0.869640  0.866586  0.859070  0.220284  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.686798  0.728823  0.702149  0.739882  0.231442  2024-01-02 00:00:00-05:00
# 1  0.761892  0.759261  0.750549  0.740429  0.224065  2024-01-03 00:00:00-05:00
# 2  0.715438  0.736261  0.721316  0.720194  0.257164  2024-01-04 00:00:00-05:00
# 3  0.714890  0.709266  0.679672  0.685603  0.208011  2024-01-05 00:00:00-05:00
# 4  0.678849  0.683923  0.682843  0.687927  0.231085  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:47:14.043351: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:47:14.043392: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:47:14.372082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:14.373119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:14.373717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:47:14.539326: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:14.540307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:14.540919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:47:14.688784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:14.690104: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:14.690803: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:47:14.833861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:14.834887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:14.835466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:47:15.148883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.149600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.150338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:15.251388: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.251997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.252593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:47:15.362467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.363740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.364463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:15.634681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.635800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.636696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:15.738836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.739597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.740201: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:15.859881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:15.860930: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:15.861799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:16.315990: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:16.627279: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:16.736286: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:16.807252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:16.971208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:17.153457: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 36s - loss: 0.0013
#  2/20 [==>...........................] - ETA: 0s - loss: 9.6446e-04
# 2024-12-31 05:47:17.287668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  4/20 [=====>........................] - ETA: 0s - loss: 7.0431e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 7.2230e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 6.8396e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 6.7725e-04
# 12/20 [=================>............] - ETA: 0s - loss: 6.1661e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 6.2553e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 6.0293e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 5.8707e-04
# 20/20 [==============================] - ETA: 0s - loss: 5.7295e-04
# 2024-12-31 05:47:18.480471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:18.481380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:18.481916: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:18.567412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:18.567983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:18.568585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:18.653097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:47:18.653668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:47:18.654248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:47:18.688699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:18.782172: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:18.843995: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:47:18.898588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 4s 88ms/step - loss: 5.7295e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3192e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0596e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4441e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7075e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.5029e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3266e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.5265e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3279e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3383e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1720e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1629e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.3585e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.5925e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8174e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6759e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6011e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0528e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9412e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1532e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1823e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1598e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1600e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.0168e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.3195e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8006e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4343e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3847e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1551e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4797e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2715e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2657e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2374e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.2045e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.8277e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0670e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.8779e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.8210e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 5.6820e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.8908e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 6.0807e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.8937e-04
# 12/20 [=================>............] - ETA: 0s - loss: 5.8364e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.8072e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.6144e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3578e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2117e-04
# 20/20 [==============================] - 1s 52ms/step - loss: 5.1901e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.2916e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.2281e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6576e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7820e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0738e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2453e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1488e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0541e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7475e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.8730e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 5.1721e-04 - val_loss: 0.0013 - lr: 1.1089e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.7855e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6919e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8184e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6342e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6470e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0529e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1062e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2341e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1305e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1759e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 5.1625e-04 - val_loss: 0.0010 - lr: 1.1089e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1322e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.4963e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.1135e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4781e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1697e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8920e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9300e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8359e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7746e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1289e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 5.1203e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.9339e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.2943e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4622e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3138e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2186e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.9219e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.6895e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.5535e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2656e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1840e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1499e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.3570e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.5706e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7915e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6031e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7401e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1317e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.6701e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3297e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2426e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2336e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.2090e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.4662e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.1798e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.2533e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.9738e-04
#  9/20 [============>.................] - ETA: 0s - loss: 6.2580e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.8294e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.6388e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3217e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1410e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1971e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1541e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.9625e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1985e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7013e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.4683e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.9867e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1381e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.5600e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3201e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1328e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1324e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1581e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.2976e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8767e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9619e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3801e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1859e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2259e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2606e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.4572e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3959e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2006e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1690e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.2732e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1488e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.9149e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5253e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1097e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0474e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9039e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1864e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1481e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1209e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.0767e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.3267e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.5221e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.6659e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4644e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1284e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0879e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9044e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8874e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6627e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1991e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1875e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.9911e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1439e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0620e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.1528e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5796e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4883e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8507e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2474e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1609e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2110e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1570e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.0306e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.3009e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3422e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8471e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6706e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3422e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1361e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2135e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2594e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1997e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1931e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.4504e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0065e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1368e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0590e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7493e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1768e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4779e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2059e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1848e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1698e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1520e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8861e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.7146e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1534e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.0485e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.8216e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5904e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4686e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2010e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1433e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1288e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1188e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.8428e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.3349e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9133e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.8231e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.5319e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3293e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2882e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1389e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1728e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1863e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1797e-04 - val_loss: 0.0010 - lr: 1.1089e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2664e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6842e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6792e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3922e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0353e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5651e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.5485e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.4158e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3260e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1911e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1329e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.0089e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1702e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4847e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.6437e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6828e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6769e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1306e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1527e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1691e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1792e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1604e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.2524e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.5563e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.8813e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9848e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1737e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0751e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0489e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0034e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1404e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1633e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1405e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5766e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.2571e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.3116e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.6174e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3270e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2197e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2833e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0622e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0787e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1012e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.0842e-04 - val_loss: 0.0013 - lr: 1.1089e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.8861e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3636e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4697e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4192e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2499e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9113e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7354e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9252e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0794e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1234e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.0981e-04 - val_loss: 0.0010 - lr: 1.1089e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 0s - loss: 7.2841e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.2788e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.5593e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.0623e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.6540e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3123e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2629e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1885e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2408e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1643e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1529e-04 - val_loss: 9.9651e-04 - lr: 1.1089e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.7111e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0651e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1180e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7004e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8265e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2498e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2402e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9947e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1334e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1586e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1996e-04 - val_loss: 0.0013 - lr: 1.1089e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.8983e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8625e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.2634e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4536e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2250e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9427e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7089e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9979e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0042e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1080e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1686e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3902e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3824e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0683e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5802e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6414e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.2697e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.3925e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.3383e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9496e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2438e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1894e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.6706e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.7197e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3990e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3570e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5490e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9620e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2172e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3995e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3362e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2528e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1921e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8940e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.5910e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9314e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7063e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.3781e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0257e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1596e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1285e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1345e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1003e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1221e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8148e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.1224e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.2267e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.4665e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.7693e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2385e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1122e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8299e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9578e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2271e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1964e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.4588e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2833e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7964e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.2041e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1305e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5780e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4364e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.4691e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.4042e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1560e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.1415e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.2950e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.0633e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.6570e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.1662e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8196e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0485e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9676e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0523e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3606e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1758e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1671e-04 - val_loss: 0.0010 - lr: 1.1089e-04
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.1283e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.3711e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2944e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.6490e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2054e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.9243e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6942e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3263e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1295e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0982e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 5.1369e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 36/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.9795e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4734e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4408e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5486e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8401e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7719e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7984e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7709e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6453e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1622e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1683e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 37/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.6706e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.4896e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.5896e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9672e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8179e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7212e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7740e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6153e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.7463e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1970e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 5.1759e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 38/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3654e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.6345e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.4417e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7841e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.5333e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2784e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0735e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1977e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0491e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1513e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1169e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 39/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.9957e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.3721e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1789e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.6858e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.6044e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.6859e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.5304e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3587e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1988e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1955e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1733e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 40/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.8952e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.3038e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.6028e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7111e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.5489e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.4844e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.3306e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0512e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2131e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1697e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 5.1500e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 41/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.9571e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.0833e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.9023e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.5666e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.8879e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5584e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.3848e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.5475e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2958e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2266e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1911e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 42/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.5701e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3417e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.6704e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.2185e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.7669e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.6897e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4270e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2529e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0583e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.2102e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 5.1717e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 43/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.2261e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.6643e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.0893e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.5799e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 5.5410e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 5.4886e-04
# 12/20 [=================>............] - ETA: 0s - loss: 5.1937e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 5.3095e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 5.1583e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 5.1433e-04
# 20/20 [==============================] - ETA: 0s - loss: 5.1707e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 5.1707e-04 - val_loss: 0.0012 - lr: 1.1089e-04
# Epoch 44/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8331e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4116e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4045e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3943e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2040e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.0259e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2956e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2119e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1690e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1998e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 5.1489e-04 - val_loss: 0.0011 - lr: 1.1089e-04
# Epoch 45/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.4221e-04
# ...
#  9/20 [============>.................] - ETA: 0s - loss: 4.7832e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8054e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8232e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2927e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2963e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1959e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1656e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 72/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.2978e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.9679e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3483e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.7059e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.5808e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1138e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2522e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1663e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1676e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1077e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0789e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 73/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.3359e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.1913e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.5051e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 6.0473e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.8875e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5218e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4997e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.4226e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.3998e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1486e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1316e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 74/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.6145e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8071e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.5581e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5943e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.5788e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4131e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.6653e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6404e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9878e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0420e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0886e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 75/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.6963e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4113e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.4287e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9333e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.8003e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6043e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7785e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7739e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1495e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0858e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.1052e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 76/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.0971e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.9639e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6680e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7419e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0476e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.2363e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1941e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2232e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2307e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0398e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.0700e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 77/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.1959e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.6292e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.0378e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3061e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1245e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8657e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8107e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9805e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2357e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1355e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0885e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 78/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.6647e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8809e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.1557e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8562e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.6107e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3690e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.1937e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1125e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9365e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1023e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 5.0980e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 79/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8673e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2058e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7386e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.7082e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6410e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1044e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.2598e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.0942e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1280e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0947e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0783e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 80/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.8925e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.0336e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.3557e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.3840e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.6203e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1049e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0254e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8709e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0512e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0967e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 5.1091e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 81/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.7203e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.1781e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.5011e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0839e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7036e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8478e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.7053e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.8539e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.8360e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0370e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0343e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 82/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.8607e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.3121e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.4416e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.0217e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.6203e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.1628e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0794e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.1477e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.9251e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.9845e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0817e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 83/1000
#  1/20 [>.............................] - ETA: 0s - loss: 6.5667e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 5.0044e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.5565e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.1954e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.4286e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.4756e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4885e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 5.3907e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2072e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 5.1885e-04
# 20/20 [==============================] - ETA: 0s - loss: 5.1256e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 5.1256e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 84/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.6845e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.8358e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.2899e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.5324e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.3991e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.4019e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.0831e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.9537e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1124e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1434e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.0967e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 85/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3434e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 6.8105e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.8616e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.3512e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.2979e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.5349e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.4213e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.3659e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2134e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1915e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 5.1690e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 86/1000
#  1/20 [>.............................] - ETA: 0s - loss: 0.0011
#  2/20 [==>...........................] - ETA: 0s - loss: 7.6635e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 7.4583e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 6.2083e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 6.1337e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 5.7609e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 5.4722e-04
# 12/20 [=================>............] - ETA: 0s - loss: 5.3693e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 5.3090e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 5.2493e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 5.1875e-04
# 20/20 [==============================] - ETA: 0s - loss: 5.0987e-04
# 20/20 [==============================] - 1s 43ms/step - loss: 5.0987e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 87/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.7753e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4401e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.7398e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.8655e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.7092e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.7339e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8270e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5767e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.1203e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 4.9831e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 5.0615e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 88/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.4997e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.4367e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 5.3168e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 5.2433e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.1759e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 5.3562e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 5.5656e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 5.2045e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.2276e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1120e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.0723e-04 - val_loss: 0.0011 - lr: 3.6926e-05
# Epoch 89/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.2320e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 3.3435e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.6792e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.9121e-04
#  9/20 [============>.................] - ETA: 0s - loss: 5.0931e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.8655e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.9052e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.7101e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 5.0023e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.1305e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1031e-04 - val_loss: 0.0012 - lr: 3.6926e-05
# Epoch 90/1000
#  1/20 [>.............................] - ETA: 0s - loss: 4.3366e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 4.2934e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 4.1475e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 4.0562e-04
#  9/20 [============>.................] - ETA: 0s - loss: 4.1115e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 4.6605e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 4.8375e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 4.6451e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 4.6212e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 5.0322e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 5.1002e-04 - val_loss: 0.0011 - lr: 3.6926e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
