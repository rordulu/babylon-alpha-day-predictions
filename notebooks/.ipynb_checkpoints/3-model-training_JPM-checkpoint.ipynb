# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Parameters
TICKER = "JPM"

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 32
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 05:49:15.242000: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (680, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (40, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.016269  0.020477  0.020777  0.028379  0.272484  2020-10-15 00:00:00-04:00
# 1  0.028879  0.023441  0.029962  0.027228  0.196383  2020-10-16 00:00:00-04:00
# 2  0.029917  0.020962  0.023620  0.017860  0.166123  2020-10-19 00:00:00-04:00
# 3  0.022874  0.020423  0.026682  0.020983  0.156970  2020-10-20 00:00:00-04:00
# 4  0.023147  0.016220  0.022363  0.015504  0.146685  2020-10-21 00:00:00-04:00
# Validation Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.332116  0.325263  0.336320  0.333456  0.093775  2023-07-03 00:00:00-04:00
# 1  0.330624  0.319181  0.332513  0.327711  0.111613  2023-07-05 00:00:00-04:00
# 2  0.319293  0.307297  0.315254  0.319242  0.126742  2023-07-06 00:00:00-04:00
# 3  0.324545  0.321569  0.324474  0.325934  0.112445  2023-07-07 00:00:00-04:00
# 4  0.328027  0.322443  0.333340  0.330731  0.114840  2023-07-10 00:00:00-04:00
# Testing Dataset:
#        Open      High       Low     Close    Volume                       Date
# 0  0.480509  0.482348  0.484984  0.497740  0.131975  2024-01-02 00:00:00-05:00
# 1  0.496977  0.481585  0.493677  0.493265  0.129532  2024-01-03 00:00:00-05:00
# 2  0.495980  0.495545  0.500951  0.500048  0.170943  2024-01-04 00:00:00-05:00
# 3  0.500945  0.495723  0.506522  0.505211  0.133670  2024-01-05 00:00:00-05:00
# 4  0.504235  0.489700  0.494660  0.503710  0.156439  2024-01-08 00:00:00-05:00

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (680, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (104, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (846, 5)
#
#  Data Train Scaled: (680, 5)
# > Data Train X: (616, 64, 5)
# > Data Train y: (616,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (40, 5)
# > Data Test X: (40, 64, 5)
# > Data Test y: (40,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 05:49:16.994358: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 05:49:16.994391: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# Add first LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:49:17.314081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:17.315133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:17.315807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:49:17.488465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:17.489529: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:17.490082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:49:17.635844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:17.636830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:17.637480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 05:49:17.774345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:17.775052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:17.775901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 400)           1281600
#  dropout_1 (Dropout)         (None, 64, 400)           0
#  lstm_2 (LSTM)               (None, 64, 200)           480800
#  dropout_2 (Dropout)         (None, 64, 200)           0
#  lstm_3 (LSTM)               (None, 100)               120400
#  dropout_3 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 2,532,501
# Trainable params: 2,532,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, reduce_lr, early_stopping])
# Out:
# 2024-12-31 05:49:18.096506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.097623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.098334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:18.202957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.203557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.204173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 05:49:18.299885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.300809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.301490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:18.535744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.536515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.537198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:18.626306: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.626931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.627600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:18.716723: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:18.717340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:18.717983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:19.134561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:19.433152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:19.539972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:19.607524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:19.770410: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:19.974015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:20.107745: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/20 [>.............................] - ETA: 34s - loss: 3.6822e-04
#  2/20 [==>...........................] - ETA: 1s - loss: 2.5480e-04
#  4/20 [=====>........................] - ETA: 0s - loss: 1.9586e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 1.8456e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 1.9200e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.8591e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.9632e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.9403e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.8967e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.8271e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.7885e-04
# 2024-12-31 05:49:21.267053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:21.268014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:21.268676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:21.354675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:21.355297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:21.355869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:21.441791: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 05:49:21.442400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 05:49:21.442995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 05:49:21.477330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:21.572293: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:21.622787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 05:49:21.679305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 3s 86ms/step - loss: 1.7885e-04 - val_loss: 1.3517e-04 - lr: 1.1089e-04
# Epoch 2/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8344e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6874e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6671e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7785e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7512e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6933e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6219e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5865e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5660e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6774e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6750e-04 - val_loss: 1.7105e-04 - lr: 1.1089e-04
# Epoch 3/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.7795e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5121e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7679e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.9130e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8729e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.8041e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7215e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6811e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6558e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6562e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6560e-04 - val_loss: 1.6379e-04 - lr: 1.1089e-04
# Epoch 4/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5369e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5178e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4072e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4297e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5764e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6174e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5686e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5430e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6037e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6918e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6817e-04 - val_loss: 1.4297e-04 - lr: 1.1089e-04
# Epoch 5/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8506e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6192e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5800e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5656e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5289e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6189e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6501e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7470e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7168e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.7057e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6954e-04 - val_loss: 1.5407e-04 - lr: 1.1089e-04
# Epoch 6/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2307e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5099e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5155e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6553e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6047e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6246e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5319e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5464e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6468e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6783e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6705e-04 - val_loss: 1.4713e-04 - lr: 1.1089e-04
# Epoch 7/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.7266e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8115e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7733e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8060e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8693e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.8036e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7588e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7363e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7149e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6660e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6687e-04 - val_loss: 1.4718e-04 - lr: 1.1089e-04
# Epoch 8/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3731e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7851e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7544e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6138e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5618e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6440e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7431e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6922e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6903e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6809e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6685e-04 - val_loss: 1.6668e-04 - lr: 1.1089e-04
# Epoch 9/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.9117e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6036e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5753e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6293e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7256e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7926e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7381e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7160e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6719e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6858e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6775e-04 - val_loss: 1.6643e-04 - lr: 1.1089e-04
# Epoch 10/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4284e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.1895e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3785e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6108e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6494e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6899e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7512e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7966e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7309e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.7186e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6645e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6645e-04 - val_loss: 1.7305e-04 - lr: 1.1089e-04
# Epoch 11/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3334e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3926e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8194e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7779e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6580e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6160e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7071e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7269e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7086e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6824e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6763e-04 - val_loss: 1.6190e-04 - lr: 1.1089e-04
# Epoch 12/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2538e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6037e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5521e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5234e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5952e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5751e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6269e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6853e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6641e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6706e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6651e-04 - val_loss: 1.6428e-04 - lr: 1.1089e-04
# Epoch 13/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5671e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7524e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7487e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7917e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7207e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6452e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6380e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6570e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6906e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6826e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6639e-04 - val_loss: 1.5218e-04 - lr: 1.1089e-04
# Epoch 14/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5248e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9287e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7475e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6132e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6352e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6650e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6443e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6316e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6868e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6406e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6687e-04 - val_loss: 1.4554e-04 - lr: 1.1089e-04
# Epoch 15/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.7976e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9775e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7800e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7348e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6626e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6640e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7122e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6837e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6845e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6767e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6759e-04 - val_loss: 1.6858e-04 - lr: 1.1089e-04
# Epoch 16/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5109e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5822e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7245e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5977e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6014e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7571e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7743e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7552e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7075e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6627e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6527e-04 - val_loss: 1.6363e-04 - lr: 1.1089e-04
# Epoch 17/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1226e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5960e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6745e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7262e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7158e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7547e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6998e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7389e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7090e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6692e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6565e-04 - val_loss: 1.6818e-04 - lr: 1.1089e-04
# Epoch 18/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5483e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5642e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4662e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5305e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4840e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4329e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6252e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5698e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5949e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6476e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6417e-04 - val_loss: 1.6798e-04 - lr: 1.1089e-04
# Epoch 19/1000
#  1/20 [>.............................] - ETA: 0s - loss: 9.3193e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2572e-04
#  4/20 [=====>........................] - ETA: 0s - loss: 1.2621e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 1.4787e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 1.5897e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.6684e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.7176e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.7737e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.7145e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.7048e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6700e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 1.6700e-04 - val_loss: 1.8264e-04 - lr: 1.1089e-04
# Epoch 20/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5906e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9678e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7841e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7725e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7652e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.8682e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7866e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7383e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6895e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6739e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6606e-04 - val_loss: 1.8029e-04 - lr: 1.1089e-04
# Epoch 21/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.6903e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9988e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8229e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8324e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7695e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7111e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6299e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6084e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5685e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6445e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6587e-04 - val_loss: 1.6409e-04 - lr: 1.1089e-04
# Epoch 22/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6142e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4224e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6217e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5351e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4464e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4629e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5344e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5722e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5642e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6531e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6563e-04 - val_loss: 1.6501e-04 - lr: 1.1089e-04
# Epoch 23/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3107e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3783e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3234e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4044e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5967e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5750e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5873e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5358e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5783e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6522e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6495e-04 - val_loss: 1.7566e-04 - lr: 1.1089e-04
# Epoch 24/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3864e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5193e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6189e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5943e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5289e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6296e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6371e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6236e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6109e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6605e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6528e-04 - val_loss: 1.7620e-04 - lr: 1.1089e-04
# Epoch 25/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.8802e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7746e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8009e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8007e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8073e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7630e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7798e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7142e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6900e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6562e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6551e-04 - val_loss: 1.7164e-04 - lr: 1.1089e-04
# Epoch 26/1000
#  1/20 [>.............................] - ETA: 0s - loss: 5.6644e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2016e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3357e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5524e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6793e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6214e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6503e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7003e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6644e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6693e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6576e-04 - val_loss: 1.7114e-04 - lr: 1.1089e-04
# Epoch 27/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6777e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3411e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3808e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5458e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6020e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6142e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5820e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.8114e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6920e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6508e-04
# 20/20 [==============================] - 1s 36ms/step - loss: 1.6511e-04 - val_loss: 1.7849e-04 - lr: 1.1089e-04
# Epoch 28/1000
#  1/20 [>.............................] - ETA: 0s - loss: 3.3566e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.1742e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9390e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6272e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6385e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6519e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.5881e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.6108e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.6540e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.6326e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6270e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6420e-04
# 20/20 [==============================] - 1s 46ms/step - loss: 1.6420e-04 - val_loss: 1.6386e-04 - lr: 1.1089e-04
# Epoch 29/1000
#  1/20 [>.............................] - ETA: 1s - loss: 2.4274e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5478e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4065e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4919e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4536e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6014e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6837e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7238e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7120e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6554e-04
# 20/20 [==============================] - 1s 42ms/step - loss: 1.6699e-04 - val_loss: 1.4830e-04 - lr: 1.1089e-04
# Epoch 30/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.6225e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7535e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9001e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.9623e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7797e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7606e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7003e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6665e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6491e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6557e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6515e-04 - val_loss: 1.7819e-04 - lr: 1.1089e-04
# Epoch 31/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.6767e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6089e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7481e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6882e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6602e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6948e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6676e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6661e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.7138e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6647e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6619e-04 - val_loss: 1.7760e-04 - lr: 1.1089e-04
# Epoch 32/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.4025e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7115e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6857e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7167e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8124e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6948e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6653e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6612e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6745e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6520e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6488e-04 - val_loss: 1.5548e-04 - lr: 1.1089e-04
# Epoch 33/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.2005e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6148e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6054e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4779e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4395e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4981e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5834e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5671e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6317e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6480e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6515e-04 - val_loss: 1.8551e-04 - lr: 1.1089e-04
# Epoch 34/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4621e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7632e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5965e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5927e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6492e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7713e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6750e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7208e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6890e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6647e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6562e-04 - val_loss: 1.7303e-04 - lr: 3.6926e-05
# Epoch 35/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5508e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6862e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6850e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6138e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6628e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6218e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6008e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6346e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6403e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6716e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6737e-04 - val_loss: 1.7597e-04 - lr: 3.6926e-05
# Epoch 36/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.4578e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.9543e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 2.0345e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 2.0447e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8845e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7995e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.8133e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7399e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6569e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6519e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6348e-04 - val_loss: 1.7554e-04 - lr: 3.6926e-05
# Epoch 37/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0660e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6990e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6752e-04
#  6/20 [========>.....................] - ETA: 0s - loss: 1.6386e-04
#  8/20 [===========>..................] - ETA: 0s - loss: 1.7555e-04
# 10/20 [==============>...............] - ETA: 0s - loss: 1.7196e-04
# 12/20 [=================>............] - ETA: 0s - loss: 1.6619e-04
# 14/20 [====================>.........] - ETA: 0s - loss: 1.6118e-04
# 16/20 [=======================>......] - ETA: 0s - loss: 1.6386e-04
# 18/20 [==========================>...] - ETA: 0s - loss: 1.5951e-04
# 20/20 [==============================] - ETA: 0s - loss: 1.6530e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6530e-04 - val_loss: 1.7478e-04 - lr: 3.6926e-05
# Epoch 38/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.7949e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8454e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7337e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7665e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6182e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5682e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5888e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6235e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6010e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6467e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6446e-04 - val_loss: 1.7513e-04 - lr: 3.6926e-05
# Epoch 39/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1629e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6213e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6376e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6895e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6208e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6184e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5682e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6280e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6763e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6623e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6559e-04 - val_loss: 1.7062e-04 - lr: 3.6926e-05
# Epoch 40/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0986e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7916e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8647e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8737e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7431e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7050e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6381e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6076e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6342e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6679e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6608e-04 - val_loss: 1.6770e-04 - lr: 3.6926e-05
# Epoch 41/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1927e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4649e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5198e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6353e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5755e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5154e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5245e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7170e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6800e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6556e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6708e-04 - val_loss: 1.7026e-04 - lr: 3.6926e-05
# Epoch 42/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5168e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7156e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6831e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7203e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7677e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6476e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6702e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6875e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6531e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6478e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6335e-04 - val_loss: 1.7148e-04 - lr: 3.6926e-05
# Epoch 43/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4037e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7240e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5950e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.3937e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4806e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4792e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5315e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5163e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5155e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6264e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6383e-04 - val_loss: 1.7496e-04 - lr: 3.6926e-05
# Epoch 44/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3069e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6160e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7566e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.9149e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8179e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7369e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7651e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7456e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6977e-04
# ...
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7266e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5228e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4988e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6698e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6149e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6349e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6278e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6368e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6379e-04 - val_loss: 1.7320e-04 - lr: 3.6926e-05
# Epoch 47/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.4028e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.0411e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7808e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6793e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5884e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6030e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5543e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5641e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6370e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6941e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6790e-04 - val_loss: 1.7137e-04 - lr: 3.6926e-05
# Epoch 48/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0614e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5237e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6092e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7195e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7657e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7187e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7785e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7003e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6350e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6533e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6405e-04 - val_loss: 1.7007e-04 - lr: 3.6926e-05
# Epoch 49/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.0786e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4832e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8385e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7787e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6773e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6444e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6313e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6590e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6479e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6732e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6721e-04 - val_loss: 1.6674e-04 - lr: 3.6926e-05
# Epoch 50/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.0186e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8670e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7342e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.8076e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8214e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7651e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7424e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7015e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6976e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6430e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6426e-04 - val_loss: 1.7336e-04 - lr: 3.6926e-05
# Epoch 51/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.3679e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6060e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7167e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7139e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7807e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7404e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6890e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6660e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6843e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6612e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6524e-04 - val_loss: 1.6982e-04 - lr: 3.6926e-05
# Epoch 52/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5285e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.3325e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4953e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6740e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6764e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5469e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5426e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6362e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6050e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6584e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6554e-04 - val_loss: 1.6595e-04 - lr: 3.6926e-05
# Epoch 53/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3689e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4483e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5739e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6190e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5619e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6228e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5401e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6009e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6577e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6640e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6704e-04 - val_loss: 1.7160e-04 - lr: 3.6926e-05
# Epoch 54/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4881e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5645e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4994e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4545e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4100e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.3979e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5636e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5783e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5884e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6554e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6545e-04 - val_loss: 1.6728e-04 - lr: 3.6926e-05
# Epoch 55/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3222e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6049e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4393e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5581e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.5355e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.4889e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6000e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5931e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5994e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6409e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6318e-04 - val_loss: 1.7341e-04 - lr: 3.6926e-05
# Epoch 56/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.5959e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 2.3891e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 2.1373e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 2.0183e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.8239e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7465e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6963e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6931e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6612e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6836e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6764e-04 - val_loss: 1.6697e-04 - lr: 3.6926e-05
# Epoch 57/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.3340e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4866e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8168e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7067e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6379e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6726e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6503e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6005e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6430e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6306e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6504e-04 - val_loss: 1.6901e-04 - lr: 3.6926e-05
# Epoch 58/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.4318e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5831e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6396e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6649e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6639e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.7105e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.7244e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7184e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6627e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6231e-04
# 20/20 [==============================] - 1s 41ms/step - loss: 1.6501e-04 - val_loss: 1.6723e-04 - lr: 3.6926e-05
# Epoch 59/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.1963e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.4506e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.3773e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.4341e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.4868e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6721e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6718e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.7524e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6977e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6397e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6372e-04 - val_loss: 1.6665e-04 - lr: 3.6926e-05
# Epoch 60/1000
#  1/20 [>.............................] - ETA: 0s - loss: 8.8635e-05
#  3/20 [===>..........................] - ETA: 0s - loss: 1.2216e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.4635e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6881e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7373e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6338e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6316e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6033e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6058e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6458e-04
# 20/20 [==============================] - 1s 37ms/step - loss: 1.6415e-04 - val_loss: 1.6569e-04 - lr: 3.6926e-05
# Epoch 61/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2354e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6865e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.7791e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6597e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6051e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6743e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6573e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6333e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6611e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6585e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6434e-04 - val_loss: 1.6997e-04 - lr: 3.6926e-05
# Epoch 62/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.2147e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.8378e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.8035e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7364e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.7826e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6786e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6819e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6798e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6391e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6398e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6420e-04 - val_loss: 1.7057e-04 - lr: 3.6926e-05
# Epoch 63/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.7004e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.6049e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.9223e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.6860e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6586e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5388e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5772e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.5957e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.5923e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6606e-04
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6555e-04 - val_loss: 1.7176e-04 - lr: 3.6926e-05
# Epoch 64/1000
#  1/20 [>.............................] - ETA: 0s - loss: 1.5691e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.7196e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.6900e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.7728e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6499e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.6914e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.6832e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6750e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6924e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6653e-04
# 20/20 [==============================] - 1s 40ms/step - loss: 1.6595e-04 - val_loss: 1.7121e-04 - lr: 3.6926e-05
# Epoch 65/1000
#  1/20 [>.............................] - ETA: 0s - loss: 2.1634e-04
#  3/20 [===>..........................] - ETA: 0s - loss: 1.5176e-04
#  5/20 [======>.......................] - ETA: 0s - loss: 1.5253e-04
#  7/20 [=========>....................] - ETA: 0s - loss: 1.5907e-04
#  9/20 [============>.................] - ETA: 0s - loss: 1.6632e-04
# 11/20 [===============>..............] - ETA: 0s - loss: 1.5935e-04
# 13/20 [==================>...........] - ETA: 0s - loss: 1.5311e-04
# 15/20 [=====================>........] - ETA: 0s - loss: 1.6172e-04
# 17/20 [========================>.....] - ETA: 0s - loss: 1.6268e-04
# 19/20 [===========================>..] - ETA: 0s - loss: 1.6505e-04
# 20/20 [==============================] - 1s 39ms/step - loss: 1.6529e-04 - val_loss: 1.6647e-04 - lr: 3.6926e-05

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
