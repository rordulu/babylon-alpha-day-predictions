# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %run "../helpers/data_manipulator.py"

# %%
import numpy as np
import random
import os

np.random.seed(42)
random.seed(42)
os.environ["PYTHONHASHSEED"] = "42"

# %%
add_prev_day = False

do_binary_reg = True
use_log_for_linear_reg = False
use_horizon = True

all_data = pd.DataFrame()
all_data_val = pd.DataFrame()

N1 = 18
N2 = 20
gamma = 0.8


for ticker in my_stocks:
    # GET RAW DATA FOR THE TICKER
    stock_file, earnings_file = fetch_finance_data_for_tickers(ticker, "10y", refresh=False, verbose=False, incl_earnings=True)
    data = pd.read_csv(stock_file)
    earnings = pd.read_csv(earnings_file)
    data = data.drop(data[data['Volume'] == 0].index)
    data.reset_index(drop=True, inplace=True)
    data = make_new_features_for(data, earnings=earnings, use_adj_close=True)

    
    data, data_val, _ = split_data(data,
                                train_cut_date = "2024-03-01",
                                validate_cut_date = "2025-03-01",
                                test_end_date = "2025-03-10",
                                train_start_date = "2016-07-01"
                               )
    normalized_data = normalize_data(data, ticker)
    normalized_data_val = normalize_data(data_val, ticker)
    normalized_data["Close"] = data["Adj Close"]
    normalized_data_val["Close"] = data_val["Adj Close"]
    all_data = normalized_data
    all_data_val = normalized_data_val
    # all_data = pd.concat([all_data, data], ignore_index=True)
    # all_data_val = pd.concat([all_data_val, data_val], ignore_index=True)


    # 1. Prepare data
    features = lstm_features_v2 
        
    print("Maximum values:\n", all_data[features].iloc[0:].max().to_dict())
    print("\nMinimum values:\n", all_data[features].iloc[0:].min().to_dict())
    
        
    unique_tickers = all_data["TICKER"].unique()
    
    # Convert to a 2D array where rows = tickers, cols = Close values
    all_data_np = np.array([all_data[all_data["TICKER"] == ticker]["Close"].values for ticker in unique_tickers], dtype=object)
    all_data_np_val = np.array([all_data_val[all_data_val["TICKER"] == ticker]["Close"].values for ticker in unique_tickers], dtype=object)
    
    print("Maximum values:\n", all_data[features].iloc[0:].max().to_dict())
    print("\nMinimum values:\n", all_data[features].iloc[0:].min().to_dict())
    
    
    
    if add_prev_day:
        
        print(f"all_data: {all_data}")
        prev_day_df = all_data.shift(1).add_prefix("prev_day_")
        all_data = pd.concat([all_data, prev_day_df], axis=1)
        all_data = all_data.iloc[1:]
        # all_data = all_data.dropna()
    
        print(f"all_data: {all_data}")
    
    
        prev_day_df_val = all_data_val.shift(1).add_prefix("prev_day_")
        all_data_val = pd.concat([all_data_val, prev_day_df_val], axis=1)
        # all_data_val = all_data_val.dropna()
        all_data_val = all_data_val.iloc[1:]
    
    import pandas as pd
    import xgboost as xgb
    from xgboost import XGBRegressor
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
    from xgboost import plot_importance
    import matplotlib.pyplot as plt
    
    if use_horizon:
        # # Calculate 10-day moving average
        # all_data['ma_10'] = all_data['Close'].rolling(window=20).mean()
        
        # # Shift it -10 days to get future 10D MA
        # all_data['ma_10_future'] = all_data['ma_10'].shift(-20)
        
        # # Binary target: 1 if future MA is higher than current MA
        # all_data['target'] = (all_data['ma_10_future'] > all_data['Close']).astype(int)
        
        # Define symmetric weights centered at N2
        weights = {
            i: gamma ** abs(i - N2)  # weight decreases as distance from N2 increases
            for i in range(N1, N2 + 1)
        }
        
        # Create numerator using the symmetric weights
        numerator = sum([
            all_data['Close'].shift(-i) * weight
            for i, weight in weights.items()
        ])
        
        # Denominator is the sum of all weights
        denominator = sum(weights.values())
        
        # Calculate the future weighted average
        future_weighted_avg = numerator / denominator

        
        # Set as regression target
        all_data['future_avg_close'] = future_weighted_avg
        all_data['forward_log_return'] = all_data['future_avg_close'] / all_data['Close']
        
        # Drop NaNs from shifting
        all_data = all_data.dropna(subset=['forward_log_return'])
        
        if use_log_for_linear_reg:
            all_data['forward_log_return'] = np.log(all_data['forward_log_return'])
        
        # Binary classification target (optional)
        all_data['target'] = ((all_data['future_avg_close'] / all_data['Close']) > 1.0).astype(int)
    
    else:
        all_data['target'] = (all_data["Next-Day-Close-To-Todays-Close-Ratio"] > 0)
        all_data["forward_log_return"] = all_data['Next-Day-Close-To-Todays-Close-Ratio']
    
    # Drop NaNs caused by shifting
    
    
    if add_prev_day:
        prev_day_features = [f"prev_day_{col}" for col in features]
        X = all_data[features + prev_day_features]
        X_val = all_data_val[features + prev_day_features]  # same features used in training
    else:
        X = all_data[features]
        X_val = all_data_val[features]
    
    
    if do_binary_reg:
        y = all_data['target']
    else:
        y = all_data['forward_log_return']
    
    # 2. Train-test split (time-aware if it's time series!)
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)
    
    if do_binary_reg:
        print(f"doing binary classification")
    
        class_counts = y_train.value_counts()
    
        # Get number of negative and positive samples
        num_neg = class_counts[0]
        num_pos = class_counts[1]

        print(f"num_neg: {num_neg}, num_pos: {num_pos}")
        
        # Calculate scale_pos_weight
        scale_pos_weight = num_neg / num_pos
    
        # 3. Train XGBoost Regressor
        model = xgb.XGBClassifier(
            n_estimators=1024,
            max_depth=5,
            learning_rate=0.05,
            objective='binary:logistic',
            eval_metric='logloss',
            random_state=42,
            subsample=0.8,         # fraction of rows to sample per tree
            colsample_bytree=0.8,  # fraction of features per tree
            tree_method='hist',   # Optional: can improve speed + determinism
            enable_categorical=False,  # ensure consistent parsing
            # class_weight='balanced',
            scale_pos_weight=scale_pos_weight,
        )
    else:
        print(f"doing linear regression")
        # 3. Train XGBoost Regressor
        model = xgb.XGBRegressor(
            n_estimators=512,
            max_depth=8,
            learning_rate=0.01,
            objective='reg:squarederror',
            eval_metric='rmse'
        )
        
    model.fit(X_train, 
              y_train,
              # num_boost_round=500,
              eval_set=[(X_test, y_test)],
              # early_stopping_rounds=10,
              verbose=False
             )
    
    # 4. Evaluate regression performance


    folder = "..//xgboost-models//" + ticker + "//"
    # Save folder if not exists
    os.makedirs(folder, exist_ok=True)

    
    y_pred = model.predict(X_test)
    if do_binary_reg:
        # Compute metrics
        cm = confusion_matrix(y_test, y_pred)
        cr = classification_report(y_test, y_pred, output_dict=True)
        accuracy = accuracy_score(y_test, y_pred)
        
        # Print metrics
        print("Confusion Matrix:")
        print(confusion_matrix(y_test, y_pred))
        
        print("\nClassification Report:")
        print(classification_report(y_test, y_pred))
        
        print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
        
        # Create a more detailed metrics DataFrame
        metrics_df = pd.DataFrame([
            # Confusion Matrix Details
            {'Category': 'Confusion Matrix', 'Metric': 'True Negatives', 'Value': cm[0, 0]},
            {'Category': 'Confusion Matrix', 'Metric': 'False Positives', 'Value': cm[0, 1]},
            {'Category': 'Confusion Matrix', 'Metric': 'False Negatives', 'Value': cm[1, 0]},
            {'Category': 'Confusion Matrix', 'Metric': 'True Positives', 'Value': cm[1, 1]},
            
            # Classification Report Metrics
            {'Category': 'Class 0', 'Metric': 'Precision', 'Value': cr['0']['precision']},
            {'Category': 'Class 0', 'Metric': 'Recall', 'Value': cr['0']['recall']},
            {'Category': 'Class 0', 'Metric': 'F1-Score', 'Value': cr['0']['f1-score']},
            {'Category': 'Class 0', 'Metric': 'Support', 'Value': cr['0']['support']},
            
            {'Category': 'Class 1', 'Metric': 'Precision', 'Value': cr['1']['precision']},
            {'Category': 'Class 1', 'Metric': 'Recall', 'Value': cr['1']['recall']},
            {'Category': 'Class 1', 'Metric': 'F1-Score', 'Value': cr['1']['f1-score']},
            {'Category': 'Class 1', 'Metric': 'Support', 'Value': cr['1']['support']},
            
            {'Category': 'Overall', 'Metric': 'Accuracy', 'Value': accuracy},
            {'Category': 'Overall', 'Metric': 'Macro Avg Precision', 'Value': cr['macro avg']['precision']},
            {'Category': 'Overall', 'Metric': 'Macro Avg Recall', 'Value': cr['macro avg']['recall']},
            {'Category': 'Overall', 'Metric': 'Macro Avg F1-Score', 'Value': cr['macro avg']['f1-score']},
            
            {'Category': 'Overall', 'Metric': 'Weighted Avg Precision', 'Value': cr['weighted avg']['precision']},
            {'Category': 'Overall', 'Metric': 'Weighted Avg Recall', 'Value': cr['weighted avg']['recall']},
            {'Category': 'Overall', 'Metric': 'Weighted Avg F1-Score', 'Value': cr['weighted avg']['f1-score']}
        ])
        
        # Save to CSV
        filename = f"../xgboost-models/{ticker}/model_metrics.csv"
        metrics_df.to_csv(filename, index=False)


    else:
        print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred):.6f}")
        print(f"R² Score: {r2_score(y_test, y_pred):.4f}")
    
    # 5. Predict full signals
    all_data['prediction'] = model.predict(X)
    
    # 6. Convert predicted return ratio to buy/sell signal
    # Buy = 1 if expected return is positive (i.e., predicted ratio > 1)
    if do_binary_reg:
        all_data['signal'] = (all_data['prediction'] > 0.5).astype(int)
    else:
        all_data['signal'] = (all_data['prediction'] > 0).astype(int)
    
    # Optional: Check some predictions
    print(all_data[['prediction', 'signal']].tail())
    
    plot_importance(model)

    # Predict return ratio
    all_data_val['prediction'] = model.predict(X_val)
    
    # Generate signal: Buy if predicted return > 0
    if do_binary_reg:
        all_data_val['signal'] = (all_data_val['prediction'] > 0.5).astype(int)
    else:
        all_data_val['signal'] = (all_data_val['prediction'] > 0).astype(int)


    initial_cash = 10000
    cash = 0
    position = initial_cash / all_data_val["Close"].iloc[0]
    portfolio_value = []
    
    for i in range(1, len(all_data_val)):
        price_today = all_data_val.iloc[i]['Close']
        signal = all_data_val.iloc[i - 1]['signal']  # we act on yesterday's prediction
    
        # Buy signal (if not already in position)
        if signal == 1 and position == 0:
            position = cash / price_today
            cash = 0
    
        # Sell signal (if holding)
        elif signal == 0 and position > 0:
            cash = position * price_today
            position = 0
    
        # Track portfolio value
        value = cash + position * price_today
        portfolio_value.append(value)
    
    # Final value (if still holding)
    final_value = cash + position * all_data_val.iloc[-1]['Close']
    total_return = final_value - initial_cash
    
    buy_signals_count = (all_data_val['signal'] == 1).sum()
    total_rows = len(all_data_val)
    
    print(f"buy_signals_count: {buy_signals_count}")
    print(f"total_rows: {total_rows}")

    # Compute stats
    final_value = portfolio_value[-1]
    total_return = final_value - initial_cash
    return_percent = 100 * total_return / initial_cash
    invested_percent = 100 * buy_signals_count / total_rows
    stock_change_percent = 100 * ((all_data_val["Close"].iloc[-1] / all_data_val["Close"].iloc[0]) - 1.0)
    
    # Create DataFrame
    summary_df = pd.DataFrame({
        "Final Portfolio Value ($)": [round(final_value, 2)],
        "Total Return ($)": [round(total_return, 2)],
        "Return (%)": [round(return_percent, 2)],
        "Time Invested (%)": [round(invested_percent, 2)],
        "Stock Change (%)": [round(stock_change_percent, 2)],
    })
    
    
    # Save to CSV or Excel
    summary_df.to_csv(os.path.join(folder, "performance_summary.csv"), index=False)
    # summary_df.to_excel(os.path.join(folder, "performance_summary.xlsx"), index=False)  # optional Excel version
    
    print("Saved performance summary to:", os.path.join(folder, "performance_summary.csv"))


    import matplotlib.pyplot as plt
    import os
    
    os.makedirs(folder, exist_ok=True)

    
    plt.figure()
    plt.plot(portfolio_value)
    plt.title("Portfolio Value Over Time")
    plt.xlabel("Days")
    plt.ylabel("Value ($)")
    plt.savefig(folder + "-portfolio-value")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    plt.figure()
    plt.plot(all_data_val["Close"])
    plt.title("Close Value Over Time")
    plt.xlabel("Days")
    plt.ylabel("Value ($)")
    plt.savefig(folder + "-close-over-time")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    plt.figure()
    plt.plot(all_data_val["signal"])
    plt.title("Signal Over Time")
    plt.xlabel("Days")
    plt.ylabel("Value")
    plt.savefig(folder + "-signal-over-time")
    plt.legend()
    plt.grid(True)
    plt.show()

    model.save_model(folder + "xgb_model.json")
# Out:
# fetch_finance_data_for_tickers: just returning file name: MSFT for interval: 10y
# DOING EARNINGS
# fixed_mean: -0.00012976271957357454, fixed_stddev: 0.011478001104606573
# train_data:            Date        Open        High         Low       Close      Volume  \
# 313  2016-07-05   50.830002   51.279999   50.740002   45.685928  24806400.0
# 314  2016-07-06   50.779999   51.540001   50.389999   45.873417  28167500.0
# 315  2016-07-07   51.419998   51.610001   51.070000   45.873417  19585200.0
# 316  2016-07-08   51.730000   52.360001   51.549999   46.694828  28391000.0
# 317  2016-07-11   52.500000   52.830002   52.470001   46.953743  22269200.0
# ...         ...         ...         ...         ...         ...         ...
# 2236 2024-02-26  411.459991  412.160004  407.359985  404.452148  16193500.0
# 2237 2024-02-27  407.989990  408.320007  403.850006  404.392639  14835800.0
# 2238 2024-02-28  408.179993  409.299988  405.320007  404.630798  13183100.0
# 2239 2024-02-29  408.640015  414.200012  405.920013  410.505951  31947300.0
# 2240 2024-03-01  411.269989  415.869995  410.880005  412.351837  17800300.0
#
#        Adj Close TICKER      MACD  SIG_LINE  ...  10-D-up-from-yesterday  \
# 313    45.685928   MSFT -0.204423 -0.326165  ...                     1.0
# 314    45.873417   MSFT -0.131719 -0.287276  ...                     1.0
# 315    45.873417   MSFT -0.073255 -0.244472  ...                     1.0
# 316    46.694828   MSFT  0.046774 -0.186223  ...                     1.0
# 317    46.953743   MSFT  0.163415 -0.116295  ...                     1.0
# ...          ...    ...       ...       ...  ...                     ...
# 2236  404.452148   MSFT  4.004854  5.362422  ...                     0.0
# 2237  404.392639   MSFT  3.698509  5.029640  ...                     0.0
# 2238  404.630798   MSFT  3.435491  4.710810  ...                     1.0
# 2239  410.505951   MSFT  3.662524  4.501153  ...                     1.0
# 2240  412.351837   MSFT  3.947035  4.390329  ...                     1.0
#
#       20-D-up-from-yesterday  50-D-up-from-yesterday  100-D-up-from-yesterday  \
# 313                      0.0                     0.0                      1.0
# 314                      0.0                     0.0                      1.0
# 315                      0.0                     1.0                      1.0
# 316                      1.0                     1.0                      1.0
# 317                      1.0                     1.0                      1.0
# ...                      ...                     ...                      ...
# 2236                     1.0                     1.0                      1.0
# 2237                     0.0                     1.0                      1.0
# 2238                     0.0                     1.0                      1.0
# 2239                     1.0                     1.0                      1.0
# 2240                     1.0                     1.0                      1.0
#
#       200-D-up-from-yesterday  10-D-up-derivate-from-yesterday  \
# 313                       1.0                              0.0
# 314                       1.0                              0.0
# 315                       1.0                              0.0
# 316                       1.0                              0.0
# 317                       1.0                              0.0
# ...                       ...                              ...
# 2236                      1.0                              0.0
# 2237                      1.0                              0.0
# 2238                      1.0                              1.0
# 2239                      1.0                              0.0
# 2240                      1.0                              0.0
#
#       20-D-up-derivate-from-yesterday  50-D-up-derivate-from-yesterday  \
# 313                               0.0                              0.0
# 314                               0.0                              0.0
# 315                               0.0                              1.0
# 316                               1.0                              0.0
# 317                               0.0                              0.0
# ...                               ...                              ...
# 2236                              0.0                              0.0
# 2237                             -1.0                              0.0
# 2238                              0.0                              0.0
# 2239                              1.0                              0.0
# 2240                              0.0                              0.0
#
#       100-D-up-derivate-from-yesterday  200-D-up-derivate-from-yesterday
# 313                                0.0                               0.0
# 314                                0.0                               0.0
# 315                                0.0                               0.0
# 316                                0.0                               0.0
# 317                                0.0                               0.0
# ...                                ...                               ...
# 2236                               0.0                               0.0
# 2237                               0.0                               0.0
# 2238                               0.0                               0.0
# 2239                               0.0                               0.0
# 2240                               0.0                               0.0
#
# [1928 rows x 164 columns]
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:472: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Threshold"] = data["Threshold"].apply(lambda x: min(x, 0.025))
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:474: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fixed_mean = data[underlying_target].rolling(window=200).mean().iloc[-2]
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:475: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fixed_stddev = data[underlying_target].rolling(window=200).std().iloc[-2]
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:493: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:498: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:500: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:502: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Close-To-Open-200-Stddev"] = talib.STDDEV(data["Close-Open-Ratio"], timeperiod=period)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:503: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Close-To-Open-200-Threshold"] = (data["Close-To-Open-200-Mean"] + 1.0 * data["Close-To-Open-200-Stddev"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:548: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    print(f"Next-Day-High-To-Next-Day-Open-Ratio: VAL HERE: {val} SIGMA HERE: {sigma}")
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:549: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:550: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Next-Day-High-To-Next-Day-Open-Ratio-Above-One-Sigma"] = (data["Next-Day-High-To-Next-Day-Open-Ratio"] > val+ 1 * sigma).astype(float)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:551: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:552: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Above-1.02"] = (data[underlying_target] > 0.02).astype(float)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:553: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:554: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Open-To-Prev-Close-Ratio'] = data['Open'].div(data['Close'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:557: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['High-To-Prev-High-Ratio'] = data['High'].div(data['High'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:558: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Low-To-Prev-Low-Ratio'] = data['Low'].div(data['Low'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:559: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Volume-To-Prev-Volume-Ratio'] = data['Volume'].div(data['Volume'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:560: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['100-D-MA'] = data['Close'].rolling(window=100).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:561: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['50-D-MA'] = data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['target'] = ((all_data['future_avg_close'] / all_data['Close']) > 1.0).astype(int)
# Maximum values:
#  {'High-Low-Ratio': 0.5016700674478325, 'High-Open-Ratio': 0.3256498002736582, 'Close-Open-Ratio': 0.2700816579331737, 'Close-Prev-Close': 0.47389627066381246, '200D-Ratio': 0.3578032274705762, '100D-Ratio': 0.26938649585435076, '50D-Ratio': 0.18696247840592983, '20D-Ratio': 0.1415418273573467, 'MACD_HIST_NORM': 0.16450591881630527, 'MACD-Increase-Prev-MACD': 0.08409713512221625, 'MACD_BUY': 1.0, 'MACD_SELL': 1.0, 'MACD_HIST_NORM_SIGN': 1.0, 'MACD_SIGN': 1.0, 'MACD_TREND_SIGN': 1.0, 'RSI-below-30': 1.0, 'RSI-above-70': 1.0, 'RSI-trend-sign': 1.0, 'MACD_TREND_DERIV_SIGN': 1.0, 'SIG_TREND_DERIV_SIGN': 1.0, 'Above-200D': 1.0, 'Above-100D': 1.0, 'Above-50D': 1.0, 'Above-20D': 1.0, '200D-Trend': 1.0, '100D-Trend': 1.0, '50D-Trend': 1.0, '20D-Trend': 1.0, '200D-Trend-Deriv': 1.0, '100D-Trend-Deriv': 1.0, '50D-Trend-Deriv': 1.0, '20D-Trend-Deriv': 1.0, 'Volatility-10': 0.4452573322114096, 'Volatility-20': 0.3563722258177341, 'Volatility-50': 0.2558049814171854, 'Volatility-100': 0.18944627156556368, 'Volatility-200': 0.15322220829013417, 'MACD_SIG': 1.111111111111111, 'below-three-sigma': 1.0, 'below-two-sigma': 1.0, 'below-one-sigma': 1.0, 'above-mean': 1.0, 'above-one-sigma': 1.0, 'above-two-sigma': 1.0, 'above-three-sigma': 1.0, 'up-from-yesterday': 1.0, 'up-one-sigma': 1.0, 'down-one-sigma': 1.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 1.0, '20-D-up-from-yesterday': 1.0, '50-D-up-from-yesterday': 1.0, '100-D-up-from-yesterday': 1.0, '200-D-up-from-yesterday': 1.0, '10-D-up-derivate-from-yesterday': 1.0, '20-D-up-derivate-from-yesterday': 1.0, '50-D-up-derivate-from-yesterday': 1.0, '100-D-up-derivate-from-yesterday': 1.0, '200-D-up-derivate-from-yesterday': 1.0}
#
# Minimum values:
#  {'High-Low-Ratio': 0.012517218580606245, 'High-Open-Ratio': 0.0, 'Close-Open-Ratio': -0.1974884451252142, 'Close-Prev-Close': -0.49130104288085064, '200D-Ratio': -0.23337174402001573, '100D-Ratio': -0.18121604071523634, '50D-Ratio': -0.21688141710326997, '20D-Ratio': -0.1994709429318135, 'MACD_HIST_NORM': -0.22982856467561535, 'MACD-Increase-Prev-MACD': -0.11815240293839381, 'MACD_BUY': 0.0, 'MACD_SELL': 0.0, 'MACD_HIST_NORM_SIGN': 0.0, 'MACD_SIGN': 0.0, 'MACD_TREND_SIGN': 0.0, 'RSI-below-30': 0.0, 'RSI-above-70': 0.0, 'RSI-trend-sign': 0.0, 'MACD_TREND_DERIV_SIGN': 0.0, 'SIG_TREND_DERIV_SIGN': 0.0, 'Above-200D': 0.0, 'Above-100D': 0.0, 'Above-50D': 0.0, 'Above-20D': 0.0, '200D-Trend': 0.0, '100D-Trend': 0.0, '50D-Trend': 0.0, '20D-Trend': 0.0, '200D-Trend-Deriv': 0.0, '100D-Trend-Deriv': 0.0, '50D-Trend-Deriv': 0.0, '20D-Trend-Deriv': 0.0, 'Volatility-10': 0.011777735253685598, 'Volatility-20': 0.017434606615689144, 'Volatility-50': 0.027291469546054343, 'Volatility-100': 0.032999227362946984, 'Volatility-200': 0.04068867623659954, 'MACD_SIG': 0.0, 'below-three-sigma': 0.0, 'below-two-sigma': 0.0, 'below-one-sigma': 0.0, 'above-mean': 0.0, 'above-one-sigma': 0.0, 'above-two-sigma': 0.0, 'above-three-sigma': 0.0, 'up-from-yesterday': 0.0, 'up-one-sigma': 0.0, 'down-one-sigma': 0.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 0.0, '20-D-up-from-yesterday': 0.0, '50-D-up-from-yesterday': 0.0, '100-D-up-from-yesterday': 0.0, '200-D-up-from-yesterday': 0.0, '10-D-up-derivate-from-yesterday': -1.0, '20-D-up-derivate-from-yesterday': -1.0, '50-D-up-derivate-from-yesterday': -1.0, '100-D-up-derivate-from-yesterday': -1.0, '200-D-up-derivate-from-yesterday': -1.0}
# Maximum values:
#  {'High-Low-Ratio': 0.5016700674478325, 'High-Open-Ratio': 0.3256498002736582, 'Close-Open-Ratio': 0.2700816579331737, 'Close-Prev-Close': 0.47389627066381246, '200D-Ratio': 0.3578032274705762, '100D-Ratio': 0.26938649585435076, '50D-Ratio': 0.18696247840592983, '20D-Ratio': 0.1415418273573467, 'MACD_HIST_NORM': 0.16450591881630527, 'MACD-Increase-Prev-MACD': 0.08409713512221625, 'MACD_BUY': 1.0, 'MACD_SELL': 1.0, 'MACD_HIST_NORM_SIGN': 1.0, 'MACD_SIGN': 1.0, 'MACD_TREND_SIGN': 1.0, 'RSI-below-30': 1.0, 'RSI-above-70': 1.0, 'RSI-trend-sign': 1.0, 'MACD_TREND_DERIV_SIGN': 1.0, 'SIG_TREND_DERIV_SIGN': 1.0, 'Above-200D': 1.0, 'Above-100D': 1.0, 'Above-50D': 1.0, 'Above-20D': 1.0, '200D-Trend': 1.0, '100D-Trend': 1.0, '50D-Trend': 1.0, '20D-Trend': 1.0, '200D-Trend-Deriv': 1.0, '100D-Trend-Deriv': 1.0, '50D-Trend-Deriv': 1.0, '20D-Trend-Deriv': 1.0, 'Volatility-10': 0.4452573322114096, 'Volatility-20': 0.3563722258177341, 'Volatility-50': 0.2558049814171854, 'Volatility-100': 0.18944627156556368, 'Volatility-200': 0.15322220829013417, 'MACD_SIG': 1.111111111111111, 'below-three-sigma': 1.0, 'below-two-sigma': 1.0, 'below-one-sigma': 1.0, 'above-mean': 1.0, 'above-one-sigma': 1.0, 'above-two-sigma': 1.0, 'above-three-sigma': 1.0, 'up-from-yesterday': 1.0, 'up-one-sigma': 1.0, 'down-one-sigma': 1.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 1.0, '20-D-up-from-yesterday': 1.0, '50-D-up-from-yesterday': 1.0, '100-D-up-from-yesterday': 1.0, '200-D-up-from-yesterday': 1.0, '10-D-up-derivate-from-yesterday': 1.0, '20-D-up-derivate-from-yesterday': 1.0, '50-D-up-derivate-from-yesterday': 1.0, '100-D-up-derivate-from-yesterday': 1.0, '200-D-up-derivate-from-yesterday': 1.0}
#
# Minimum values:
#  {'High-Low-Ratio': 0.012517218580606245, 'High-Open-Ratio': 0.0, 'Close-Open-Ratio': -0.1974884451252142, 'Close-Prev-Close': -0.49130104288085064, '200D-Ratio': -0.23337174402001573, '100D-Ratio': -0.18121604071523634, '50D-Ratio': -0.21688141710326997, '20D-Ratio': -0.1994709429318135, 'MACD_HIST_NORM': -0.22982856467561535, 'MACD-Increase-Prev-MACD': -0.11815240293839381, 'MACD_BUY': 0.0, 'MACD_SELL': 0.0, 'MACD_HIST_NORM_SIGN': 0.0, 'MACD_SIGN': 0.0, 'MACD_TREND_SIGN': 0.0, 'RSI-below-30': 0.0, 'RSI-above-70': 0.0, 'RSI-trend-sign': 0.0, 'MACD_TREND_DERIV_SIGN': 0.0, 'SIG_TREND_DERIV_SIGN': 0.0, 'Above-200D': 0.0, 'Above-100D': 0.0, 'Above-50D': 0.0, 'Above-20D': 0.0, '200D-Trend': 0.0, '100D-Trend': 0.0, '50D-Trend': 0.0, '20D-Trend': 0.0, '200D-Trend-Deriv': 0.0, '100D-Trend-Deriv': 0.0, '50D-Trend-Deriv': 0.0, '20D-Trend-Deriv': 0.0, 'Volatility-10': 0.011777735253685598, 'Volatility-20': 0.017434606615689144, 'Volatility-50': 0.027291469546054343, 'Volatility-100': 0.032999227362946984, 'Volatility-200': 0.04068867623659954, 'MACD_SIG': 0.0, 'below-three-sigma': 0.0, 'below-two-sigma': 0.0, 'below-one-sigma': 0.0, 'above-mean': 0.0, 'above-one-sigma': 0.0, 'above-two-sigma': 0.0, 'above-three-sigma': 0.0, 'up-from-yesterday': 0.0, 'up-one-sigma': 0.0, 'down-one-sigma': 0.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 0.0, '20-D-up-from-yesterday': 0.0, '50-D-up-from-yesterday': 0.0, '100-D-up-from-yesterday': 0.0, '200-D-up-from-yesterday': 0.0, '10-D-up-derivate-from-yesterday': -1.0, '20-D-up-derivate-from-yesterday': -1.0, '50-D-up-derivate-from-yesterday': -1.0, '100-D-up-derivate-from-yesterday': -1.0, '200-D-up-derivate-from-yesterday': -1.0}
# doing binary classification
# num_neg: 615, num_pos: 925
# Confusion Matrix:
# [[ 68  99]
#  [ 88 130]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.41      0.42       167
#            1       0.57      0.60      0.58       218
#
#     accuracy                           0.51       385
#    macro avg       0.50      0.50      0.50       385
# weighted avg       0.51      0.51      0.51       385
#
# Accuracy: 0.5143
#       prediction  signal
# 2233           1       1
# 2234           0       0
# 2235           0       0
# 2236           0       0
# 2237           0       0
# buy_signals_count: 204
# total_rows: 249
# Saved performance summary to: ..//xgboost-models//MSFT//performance_summary.csv
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['prediction'] = model.predict(X)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['signal'] = (all_data['prediction'] > 0.5).astype(int)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:354: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:364: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:374: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:472: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Threshold"] = data["Threshold"].apply(lambda x: min(x, 0.025))
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:473: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:474: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fixed_mean = data[underlying_target].rolling(window=200).mean().iloc[-2]
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:475: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fixed_stddev = data[underlying_target].rolling(window=200).std().iloc[-2]
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:493: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:498: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:500: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:502: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Close-To-Open-200-Stddev"] = talib.STDDEV(data["Close-Open-Ratio"], timeperiod=period)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:503: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Close-To-Open-200-Threshold"] = (data["Close-To-Open-200-Mean"] + 1.0 * data["Close-To-Open-200-Stddev"])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:548: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    print(f"Next-Day-High-To-Next-Day-Open-Ratio: VAL HERE: {val} SIGMA HERE: {sigma}")
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:549: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:550: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Next-Day-High-To-Next-Day-Open-Ratio-Above-One-Sigma"] = (data["Next-Day-High-To-Next-Day-Open-Ratio"] > val+ 1 * sigma).astype(float)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:551: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:552: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   #    data["Above-1.02"] = (data[underlying_target] > 0.02).astype(float)
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:553: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:554: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Open-To-Prev-Close-Ratio'] = data['Open'].div(data['Close'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:557: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['High-To-Prev-High-Ratio'] = data['High'].div(data['High'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:558: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Low-To-Prev-Low-Ratio'] = data['Low'].div(data['Low'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:559: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Volume-To-Prev-Volume-Ratio'] = data['Volume'].div(data['Volume'].shift())
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:560: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['100-D-MA'] = data['Close'].rolling(window=100).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:561: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['50-D-MA'] = data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:566: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /Users/rifatordulu/Developer/lstm-stock-price-prediction/helpers/data_manipulator.py:572: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   # data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# fetch_finance_data_for_tickers: just returning file name: AMZN for interval: 10y
# DOING EARNINGS
# fixed_mean: 0.0003136110631468425, fixed_stddev: 0.016442057848305523
# train_data:            Date        Open        High         Low       Close      Volume  \
# 313  2016-07-05   36.139999   36.478001   35.980499   36.404999  48628000.0
# 314  2016-07-06   36.285500   36.888500   36.129002   36.880501  78764000.0
# 315  2016-07-07   36.966499   36.977501   36.581501   36.828499  58916000.0
# 316  2016-07-08   37.007000   37.305000   36.900002   37.290501  68584000.0
# 317  2016-07-11   37.500000   37.794998   37.349998   37.688999  63906000.0
# ...         ...         ...         ...         ...         ...         ...
# 2236 2024-02-26  175.699997  176.369995  174.259995  174.729996  44368600.0
# 2237 2024-02-27  174.080002  174.619995  172.860001  173.539993  31141700.0
# 2238 2024-02-28  172.440002  174.050003  172.270004  173.160004  28180500.0
# 2239 2024-02-29  173.009995  177.220001  172.850006  176.759995  53805400.0
# 2240 2024-03-01  176.750000  178.729996  176.070007  178.220001  31956200.0
#
#        Adj Close TICKER      MACD  SIG_LINE  ...  10-D-up-from-yesterday  \
# 313    36.404999   AMZN  0.246906  0.261927  ...                     1.0
# 314    36.880501   AMZN  0.315486  0.272639  ...                     1.0
# 315    36.828499   AMZN  0.361474  0.290406  ...                     1.0
# 316    37.290501   AMZN  0.430240  0.318373  ...                     1.0
# 317    37.688999   AMZN  0.511002  0.356899  ...                     1.0
# ...          ...    ...       ...       ...  ...                     ...
# 2236  174.729996   AMZN  4.376422  4.396182  ...                     1.0
# 2237  173.539993   AMZN  4.271931  4.371332  ...                     1.0
# 2238  173.160004   AMZN  4.111070  4.319280  ...                     1.0
# 2239  176.759995   AMZN  4.225369  4.300497  ...                     1.0
# 2240  178.220001   AMZN  4.383234  4.317045  ...                     1.0
#
#       20-D-up-from-yesterday  50-D-up-from-yesterday  100-D-up-from-yesterday  \
# 313                      1.0                     1.0                      1.0
# 314                      1.0                     1.0                      1.0
# 315                      1.0                     1.0                      1.0
# 316                      1.0                     1.0                      1.0
# 317                      1.0                     1.0                      1.0
# ...                      ...                     ...                      ...
# 2236                     1.0                     1.0                      1.0
# 2237                     1.0                     1.0                      1.0
# 2238                     1.0                     1.0                      1.0
# 2239                     1.0                     1.0                      1.0
# 2240                     1.0                     1.0                      1.0
#
# ...
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['target'] = ((all_data['future_avg_close'] / all_data['Close']) > 1.0).astype(int)
# fetch_finance_data_for_tickers: just returning file name: BAC for interval: 10y
# DOING EARNINGS
# fixed_mean: -0.000489240451992079, fixed_stddev: 0.0124837245735405
# train_data:            Date       Open       High        Low      Close       Volume  \
# 313  2016-07-05  12.930000  12.940000  12.630000  10.479042   98246500.0
# 314  2016-07-06  12.520000  12.920000  12.450000  10.577745   94983300.0
# 315  2016-07-07  12.870000  13.110000  12.840000  10.701127  101100300.0
# 316  2016-07-08  13.280000  13.320000  13.110000  10.832732   92698900.0
# 317  2016-07-11  13.290000  13.400000  13.200000  10.865631   67267300.0
# ...         ...        ...        ...        ...        ...          ...
# 2236 2024-02-26  33.790001  34.220001  33.529999  32.570396   31129200.0
# 2237 2024-02-27  33.730000  34.430000  33.709999  33.219669   40536300.0
# 2238 2024-02-28  34.220001  34.599998  34.110001  33.248749   39548600.0
# 2239 2024-02-29  34.330002  34.650002  34.150002  33.687897   43863400.0
# 2240 2024-03-01  34.529999  34.650002  34.029999  33.521996   38424200.0
#
#       Adj Close TICKER      MACD  SIG_LINE  ...  10-D-up-from-yesterday  \
# 313   10.479042    BAC -0.348299 -0.310188  ...                     0.0
# 314   10.577745    BAC -0.348304 -0.317811  ...                     0.0
# 315   10.701127    BAC -0.332372 -0.320723  ...                     0.0
# 316   10.832732    BAC -0.303339 -0.317246  ...                     0.0
# 317   10.865631    BAC -0.273944 -0.308586  ...                     1.0
# ...         ...    ...       ...       ...  ...                     ...
# 2236  32.570396    BAC  0.211797  0.210182  ...                     1.0
# 2237  33.219669    BAC  0.248942  0.217934  ...                     1.0
# 2238  33.248749    BAC  0.277600  0.229868  ...                     1.0
# 2239  33.687897    BAC  0.313642  0.246622  ...                     1.0
# 2240  33.521996    BAC  0.324744  0.262247  ...                     1.0
#
#       20-D-up-from-yesterday  50-D-up-from-yesterday  100-D-up-from-yesterday  \
# 313                      0.0                     0.0                      1.0
# 314                      0.0                     0.0                      1.0
# 315                      0.0                     0.0                      1.0
# 316                      0.0                     0.0                      1.0
# 317                      0.0                     0.0                      1.0
# ...                      ...                     ...                      ...
# 2236                     1.0                     1.0                      1.0
# 2237                     1.0                     1.0                      1.0
# 2238                     0.0                     1.0                      1.0
# 2239                     1.0                     1.0                      1.0
# 2240                     1.0                     1.0                      1.0
#
#       200-D-up-from-yesterday  10-D-up-derivate-from-yesterday  \
# 313                       0.0                              0.0
# 314                       0.0                              0.0
# 315                       0.0                              0.0
# 316                       0.0                              0.0
# 317                       0.0                              1.0
# ...                       ...                              ...
# 2236                      1.0                              0.0
# 2237                      1.0                              0.0
# 2238                      1.0                              0.0
# 2239                      1.0                              0.0
# 2240                      1.0                              0.0
#
#       20-D-up-derivate-from-yesterday  50-D-up-derivate-from-yesterday  \
# 313                               0.0                              0.0
# 314                               0.0                              0.0
# 315                               0.0                              0.0
# 316                               0.0                              0.0
# 317                               0.0                              0.0
# ...                               ...                              ...
# 2236                              0.0                              0.0
# 2237                              0.0                              0.0
# 2238                             -1.0                              0.0
# 2239                              1.0                              0.0
# 2240                              0.0                              0.0
#
#       100-D-up-derivate-from-yesterday  200-D-up-derivate-from-yesterday
# 313                                0.0                               0.0
# 314                                0.0                               0.0
# 315                                0.0                               0.0
# 316                                0.0                               0.0
# 317                                0.0                               0.0
# ...                                ...                               ...
# 2236                               0.0                               0.0
# 2237                               0.0                               0.0
# 2238                               0.0                               0.0
# 2239                               0.0                               0.0
# 2240                               0.0                               0.0
#
# [1928 rows x 164 columns]
# Maximum values:
#  {'High-Low-Ratio': 0.48245614035087686, 'High-Open-Ratio': 0.36911132746461595, 'Close-Open-Ratio': 0.29592898692227, 'Close-Prev-Close': 0.5932064972855544, '200D-Ratio': 0.566073379238626, '100D-Ratio': 0.42006108703184886, '50D-Ratio': 0.29712185582140804, '20D-Ratio': 0.2096624094194165, 'MACD_HIST_NORM': 0.3377279721667319, 'MACD-Increase-Prev-MACD': 0.1444225727722968, 'MACD_BUY': 1.0, 'MACD_SELL': 1.0, 'MACD_HIST_NORM_SIGN': 1.0, 'MACD_SIGN': 1.0, 'MACD_TREND_SIGN': 1.0, 'RSI-below-30': 1.0, 'RSI-above-70': 1.0, 'RSI-trend-sign': 1.0, 'MACD_TREND_DERIV_SIGN': 1.0, 'SIG_TREND_DERIV_SIGN': 1.0, 'Above-200D': 1.0, 'Above-100D': 1.0, 'Above-50D': 1.0, 'Above-20D': 1.0, '200D-Trend': 1.0, '100D-Trend': 1.0, '50D-Trend': 1.0, '20D-Trend': 1.0, '200D-Trend-Deriv': 1.0, '100D-Trend-Deriv': 1.0, '50D-Trend-Deriv': 1.0, '20D-Trend-Deriv': 1.0, 'Volatility-10': 0.5603638803840032, 'Volatility-20': 0.4548782913107541, 'Volatility-50': 0.3279720354032644, 'Volatility-100': 0.2644102890972616, 'Volatility-200': 0.2050302838573073, 'MACD_SIG': 1.1111111111111112, 'below-three-sigma': 1.0, 'below-two-sigma': 1.0, 'below-one-sigma': 1.0, 'above-mean': 1.0, 'above-one-sigma': 1.0, 'above-two-sigma': 1.0, 'above-three-sigma': 1.0, 'up-from-yesterday': 1.0, 'up-one-sigma': 1.0, 'down-one-sigma': 1.0, 'up-two-sigma': 1.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 1.0, '20-D-up-from-yesterday': 1.0, '50-D-up-from-yesterday': 1.0, '100-D-up-from-yesterday': 1.0, '200-D-up-from-yesterday': 1.0, '10-D-up-derivate-from-yesterday': 1.0, '20-D-up-derivate-from-yesterday': 1.0, '50-D-up-derivate-from-yesterday': 1.0, '100-D-up-derivate-from-yesterday': 1.0, '200-D-up-derivate-from-yesterday': 1.0}
#
# Minimum values:
#  {'High-Low-Ratio': 0.01463954494270725, 'High-Open-Ratio': 0.0, 'Close-Open-Ratio': -0.3201593337322754, 'Close-Prev-Close': -0.5132449416182369, '200D-Ratio': -0.45110438132801384, '100D-Ratio': -0.4843987448683372, '50D-Ratio': -0.4498312424944415, '20D-Ratio': -0.33432749910320664, 'MACD_HIST_NORM': -0.45210932695407824, 'MACD-Increase-Prev-MACD': -0.20483381934902056, 'MACD_BUY': 0.0, 'MACD_SELL': 0.0, 'MACD_HIST_NORM_SIGN': 0.0, 'MACD_SIGN': 0.0, 'MACD_TREND_SIGN': 0.0, 'RSI-below-30': 0.0, 'RSI-above-70': 0.0, 'RSI-trend-sign': 0.0, 'MACD_TREND_DERIV_SIGN': 0.0, 'SIG_TREND_DERIV_SIGN': 0.0, 'Above-200D': 0.0, 'Above-100D': 0.0, 'Above-50D': 0.0, 'Above-20D': 0.0, '200D-Trend': 0.0, '100D-Trend': 0.0, '50D-Trend': 0.0, '20D-Trend': 0.0, '200D-Trend-Deriv': 0.0, '100D-Trend-Deriv': 0.0, '50D-Trend-Deriv': 0.0, '20D-Trend-Deriv': 0.0, 'Volatility-10': 0.018050630904230393, 'Volatility-20': 0.030247846326312517, 'Volatility-50': 0.04443475403161625, 'Volatility-100': 0.05297801178669953, 'Volatility-200': 0.062164806083318466, 'MACD_SIG': 0.0, 'below-three-sigma': 0.0, 'below-two-sigma': 0.0, 'below-one-sigma': 0.0, 'above-mean': 0.0, 'above-one-sigma': 0.0, 'above-two-sigma': 0.0, 'above-three-sigma': 0.0, 'up-from-yesterday': 0.0, 'up-one-sigma': 0.0, 'down-one-sigma': 0.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 0.0, '20-D-up-from-yesterday': 0.0, '50-D-up-from-yesterday': 0.0, '100-D-up-from-yesterday': 0.0, '200-D-up-from-yesterday': 0.0, '10-D-up-derivate-from-yesterday': -1.0, '20-D-up-derivate-from-yesterday': -1.0, '50-D-up-derivate-from-yesterday': -1.0, '100-D-up-derivate-from-yesterday': -1.0, '200-D-up-derivate-from-yesterday': -1.0}
# Maximum values:
#  {'High-Low-Ratio': 0.48245614035087686, 'High-Open-Ratio': 0.36911132746461595, 'Close-Open-Ratio': 0.29592898692227, 'Close-Prev-Close': 0.5932064972855544, '200D-Ratio': 0.566073379238626, '100D-Ratio': 0.42006108703184886, '50D-Ratio': 0.29712185582140804, '20D-Ratio': 0.2096624094194165, 'MACD_HIST_NORM': 0.3377279721667319, 'MACD-Increase-Prev-MACD': 0.1444225727722968, 'MACD_BUY': 1.0, 'MACD_SELL': 1.0, 'MACD_HIST_NORM_SIGN': 1.0, 'MACD_SIGN': 1.0, 'MACD_TREND_SIGN': 1.0, 'RSI-below-30': 1.0, 'RSI-above-70': 1.0, 'RSI-trend-sign': 1.0, 'MACD_TREND_DERIV_SIGN': 1.0, 'SIG_TREND_DERIV_SIGN': 1.0, 'Above-200D': 1.0, 'Above-100D': 1.0, 'Above-50D': 1.0, 'Above-20D': 1.0, '200D-Trend': 1.0, '100D-Trend': 1.0, '50D-Trend': 1.0, '20D-Trend': 1.0, '200D-Trend-Deriv': 1.0, '100D-Trend-Deriv': 1.0, '50D-Trend-Deriv': 1.0, '20D-Trend-Deriv': 1.0, 'Volatility-10': 0.5603638803840032, 'Volatility-20': 0.4548782913107541, 'Volatility-50': 0.3279720354032644, 'Volatility-100': 0.2644102890972616, 'Volatility-200': 0.2050302838573073, 'MACD_SIG': 1.1111111111111112, 'below-three-sigma': 1.0, 'below-two-sigma': 1.0, 'below-one-sigma': 1.0, 'above-mean': 1.0, 'above-one-sigma': 1.0, 'above-two-sigma': 1.0, 'above-three-sigma': 1.0, 'up-from-yesterday': 1.0, 'up-one-sigma': 1.0, 'down-one-sigma': 1.0, 'up-two-sigma': 1.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 1.0, '20-D-up-from-yesterday': 1.0, '50-D-up-from-yesterday': 1.0, '100-D-up-from-yesterday': 1.0, '200-D-up-from-yesterday': 1.0, '10-D-up-derivate-from-yesterday': 1.0, '20-D-up-derivate-from-yesterday': 1.0, '50-D-up-derivate-from-yesterday': 1.0, '100-D-up-derivate-from-yesterday': 1.0, '200-D-up-derivate-from-yesterday': 1.0}
#
# Minimum values:
#  {'High-Low-Ratio': 0.01463954494270725, 'High-Open-Ratio': 0.0, 'Close-Open-Ratio': -0.3201593337322754, 'Close-Prev-Close': -0.5132449416182369, '200D-Ratio': -0.45110438132801384, '100D-Ratio': -0.4843987448683372, '50D-Ratio': -0.4498312424944415, '20D-Ratio': -0.33432749910320664, 'MACD_HIST_NORM': -0.45210932695407824, 'MACD-Increase-Prev-MACD': -0.20483381934902056, 'MACD_BUY': 0.0, 'MACD_SELL': 0.0, 'MACD_HIST_NORM_SIGN': 0.0, 'MACD_SIGN': 0.0, 'MACD_TREND_SIGN': 0.0, 'RSI-below-30': 0.0, 'RSI-above-70': 0.0, 'RSI-trend-sign': 0.0, 'MACD_TREND_DERIV_SIGN': 0.0, 'SIG_TREND_DERIV_SIGN': 0.0, 'Above-200D': 0.0, 'Above-100D': 0.0, 'Above-50D': 0.0, 'Above-20D': 0.0, '200D-Trend': 0.0, '100D-Trend': 0.0, '50D-Trend': 0.0, '20D-Trend': 0.0, '200D-Trend-Deriv': 0.0, '100D-Trend-Deriv': 0.0, '50D-Trend-Deriv': 0.0, '20D-Trend-Deriv': 0.0, 'Volatility-10': 0.018050630904230393, 'Volatility-20': 0.030247846326312517, 'Volatility-50': 0.04443475403161625, 'Volatility-100': 0.05297801178669953, 'Volatility-200': 0.062164806083318466, 'MACD_SIG': 0.0, 'below-three-sigma': 0.0, 'below-two-sigma': 0.0, 'below-one-sigma': 0.0, 'above-mean': 0.0, 'above-one-sigma': 0.0, 'above-two-sigma': 0.0, 'above-three-sigma': 0.0, 'up-from-yesterday': 0.0, 'up-one-sigma': 0.0, 'down-one-sigma': 0.0, 'up-two-sigma': 0.0, 'down-two-sigma': 0.0, '10-D-up-from-yesterday': 0.0, '20-D-up-from-yesterday': 0.0, '50-D-up-from-yesterday': 0.0, '100-D-up-from-yesterday': 0.0, '200-D-up-from-yesterday': 0.0, '10-D-up-derivate-from-yesterday': -1.0, '20-D-up-derivate-from-yesterday': -1.0, '50-D-up-derivate-from-yesterday': -1.0, '100-D-up-derivate-from-yesterday': -1.0, '200-D-up-derivate-from-yesterday': -1.0}
# doing binary classification
# num_neg: 712, num_pos: 828
# Confusion Matrix:
# [[ 64 133]
#  [ 68 120]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.32      0.39       197
#            1       0.47      0.64      0.54       188
#
#     accuracy                           0.48       385
#    macro avg       0.48      0.48      0.47       385
# weighted avg       0.48      0.48      0.46       385
#
# Accuracy: 0.4779
#       prediction  signal
# 2233           0       0
# 2234           0       0
# 2235           0       0
# 2236           0       0
# 2237           1       1
# buy_signals_count: 76
# total_rows: 249
# Saved performance summary to: ..//xgboost-models//BAC//performance_summary.csv
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['prediction'] = model.predict(X)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['signal'] = (all_data['prediction'] > 0.5).astype(int)
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:354: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:364: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_34198/199254596.py:374: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# do_binary_reg = True
# use_log_for_linear_reg = False
# use_horizon = True

# import pandas as pd
# import xgboost as xgb
# from xgboost import XGBRegressor
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# from xgboost import plot_importance
# import matplotlib.pyplot as plt

# # 1. Prepare data
# features = lstm_features_v2

# if use_horizon:
#     N1 = 1
#     N2 = 20
#     gamma = 0.8
    
#     # Create numerator and denominator separately
#     weights = [gamma**i for i in range(N1, N2 + 1)]
    
#     # Weighted sum of future closes
#     numerator = sum([
#         all_data['Close'].shift(-i) * weight
#         for i, weight in zip(range(N1, N2 + 1), weights)
#     ])
    
#     # Weighted average
#     denominator = sum(weights)
#     future_weighted_avg = numerator / denominator
    
#     # Set as regression target
#     all_data['future_avg_close'] = future_weighted_avg
#     all_data['forward_log_return'] = all_data['future_avg_close'] / all_data['Close']
    
#     # Drop NaNs from shifting
#     all_data = all_data.dropna(subset=['forward_log_return'])
    
#     if use_log_for_linear_reg:
#         all_data['forward_log_return'] = np.log(all_data['forward_log_return'])
    
#     # Binary classification target (optional)
#     all_data['target'] = ((all_data['future_avg_close'] / all_data['Close']) > 1.00).astype(int)

# else:
#     all_data['target'] = (all_data["Next-Day-Close-To-Todays-Close-Ratio"] > 0)
#     all_data["forward_log_return"] = all_data['Next-Day-Close-To-Todays-Close-Ratio']

# # Drop NaNs caused by shifting


# if add_prev_day:
#     prev_day_features = [f"prev_day_{col}" for col in features]
#     X = all_data[features + prev_day_features]
#     X_val = all_data_val[features + prev_day_features]  # same features used in training
# else:
#     X = all_data[features]
#     X_val = all_data_val[features]


# if do_binary_reg:
#     y = all_data['target']
# else:
#     y = all_data['forward_log_return']

# # 2. Train-test split (time-aware if it's time series!)
# X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

# if do_binary_reg:
#     print(f"doing binary classification")

#     class_counts = y_train.value_counts()

#     # Get number of negative and positive samples
#     num_neg = class_counts[0]
#     num_pos = class_counts[1]
    
#     # Calculate scale_pos_weight
#     scale_pos_weight = num_neg / num_pos

#     # 3. Train XGBoost Regressor
#     model = xgb.XGBClassifier(
#         n_estimators=2048,
#         max_depth=5,
#         learning_rate=0.05,
#         objective='binary:logistic',
#         eval_metric='logloss',
#         random_state=42,
#         subsample=0.8,         # fraction of rows to sample per tree
#         colsample_bytree=0.8,  # fraction of features per tree
#         tree_method='hist',   # Optional: can improve speed + determinism
#         enable_categorical=False,  # ensure consistent parsing
#         # class_weight='balanced',
#         scale_pos_weight=scale_pos_weight,
#     )
# else:
#     print(f"doing linear regression")
#     # 3. Train XGBoost Regressor
#     model = xgb.XGBRegressor(
#         n_estimators=512,
#         max_depth=8,
#         learning_rate=0.01,
#         objective='reg:squarederror',
#         eval_metric='rmse'
#     )
    
# model.fit(X_train, 
#           y_train,
#           # num_boost_round=500,
#           eval_set=[(X_test, y_test)],
#           # early_stopping_rounds=10,
#           verbose=False
#          )

# # 4. Evaluate regression performance
# y_pred = model.predict(X_test)
# if do_binary_reg:
#     print("Confusion Matrix:")
#     print(confusion_matrix(y_test, y_pred))
    
#     print("\nClassification Report:")
#     print(classification_report(y_test, y_pred))
    
#     print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# else:
#     print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred):.6f}")
#     print(f"R² Score: {r2_score(y_test, y_pred):.4f}")

# # 5. Predict full signals
# all_data['prediction'] = model.predict(X)

# # 6. Convert predicted return ratio to buy/sell signal
# # Buy = 1 if expected return is positive (i.e., predicted ratio > 1)
# if do_binary_reg:
#     all_data['signal'] = (all_data['prediction'] > 0.5).astype(int)
# else:
#     all_data['signal'] = (all_data['prediction'] > 0).astype(int)

# # Optional: Check some predictions
# print(all_data[['prediction', 'signal']].tail())

# plot_importance(model)

# %%
# # Predict return ratio
# all_data_val['prediction'] = model.predict(X_val)

# # Generate signal: Buy if predicted return > 0
# if do_binary_reg:
#     all_data_val['signal'] = (all_data_val['prediction'] > 0.5).astype(int)
# else:
#     all_data_val['signal'] = (all_data_val['prediction'] > 0).astype(int)

# %%
# initial_cash = 10000
# cash = 0
# position = initial_cash / all_data_val["Close"].iloc[0]
# portfolio_value = []

# for i in range(1, len(all_data_val)):
#     price_today = all_data_val.iloc[i]['Close']
#     signal = all_data_val.iloc[i - 1]['signal']  # we act on yesterday's prediction

#     # Buy signal (if not already in position)
#     if signal == 1 and position == 0:
#         position = cash / price_today
#         cash = 0

#     # Sell signal (if holding)
#     elif signal == 0 and position > 0:
#         cash = position * price_today
#         position = 0

#     # Track portfolio value
#     value = cash + position * price_today
#     portfolio_value.append(value)

# # Final value (if still holding)
# final_value = cash + position * all_data_val.iloc[-1]['Close']
# total_return = final_value - initial_cash

# buy_signals_count = (all_data_val['signal'] == 1).sum()
# total_rows = len(all_data_val)

# print(f"buy_signals_count: {buy_signals_count}")
# print(f"total_rows: {total_rows}")

# print(f"Final portfolio value: ${final_value:.2f}")
# print(f"Total return: ${total_return:.2f}")
# print(f"Return %: {100 * total_return / initial_cash:.2f}%")
# print(f"Stayed invest at : {100 * buy_signals_count / total_rows:.2f}% of times")
# print(f"Stock change %: {100 * ((all_data_val["Close"].iloc[-1] / all_data_val["Close"].iloc[0]) - 1.0)}%")

# %%
# import matplotlib.pyplot as plt

# plt.plot(portfolio_value)
# plt.title("Portfolio Value Over Time")
# plt.xlabel("Days")
# plt.ylabel("Value ($)")
# plt.grid(True)
# plt.show()


# plt.plot(all_data_val["Close"])
# plt.title("Close Value Over Time")
# plt.xlabel("Days")
# plt.ylabel("Value ($)")
# plt.grid(True)
# plt.show()


# plt.plot(all_data_val["signal"])
# plt.title("Signal Over Time")
# plt.xlabel("Days")
# plt.ylabel("Value")
# plt.grid(True)
# plt.show()
