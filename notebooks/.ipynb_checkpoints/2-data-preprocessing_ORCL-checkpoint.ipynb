# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 2 - Data Preprocessing
# This notebook focuses on processing the filtered dataset containing the historical prices of Google stocks over the past five years.
#
# > **INPUT**: Filtered dataset containing Google's stock prices from the last five years, obtained from the previous phase. <br/>
# > **OUTPUT**: Preprocessed and transformed data divided into training, validation, and testing subsets, stored in an interim location for the training phase.

# %%
# Parameters
TICKER = None  # Default value

# %%
# Parameters
TICKER = "ORCL"

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Import necessary libraries and modules
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import joblib
import matplotlib.dates as mdates
import numpy as np

# %%
# Set output width
pd.set_option("display.width", 120)

# %% [markdown]
# ### 2. LOADING DATASET

# %%
# Prepare data file location and name
# data_file_location = "..//data//raw//"
# data_file_name = "google_stock_price_full"
# data_file_ext = "csv"

data_file_location = "..//data//raw//"
data_file_name = "ALL_stock_price_recent"
data_file_ext = "csv"

# Load data file
data = pd.read_csv(data_file_location + data_file_name + "." + data_file_ext)


if TICKER is not None:
    data = data[data['TICKER'] == TICKER]
    print(f"Loaded ticker: {TICKER}")
else:
    print(f"Could not load any TICKER")
# Out:
# Loaded ticker: ORCL

# %%
# Check loaded data shape
data.shape
# Out:
# (1258, 8)

# %%
# Check loaded data head
data.head()
# Out:
#        Unnamed: 0                       Date       Open       High        Low      Close    Volume TICKER
# 15096           0  2020-01-02 00:00:00-05:00  49.313980  49.952737  49.276950  49.943481  13899600   ORCL
# 15097           1  2020-01-03 00:00:00-05:00  49.054768  50.036046  49.017738  49.767582  11026700   ORCL
# 15098           2  2020-01-06 00:00:00-05:00  49.397293  50.174912  49.388034  50.026794  10982400   ORCL
# 15099           3  2020-01-07 00:00:00-05:00  49.887929  50.295255  49.628724  50.137878  12015400   ORCL
# 15100           4  2020-01-08 00:00:00-05:00  50.156474  50.770179  49.933310  50.333149  11856700   ORCL

# %%
# Check columns types
data.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume          int64
# TICKER         object
# dtype: object

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# #### Validate Data Types

# %%
# Convert date column to a valid Datetime format
data["Date"] = pd.to_datetime(data["Date"])

# Check column types
data.dtypes
# Out:
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_12235/713007676.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   data["Date"] = pd.to_datetime(data["Date"])
# Unnamed: 0      int64
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume          int64
# TICKER         object
# dtype: object

# %% [markdown]
# #### Select Independent Features

# %% [markdown]
# The objective of this analysis is to implement a multi-variant prediction, taking into account possible impact of several independent features such as the Open price, Close price and Volume on future stock price performance.
#
# Therefore, in this analysis, we will incorporate all the available variables:
# - Opening price
# - Highest price
# - Lowest price
# - Closing price
# - Adjusted closing price
# - Trading volume
#
# These features will be utilized to forecast the future opening price.

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %% [markdown]
# #### Create Train, Validation, and Test Datasets

# %% [markdown]
# To monitor and assess the performance of our model, we will partition the recent stock price dataset into three segments: training, validation, and testing sets.
#
# The division will be structured as follows:
# - **Training dataset:** covering the period from the start of 2019 till June, 2023.
# - **Validation dataset:** representing the stock prices from July, 2023 till the end of 2023.
# - **Testing dataset:** representing the stock prices for the first two months of 2024.

# %%
# Feature engineering:
data["High-Low-Diff"] = (data["High"] - data["Low"]) / data["Low"]
data["High-Low-Perc"] = data["High"] / data["Low"]
data["Close-Open-Diff"] = (data["Close"] - data["Open"]) / data["Open"]
data["Close-Open-Perc"] = data["Close"] / data["Open"]
data["Volume-In-Usd"] = data["Volume"] * (data["Low"] + (data["High-Low-Diff"] / 2) ) 
data['Compared-To-Prev-Close'] = data['Open'].div(data['Close'].shift())
data['Compared-To-Prev-Close-For-Close'] = data['Close'].div(data['Close'].shift())
data['Compared-To-Prev-Open-For-Open'] = data['Open'].div(data['Open'].shift())
data['Compared-To-Prev-High-For-High'] = data['High'].div(data['High'].shift())
data['Compared-To-Prev-Low-For-Low'] = data['Low'].div(data['Low'].shift())
data['Volume-In-Usd-In-Comparison'] = data['Volume-In-Usd'].div(data['Volume-In-Usd'].shift())
data['Pos-To-200D-MA'] = data["Close"] / data['Close'].rolling(window=200).mean()
data['Pos-To-100D-MA'] = data["Close"] / data['Close'].rolling(window=100).mean()
data['Pos-To-50D-MA'] = data["Close"] / data['Close'].rolling(window=50).mean()
data['Pos-To-20D-MA'] = data["Close"] / data['Close'].rolling(window=20).mean()
data['Pos-To-200D-MA-DoD'] = data['Pos-To-200D-MA'].div(data['Pos-To-200D-MA'].shift())
data['Pos-To-100D-MA-DoD'] = data['Pos-To-100D-MA'].div(data['Pos-To-100D-MA'].shift())
data['Pos-To-50D-MA-DoD'] = data['Pos-To-50D-MA'].div(data['Pos-To-50D-MA'].shift())
data['Pos-To-20D-MA-DoD'] = data['Pos-To-20D-MA'].div(data['Pos-To-20D-MA'].shift())
data['Log-Compared-To-Prev-Close-For-Close'] = np.log1p(data['Compared-To-Prev-Close-For-Close'])
data['Sq-Compared-To-Prev-Close-For-Close'] = data['Compared-To-Prev-Close-For-Close'] ** 2
data['Sq-Close-Open-Perc'] = data['Close-Open-Perc'] ** 2
data['Sq-Compared-To-Prev-Open'] = data['Compared-To-Prev-Open-For-Open'] ** 2

data['Open-Log'] = np.log(data['Open'])
data['Close-Log'] = np.log(data['Close'])
data['High-Log'] = np.log(data['High'])
data['Low-Log'] = np.log(data['Low'])
data['Open-Base'] = data['Open'] / min(data['Open'])
data['Close-Base'] = data['Close'] / min(data['Close'])
data['High-Base'] = data['High'] / min(data['High'])
data['Low-Base'] = data['Low'] / min(data['Low'])

data.replace([np.inf, -np.inf], np.nan, inplace=True)
data = data.dropna()

data = data.drop(columns=['Volume-In-Usd'])


print(f"DEBUG: {data.shape} + HEAD: {data.head()}")

# Initialize scaler with range [0,1]
sc = MinMaxScaler(feature_range=(0,1))

# Fit and transform scaler to training set
data[features_to_be_used] = sc.fit_transform(data[features_to_be_used])
# Out:
# DEBUG: (1058, 38) + HEAD:        Unnamed: 0                       Date       Open       High        Low      Close    Volume TICKER  \
# 15296         200  2020-10-16 00:00:00-04:00  57.190215  57.567026  56.766304  56.794567   6070800   ORCL
# 15297         201  2020-10-19 00:00:00-04:00  56.888772  57.227901  55.946749  56.163414   8311000   ORCL
# 15298         202  2020-10-20 00:00:00-04:00  56.446019  56.832252  56.172835  56.285877   9241200   ORCL
# 15299         203  2020-10-21 00:00:00-04:00  55.899652  56.634429  55.786610  56.210518  10114900   ORCL
# 15300         204  2020-10-22 00:00:00-04:00  55.993853  56.398923  55.287336  56.229359  11900600   ORCL
#
#        High-Low-Diff  High-Low-Perc  ...  Sq-Close-Open-Perc  Sq-Compared-To-Prev-Open  Open-Log  Close-Log  High-Log  \
# 15296       0.014106       1.014106  ...            0.986212                  1.014654  4.046383   4.039441  4.052950
# 15297       0.022899       1.022899  ...            0.974662                  0.989486  4.041098   4.028266  4.047042
# 15298       0.011739       1.011739  ...            0.994334                  0.984495  4.033285   4.030444  4.040104
# 15299       0.015198       1.015198  ...            1.011153                  0.980735  4.023558   4.029104  4.036617
# 15300       0.020106       1.020106  ...            1.008430                  1.003373  4.025242   4.029439  4.032450
#
#         Low-Log  Open-Base  Close-Base  High-Base  Low-Base
# 15296  4.038943   1.495728    1.534644   1.426488  1.537357
# 15297  4.024400   1.487844    1.517590   1.418084  1.515162
# 15298  4.028433   1.476265    1.520899   1.408280  1.521284
# 15299  4.021534   1.461975    1.518863   1.403378  1.510825
# 15300  4.012544   1.464439    1.519372   1.397543  1.497303
#
# [5 rows x 38 columns]

# %%
# Define start and end time for each period
train_end_date = pd.to_datetime("2023-06-30").tz_localize('UTC')
validate_start_date = pd.to_datetime("2023-07-01").tz_localize('UTC')
validate_end_date = pd.to_datetime("2023-12-31").tz_localize('UTC')
test_start_date = pd.to_datetime("2024-01-01").tz_localize('UTC')
test_end_date = pd.to_datetime("2024-02-29").tz_localize('UTC')

# Split dataset into training, validation, and testing
data_train = data[data["Date"] <= train_end_date][features_to_be_used]
data_train_dates = data[data["Date"] <= train_end_date]["Date"]
data_validate = data[(data["Date"] >= validate_start_date) & (data["Date"] <= validate_end_date)][features_to_be_used]
data_validate_dates = data[(data["Date"] >= validate_start_date) & (data["Date"] <= validate_end_date)]["Date"]
data_test = data[(data["Date"] >= test_start_date) & (data["Date"] <= test_end_date)][features_to_be_used]
data_test_dates = data[(data["Date"] >= test_start_date) & (data["Date"] <= test_end_date)]["Date"]

# %%
# Display the shape of each dataset
print(f"Training Set: {data_train.shape}")
print(f"Validation Set: {data_validate.shape}")
print(f"Testing Set: {data_test.shape}")
# Out:
# Training Set: (679, 5)
# Validation Set: (126, 5)
# Testing Set: (40, 5)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train.head())
print("Validation Dataset:")
print(data_validate.head())
print("Testing Dataset:")
print(data_test.head())
# Out:
# Training Dataset:
#            Open      High       Low     Close    Volume
# 15296  0.035970  0.030310  0.034526  0.031611  0.058741
# 15297  0.033881  0.027973  0.028659  0.027105  0.092460
# 15298  0.030813  0.025248  0.030278  0.027979  0.106461
# 15299  0.027027  0.023885  0.027513  0.027441  0.119612
# 15300  0.027680  0.022262  0.023939  0.027575  0.146490
# Validation Dataset:
#            Open      High       Low     Close    Volume
# 15976  0.441810  0.432821  0.448488  0.446531  0.031857
# 15977  0.431682  0.424441  0.438518  0.438197  0.094800
# 15978  0.419107  0.416332  0.433111  0.434625  0.087520
# 15979  0.420262  0.417481  0.432058  0.428743  0.072739
# 15980  0.416455  0.411060  0.426230  0.427132  0.071688
# Testing Dataset:
#            Open      High       Low     Close    Volume
# 16102  0.355215  0.346195  0.352615  0.360094  0.111824
# 16103  0.346862  0.337347  0.347665  0.348808  0.109688
# 16104  0.343234  0.337211  0.352332  0.349725  0.070052
# 16105  0.341591  0.339661  0.351555  0.350713  0.059655
# 16106  0.344398  0.346808  0.350423  0.364326  0.073310

# %%
# # Plot stock prices for each data split
# plt.figure(figsize=(18,6))
# plt.plot(data_train_dates, data_train["Open"], color="cornflowerblue")
# plt.plot(data_validate_dates, data_validate["Open"], color="orange")
# plt.plot(data_test_dates, data_test["Open"], color="green")
# plt.legend(["Train Data", "Validation Data", "Test Data"])
# plt.title("Data Split for Google Stock Price")
# plt.xlabel("Samples Over Time")
# plt.ylabel("Price (USD)")
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
# plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
# plt.xticks(rotation=45)
# plt.grid()

# %% [markdown]
# #### Data Scaling

# %%
# Check the distribution of input features
data_train[features_to_be_used].describe()
# Out:
#              Open        High         Low       Close      Volume
# count  679.000000  679.000000  679.000000  679.000000  679.000000
# mean     0.173674    0.170706    0.174471    0.176855    0.114496
# std      0.089300    0.089858    0.091436    0.092258    0.083806
# min      0.000000    0.000000    0.000000    0.000000    0.008831
# 25%      0.113855    0.112317    0.113545    0.115485    0.062824
# 50%      0.170453    0.167333    0.172489    0.174221    0.090729
# 75%      0.230929    0.227788    0.234400    0.236144    0.136093
# max      0.503871    0.495603    0.506907    0.512360    0.841404

# %% [markdown]
# Looking at these details, it's noticeable and anticipated that all price values exhibit similar distributions given they log the price fluctuation on daily basis.
#
# Conversely, the trading volume presents a distinct distribution that differs significantly.
#
# Accordingly, input features need to be transformed into a unified scale and since the distribution doesn't indicate any outliers, we will use the [0,1] range to normalize all features.
#
# To prevent data leakage, we will fit the scaler solely to the training data. Subsequently, we will use this fitted scaler to transform the training, validation, and testing datasets.

# %%
# Initialize scaler with range [0,1]
# sc = MinMaxScaler(feature_range=(0,1))

# Fit and transform scaler to training set
data_train_scaled = data_train #sc.fit_transform(data_train)

# Transform validating and testing datasets
data_validate_scaled = data_validate#sc.transform(data_validate)
data_test_scaled = data_test#sc.transform(data_test)

# %% [markdown]
# The scaler employed here will also be utilized in subsequent phases to revert the scaled data back to its original distribution. Therefore, it is essential to save this scaler to a local folder for future use.

# %%
# Prepare scaler model name and location
scaler_model_location = "..//models//"
scaler_model_name = TICKER + "_stock_price_scaler"
scaler_model_ext = "gz"

# Store scaler model
joblib.dump(sc, scaler_model_location + scaler_model_name + "." + scaler_model_ext)
# Out:
# ['..//models//ORCL_stock_price_scaler.gz']

# %% [markdown]
# ### 4. STORING PROCESSED DATASETS

# %% [markdown]
# The training, validation, and testing datasets have been processed and are prepared for training the LSTM model in the next phase.
#
# Prior to saving these datasets, it is necessary to reassemble the dates corresponding to each dataset. This will facilitate later evaluation of the model's performance.

# %%
# Combine dates with each corresponding dataset
data_train_scaled_final = pd.DataFrame(data_train_scaled, columns=features_to_be_used, index=None)
data_train_scaled_final["Date"] = data_train_dates.values

data_validate_scaled_final = pd.DataFrame(data_validate_scaled, columns=features_to_be_used, index=None)
data_validate_scaled_final["Date"] = data_validate_dates.values

data_test_scaled_final = pd.DataFrame(data_test_scaled, columns=features_to_be_used, index=None)
data_test_scaled_final["Date"] = data_test_dates.values

# %%
# Prepare datasets files and location
data_file_location = "..//data//processed//"
data_file_name_train = TICKER + "_stock_price_processed_train"
data_file_name_validate = TICKER + "_stock_price_processed_validate"
data_file_name_test = TICKER + "_stock_price_processed_test"
data_file_ext = "csv"

# Store datasets
data_train_scaled_final.to_csv(data_file_location + data_file_name_train + "." + data_file_ext, index=None)
data_validate_scaled_final.to_csv(data_file_location + data_file_name_validate + "." + data_file_ext, index=None)
data_test_scaled_final.to_csv(data_file_location + data_file_name_test + "." + data_file_ext, index=None)
