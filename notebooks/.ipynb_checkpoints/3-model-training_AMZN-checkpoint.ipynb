# %%
# Parameters
TICKER = "AMZN"

# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 48
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 04:50:59.033903: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = "google_stock_price_processed_train"
data_file_name_validate = "google_stock_price_processed_validate"
data_file_name_test = "google_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

if TICKER is not None:
    data_train_df = data_train_df[data_train_df['TICKER'] == TICKER]
    data_validate_df = data_validate_df[data_validate_df['TICKER'] == TICKER]
    data_test_df = data_test_df[data_test_df['TICKER'] == TICKER]

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (932, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (41, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.095067  0.092815  0.114254  0.094749  0.133300  2019-10-17
# 1  0.096304  0.090671  0.109972  0.091093  0.221433  2019-10-18
# 2  0.095717  0.088612  0.109740  0.091411  0.149765  2019-10-21
# 3  0.093561  0.086664  0.110117  0.089795  0.149016  2019-10-22
# 4  0.090876  0.091155  0.110591  0.097671  0.124298  2019-10-23
# Validation Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.660064  0.652145  0.667228  0.653320  0.076514  2023-07-03
# 1  0.657521  0.674865  0.670659  0.673287  0.119899  2023-07-05
# 2  0.663193  0.653402  0.662830  0.656889  0.118822  2023-07-06
# 3  0.665638  0.659203  0.670949  0.649268  0.154589  2023-07-07
# 4  0.647839  0.633293  0.637602  0.617726  0.286412  2023-07-10
# Testing Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.848613  0.841590  0.841555  0.836595  0.144569  2024-01-02
# 1  0.838834  0.846182  0.848224  0.844312  0.132489  2024-01-03
# 2  0.851058  0.841783  0.844164  0.821933  0.124554  2024-01-04
# 3  0.836408  0.824139  0.832952  0.815663  0.093517  2024-01-05
# 4  0.832966  0.841831  0.842908  0.845952  0.117863  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (932, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (105, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (1099, 5)
#
#  Data Train Scaled: (932, 5)
# > Data Train X: (868, 64, 5)
# > Data Train y: (868,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (41, 5)
# > Data Test X: (41, 64, 5)
# > Data Test y: (41,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 04:51:00.889957: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 04:51:00.889999: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:51:01.217904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:01.218806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:01.219378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:51:01.367011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:01.367942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:01.368554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:51:01.510525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:01.511645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:01.512395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 200)           480800
#  dropout_1 (Dropout)         (None, 64, 200)           0
#  lstm_2 (LSTM)               (None, 100)               120400
#  dropout_2 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 1,250,901
# Trainable params: 1,250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, early_stopping])
# Out:
# 2024-12-31 04:51:01.762359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:01.763559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:01.764297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:01.869963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:01.870532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:01.871148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 04:51:02.032051: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:02.032869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:02.033436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:02.273264: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:02.274114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:02.274828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:02.364497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:02.365139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:02.365782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:02.455584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:02.456285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:02.456878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:02.871644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:03.174155: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:03.285412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:03.356232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:03.518676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:03.702619: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/28 [>.............................] - ETA: 48s - loss: 0.0019
#  2/28 [=>............................] - ETA: 1s - loss: 0.0015
# 2024-12-31 04:51:03.837480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  4/28 [===>..........................] - ETA: 1s - loss: 0.0010
#  6/28 [=====>........................] - ETA: 0s - loss: 9.2229e-04
#  8/28 [=======>......................] - ETA: 0s - loss: 8.0942e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 7.8716e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.2635e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.0583e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.7843e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.5506e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2430e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.2290e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.2078e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 6.0597e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 6.0746e-04
# 28/28 [==============================] - ETA: 0s - loss: 6.0614e-04
# 2024-12-31 04:51:05.312512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:05.313410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:05.313962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:05.400257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:05.400867: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:05.401465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:05.487039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:51:05.487747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:51:05.488307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:51:05.527161: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:05.627018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:51:05.678417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 4s 72ms/step - loss: 6.0614e-04 - val_loss: 0.0019
# 2024-12-31 04:51:05.733717: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 2/1000
#  1/28 [>.............................] - ETA: 1s - loss: 8.6033e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.9640e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5148e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7062e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8040e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6417e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5041e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9752e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6906e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5466e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3965e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3210e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1836e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0671e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0946e-04 - val_loss: 0.0013
# Epoch 3/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.6467e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.5284e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.1952e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4899e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7933e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8782e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7269e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9061e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7819e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7999e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7064e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8198e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8156e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8639e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.8956e-04 - val_loss: 0.0038
# Epoch 4/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 7.8945e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 8.8681e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 8.0286e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 8.2374e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 7.6171e-04
# 13/28 [============>.................] - ETA: 0s - loss: 7.1044e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.6080e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.4884e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.2866e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 6.1802e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0044e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8720e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7427e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.7341e-04 - val_loss: 9.0283e-04
# Epoch 5/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.1517e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7711e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3158e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.6858e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9708e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0636e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8131e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0540e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9713e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8290e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8820e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0358e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9507e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0023e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9845e-04 - val_loss: 0.0029
# Epoch 6/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.5189e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.5689e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2402e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9337e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5689e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4508e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1895e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0779e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8939e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7564e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8809e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0135e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0208e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1246e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1271e-04 - val_loss: 6.4457e-04
# Epoch 7/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.0651e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.5393e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.5977e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8202e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6508e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5412e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2674e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2453e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2490e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1426e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2729e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3891e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2633e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2947e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2901e-04 - val_loss: 0.0018
# Epoch 8/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.1736e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1652e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3706e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5859e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8483e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3801e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1423e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0246e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8095e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9377e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0806e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9642e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1682e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0555e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0429e-04 - val_loss: 0.0014
# Epoch 9/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.5411e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7256e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1687e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9696e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0175e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0444e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9340e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1205e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2160e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3808e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3221e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2907e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1681e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1104e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0979e-04 - val_loss: 9.7072e-04
# Epoch 10/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.2830e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.5367e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1749e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7168e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7504e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4923e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0910e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9798e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8765e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1252e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0055e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9323e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8686e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8483e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.8409e-04 - val_loss: 0.0033
# Epoch 11/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.6502e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.6161e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1884e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0140e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4260e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3208e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3209e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3444e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2778e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6376e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5047e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3623e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2331e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1971e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1940e-04 - val_loss: 0.0014
# Epoch 12/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.8496e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7562e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1417e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7722e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4739e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0939e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0610e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7865e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0943e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1294e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0082e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9788e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9131e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2190e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2305e-04 - val_loss: 0.0010
# Epoch 13/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.6051e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.1162e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.7510e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9425e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1492e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 5.2367e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 5.0085e-04
# 14/28 [==============>...............] - ETA: 0s - loss: 4.8621e-04
# 16/28 [================>.............] - ETA: 0s - loss: 5.2931e-04
# 18/28 [==================>...........] - ETA: 0s - loss: 5.0824e-04
# 20/28 [====================>.........] - ETA: 0s - loss: 4.9496e-04
# 22/28 [======================>.......] - ETA: 0s - loss: 4.9102e-04
# 24/28 [========================>.....] - ETA: 0s - loss: 4.8935e-04
# 26/28 [==========================>...] - ETA: 0s - loss: 4.9396e-04
# 28/28 [==============================] - ETA: 0s - loss: 4.9382e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 4.9382e-04 - val_loss: 0.0039
# Epoch 14/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0013
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0579e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7347e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3814e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3256e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6713e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6952e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4301e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3895e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1826e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2090e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1777e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0615e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0243e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0144e-04 - val_loss: 0.0032
# Epoch 15/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.7996e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.4349e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0431e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9473e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7204e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3765e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2361e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4032e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2605e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0145e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0631e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1868e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2929e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4480e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.4555e-04 - val_loss: 0.0012
# Epoch 16/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.0142e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.9415e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.8723e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.1353e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.3296e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.1932e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.1175e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.2441e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5601e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9089e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8835e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1954e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2372e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0709e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0886e-04 - val_loss: 7.6154e-04
# Epoch 17/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.9664e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.6202e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8057e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8924e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5654e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7720e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7924e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9379e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8884e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8029e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8228e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7633e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.7232e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9743e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9687e-04 - val_loss: 8.8351e-04
# Epoch 18/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.9742e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.6068e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4180e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4919e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8360e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5773e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6899e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6909e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7268e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7826e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8242e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9195e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0318e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9995e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.0277e-04 - val_loss: 5.0177e-04
# Epoch 19/1000
#  1/28 [>.............................] - ETA: 1s - loss: 0.0013
#  3/28 [==>...........................] - ETA: 0s - loss: 9.0464e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4456e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3493e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7693e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6863e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5985e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5417e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6270e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9181e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7952e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7416e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6732e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.6071e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 5.5857e-04 - val_loss: 0.0011
# Epoch 20/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.7714e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7677e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.6204e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.6547e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.4554e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5808e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1008e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1819e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1224e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2964e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2082e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0585e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1807e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1079e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1014e-04 - val_loss: 8.4468e-04
# Epoch 21/1000
#  1/28 [>.............................] - ETA: 1s - loss: 5.1943e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.2871e-04
#  5/28 [====>.........................] - ETA: 1s - loss: 5.3325e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0524e-04
#  8/28 [=======>......................] - ETA: 0s - loss: 5.4660e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 5.1507e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 5.2567e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1937e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1769e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0758e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0292e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8412e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8337e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8353e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9400e-04
# 28/28 [==============================] - 1s 45ms/step - loss: 4.9559e-04 - val_loss: 0.0025
# Epoch 22/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.9355e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7584e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.2143e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4136e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3982e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1535e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4477e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4020e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2705e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0418e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0989e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0920e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2118e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0596e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 5.1329e-04 - val_loss: 7.3844e-04
# Epoch 23/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.0138e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.3509e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1048e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1318e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9514e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7574e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6776e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8885e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1327e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0069e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9170e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9980e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0415e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0666e-04
# 28/28 [==============================] - 1s 39ms/step - loss: 5.0466e-04 - val_loss: 8.1210e-04
# Epoch 24/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.4330e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.8287e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3843e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8948e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9091e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7188e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.3710e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.3434e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.6733e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7107e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8186e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8253e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0299e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0697e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0481e-04 - val_loss: 0.0014
# Epoch 25/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.3992e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.3393e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.9679e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7368e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5199e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2438e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9613e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1014e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1026e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4338e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.6263e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5689e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3835e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2283e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2158e-04 - val_loss: 6.2348e-04
# Epoch 26/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8734e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6645e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1725e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4742e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8164e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8062e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7418e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9824e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3120e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2709e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1789e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0567e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1085e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0946e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.0880e-04 - val_loss: 6.6564e-04
# Epoch 27/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.3745e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.2152e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.3073e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7031e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4969e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3842e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4244e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7483e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5517e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3159e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4442e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3972e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2262e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1212e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1317e-04 - val_loss: 0.0033
# Epoch 28/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.5457e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.1534e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.3176e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6728e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5159e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2540e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5347e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7463e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7289e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4696e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3498e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3232e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1793e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1136e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.0921e-04 - val_loss: 0.0012
# Epoch 29/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.3813e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4777e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.6335e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.2968e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.2665e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4815e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5565e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8244e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1398e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2176e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1823e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1924e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1901e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2435e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2405e-04 - val_loss: 5.8508e-04
# Epoch 30/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.9560e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1069e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.1020e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3092e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5103e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5690e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.7292e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8712e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8974e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0014e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2789e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2780e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2115e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2457e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2595e-04 - val_loss: 0.0033
# Epoch 31/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0015
#  3/28 [==>...........................] - ETA: 0s - loss: 8.1627e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.3384e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0759e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.7347e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.1034e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7930e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9009e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9590e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6623e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4575e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3907e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3871e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3021e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2877e-04 - val_loss: 0.0013
# Epoch 32/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.8107e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4101e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9858e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1580e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9152e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0483e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0830e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9961e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9626e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9366e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9656e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9429e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0162e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9932e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9846e-04 - val_loss: 6.6091e-04
# Epoch 33/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.3764e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1578e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.5829e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.4240e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8452e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.1436e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.0090e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6508e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6014e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6960e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4426e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3456e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1635e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2040e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1854e-04 - val_loss: 8.2323e-04
# Epoch 34/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.5882e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.8784e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.0297e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0575e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8077e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9626e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0972e-04
# ...
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9480e-04 - val_loss: 0.0011
# Epoch 117/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8889e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7518e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6599e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3968e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9949e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6971e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3224e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3841e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4539e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3926e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4076e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3671e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2195e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1224e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1005e-04 - val_loss: 0.0015
# Epoch 118/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.5580e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.1249e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1809e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3249e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9079e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.7620e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8672e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9216e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1547e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0936e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0418e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0117e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0025e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8849e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8671e-04 - val_loss: 9.1844e-04
# Epoch 119/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.5380e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.0708e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.1761e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.5514e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.4158e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4702e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6408e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.5186e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.4908e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.4846e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.3694e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.5109e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.6455e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8116e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8020e-04 - val_loss: 6.3579e-04
# Epoch 120/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.8905e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6278e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2318e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0950e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9251e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8962e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9581e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0333e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2881e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2255e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0882e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2392e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1424e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2739e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2560e-04 - val_loss: 7.1218e-04
# Epoch 121/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.1856e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6691e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4841e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6611e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8634e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6122e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3528e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1657e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0624e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8837e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9098e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0140e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9260e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1957e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1835e-04 - val_loss: 0.0024
# Epoch 122/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.7494e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7754e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8594e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1973e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3727e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1632e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3824e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4818e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4002e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2600e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1710e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1647e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2471e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1754e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1622e-04 - val_loss: 0.0023
# Epoch 123/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.5942e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.2179e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4745e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9660e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2501e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.2525e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0755e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8499e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8533e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9015e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1270e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1905e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1376e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0944e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1162e-04 - val_loss: 4.7014e-04
# Epoch 124/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.7048e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.1768e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.4597e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3207e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.3677e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4963e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6844e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2640e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1047e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9924e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8194e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1157e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3632e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2526e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.2413e-04 - val_loss: 0.0028
# Epoch 125/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.4240e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9642e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8084e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9744e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9442e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8187e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5898e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6298e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.6706e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.6766e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.7609e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8508e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8571e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9148e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 4.9035e-04 - val_loss: 0.0025
# Epoch 126/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.0780e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.6592e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.9483e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5515e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0857e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1208e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1797e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9690e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7887e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8464e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9199e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8256e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8299e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8026e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.8040e-04 - val_loss: 0.0014
# Epoch 127/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.2709e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 9.3686e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3853e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.3818e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.7506e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.3284e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.0112e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8364e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6034e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5884e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3489e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1678e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1350e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9573e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9457e-04 - val_loss: 0.0018
# Epoch 128/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.6514e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.3647e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2094e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.6718e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0353e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8707e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.6544e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7557e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8362e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8778e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9150e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.8144e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8341e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.8727e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 4.8555e-04 - val_loss: 0.0015
# Epoch 129/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.5297e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.3865e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9775e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8628e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5220e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3052e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2110e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1776e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0347e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0409e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1668e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1380e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0229e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9919e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 4.9911e-04 - val_loss: 0.0017
# Epoch 130/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0010
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7740e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0774e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3948e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9733e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8040e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3465e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9708e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8803e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9215e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0072e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1066e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1291e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1191e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1022e-04 - val_loss: 7.4393e-04
# Epoch 131/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.3337e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.9500e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.4263e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.8119e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4567e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0928e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1208e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2586e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2722e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3403e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2978e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1574e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1071e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2313e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.2113e-04 - val_loss: 9.3234e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
