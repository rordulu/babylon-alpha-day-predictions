# %%
# Parameters
TICKER = "AAPL"

# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Parameters
TICKER = None  # Default value, overwritten by papermill

# %%
# Global parameters

NUM_EPOCH = 1000
STARTING_LR = 0.001
SEQUENCE_SIZE = 64
REDUCE_LR_PATIENCE = 48
STOP_L_PATIENCE = 64
BATCH_SIZE = 32

# %%
# Define selected features and target attribute
features = ["Open", "High", "Low",	"Close", "Adj Close", "Volume", "High-Low-Diff", "High-Low-Perc", "Close-Open-Diff", "Close-Open-Perc", "Compared-To-Prev-Close", "Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open", "Volume-In-Usd-In-Comparison", "Pos-To-200D-MA", "Pos-To-200D-MA-DoD", "Pos-To-100D-MA", "Pos-To-100D-MA-DoD", "Pos-To-50D-MA", "Pos-To-50D-MA-DoD", "Pos-To-20D-MA", "Pos-To-20D-MA-DoD", "Log-Compared-To-Prev-Close-For-Close", "Sq-Compared-To-Prev-Close-For-Close", "Sq-Close-Open-Perc", "Sq-Compared-To-Prev-Open"]
features_to_be_used = ["Open", "High", "Low", "Close", "Volume"] #["Compared-To-Prev-Close-For-Close", "Compared-To-Prev-Open-For-Open", "Compared-To-Prev-High-For-High",	"Compared-To-Prev-Low-For-Low", "Volume-In-Usd-In-Comparison"]
target = "Close"

# %%
# Import necessary libraries and modules
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Conv1D, BatchNormalization, PReLU, LayerNormalization
import joblib
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import os
import logging
import absl.logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')
# Suppress absl.logging (used internally by TensorFlow)
logging.getLogger('absl').setLevel(logging.ERROR)
# Out:
# 2024-12-31 04:44:44.865520: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and name
data_file_location = "..//data//processed//"
data_file_name_train = "google_stock_price_processed_train"
data_file_name_validate = "google_stock_price_processed_validate"
data_file_name_test = "google_stock_price_processed_test"
data_file_ext = "csv"

# Load data files
data_train_df = pd.read_csv(data_file_location + data_file_name_train + "." + data_file_ext)
data_validate_df = pd.read_csv(data_file_location + data_file_name_validate + "." + data_file_ext)
data_test_df = pd.read_csv(data_file_location + data_file_name_test + "." + data_file_ext)

if TICKER is not None:
    data_train_df = data_train_df[data_train_df['TICKER'] == TICKER]
    data_validate_df = data_validate_df[data_validate_df['TICKER'] == TICKER]
    data_test_df = data_test_df[data_test_df['TICKER'] == TICKER]

# %%
# Check loaded datasets shape
print(f"Training Dataset Shape: {data_train_df.shape}")
print(f"Validation Dataset Shape: {data_validate_df.shape}")
print(f"Testing Dataset Shape: {data_test_df.shape}")
# Out:
# Training Dataset Shape: (932, 6)
# Validation Dataset Shape: (126, 6)
# Testing Dataset Shape: (41, 6)

# %%
# Display a summary of each dataset
print("Training Dataset:")
print(data_train_df.head())
print("Validation Dataset:")
print(data_validate_df.head())
print("Testing Dataset:")
print(data_test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.095067  0.092815  0.114254  0.094749  0.133300  2019-10-17
# 1  0.096304  0.090671  0.109972  0.091093  0.221433  2019-10-18
# 2  0.095717  0.088612  0.109740  0.091411  0.149765  2019-10-21
# 3  0.093561  0.086664  0.110117  0.089795  0.149016  2019-10-22
# 4  0.090876  0.091155  0.110591  0.097671  0.124298  2019-10-23
# Validation Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.660064  0.652145  0.667228  0.653320  0.076514  2023-07-03
# 1  0.657521  0.674865  0.670659  0.673287  0.119899  2023-07-05
# 2  0.663193  0.653402  0.662830  0.656889  0.118822  2023-07-06
# 3  0.665638  0.659203  0.670949  0.649268  0.154589  2023-07-07
# 4  0.647839  0.633293  0.637602  0.617726  0.286412  2023-07-10
# Testing Dataset:
#        Open      High       Low     Close    Volume        Date
# 0  0.848613  0.841590  0.841555  0.836595  0.144569  2024-01-02
# 1  0.838834  0.846182  0.848224  0.844312  0.132489  2024-01-03
# 2  0.851058  0.841783  0.844164  0.821933  0.124554  2024-01-04
# 3  0.836408  0.824139  0.832952  0.815663  0.093517  2024-01-05
# 4  0.832966  0.841831  0.842908  0.845952  0.117863  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING

# %% [markdown]
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date column to a valid Datetime format
data_train_df["Date"] = pd.to_datetime(data_train_df["Date"])
data_validate_df["Date"] = pd.to_datetime(data_validate_df["Date"])
data_test_df["Date"] = pd.to_datetime(data_test_df["Date"])

# %%
# Extract dates from each dataset
data_train_dates = data_train_df["Date"]
data_validate_dates = data_validate_df["Date"]
data_test_dates = data_test_df["Date"]

# %%
# Extract features
data_train_scaled = data_train_df[features_to_be_used].values
data_validate_scaled = data_validate_df[features_to_be_used].values
data_test_scaled = data_test_df[features_to_be_used].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE

# %% [markdown]
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the input data X and Y
def construct_lstm_data(data):
    """
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    print(f"inside construct_lstm_data with shape: {data.shape}")
    
    # Initialize constructed data variables
    data_X = []
    data_y = []
    target_attr_idx = features_to_be_used.index(target)
    
    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        # Exclude the target attribute column from the input features
        # input_features = np.delete(data[i-sequence_size:i, :], target_attr_idx, axis=1)
        # data_X.append(input_features)
        new_data = data[i-SEQUENCE_SIZE:i,0:data.shape[1]]
        # new_data = np.delete(new_data, target_attr_idx , axis=1)
        data_X.append(new_data)
        data_y.append(data[i, target_attr_idx])
            
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence size
sequence_size = SEQUENCE_SIZE

# Construct training data
X_train, y_train = construct_lstm_data(data_train_scaled)
# Out:
# inside construct_lstm_data with shape: (932, 5)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine scaled datasets all together
data_all_scaled = np.concatenate([data_train_scaled, data_validate_scaled, data_test_scaled], axis=0)

# Calculate data size
train_size = len(data_train_scaled)
validate_size = len(data_validate_scaled)
test_size = len(data_test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(data_all_scaled[train_size-sequence_size:train_size+validate_size,:])

# Construct testing dataset
X_test, y_test = construct_lstm_data(data_all_scaled[-(test_size+sequence_size):,:])
# Out:
# inside construct_lstm_data with shape: (190, 5)
# inside construct_lstm_data with shape: (105, 5)

# %%
# Check original data and data splits shapes
print(f"Full Scaled Data: {data_all_scaled.shape}")
print(f"\n Data Train Scaled: {data_train_scaled.shape}")
print(f"> Data Train X: {X_train.shape}")
print(f"> Data Train y: {y_train.shape}")

print(f"\n Data Validate Scaled: {data_validate_scaled.shape}")
print(f"> Data Validate X: {X_validate.shape}")
print(f"> Data Validate y: {y_validate.shape}")

print(f"\n Data Test Scaled: {data_test_scaled.shape}")
print(f"> Data Test X: {X_test.shape}")
print(f"> Data Test y: {y_test.shape}")
# Out:
# Full Scaled Data: (1099, 5)
#
#  Data Train Scaled: (932, 5)
# > Data Train X: (868, 64, 5)
# > Data Train y: (868,)
#
#  Data Validate Scaled: (126, 5)
# > Data Validate X: (126, 64, 5)
# > Data Validate y: (126,)
#
#  Data Test Scaled: (41, 5)
# > Data Test X: (41, 64, 5)
# > Data Test y: (41,)

# %% [markdown]
# ### 5. TRAINING LSTM MODEL

# %% [markdown]
# #### Building LSTM Model

# %%
# Initializing the model
regressor = Sequential()
# Out:
# 2024-12-31 04:44:46.603061: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-31 04:44:46.603105: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class CustomBatchNormalization(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(CustomBatchNormalization, self).__init__(**kwargs)

    def call(self, inputs):
        # Compute batch mean and variance
        mean = tf.reduce_mean(inputs, axis=0)
        variance = tf.math.reduce_variance(inputs, axis=0)
        epsilon = 1e-6  # Small constant to prevent division by zero

        # Normalize inputs
        normalized = (inputs - mean) / tf.sqrt(variance + epsilon)

        # Adjust the first element to be 1.0
        first_element_scale = 1.0 / (normalized[0] + epsilon)  # Ensure first element becomes 1.0
        normalized = normalized * first_element_scale

        return normalized

# %%
# # Add input layer
regressor.add(Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
# # regressor.add(CustomBatchNormalization())
# regressor.add(Conv1D(8, 3))
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(8, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(16, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(32, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(64, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3, strides=2))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# regressor.add(Conv1D(128, 3))
# # regressor.add(BatchNormalization())
# regressor.add(PReLU(shared_axes=[1], alpha_initializer=tf.initializers.constant(0.25)))

# %%
# # Add first LSTM layer and dropout regularization layer
# regressor.add(LSTM(units = 800, return_sequences = True))
# regressor.add(Dropout(rate = 0.2))

# %%
# Add second LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 400, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:44:46.925021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:46.926050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:46.926778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add third LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 200, return_sequences = True))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:44:47.072346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.073133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:47.073969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add forth LSTM layer and dropout regularization layer
regressor.add(LSTM(units = 100))
regressor.add(Dropout(rate = 0.2))
# Out:
# 2024-12-31 04:44:47.212202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.213061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:47.213991: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Add last dense layer/output layer
regressor.add(Dense(1))
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 400)           649600
#  dropout (Dropout)           (None, 64, 400)           0
#  lstm_1 (LSTM)               (None, 64, 200)           480800
#  dropout_1 (Dropout)         (None, 64, 200)           0
#  lstm_2 (LSTM)               (None, 100)               120400
#  dropout_2 (Dropout)         (None, 100)               0
#  dense (Dense)               (None, 1)                 101
# =================================================================
# Total params: 1,250,901
# Trainable params: 1,250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
from keras.optimizers import Adam
import keras.backend as K



optimizer = Adam(learning_rate=STARTING_LR)
regressor.compile(loss='mean_squared_error')

# %% [markdown]
# #### Training Model

# %%
# Create a checkpoint to monitor the validation loss and save the model with the best performance.
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callback = ModelCheckpoint(
    model_location + model_name, 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=0)

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',     # Metric to monitor
    factor=0.333,             # Factor to reduce the learning rate (new_lr = lr * factor)
    patience=REDUCE_LR_PATIENCE,             # Number of epochs with no improvement before reducing
    min_lr=1e-9             # Minimum learning rate
)

# EarlyStopping to stop training
early_stopping = EarlyStopping(
    monitor='val_loss', patience=STOP_L_PATIENCE, restore_best_weights=True
)

# %%
# Load the best performing model
best_model = load_model(model_location + model_name)
if best_model is not None:
    print(f"Using already trained model")
    regressor = best_model

# Training the model
history = regressor.fit(
    x = X_train, 
    y = y_train, 
    validation_data=(X_validate, y_validate), 
    epochs=NUM_EPOCH, 
    batch_size = BATCH_SIZE, 
    callbacks = [best_model_checkpoint_callback, early_stopping])
# Out:
# 2024-12-31 04:44:47.461718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.462637: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:47.463218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:47.565273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.565847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:47.566463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:47.662489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.663143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# Using already trained model
# Epoch 1/1000
# 2024-12-31 04:44:47.663954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:47.965619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:47.966622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:47.967206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:48.055132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:48.055756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:48.056429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:48.148864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:48.149626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:48.150231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:48.570424: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:48.881811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:48.993883: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:49.066297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:49.230824: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:49.412849: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  1/28 [>.............................] - ETA: 49s - loss: 0.0036
# 2024-12-31 04:44:49.549202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  2/28 [=>............................] - ETA: 1s - loss: 0.0023
#  4/28 [===>..........................] - ETA: 1s - loss: 0.0014
#  6/28 [=====>........................] - ETA: 1s - loss: 0.0011
#  8/28 [=======>......................] - ETA: 0s - loss: 9.5813e-04
# 10/28 [=========>....................] - ETA: 0s - loss: 8.6128e-04
# 12/28 [===========>..................] - ETA: 0s - loss: 8.1162e-04
# 14/28 [==============>...............] - ETA: 0s - loss: 7.6266e-04
# 16/28 [================>.............] - ETA: 0s - loss: 7.3116e-04
# 18/28 [==================>...........] - ETA: 0s - loss: 7.0864e-04
# 20/28 [====================>.........] - ETA: 0s - loss: 6.8950e-04
# 22/28 [======================>.......] - ETA: 0s - loss: 6.6247e-04
# 24/28 [========================>.....] - ETA: 0s - loss: 6.5082e-04
# 26/28 [==========================>...] - ETA: 0s - loss: 6.3201e-04
# 28/28 [==============================] - ETA: 0s - loss: 6.3064e-04
# 2024-12-31 04:44:51.002987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:51.003733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:51.004470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:51.089835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:51.090429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:51.090966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:51.175383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-31 04:44:51.175957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-31 04:44:51.176553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-31 04:44:51.210763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:51.315048: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-12-31 04:44:51.364639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 28/28 [==============================] - 4s 71ms/step - loss: 6.3064e-04 - val_loss: 0.0032
# 2024-12-31 04:44:51.418875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 2/1000
#  1/28 [>.............................] - ETA: 1s - loss: 9.7685e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.7198e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3079e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.7017e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.5275e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0879e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7065e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5689e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6243e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5226e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4999e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7899e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8204e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7940e-04
# 28/28 [==============================] - 1s 38ms/step - loss: 5.7942e-04 - val_loss: 0.0025
# Epoch 3/1000
#  1/28 [>.............................] - ETA: 1s - loss: 6.9295e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7488e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8261e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.3840e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5500e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5515e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1840e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0220e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9745e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0751e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0383e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1898e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1516e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1819e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.1749e-04 - val_loss: 6.9536e-04
# Epoch 4/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.9275e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.0223e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.4876e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.7266e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4633e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0876e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8239e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4743e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2917e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3045e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2718e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2330e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1082e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3089e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.3052e-04 - val_loss: 0.0022
# Epoch 5/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.2652e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.1567e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8098e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7708e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0238e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0009e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4249e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3783e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3419e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1212e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2165e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1584e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0925e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0494e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0365e-04 - val_loss: 0.0029
# Epoch 6/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.5247e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8442e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.6795e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 7.2225e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.9652e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.4977e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.1660e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8211e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6713e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5428e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.6183e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6362e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6124e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7607e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.7569e-04 - val_loss: 0.0024
# Epoch 7/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.6301e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.3493e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.2057e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9594e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.0164e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5899e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2357e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0161e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3707e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2400e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1940e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1482e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1518e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2364e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2287e-04 - val_loss: 9.5702e-04
# Epoch 8/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.9950e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.8825e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.3803e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7570e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3240e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4743e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2777e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6308e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4185e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4484e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4478e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4881e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4861e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4919e-04
# 28/28 [==============================] - 1s 37ms/step - loss: 5.4918e-04 - val_loss: 6.1788e-04
# Epoch 9/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.3923e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8192e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0544e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7226e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3600e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0454e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.7324e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7872e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5426e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3397e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3575e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3472e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3443e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4253e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4638e-04 - val_loss: 0.0026
# Epoch 10/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.8991e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.6829e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8784e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7515e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6580e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7738e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5422e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6801e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3877e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3908e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4126e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4382e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3018e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2894e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2713e-04 - val_loss: 0.0012
# Epoch 11/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.9180e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.4845e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.9582e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.2892e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.6016e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1815e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3215e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3524e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2560e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2633e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1025e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1230e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0523e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1757e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1572e-04 - val_loss: 0.0015
# Epoch 12/1000
#  1/28 [>.............................] - ETA: 1s - loss: 4.1851e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.5817e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.5091e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4838e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5725e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5900e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8146e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9667e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8952e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8652e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0542e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2236e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2548e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2159e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2048e-04 - val_loss: 0.0024
# Epoch 13/1000
#  1/28 [>.............................] - ETA: 1s - loss: 9.5738e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.2035e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5246e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.2025e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8281e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8318e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6130e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6503e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5213e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3762e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4386e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4619e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3679e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2909e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2791e-04 - val_loss: 7.6312e-04
# Epoch 14/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.0998e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.2652e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.2031e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.8241e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.5629e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2826e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.9044e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9302e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.8258e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.9596e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8637e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 6.0226e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.9809e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7447e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.7252e-04 - val_loss: 0.0020
# Epoch 15/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.3656e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.7520e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.1576e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.2987e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.3164e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6578e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.5750e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.5386e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9627e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9662e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1271e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1394e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1807e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2576e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2544e-04 - val_loss: 0.0011
# Epoch 16/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.1869e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.6520e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6059e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3424e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.4824e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0468e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8142e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6922e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3936e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4523e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4515e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5995e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4510e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3409e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.3223e-04 - val_loss: 0.0013
# Epoch 17/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.8282e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.9378e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6477e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0787e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0403e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1828e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4613e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.3298e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2315e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3169e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2209e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1648e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2177e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.3707e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.3673e-04 - val_loss: 7.6042e-04
# Epoch 18/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.0163e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1494e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.4976e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9882e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4689e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3563e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3516e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5163e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6599e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.7614e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7938e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6297e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4997e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4489e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4365e-04 - val_loss: 0.0017
# Epoch 19/1000
#  1/28 [>.............................] - ETA: 0s - loss: 2.9319e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.9500e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.0936e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0738e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1586e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3029e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2218e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2740e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1940e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1809e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2277e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2324e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1319e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2912e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.3091e-04 - val_loss: 0.0034
# Epoch 20/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0014
#  3/28 [==>...........................] - ETA: 0s - loss: 8.4265e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.6962e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.9964e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.7089e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.4580e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.4627e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.2408e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.9663e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 6.0221e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.9256e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.9645e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.8499e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.7524e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.7475e-04 - val_loss: 5.1224e-04
# Epoch 21/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 7.8514e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.5406e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0171e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8349e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.6327e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.3448e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.0314e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0534e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8417e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.7307e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.6772e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5507e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4706e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4751e-04 - val_loss: 0.0013
# Epoch 22/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.0399e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 8.1127e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.3826e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.6308e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2309e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0089e-04
# 13/28 [============>.................] - ETA: 0s - loss: 6.2725e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 6.2177e-04
# 17/28 [=================>............] - ETA: 0s - loss: 6.0238e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.8877e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.8117e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.7914e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6532e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4837e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4630e-04 - val_loss: 0.0016
# Epoch 23/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.6097e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.7703e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.5543e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.3900e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5487e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5189e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6821e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8843e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.5078e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4737e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5012e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5281e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6354e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.6617e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.6593e-04 - val_loss: 9.4793e-04
# Epoch 24/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.5905e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8066e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.1376e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.1354e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.0649e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.6308e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.6837e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6119e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6211e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4294e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3618e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4243e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4098e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2976e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2858e-04 - val_loss: 5.1773e-04
# Epoch 25/1000
#  1/28 [>.............................] - ETA: 0s - loss: 9.2869e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0832e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.6544e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.5570e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.1743e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7264e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.5712e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6543e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4858e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4288e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.6536e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5700e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5527e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.4130e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.4194e-04 - val_loss: 0.0040
# Epoch 26/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 7.8126e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1040e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.7544e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.3271e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.8672e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4937e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5498e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4405e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5457e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5655e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4536e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.5092e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5783e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.5942e-04 - val_loss: 0.0021
# Epoch 27/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.0292e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4952e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.7772e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9335e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.9749e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.0654e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.9879e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.8320e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7024e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6222e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5555e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3249e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2795e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2771e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.2625e-04 - val_loss: 7.2004e-04
# Epoch 28/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.4522e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.0440e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2041e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0677e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.8967e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0941e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4662e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4904e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4338e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3304e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4879e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.3004e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2717e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2597e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2432e-04 - val_loss: 0.0029
# Epoch 29/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.6980e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.9220e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9858e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8121e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.9718e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3364e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2917e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1147e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3293e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2543e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3222e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4631e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3885e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2716e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2985e-04 - val_loss: 0.0040
# Epoch 30/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0015
#  3/28 [==>...........................] - ETA: 0s - loss: 9.0957e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 7.1441e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.4586e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.1279e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.9134e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8443e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.9236e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.6820e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4082e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4140e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4637e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4727e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5358e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.5429e-04 - val_loss: 0.0011
# Epoch 31/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.1658e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.9311e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.7298e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.1217e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5250e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.9381e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9184e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8643e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0430e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0842e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1995e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2328e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1794e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1819e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2114e-04 - val_loss: 0.0034
# Epoch 32/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.1510e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1763e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.5888e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.5134e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5780e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3580e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1366e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5611e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7212e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6518e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.6977e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.5577e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.6090e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.6327e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.6176e-04 - val_loss: 0.0012
# Epoch 33/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.1347e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1270e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.5885e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.7493e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.6761e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.5536e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9357e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0008e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8375e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0929e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0742e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1479e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1464e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1822e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1756e-04 - val_loss: 0.0029
# Epoch 34/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.7114e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.3652e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.7792e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.1319e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.8786e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.7564e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.2941e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2253e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1483e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.1568e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1876e-04
# ...
# 28/28 [==============================] - 1s 35ms/step - loss: 5.5354e-04 - val_loss: 7.6345e-04
# Epoch 145/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.4227e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1742e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2257e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9595e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7087e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.4575e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0183e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7789e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9464e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9304e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9331e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9212e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9042e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9727e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 4.9591e-04 - val_loss: 8.6024e-04
# Epoch 146/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.0692e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.4932e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8309e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8260e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1971e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1126e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8727e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7571e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9018e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8847e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.9317e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9261e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1543e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0947e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0811e-04 - val_loss: 0.0021
# Epoch 147/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.5512e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.0062e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.7569e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.0614e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2444e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.2076e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8015e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.6551e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7175e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5709e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.3724e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4006e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.3145e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2353e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2127e-04 - val_loss: 0.0012
# Epoch 148/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.0143e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.5651e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.9439e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 3.9524e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.6910e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6745e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.4948e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.5199e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8329e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8530e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8096e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.7305e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.8987e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0946e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.0764e-04 - val_loss: 0.0019
# Epoch 149/1000
#  1/28 [>.............................] - ETA: 0s - loss: 3.0939e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 3.3253e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 3.9947e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.4793e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.5124e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.6317e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9294e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.7008e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.8076e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.7436e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8154e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9264e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0190e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0100e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 4.9894e-04 - val_loss: 0.0018
# Epoch 150/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.6844e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.5441e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.8807e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.8201e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7209e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1691e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.0449e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.8500e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.0252e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.9883e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1462e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1167e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0458e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0191e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.0171e-04 - val_loss: 6.7789e-04
# Epoch 151/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.1617e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 4.9631e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.3894e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 4.9572e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 4.7435e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 4.8790e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.8449e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.6810e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.5202e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.4848e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8451e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9686e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.0283e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0444e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.0341e-04 - val_loss: 0.0014
# Epoch 152/1000
#  1/28 [>.............................] - ETA: 0s - loss: 5.8622e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.1397e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.6193e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.0533e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.4046e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0548e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1898e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.2108e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4273e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.5379e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.4953e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2434e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2073e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1309e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1283e-04 - val_loss: 7.4246e-04
# Epoch 153/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.7589e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.0282e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.5630e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2841e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5495e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.5363e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8651e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.5348e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.3433e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0888e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.0891e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9898e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1496e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1921e-04
# 28/28 [==============================] - 1s 36ms/step - loss: 5.1726e-04 - val_loss: 6.4238e-04
# Epoch 154/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.2289e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.3125e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.2715e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2333e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3586e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.4038e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.3928e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4925e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.4960e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.4325e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.2582e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2896e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1060e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.0437e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.0249e-04 - val_loss: 0.0028
# Epoch 155/1000
#  1/28 [>.............................] - ETA: 0s - loss: 7.6000e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 7.3245e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.1766e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.9594e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.5206e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1732e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.1138e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.0345e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.9819e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 4.8320e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 4.8965e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 4.9565e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.1684e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2138e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2487e-04 - val_loss: 0.0030
# Epoch 156/1000
#  1/28 [>.............................] - ETA: 0s - loss: 8.5140e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.8879e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 5.8919e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.7580e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.1082e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.1432e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4209e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.1343e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.1448e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.3069e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1257e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.1152e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9998e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.1116e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1205e-04 - val_loss: 0.0014
# Epoch 157/1000
#  1/28 [>.............................] - ETA: 0s - loss: 4.3417e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 6.7242e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.0449e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.4618e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.2213e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.3176e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.4188e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.4771e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.2631e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.2404e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1356e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.0328e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 4.9866e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 4.9516e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 4.9404e-04 - val_loss: 4.7408e-04
# Epoch 158/1000
#  1/28 [>.............................] - ETA: 0s - loss: 0.0011
#  3/28 [==>...........................] - ETA: 0s - loss: 8.3857e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 6.3012e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 6.3866e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 6.2291e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 6.1863e-04
# 13/28 [============>.................] - ETA: 0s - loss: 5.8220e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 5.7252e-04
# 17/28 [=================>............] - ETA: 0s - loss: 5.7530e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.6999e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.5642e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.4868e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.4952e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.5325e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.5297e-04 - val_loss: 0.0011
# Epoch 159/1000
#  1/28 [>.............................] - ETA: 0s - loss: 6.5872e-04
#  3/28 [==>...........................] - ETA: 0s - loss: 5.7812e-04
#  5/28 [====>.........................] - ETA: 0s - loss: 4.9668e-04
#  7/28 [======>.......................] - ETA: 0s - loss: 5.2496e-04
#  9/28 [========>.....................] - ETA: 0s - loss: 5.3323e-04
# 11/28 [==========>...................] - ETA: 0s - loss: 5.0965e-04
# 13/28 [============>.................] - ETA: 0s - loss: 4.9032e-04
# 15/28 [===============>..............] - ETA: 0s - loss: 4.9593e-04
# 17/28 [=================>............] - ETA: 0s - loss: 4.7975e-04
# 19/28 [===================>..........] - ETA: 0s - loss: 5.0776e-04
# 21/28 [=====================>........] - ETA: 0s - loss: 5.1008e-04
# 23/28 [=======================>......] - ETA: 0s - loss: 5.2181e-04
# 25/28 [=========================>....] - ETA: 0s - loss: 5.2043e-04
# 27/28 [===========================>..] - ETA: 0s - loss: 5.2115e-04
# 28/28 [==============================] - 1s 35ms/step - loss: 5.1975e-04 - val_loss: 0.0011

# %% [markdown]
# #### Performance Evaluation

# %%
# Visualizing model performance during training
plt.figure(figsize=(18, 6))

plt.plot(history.history["loss"][1:], label="Training Loss")
plt.plot(history.history["val_loss"][1:], label="Validation Loss")

plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %%
np.save('X_train.npy', X_train)
np.save('X_validate.npy', X_validate)
np.save('X_test.npy', X_test)

np.save('y_train.npy', y_train)
np.save('y_validate.npy', y_validate)
np.save('y_test.npy', y_test)


data_train_dates.to_csv('data_train_dates.csv', index=False)
data_validate_dates.to_csv('data_validate_dates.csv', index=False)
data_test_dates.to_csv('data_test_dates.csv', index=False)
