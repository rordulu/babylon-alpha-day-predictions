# %%
import gym
import talib
import numpy as np
import pandas as pd
import math
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.utils import get_schedule_fn
from gym import spaces
import torch.nn as nn
import torch as th
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.vec_env import SubprocVecEnv
import torch
import os

sequence_len = 1
use_gpu = False
use_prev_action = True
use_comission = True
punish_negatives_extra = False
include_singular_rewards = False
use_fully_connected_after_stocks = False
use_common_dense_layers = False
compare_reward_to_mean = False
add_punishment_for_deviating_from_mean = False
add_punishment_for_deviating_from_mean_divider = 1000
use_multi_env = False
single_stock_reward = True
normalize_reward = False

if single_stock_reward:
    punish_negatives_extra = False
    use_prev_action = True
    normalize_reward = False

upper_cap = 1.02
lower_cap = 0.98
cash_interest = 0.04

if use_gpu:
    os.environ["PYTORCH_DISABLE_MODEL_LOADING_RAM_OPTIMIZATION"] = "1"
    torch.set_default_dtype(torch.float32)  # Ensure all tensors use float32
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
else:
    device = "cpu"

# %run "../helpers/data_manipulator.py"

all_data = None
all_data_np = None

def calculate_reward(action, cash_balance, current_step, positions, last_prices, average_buy_prices, price_data, tickers, disable_comission=False):
    
    positions = positions.copy()
    last_prices = last_prices.copy()
    average_buy_prices = average_buy_prices.copy()
    
    penalty_strength = 0.03 / len(action)   # Tune this value to adjust punishment effect
    penalty = 0#-penalty_strength * np.sum(np.abs(action - ideal_value))

    today_value = cash_balance
    tomorrow_value_if_no_change = cash_balance + (cash_balance * 0.04 / 365)
    tomorrow_value_with_change = 0
    tomorrow_value_with_change_capped = 0
    reward = 0

    if use_comission and not disable_comission:
        comission = 0.002
    else:
        comission = 0.0

    for i, ticker in enumerate(my_stocks):
        today_stock_price = price_data[i, current_step]
        tomorrow_stock_price = price_data[i, current_step + 1]
        tomorrow_stock_price_capped = max(min(tomorrow_stock_price, today_stock_price * upper_cap), today_stock_price * lower_cap)
        today_value += today_stock_price * positions[i]
        tomorrow_value_if_no_change += tomorrow_stock_price_capped * positions[i]
        # print(f"current step: {self.current_step} ticker: {ticker}, today_stock_price: {today_stock_price}")

    # print(action)
    for i, act in enumerate(action):
        if i == len(action) - 1:
            ## MEANS THE CASH TO HOLD
            break
            
        ticker = tickers[i]
        
        today_stock_price = price_data[i, current_step]
        tomorrow_stock_price = price_data[i, current_step + 1]
        tomorrow_stock_price_capped = max(min(tomorrow_stock_price, today_stock_price * upper_cap), today_stock_price * lower_cap)
        
        today_stock_allocation = (today_stock_price * positions[i]) / today_value
        last_prices[i] = today_stock_price
        
        if act > today_stock_allocation and act > 0:
            desired_invest = act * today_value
            current_invest = today_stock_price * positions[i]
            diff = desired_invest - current_invest
            amount_to_buy = math.floor((diff / today_stock_price) * (1 - comission))
            if amount_to_buy > 0:
                positions[i] += amount_to_buy
                cash_balance -= (today_stock_price * amount_to_buy) * (1 + comission)
                if positions[i] > 0:
                    average_buy_prices[i] = ((average_buy_prices[i-1] * positions[i-1]) + (today_stock_price * amount_to_buy)) / positions[i]
                else:
                    average_buy_prices[i] = current_price
        elif act < today_stock_allocation:
            desired_invest = act * today_value
            current_invest = today_stock_price * positions[i]
            diff = current_invest - desired_invest
            amount_to_sell = math.ceil(diff / today_stock_price)
            if amount_to_sell > 0:
                positions[i] -= amount_to_sell
                cash_balance += (today_stock_price * amount_to_sell) * (1 - comission)
                
        tomorrow_value_with_change += tomorrow_stock_price * positions[i]
        tomorrow_value_with_change_capped += tomorrow_stock_price_capped * positions[i]

    
    cash_balance = cash_balance + cash_balance * cash_interest / 365
    tomorrow_value_with_change += cash_balance
    tomorrow_value_with_change_capped += cash_balance

    # print(f"tomorrow_value_with_change: {tomorrow_value_with_change}, tomorrow_value_if_no_change: {tomorrow_value_if_no_change}")
    # print(f"capped reward: {tomorrow_value_with_change_capped / tomorrow_value_if_no_change - 1.0} normal reward: {tomorrow_value_with_change / tomorrow_value_if_no_change - 1.0}")
    reward += tomorrow_value_with_change_capped / tomorrow_value_if_no_change - 1.0
    reward += penalty
    # if reward < -0.008:
    #     reward *= 4
    
    if punish_negatives_extra and reward < 0:
        reward *= 2
    # reward = min(0.035, reward)
    # reward = max(-0.03, reward)
    # reward = torch.log(torch.tensor(reward + 1))

    # 🔥 Compute the penalty: L2 norm of allocation change
    # action_change_penalty = np.linalg.norm(action - self.prev_action)

    # Compute final penalized reward
    # reward = reward - self.lambda_penalty * action_change_penalty

    # diff = 0.0
    # upper_threshold = max((1.0 / len(action)), 0.25)
    # lower_threshold = min((1.0 / len(action)), 0.05)
    # for i, act in enumerate(action):
    #     if act > upper_threshold:
    #         diff += act - upper_threshold
    #     elif act < lower_threshold:
    #         diff += lower_threshold - act
    # punishment = 0.01 * diff
    # reward -= punishment

    # print(f"XXXX: {self.cash_balance, self.current_step, self.positions, self.last_prices, self.average_buy_prices, self.tickers}")
    return reward, cash_balance, positions, last_prices, average_buy_prices

def calculate_daily_loss(actions, current_step, price_data, tickers):
    loss = 0
    # actions = actions * 0.2 - 0.1
    for i, ticker in enumerate(my_stocks):
        today_stock_price = price_data[i, current_step]
        tomorrow_stock_price = price_data[i, current_step + 1]
        diff = (tomorrow_stock_price / today_stock_price - 1.0)
        
        print(f"Loss for ticker: {ticker}: {actions[i] - diff} .. action: {actions[i]} .. diff: {diff} at current step: {current_step}")
        loss += abs(actions[i] - diff)
        
    # print(f"Loss for {loss} at current step: {current_step}")
    loss = loss / len(actions)
    loss = loss * loss / 100
    return loss

def normalize_reward_func(reward):
    return np.sign(reward) * (abs(reward) ** 0.4)
    # return reward + 1

class TradingEnv(gym.Env):
    def __init__(self, data, price_data, initial_balance=10000):
        super(TradingEnv, self).__init__()
        self.data = data
        self.price_data = price_data
        self.tickers = my_stocks
        self.lambda_penalty = 0.002
        self.initial_balance = initial_balance
        self.current_step = 0  # Start at 201 for history
        # self.max_steps = len(self.data[self.data["TICKER"] == my_stocks[0]]) - self.current_step
        self.max_steps = len(self.data) - self.current_step
        self.cash_balance = self.initial_balance
        self.positions = np.zeros(len(my_stocks))
        self.last_prices = np.zeros(len(my_stocks))
        self.total_reward = 1.0
        self.average_buy_prices = np.zeros(len(my_stocks))
       
        # For reward normalization
        self.reward_running_mean = 0.0
        self.reward_running_var = 1.0
        self.alpha = 0.01  # smoothing factor

        
        num_features = data.shape[3]#  - 2  # Exclude price column
        print(f"num_features: {num_features}")

        action_size = len(my_stocks)
        
        if not single_stock_reward:
            action_size += 1
        
        enlarged_action_size = action_size
        if include_singular_rewards:
            enlarged_action_size += len(my_stocks)
            low = np.array([0.0] * action_size + [-0.05] * len(my_stocks), dtype=np.float32)
            high = np.array([0.0] * action_size + [0.05] * len(my_stocks), dtype=np.float32)
        else:
            low = np.array([0.0] * action_size, dtype=np.float32)
            high = np.array([1.0] * action_size, dtype=np.float32)

        
        # Create the action space
        self.action_space = spaces.Box(low=low, high=high, dtype=np.float32)
        # Action space: 0 = Hold, 1 = Buy, 2 = Sell
        # self.action_space = spaces.Box(low=0.0, high=1.0, shape=(enlarged_action_size,), dtype=np.float32)
        
        print(f"self.action_space.shape: {self.action_space.shape}")
        self.prev_action = np.ones((action_size,), dtype=np.float32) / (len(my_stocks) + 1)
        
        # Observation space: Last sequence_len days of features
        # self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(len(my_stocks), sequence_len, num_features), dtype=np.float32)

        self.observation_space = spaces.Dict({
            "obs": spaces.Box(low=-np.inf, high=np.inf, shape=(len(my_stocks), sequence_len, num_features), dtype=np.float32),
            "prev_action": spaces.Box(low=0.0, high=1.0, shape=(len(my_stocks) + 1,), dtype=np.float32)
        })

    def seed(self, seed=None):
        """Set the seed for this environment's random number generator."""
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(self):
        
        action_size = len(my_stocks) + 1
        
        self.current_step = 0
        self.tickers = my_stocks
        self.cash_balance = self.initial_balance
        self.positions = np.zeros(len(my_stocks))
        self.last_prices = np.zeros(len(my_stocks))
        self.total_reward = 1.0
        self.average_buy_prices = np.zeros(len(my_stocks))
        self.prev_action = np.ones((action_size,), dtype=np.float32) / (len(my_stocks) + 1)
        
        return self._next_observation()

    def _next_observation(self):
        
        return {
            "obs": self.data[self.current_step],  # Current observation
            "prev_action": self.prev_action  # Previously taken action
        }
    
    def step(self, action):

        # print(f"action: {action}")
        if include_singular_rewards:
            singular_actions = action[-len(my_stocks):]
            action = action[:len(my_stocks)+1]

        if single_stock_reward:
            action = np.array([action[0], 1.0 - action[0]])

        # action = action * 0.2 + 0.05
        # print(f"actions: {action}")
        epsilon = 1e-8  # Small constant to prevent division by zero
        action /= (np.sum(action) + epsilon)
    
        ideal_value = 1 / len(action)  # 0.0909 for 11 actions
        ideal_actions = [ideal_value] * len(action)

        
        
        default_reward, _ , _ , _ , _ = calculate_reward(ideal_actions, self.cash_balance, self.current_step, self.positions.copy(), self.last_prices.copy(), self.average_buy_prices.copy(), self.price_data, self.tickers, disable_comission=True)
        my_reward, cash_balance, positions, last_prices, average_buy_prices = calculate_reward(action, self.cash_balance, self.current_step, self.positions, self.last_prices, self.average_buy_prices, self.price_data, self.tickers)
        
        self.cash_balance = cash_balance
        self.positions = positions
        self.last_prices = last_prices
        self.average_buy_prices = average_buy_prices

        # reward = 1000 * (torch.log(torch.tensor((my_reward - default_reward) + 1)) - loss)
        if compare_reward_to_mean:
            reward = my_reward - default_reward
            reward = 1000 * torch.log(torch.tensor(reward + 1))
        elif include_singular_rewards:
            loss = calculate_daily_loss(singular_actions, current_step, self.price_data, self.tickers)
            reward = my_reward - default_reward - loss
            reward *= 1000
        elif add_punishment_for_deviating_from_mean:
            diff_sum = np.sum(np.abs(action - ideal_actions))
            reward = my_reward - (diff_sum / add_punishment_for_deviating_from_mean_divider)
            reward = 1000 * torch.log(torch.tensor(reward + 1))
        else:
            reward = my_reward
            reward = 1000 * torch.log(torch.tensor(reward + 1))
            # print(f"reward: {reward}")


        # if single_stock_reward:
        #     today_stock_price = self.price_data[0, self.current_step]
        #     tomorrow_stock_price = self.price_data[0, self.current_step + 1]
        #     tomorrow_stock_price_capped = max(min(tomorrow_stock_price, today_stock_price * upper_cap), today_stock_price * lower_cap)
        #     reward = action[0] * ((tomorrow_stock_price_capped / today_stock_price) - 1.0)
        #     if punish_negatives_extra and reward < 0:
        #         reward *= 2
        #     if normalize_reward:
        #         reward = normalize_reward_func(reward)
        #         # reward = np.sign(reward) * np.sqrt(abs(0.5 * reward))
        #     else:
        #         reward = 1000 * torch.log(torch.tensor(reward + 1))



        
        self.current_step += 1
        # print(f"self.data.shape[0]: {self.data.shape[0]}")
        done = self.current_step >= self.data.shape[0] - 1
        
        # Store action for next timestep
        self.prev_action = action

        # print(f"reward: {reward}")
        
        obs = self._next_observation()
        self.total_reward *= reward
        return obs, reward, done, {}

all_data = pd.DataFrame()
all_data_val = pd.DataFrame()

for ticker in my_stocks:
    # GET RAW DATA FOR THE TICKER
    stock_file, earnings_file = fetch_finance_data_for_tickers(ticker, "10y", refresh=False, verbose=False, incl_earnings=True)
    data = pd.read_csv(stock_file)
    earnings = pd.read_csv(earnings_file)
    data = data.drop(data[data['Volume'] == 0].index)
    data.reset_index(drop=True, inplace=True)
    data = make_new_features_for(data, earnings=earnings, use_adj_close=True)
    data, data_val, _ = split_data(data,
                                train_cut_date = "2024-07-01",
                                validate_cut_date = "2025-03-01",
                                test_end_date = "2025-03-10",
                                train_start_date = "2016-07-01"
                               )
    normalized_data = normalize_data(data, ticker)
    normalized_data_val = normalize_data(data_val, ticker)
    normalized_data["Close"] = data["Adj Close"]
    normalized_data_val["Close"] = data_val["Adj Close"]
    data = normalized_data
    data_val = normalized_data_val
    all_data = pd.concat([all_data, data], ignore_index=True)
    all_data_val = pd.concat([all_data_val, data_val], ignore_index=True)


features_to_use = lstm_features_v2# + extra_dense_layers_features
    
print("Maximum values:\n", all_data[features_to_use].iloc[0:].max().to_dict())
print("\nMinimum values:\n", all_data[features_to_use].iloc[0:].min().to_dict())
    

obs = []
obs_val = []
for ticker in my_stocks:
    ticker_data = all_data[all_data["TICKER"] == ticker]
    ticker_data_val = all_data_val[all_data_val["TICKER"] == ticker]
    
    dat = ticker_data[features_to_use]
    dat = dat.values  

    dat_val = ticker_data_val[features_to_use]
    dat_val = dat_val.values
    
    # Create the sliding window array
    result = np.array([dat[i - (sequence_len-1):i+1] for i in range(sequence_len-1, len(dat))])
    result_val = np.array([dat_val[i - (sequence_len-1):i+1] for i in range(sequence_len-1, len(dat_val))])
    
    # Result shape: (100 - 20, 21, 3) → (80, 21, 3)
    print(result.shape)  # Should print (80, 21, 3)
    print(result_val.shape)  # Should print (80, 21, 3)

    obs.append(result)
    obs_val.append(result_val)

    

# print(obs.to_numpy())
obs = np.array(obs)
obs = obs.transpose(1, 0, 2, 3)
obs = obs.astype(np.float32)
print(obs.shape)

# print(obs.to_numpy())
obs_val = np.array(obs_val)
obs_val = obs_val.transpose(1, 0, 2, 3)
obs_val = obs_val.astype(np.float32)
print(obs_val.shape)




unique_tickers = all_data["TICKER"].unique()

# Convert to a 2D array where rows = tickers, cols = Close values
all_data_np = np.array([all_data[all_data["TICKER"] == ticker]["Close"].values for ticker in unique_tickers], dtype=object)
all_data_np_val = np.array([all_data_val[all_data_val["TICKER"] == ticker]["Close"].values for ticker in unique_tickers], dtype=object)

all_data_np = all_data_np[:, sequence_len-1:]
all_data_np_val = all_data_np_val[:, sequence_len-1:]


print(f"all_data_np.shape: {all_data_np.shape}")

def calculate_output_for_cnn(initial_len, cnn_depth=3):
    affect = math.floor((initial_len-1)/2)
    if (cnn_depth == 1): 
        return affect
    else:
        return calculate_output_for_cnn(affect, cnn_depth-1)

class SharedStockNetwork(BaseFeaturesExtractor):
    def __init__(self, observation_space: spaces.Dict, num_stocks, input_dim):

        total_end = 100
        
        obs_dim = observation_space.spaces["obs"].shape[0]
        action_dim = observation_space.spaces["prev_action"].shape[0]
        print(f"obs_dim: {obs_dim}, action_dim: {action_dim}, num_stocks: {num_stocks}")
        total_input_dim = obs_dim + action_dim  # Combined input

        features_dim = num_stocks #+ action_dim # Must match final layer output
        # self.daily_dense_output = 83
        self.daily_dense_output = 4
        cnn_end = 4

        stocks_output = num_stocks * cnn_end
        total_output = stocks_output
        
        if use_common_dense_layers:
            final_output = 128
        else:
            if use_fully_connected_after_stocks:
                final_output = total_output * 4
            else:
                final_output = total_output
            if use_prev_action:
                final_output += action_dim
        super(SharedStockNetwork, self).__init__(observation_space, 
                                                 final_output)
        # super(SharedStockNetwork, self).__init__(observation_space, total_end)

        self.shared_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_dim * sequence_len, 32),
            nn.ReLU(),
        )
        
        self.daily_stock_dense = nn.Sequential(
            nn.Dropout(p=0.18),
            nn.Linear(input_dim, 64),
            nn.LeakyReLU(),
            nn.Dropout(p=0.16),
            nn.Linear(64, 16),
            nn.LeakyReLU(),
            nn.Dropout(p=0.14),
            nn.Linear(16, 16),
            nn.LeakyReLU(),
            nn.Dropout(p=0.12),
            nn.Linear(16, 4),
            nn.LeakyReLU(),
            nn.Dropout(p=0.1),
            nn.Linear(4, self.daily_dense_output),
            nn.Sigmoid(),
        )

        # Create a separate daily_stock_dense for each stock
        self.daily_stock_dense_list = nn.ModuleList([
            nn.Sequential(
                # nn.Dropout(p=0.10),
                # nn.BatchNorm1d(input_dim),
                nn.Linear(input_dim, 64),
                # nn.BatchNorm1d(64),
                nn.LeakyReLU(),
                # nn.Dropout(p=0.10),
                nn.Linear(64, 32),
                # nn.BatchNorm1d(32),
                # nn.LayerNorm(32),
                nn.LeakyReLU(),
                # nn.Linear(64, 32),
                # nn.BatchNorm1d(32),
                # nn.LeakyReLU(),
                # nn.Dropout(p=0.08),
                nn.Linear(32, 16),
                # nn.BatchNorm1d(16),
                # nn.LayerNorm(16),
                nn.LeakyReLU(),
                # nn.Dropout(p=0.08),
                # nn.Linear(16, 16),
                # nn.ReLU(),
                # nn.Dropout(p=0.08),
                # nn.Linear(8, 4),
                # nn.ReLU(),
                # nn.Dropout(p=0.1),
                nn.Linear(16, self.daily_dense_output),
                # nn.BatchNorm1d(self.daily_dense_output),
                nn.LeakyReLU(),
                # nn.Tanh(),
            ) for _ in range(num_stocks)  # Create a unique layer for each stock
        ])

        if sequence_len > 1:
            # 1D Convolution across stocks
            self.conv = nn.Sequential(
                # nn.BatchNorm1d(self.daily_dense_output),
                nn.Conv1d(
                    in_channels=input_dim,  # Convolution across stocks, not features
                    out_channels=8,  # Number of filters
                    kernel_size=2
                ),
                nn.BatchNorm1d(8),
                nn.LeakyReLU(),
                nn.Conv1d(
                    in_channels=8,  # Convolution across stocks, not features
                    out_channels=32,  # Number of filters
                    kernel_size=23,  # Consider 3 neighboring stocks
                ),
                nn.BatchNorm1d(32),
                nn.LeakyReLU(),
                # nn.Conv1d(
                #     in_channels=128,  # Convolution across stocks, not features
                #     out_channels=64,  # Number of filters
                #     kernel_size=3,  # Consider 3 neighboring stocks
                #     stride=2
                # ),
                # nn.BatchNorm1d(64),
                # nn.LeakyReLU(),
                nn.Flatten(),
                nn.Linear(32, cnn_end),
                nn.BatchNorm1d(cnn_end),
                nn.LeakyReLU(),
                # nn.Linear(256, 64),
                # nn.BatchNorm1d(64),
                # nn.LeakyReLU(),
                # nn.Linear(64, cnn_end),
                # nn.BatchNorm1d(cnn_end),
                # nn.LeakyReLU(),
                # nn.Sigmoid(),
                # nn.Linear(128, 32),
                # nn.ReLU(),
                # nn.Linear(128, cnn_end),
                # nn.BatchNorm1d(cnn_end),
                # nn.LeakyReLU()
                # nn.Sigmoid(),
            )
        # 1D Convolution across stocks
        self.stock_conv = nn.Sequential(
            nn.Conv1d(
                in_channels=cnn_end,  # Convolution across stocks, not features
                out_channels=1000,  # Number of filters
                kernel_size=10
            ),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(1000, total_end),
            nn.ReLU(),
        )

        self.fc_after_combined_cnn = nn.Sequential(
            nn.Linear(num_stocks * cnn_end , num_stocks * cnn_end * 2),
            nn.ReLU(),
            nn.Linear(num_stocks * cnn_end * 2 , num_stocks * cnn_end),
            nn.ReLU(),
        )
        self.prev_action_fc = nn.Sequential(
            nn.Linear(action_dim, action_dim),
            nn.ReLU()
        )
        
        self.fully_connected = nn.Sequential(
            nn.Linear(stocks_output, stocks_output * 4),
            nn.BatchNorm1d(stocks_output * 4),
            nn.LeakyReLU(),
            # nn.Linear(stocks_output * 4, stocks_output * 2),
            # nn.BatchNorm1d(stocks_output * 2),
            # nn.LeakyReLU(),
            # nn.Linear(stocks_output * 2, stocks_output),
            # nn.BatchNorm1d(stocks_output),
            # nn.LeakyReLU(),
            # nn.Linear(total_output * 2, total_output),
            # nn.ReLU()
        )

    
        self.common_layers = nn.Sequential(
            nn.Linear(total_output, total_output),
            nn.BatchNorm1d(total_output),
            nn.LeakyReLU(),
            nn.Linear(total_output, total_output),
            nn.BatchNorm1d(total_output),
            nn.LeakyReLU(),
            # nn.Linear(total_output, total_output),
            # # nn.BatchNorm1d(total_output),
            # nn.LeakyReLU(),
            nn.Linear(total_output, final_output),
            nn.BatchNorm1d(total_output),
            nn.LeakyReLU(),
            # nn.Linear(32, 32),
            # # nn.BatchNorm1d(total_output),
            # nn.LeakyReLU(),
            # nn.Linear(32, 32),
            # # nn.BatchNorm1d(total_output),
            # nn.LeakyReLU(),
            # nn.Linear(32, final_output),
            # # nn.BatchNorm1d(total_output),
            # nn.LeakyReLU(),
            # nn.Linear(stocks_output * 4, stocks_output * 2),
            # nn.BatchNorm1d(stocks_output * 2),
            # nn.LeakyReLU(),
            # nn.Linear(stocks_output * 2, stocks_output),
            # nn.BatchNorm1d(stocks_output),
            # nn.LeakyReLU(),
            # nn.Linear(total_output * 2, total_output),
            # nn.ReLU()
        )

        self.flatten = nn.Sequential(
            nn.Flatten()
        )
    
    def forward(self, observations):
        obs = observations["obs"]
        prev_action = observations["prev_action"]

        # print(f"x.shape: {x.shape}")
        batch_size, num_stocks, sequence_len, features_len = obs.shape
        # print(f"batch_size, num_stocks, sequence_len, features_len: {batch_size, num_stocks, sequence_len, features_len}")
        
        # x = x.permute(0, 2, 1)  # Move stock dimension to be iterated
        # shared_outputs = [self.shared_layers(x[:, i, :, :]) for i in range(num_stocks)]
        # combined = torch.cat(shared_outputs, dim=-1)
        # final_layer = self.final_layer(combined)
        # flatten = self.flatten(final_layer)
        # return self.fully_connected(flatten)

        # # Apply a different `daily_stock_dense` layer for each stock
        # daily_results = []
        # for i in range(num_stocks):
        #     daily = obs[:, i, :, :].view(-1, features_len)  # Extract data for stock i
        #     daily_result = self.daily_stock_dense_list[i](daily)  # Use specific layer for stock i
        #     daily_results.append(daily_result)

        # # Stack results back together
        # daily_result = torch.stack(daily_results, dim=1).view(batch_size, num_stocks, sequence_len, self.daily_dense_output)

        
        # # Stack the results to match the original stock dimension
        if sequence_len > 1:
            output = obs
        else:
            daily_results = []
            for i in range(num_stocks):
                # Extract data for stock i across all batches and sequences
                daily = obs[:, i, :, :].reshape(-1, features_len)  # Ensures correct reshaping
                
                # Apply the corresponding dense layer for this stock
                daily_result = self.daily_stock_dense_list[i](daily)  
            
                # Reshape back to match batch and sequence dimensions
                daily_results.append(daily_result.view(batch_size, sequence_len, -1))
            
            output = torch.stack(daily_results, dim=1)  # Shape: (batch_size, num_stocks, sequence_len, dense_output_size)

        
        # print(f"obs.shape: {obs.shape}")
        # daily = obs.view(-1, features_len)
        # daily_result = self.daily_stock_dense(daily)
        # print(f"daily_result.shape: {daily_result.shape}")
        
        # Step 3: Reshape back to (batch_size, stocks, sequence)
        # daily_result = daily_result.view(batch_size, num_stocks, sequence_len, self.daily_dense_output)
        # print(f"daily_result.shape2: {daily_result.shape}")

        obs_shaped = output.permute(0, 1, 3, 2)
        if sequence_len > 1:
            stock_outputs = torch.stack([self.conv(obs_shaped[:, i, :, :]) for i in range(num_stocks)], dim=1)
        else:
            stock_outputs = torch.stack([self.flatten(obs_shaped[:, i, :, :]) for i in range(num_stocks)], dim=1)
        
        # stock_outputs = stock_outputs.permute(0, 2, 1)
        # double_cnn_outputs = self.stock_conv(stock_outputs)
        
        # print(f"stock_outputs.shape: {stock_outputs.shape}")
        # all_stocks_output = self.final_layer(stock_outputs)
        
        # print(f"stock_outputs.shape: {stock_outputs.shape}")
        stock_outputs = stock_outputs.flatten(start_dim=1)
        double_cnn_outputs = stock_outputs #self.fc_after_combined_cnn(stock_outputs)
        # print(f"stock_outputs.shape: {stock_outputs.shape}")
        
        ## POLICY
        # stock_outputs = torch.stack([self.shared_layers(obs[:, i, :, :]) for i in range(num_stocks)], dim=1)
        
        
        # prev_actions_outputs = self.prev_action_fc(prev_action)
        # combined = torch.cat([double_cnn_outputs, prev_action], dim=1)
        # policy_net = self.fully_connected(combined)

        if use_fully_connected_after_stocks:
            policy_net = self.fully_connected(double_cnn_outputs)
        else:
            policy_net = double_cnn_outputs

        if use_prev_action:
            policy_net = torch.cat([policy_net, prev_action], dim=1)

        if use_common_dense_layers:
            policy_net = self.common_layers(policy_net)
            
        
        ## VALUE
        # stock_outputs = torch.stack([self.shared_layers(obs[:, i, :, :]) for i in range(num_stocks)], dim=1)
        # value_net = self.final_layer(stock_outputs)
        
        # combined = torch.cat([all_stocks_output, prev_action], dim=1)
        
        # print(f"ASDASFD:{shared_outputs.shape}")
        # shared_outputs = shared_outputs.permute(0, 2, 1)  # (batch, features_dim, stocks)
        # conv_outputs = self.conv(shared_outputs)
        # x = x.view(batch_size * num_stocks, sequence_len, features_len)  # Flatten stock dimension
        # shared_outputs = self.shared_layers(x)  # Process all stocks in parallel
        # shared_outputs = shared_outputs.view(batch_size, num_stocks, -1)  # Reshape back
        # combined = shared_outputs.flatten(start_dim=1)  # Flatten stock outputs

        
        return policy_net
        # return all_stocks_output
        
        

from stable_baselines3.common.policies import MultiInputActorCriticPolicy
# import torch.nn as nn
# import torch.nn.functional as F
# from stable_baselines3.common.distributions import Distribution
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# 
# class DirichletDistribution(Distribution):
#     def __init__(self, action_dim):
#         super(DirichletDistribution, self).__init__()
#         self.action_dim = action_dim
#         # Learnable exploration parameter
#         self.exploration_param = nn.Parameter(torch.tensor(1.0, requires_grad=True))
        
#     def proba_distribution_net(self, latent_dim):
#         # Just a linear layer to produce concentration parameters
#         concentration_params = nn.Linear(latent_dim, self.action_dim)
#         return concentration_params
        
#     def proba_distribution(self, concentration_logits):
#         # Dynamic concentration with exploration scaling
#         scaling = torch.sigmoid(self.exploration_param)
        
#         # Apply dynamic scaling and add noise
#         self._concentration = (F.softplus(concentration_logits * scaling) * 0.5) + 0.5
        
#         # Ensure minimum concentration
#         self._concentration = torch.clamp(self._concentration, min=0.1)
        
#         # Add small random noise to encourage exploration
#         noise = torch.randn_like(self._concentration) * 0.1 * scaling
#         self._concentration += noise
        
#         # Create the Dirichlet distribution
#         self._dirichlet = torch.distributions.Dirichlet(self._concentration)
#         return self
    
#     def entropy(self):
#         # Dynamically scaled entropy with exploration parameter
#         base_entropy = self._dirichlet.entropy()
#         exploration_scale = torch.abs(self.exploration_param)
        
#         # Adaptive entropy calculation with sigmoid scaling
#         adaptive_entropy = base_entropy * torch.sigmoid(exploration_scale)
        
#         return adaptive_entropy.unsqueeze(-1)
    
#     def actions_from_params(self, concentration_logits, deterministic=False):
#         self.proba_distribution(concentration_logits)
#         if deterministic:
#             actions = self.mode()
#         else:
#             actions = self.sample()
#         log_prob = self.log_prob(actions)
#         return actions, log_prob
    
#     def log_prob_from_params(self, concentration_logits, actions=None, deterministic=False):
#         self.proba_distribution(concentration_logits)
        
#         if actions is None:
#             if deterministic:
#                 actions = self.mode()
#             else:
#                 actions = self.sample()
        
#         log_prob = self.log_prob(actions)
#         return actions, log_prob
        
#     def log_prob(self, actions):
#         return self._dirichlet.log_prob(actions).unsqueeze(-1)
        
#     def sample(self):
#         return self._dirichlet.sample()
        
#     def mode(self):
#         return self._concentration / torch.sum(self._concentration, dim=1, keepdim=True)
        

# class DirichletMultiInputPolicy(MultiInputActorCriticPolicy):
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#         action_dim = self.action_space.shape[0]
#         self.action_dist = DirichletDistribution(action_dim)
    
#     def _get_action_dist_from_latent(self, latent_pi):
#         # Get the concentration parameters from the action net
#         concentration_logits = self.action_net(latent_pi)
        
#         # Explicitly print or log the exploration parameter
#         print(f"Exploration Parameter: {self.action_dist.exploration_param.data}")
        
#         # Use our Dirichlet distribution
#         return self.action_dist.proba_distribution(concentration_logits)
    
#     def evaluate_actions(self, obs, actions):
#         # Override to ensure our custom entropy is used
#         latent_pi, latent_vf, _ = self.mlp_extractor(self.extract_features(obs))
        
#         # Get distribution from latent
#         distribution = self._get_action_dist_from_latent(latent_pi)
        
#         # Calculate log probabilities
#         log_prob = distribution.log_prob(actions)
        
#         # Use our custom entropy calculation
#         entropy = distribution.entropy()
        
#         # Value function
#         values = self.value_net(latent_vf)
        
#         return values, log_prob, entropy

policy_kwargs = dict(
    features_extractor_class=SharedStockNetwork
    ,features_extractor_kwargs={"num_stocks": len(my_stocks), "input_dim": len(features_to_use)}
    ,net_arch=dict(pi=[4], vf=[4])  # More layers for value network
    # ,activation_fn=nn.Sigmoid  # ✅ Pass the class, NOT an instance
    # ,log_std_init=0.0
)

import torch
import torch.nn.functional as F
from stable_baselines3 import PPO

class PPOWithMAE(PPO):
    def _update_policy(self, loss, approx_kl):
        """Modify loss function to use MAE for value function."""
        # Extract components from PPO loss
        policy_loss, value_loss, entropy_loss = loss

        # Convert MSE to MAE for value function
        value_loss = F.l1_loss(self.rollout_buffer.returns, self.rollout_buffer.values)
        # value_loss = torch.log(torch.cosh(self.rollout_buffer.returns - self.rollout_buffer.values)).mean()


        # Final loss combination (following PPO structure)
        total_loss = policy_loss + self.ent_coef * entropy_loss + self.vf_coef * value_loss

        return super()._update_policy(total_loss, approx_kl)


from stable_baselines3.common.callbacks import BaseCallback
import torch

class StopTrainingCallback(BaseCallback):
    def __init__(self, threshold_entropy=0.0, target_kl=0.01, lr_reduction_factor=0.4, min_lr=1e-6, 
                 threshold_policy_grad=-0.1, threshold_explained_var=0.9, verbose=1):
        super().__init__(verbose)
        self.threshold_entropy = threshold_entropy
        self.target_kl = target_kl
        self.lr_reduction_factor = lr_reduction_factor  # Added this
        self.min_lr = min_lr  # Added this
        self.threshold_policy_grad = threshold_policy_grad
        self.threshold_explained_var = threshold_explained_var
        self.approx_kl_counter = 0
        self.rewards = []


        # if len(self.model.logger.name_to_value) > 0 and "train/approx_kl" in self.model.logger.name_to_value:
        #     approx_kl = self.model.logger.name_to_value["train/approx_kl"]
        #     print(f"approx_kl: {approx_kl}")
            
        #     # If KL is too high, reduce learning rate
        #     if approx_kl > 2 * self.target_kl:
        #         old_lr = self.model.learning_rate
        #         new_lr = max(old_lr * self.lr_reduction_factor, self.min_lr)

        #         self.model.policy.optimizer = torch.optim.Adam(self.model.policy.parameters(), lr=new_lr)
        #         self.model.learning_rate = new_lr
        #         for param_group in self.model.policy.optimizer.param_groups:
        #             param_group['lr'] = new_lr
                
        #         print(f"Updated LR: {new_lr}")
                
        #         if self.verbose > 0:
        #             print(f"KL divergence too high ({approx_kl:.5f} > {2 * self.target_kl:.5f}), "
        #                   f"reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
    
    def _on_step(self) -> bool:
        self.rewards.append(self.locals["rewards"][0]) 
        """ This function is called at each training step. """
        # approx_kl is stored in the logger during training
        # Access the PPO model's losses from its logger
        try:
            entropy_loss = self.model.logger.name_to_value["train/entropy_loss"]
            policy_gradient_loss = self.model.logger.name_to_value["train/policy_gradient_loss"]
            approx_kl = self.model.logger.name_to_value["train/approx_kl"]
            explained_variance = self.model.logger.name_to_value["train/explained_variance"]
            std = self.model.logger.name_to_value["train/std"]
        except KeyError:
            if self.verbose:
                print("[WARNING] Could not retrieve some metrics, skipping check.")
            return True  # Continue training if values are not found
        
        # 🚨 Stopping conditions
        # if entropy_loss > self.threshold_entropy:
        #     print(f"[STOP] Entropy loss is above {self.threshold_entropy}! Possible bug.")
        #     return False  # Stop training
        if self.model._n_updates > 200 and approx_kl > 1.0:
            self.approx_kl_counter += 1
            if self.approx_kl_counter > 10:
                print(f"[STOP] Approx KL ({approx_kl:.2f}) is too high, stopping training.")
                return False  # Stop training
        else:
            self.approx_kl_counter = 0
                
        # if abs(policy_gradient_loss) > self.threshold_policy_grad:
        #     print(f"[STOP] Policy gradient loss is very small ({policy_gradient_loss:.5f}), stopping training.")
        #     return False  # Stop training
        if explained_variance > self.threshold_explained_var and std < 0.5:
            print(f"[STOP] Explained variance ({explained_variance:.2f}) is too high, stopping training.")
            return False  # Stop training
        
        return True  # Continue training

    def _on_rollout_end(self):
        """Called at the end of each PPO update (after batch is collected)."""
        avg_reward = sum(self.rewards) / len(self.rewards) if self.rewards else 0
        # print(f"PPO Iteration self.rewards: {self.rewards}")
        print(f"PPO Iteration Average Reward: {avg_reward:.4f}")
        self.rewards = []  # Reset for next iteration


def make_env(obs_data, price_data, rank, seed=0):
    def _init():
        env = TradingEnv(obs_data, price_data)
        env.seed(seed + rank)
        return env
    return _init

if use_multi_env:
    # Number of parallel environments
    num_envs = 4  # Adjust based on CPU cores available
    
    # Create a list of environment factory functions
    env_fns = [make_env(obs, all_data_np, i) for i in range(num_envs)]
    
    # Create the vectorized environment
    env = SubprocVecEnv(env_fns, start_method='spawn')
else:
    num_envs = 1
    # Setup Environment
    env = DummyVecEnv([lambda: TradingEnv(obs, all_data_np)])
    
    env.tickers = my_stocks


model = PPOWithMAE(
    'MultiInputPolicy',
    env, 
    verbose=1, 
    gamma=0.9,
    batch_size=256,
    n_steps=obs.shape[0] // num_envs, # Adjust steps per environment Why is this needed?
    learning_rate=0.0004,
    max_grad_norm=0.2,
    ent_coef=0.001,
    clip_range=0.2,
    vf_coef=0.9,
    gae_lambda=0.9,
    n_epochs=8,
    # use_sde=True,
    # target_kl=0.003,
    seed=42,
    policy_kwargs=policy_kwargs,
    device=device  # Use GPU if available
)

model.learning_rate = 0.0004
model._setup_lr_schedule()

# # Change gamma value
# model.gamma = 0.9  # Set your desired gamma value
# # For the change to take effect
# model._setup_model()


# Access the current optimizer
current_optimizer = model.policy.optimizer

# new_optimizer = torch.optim.Adam(model.policy.parameters(), lr=0.001, weight_decay=0.000005)
# model.policy.optimizer = new_optimizer

if use_gpu:
    model.policy.to(torch.float32)  # Convert policy to float32

stop_callback = StopTrainingCallback()
model.learn(total_timesteps=3000000, callback=stop_callback)




# Setup Environment
test_env = DummyVecEnv([lambda: TradingEnv(obs, all_data_np)])

test_env.tickers = my_stocks
# Test Model
done = False
obs_step = test_env.reset()
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action, _states = model.predict(obs_step, deterministic=True)
    obs_step, reward, done, _ = env.step(action)
    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")

    # explained_variance = model.logger.name_to_value.get("train/explained_variance", None)
    # entropy_loss = model.logger.name_to_value.get("train/entropy_loss", None)

    # if entropy_loss > 0:
    #     print(f"Early stopping triggered! Entropy loss went above 0 {entropy_loss}.")
    
    # if explained_variance is not None:
    #     if last_known_explianed_variance is not None:
    #         if explianed_variance < last_known_explianed_variance:
    #             cons_counter += 1
    #             last_known_explianed_variance = explianed_variance
    #         else:
    #             cons_counter = 0
    #             last_known_explianed_variance = None
            
    # if last_known_explianed_variance is None and explained_variance > 0.9:
    #     last_known_explianed_variance = explained_variance

    # if cons_counter == 5:
    #     print(f"Early stopping triggered! Explained variance reached {explained_variance}.")
    #     break  # Stop the loop
# Out:
# fetch_finance_data_for_tickers: just returning file name: MSFT for interval: 10y
# DOING EARNINGS
# fixed_mean: -9.867214350423036e-08, fixed_stddev: 0.011260524843983358
# train_data:            Date        Open        High         Low       Close      Volume  \
# 319  2016-07-05   50.830002   51.279999   50.740002   45.685921  24806400.0
# 320  2016-07-06   50.779999   51.540001   50.389999   45.873425  28167500.0
# 321  2016-07-07   51.419998   51.610001   51.070000   45.873425  19585200.0
# 322  2016-07-08   51.730000   52.360001   51.549999   46.694820  28391000.0
# 323  2016-07-11   52.500000   52.830002   52.470001   46.953743  22269200.0
# ...         ...         ...         ...         ...         ...         ...
# 2325 2024-06-25  448.250000  451.420013  446.750000  448.340454  16747500.0
# 2326 2024-06-26  449.000000  453.600006  448.190002  449.543457  16507000.0
# 2327 2024-06-27  452.179993  456.170013  451.769989  450.229462  14806300.0
# 2328 2024-06-28  453.070007  455.380005  446.410004  444.363647  28362300.0
# 2329 2024-07-01  448.660004  457.369995  445.660004  454.087036  17662800.0
#
#        Adj Close TICKER      MACD  SIG_LINE  ...  \
# 319    45.685921   MSFT -0.204423 -0.326165  ...
# 320    45.873425   MSFT -0.131719 -0.287276  ...
# 321    45.873425   MSFT -0.073255 -0.244472  ...
# 322    46.694820   MSFT  0.046774 -0.186223  ...
# 323    46.953743   MSFT  0.163415 -0.116295  ...
# ...          ...    ...       ...       ...  ...
# 2325  448.340454   MSFT  8.308164  6.805763  ...
# 2326  449.543457   MSFT  8.497312  7.144073  ...
# 2327  450.229462   MSFT  8.603712  7.436001  ...
# 2328  444.363647   MSFT  8.118371  7.572475  ...
# 2329  454.087036   MSFT  8.425772  7.743134  ...
#
#       Next-5-Day-Close-To-Todays-Close-Ratio  \
# 319                                 0.039867
# 320                                 0.041456
# 321                                 0.045932
# 322                                 0.027534
# 323                                 0.026051
# ...                                      ...
# 2325                                0.018472
# 2326                                0.019042
# 2327                                0.032483
# 2328                                0.046113
# 2329                                0.023712
#
#       Next-Day-Close-To-Todays-Close-Ratio  \
# 319                               0.004104
# 320                               0.000000
# 321                               0.017906
# 322                               0.005545
# 323                               0.011789
# ...                                    ...
# 2325                              0.002683
# 2326                              0.001526
# 2327                             -0.013029
# 2328                              0.021882
# 2329                              0.005583
#
#       Next-Day-Close-To-Next-Day-Open-Ratio  \
# 319                                0.011816
# 320                               -0.000778
# 321                                0.011019
# 322                                0.001714
# 323                                0.005100
# ...                                     ...
# 2325                               0.007038
# 2326                               0.001482
# 2327                              -0.013508
# 2328                               0.017987
# 2329                               0.013416
#
#       Next-Day-High-To-Next-Day-Open-Ratio  \
# 319                               0.014967
# 320                               0.003695
# 321                               0.012179
# 322                               0.006286
# 323                               0.008689
# ...                                    ...
# 2325                              0.010245
# 2326                              0.008824
# 2327                              0.005099
# 2328                              0.019413
# 2329                              0.014100
#
#       Next-Day-Low-To-Next-Day-Open-Ratio  \
# 319                             -0.007680
# 320                             -0.006807
# 321                             -0.003480
# 322                             -0.000571
# 323                             -0.002833
# ...                                   ...
# 2325                            -0.001804
# 2326                            -0.000907
# 2327                            -0.014700
# 2328                            -0.006687
# 2329                            -0.000199
#
#       Today-Close-To-Open-Ratio-Above-One-Sigma  \
# 319                                         0.0
# 320                                         0.0
# 321                                         0.0
# 322                                         0.0
# 323                                         0.0
# ...                                         ...
# 2325                                        0.0
# 2326                                        0.0
# 2327                                        0.0
# 2328                                        0.0
# 2329                                        1.0
#
#       Today-High-To-Open-Ratio-Above-One-Sigma  \
# 319                                        0.0
# 320                                        0.0
# 321                                        0.0
# 322                                        0.0
# 323                                        0.0
# ...                                        ...
# 2325                                       0.0
# 2326                                       0.0
# 2327                                       0.0
# 2328                                       0.0
# 2329                                       0.0
#
#       Next-Day-Target-above-one-sigma  Target-20D-Mean  Target-20D-Sigma
# 319                               1.0    -9.867214e-08          0.011261
# 320                               0.0    -9.867214e-08          0.011261
# 321                               0.0    -9.867214e-08          0.011261
# 322                               0.0    -9.867214e-08          0.011261
# 323                               0.0    -9.867214e-08          0.011261
# ...                               ...              ...               ...
# 2325                              0.0    -9.867214e-08          0.011261
# 2326                              0.0    -9.867214e-08          0.011261
# 2327                              0.0    -9.867214e-08          0.011261
# 2328                              1.0    -9.867214e-08          0.011261
# 2329                              1.0    -9.867214e-08          0.011261
#
# [2011 rows x 125 columns]
# Maximum values:
#  {'High-Low-Ratio': 0.5016700674478325, 'High-Open-Ratio': 0.3256498002736582, 'Close-Open-Ratio': 0.2700816579331737, 'Close-Prev-Close': 0.47389627066381246, '200D-Ratio': 0.3578032274705762, '100D-Ratio': 0.26938649585435076, '50D-Ratio': 0.18696247840592983, '20D-Ratio': 0.1415418273573467, 'MACD_HIST_NORM': 0.16450591881630527, 'MACD-Increase-Prev-MACD': 0.08409713512221625, 'MACD_BUY': 1.0, 'MACD_SELL': 1.0, 'Volatility-10': 0.44525725716919096, 'Volatility-20': 0.3563721287709795, 'Volatility-50': 0.25580504962429235, 'Volatility-100': 0.18944628195550792, 'Volatility-200': 0.15322223623474027, 'MACD_SIG': 1.111111111111111, 'MFI3': 1.0000000000000022, 'RSI': 0.8918591125649491, 'RSI3': 0.986843083942308, 'POCR': 1.0, 'fastk': 1.0, 'fastd': 0.9872946216941549, 'SlowK1': 1.0000000000000002, 'willr3': -0.0, 'willr2': -0.0, 'willr1': -0.0}
#
# Minimum values:
#  {'High-Low-Ratio': 0.012517218580606245, 'High-Open-Ratio': 0.0, 'Close-Open-Ratio': -0.1974884451252142, 'Close-Prev-Close': -0.49130104288085064, '200D-Ratio': -0.23337174402001573, '100D-Ratio': -0.18121604071523634, '50D-Ratio': -0.21688141710326997, '20D-Ratio': -0.1994709429318135, 'MACD_HIST_NORM': -0.22982856467561535, 'MACD-Increase-Prev-MACD': -0.11815240293839381, 'MACD_BUY': 0.0, 'MACD_SELL': 0.0, 'Volatility-10': 0.011777945714912544, 'Volatility-20': 0.017434491488949228, 'Volatility-50': 0.027291615274213348, 'Volatility-100': 0.03299915060779905, 'Volatility-200': 0.040688865003837914, 'MACD_SIG': 0.0, 'MFI3': -1.166581470588138e-15, 'RSI': 0.26419419755210205, 'RSI3': 0.022223975697674248, 'POCR': 0.0, 'fastk': 0.0, 'fastd': 0.02011955122036411, 'SlowK1': 0.0, 'willr3': -1.0000000000000002, 'willr2': -1.0000000000000002, 'willr1': -1.0}
# (2011, 1, 28)
# (166, 1, 28)
# (2011, 1, 1, 28)
# (166, 1, 1, 28)
# all_data_np.shape: (1, 2011)
# num_features: 28
# self.action_space.shape: (1,)
# Using cpu device
# obs_dim: 1, action_dim: 2, num_stocks: 1
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2011`, after every 7 untruncated mini-batches, there will be a truncated mini-batch of size 219
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2011 and n_envs=1)
#   warnings.warn(
# PPO Iteration Average Reward: -0.5583
# -----------------------------
# | time/              |      |
# |    fps             | 6281 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2011 |
# -----------------------------
# PPO Iteration Average Reward: -0.8579
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5836         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4022         |
# | train/                  |              |
# |    approx_kl            | 0.0002687131 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00355     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 126          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000531    |
# |    std                  | 0.994        |
# |    value_loss           | 132          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.7253
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5594          |
# |    iterations           | 3             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 6033          |
# | train/                  |               |
# |    approx_kl            | 0.00015715086 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.00719      |
# |    learning_rate        | 0.0004        |
# |    loss                 | 131           |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.00029      |
# |    std                  | 0.992         |
# |    value_loss           | 150           |
# -------------------------------------------
# PPO Iteration Average Reward: -0.7259
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5551         |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8044         |
# | train/                  |              |
# |    approx_kl            | 0.0014510765 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.00446     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 133          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 0.983        |
# |    value_loss           | 134          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.5515
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 5512       |
# |    iterations           | 5          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 10055      |
# | train/                  |            |
# |    approx_kl            | 0.00272603 |
# |    clip_fraction        | 0.00213    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | -0.00239   |
# |    learning_rate        | 0.0004     |
# |    loss                 | 128        |
# |    n_updates            | 32         |
# |    policy_gradient_loss | -0.00142   |
# |    std                  | 0.98       |
# |    value_loss           | 139        |
# ----------------------------------------
# PPO Iteration Average Reward: -0.9163
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5494         |
# |    iterations           | 6            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 12066        |
# | train/                  |              |
# |    approx_kl            | 0.0052256812 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.000554    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 90.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.979        |
# |    value_loss           | 114          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.7676
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5498         |
# |    iterations           | 7            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 14077        |
# | train/                  |              |
# |    approx_kl            | 0.0028260786 |
# |    clip_fraction        | 0.00105      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -9.11e-05    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 125          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.976        |
# |    value_loss           | 126          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.5743
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5502        |
# |    iterations           | 8           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 16088       |
# | train/                  |             |
# |    approx_kl            | 0.004145521 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -4.6e-05    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 80.4        |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00311    |
# |    std                  | 0.972       |
# |    value_loss           | 97.3        |
# -----------------------------------------
# PPO Iteration Average Reward: -0.4777
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5507         |
# |    iterations           | 9            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 18099        |
# | train/                  |              |
# |    approx_kl            | 0.0029910319 |
# |    clip_fraction        | 0.00295      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -3.81e-05    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 99.8         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.959        |
# |    value_loss           | 93.2         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.4887
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5507         |
# |    iterations           | 10           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 20110        |
# | train/                  |              |
# |    approx_kl            | 0.0029236278 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -3.08e-05    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 63           |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.939        |
# |    value_loss           | 72           |
# ------------------------------------------
# PPO Iteration Average Reward: -0.5694
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5502        |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 22121       |
# | train/                  |             |
# |    approx_kl            | 0.002968416 |
# |    clip_fraction        | 0.00232     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 56.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.93        |
# |    value_loss           | 71.2        |
# -----------------------------------------
# PPO Iteration Average Reward: -0.2505
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5479         |
# |    iterations           | 12           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 24132        |
# | train/                  |              |
# |    approx_kl            | 0.0054829535 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -2.41e-05    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 68.1         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00547     |
# |    std                  | 0.916        |
# |    value_loss           | 65.3         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.3739
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5468        |
# |    iterations           | 13          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 26143       |
# | train/                  |             |
# |    approx_kl            | 0.002667561 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -1.41e-05   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 43.4        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00317    |
# |    std                  | 0.91        |
# |    value_loss           | 43.8        |
# -----------------------------------------
# PPO Iteration Average Reward: -0.3415
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5469         |
# |    iterations           | 14           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 28154        |
# | train/                  |              |
# |    approx_kl            | 0.0041989526 |
# |    clip_fraction        | 0.00639      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -1.32e-05    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 42.5         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.899        |
# |    value_loss           | 52.6         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.1300
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5469         |
# |    iterations           | 15           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 30165        |
# | train/                  |              |
# |    approx_kl            | 0.0061601335 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -5.01e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 35.7         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00527     |
# |    std                  | 0.892        |
# |    value_loss           | 35.9         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0745
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5470         |
# |    iterations           | 16           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32176        |
# | train/                  |              |
# |    approx_kl            | 0.0015326331 |
# |    clip_fraction        | 0.000763     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 24.4         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00107     |
# |    std                  | 0.882        |
# |    value_loss           | 26.8         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0209
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5467         |
# |    iterations           | 17           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 34187        |
# | train/                  |              |
# |    approx_kl            | 0.0021668265 |
# |    clip_fraction        | 0.000183     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 15.6         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.878        |
# |    value_loss           | 22.8         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0698
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5466          |
# |    iterations           | 18            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 36198         |
# | train/                  |               |
# |    approx_kl            | 0.00022298163 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -3.34e-06     |
# |    learning_rate        | 0.0004        |
# |    loss                 | 14.3          |
# |    n_updates            | 136           |
# |    policy_gradient_loss | -0.000127     |
# |    std                  | 0.876         |
# |    value_loss           | 16.8          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.1289
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5466          |
# |    iterations           | 19            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 38209         |
# | train/                  |               |
# |    approx_kl            | 0.00067411305 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | 7.75e-07      |
# |    learning_rate        | 0.0004        |
# |    loss                 | 14.3          |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -0.000482     |
# |    std                  | 0.871         |
# |    value_loss           | 22.1          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.1253
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5467         |
# |    iterations           | 20           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 40220        |
# | train/                  |              |
# |    approx_kl            | 0.0040419763 |
# |    clip_fraction        | 0.00893      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 3.64e-06     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 9.75         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.856        |
# |    value_loss           | 15.9         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0527
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5465         |
# |    iterations           | 21           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 42231        |
# | train/                  |              |
# |    approx_kl            | 0.0045329058 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -2.38e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 9.47         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00393     |
# |    std                  | 0.849        |
# |    value_loss           | 11.7         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0273
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5465         |
# |    iterations           | 22           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 44242        |
# | train/                  |              |
# |    approx_kl            | 0.0007713735 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 8.03         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000765    |
# |    std                  | 0.845        |
# |    value_loss           | 8.95         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.1406
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5466          |
# |    iterations           | 23            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 46253         |
# | train/                  |               |
# |    approx_kl            | 0.00028447135 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.25         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0004        |
# |    loss                 | 8.03          |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.000288     |
# |    std                  | 0.841         |
# |    value_loss           | 7.67          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.0728
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5467         |
# |    iterations           | 24           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 48264        |
# | train/                  |              |
# |    approx_kl            | 0.0032916567 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -2.26e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 15.6         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00389     |
# |    std                  | 0.836        |
# |    value_loss           | 12.5         |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0007
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5470         |
# |    iterations           | 25           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 50275        |
# | train/                  |              |
# |    approx_kl            | 0.0014373395 |
# |    clip_fraction        | 0.000193     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 6.02e-06     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 4.09         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.824        |
# |    value_loss           | 3.89         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0211
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5467          |
# |    iterations           | 26            |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 52286         |
# | train/                  |               |
# |    approx_kl            | 0.00030132348 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | 5.9e-06       |
# |    learning_rate        | 0.0004        |
# |    loss                 | 2.43          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000168     |
# |    std                  | 0.825         |
# |    value_loss           | 4.27          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.1054
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5466         |
# |    iterations           | 27           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 54297        |
# | train/                  |              |
# |    approx_kl            | 9.922724e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 3.23         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -3.21e-05    |
# |    std                  | 0.826        |
# |    value_loss           | 3.47         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0334
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5466         |
# |    iterations           | 28           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 56308        |
# | train/                  |              |
# |    approx_kl            | 0.0023364364 |
# |    clip_fraction        | 0.00949      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -2.98e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 9.08         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00512     |
# |    std                  | 0.818        |
# |    value_loss           | 6.63         |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0004
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5464         |
# |    iterations           | 29           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 58319        |
# | train/                  |              |
# |    approx_kl            | 0.0020025992 |
# |    clip_fraction        | 0.000122     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 2.36         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.814        |
# |    value_loss           | 4.8          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0470
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5463         |
# |    iterations           | 30           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 60330        |
# | train/                  |              |
# |    approx_kl            | 5.616377e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.52         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | 0.000105     |
# |    std                  | 0.812        |
# |    value_loss           | 3.62         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0095
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5461         |
# |    iterations           | 31           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 62341        |
# | train/                  |              |
# |    approx_kl            | 0.0010350465 |
# |    clip_fraction        | 0.000875     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.13         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000987    |
# |    std                  | 0.796        |
# |    value_loss           | 4.82         |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0087
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5459          |
# |    iterations           | 32            |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 64352         |
# | train/                  |               |
# |    approx_kl            | 5.1494808e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0004        |
# |    loss                 | 1.45          |
# |    n_updates            | 248           |
# |    policy_gradient_loss | -0.000155     |
# |    std                  | 0.79          |
# |    value_loss           | 2.03          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.0151
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5459         |
# |    iterations           | 33           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 66363        |
# | train/                  |              |
# |    approx_kl            | 0.0004117997 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.426        |
# |    n_updates            | 256          |
# |    policy_gradient_loss | -0.000386    |
# |    std                  | 0.784        |
# |    value_loss           | 0.629        |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0070
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5460          |
# |    iterations           | 34            |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 68374         |
# | train/                  |               |
# |    approx_kl            | 0.00095304206 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0004        |
# |    loss                 | 0.591         |
# |    n_updates            | 264           |
# |    policy_gradient_loss | -0.000747     |
# |    std                  | 0.771         |
# |    value_loss           | 0.91          |
# -------------------------------------------
# PPO Iteration Average Reward: -0.0008
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5460         |
# |    iterations           | 35           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 70385        |
# | train/                  |              |
# |    approx_kl            | 0.0032773453 |
# |    clip_fraction        | 0.00275      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 1.13e-06     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.42         |
# |    n_updates            | 272          |
# |    policy_gradient_loss | -0.000798    |
# |    std                  | 0.768        |
# |    value_loss           | 1.38         |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0069
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5460         |
# |    iterations           | 36           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 72396        |
# | train/                  |              |
# |    approx_kl            | 0.0011007353 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 7.15e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.26         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 5.63e-05     |
# |    std                  | 0.766        |
# |    value_loss           | 0.942        |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0079
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5460        |
# |    iterations           | 37          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 74407       |
# | train/                  |             |
# |    approx_kl            | 0.000570428 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 2.9e-05     |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.17        |
# |    n_updates            | 288         |
# |    policy_gradient_loss | -0.000962   |
# |    std                  | 0.773       |
# |    value_loss           | 0.366       |
# -----------------------------------------
# PPO Iteration Average Reward: -0.0073
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5460         |
# |    iterations           | 38           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 76418        |
# | train/                  |              |
# |    approx_kl            | 0.0017986769 |
# |    clip_fraction        | 0.00181      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.3          |
# |    n_updates            | 296          |
# |    policy_gradient_loss | -0.00157     |
# |    std                  | 0.768        |
# |    value_loss           | 0.888        |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0082
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5460         |
# |    iterations           | 39           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 78429        |
# | train/                  |              |
# |    approx_kl            | 0.0012135982 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -2.15e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.285        |
# |    n_updates            | 304          |
# |    policy_gradient_loss | -0.000321    |
# |    std                  | 0.764        |
# |    value_loss           | 0.513        |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0079
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5460         |
# |    iterations           | 40           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 80440        |
# | train/                  |              |
# |    approx_kl            | 0.0014036737 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.3          |
# |    n_updates            | 312          |
# |    policy_gradient_loss | -0.000154    |
# |    std                  | 0.762        |
# |    value_loss           | 1.1          |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0280
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5459         |
# |    iterations           | 41           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 82451        |
# | train/                  |              |
# |    approx_kl            | 0.0008708242 |
# |    clip_fraction        | 0.000377     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 9.48e-06     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0497       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.751        |
# |    value_loss           | 0.124        |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0002
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5458        |
# |    iterations           | 42          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 84462       |
# | train/                  |             |
# |    approx_kl            | 0.004967103 |
# |    clip_fraction        | 0.00939     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 2.46        |
# |    n_updates            | 328         |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 0.747       |
# |    value_loss           | 1.21        |
# -----------------------------------------
# PPO Iteration Average Reward: 0.0048
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5458          |
# |    iterations           | 43            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 86473         |
# | train/                  |               |
# |    approx_kl            | 2.3087578e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | -4.41e-06     |
# |    learning_rate        | 0.0004        |
# |    loss                 | 0.0999        |
# |    n_updates            | 336           |
# |    policy_gradient_loss | 6.12e-05      |
# |    std                  | 0.746         |
# |    value_loss           | 0.329         |
# -------------------------------------------
# PPO Iteration Average Reward: -0.0051
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5458          |
# |    iterations           | 44            |
# |    time_elapsed         | 16            |
# ...
# |    total_timesteps      | 520849       |
# | train/                  |              |
# |    approx_kl            | 0.0021857005 |
# |    clip_fraction        | 0.00212      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00174     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.000992     |
# |    n_updates            | 2064         |
# |    policy_gradient_loss | -0.00211     |
# |    std                  | 0.919        |
# |    value_loss           | 0.00797      |
# ------------------------------------------
# PPO Iteration Average Reward: -0.0092
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5359         |
# |    iterations           | 260          |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 522860       |
# | train/                  |              |
# |    approx_kl            | 0.0007122095 |
# |    clip_fraction        | 0.00119      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00304      |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.00519      |
# |    n_updates            | 2072         |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.926        |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5359         |
# |    iterations           | 261          |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 524871       |
# | train/                  |              |
# |    approx_kl            | 0.0034739184 |
# |    clip_fraction        | 0.00778      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00321      |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.404        |
# |    n_updates            | 2080         |
# |    policy_gradient_loss | -0.00365     |
# |    std                  | 0.922        |
# |    value_loss           | 0.358        |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5359         |
# |    iterations           | 262          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 526882       |
# | train/                  |              |
# |    approx_kl            | 0.0021456243 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.647       |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0159       |
# |    n_updates            | 2088         |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 0.92         |
# |    value_loss           | 0.000128     |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5359         |
# |    iterations           | 263          |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 528893       |
# | train/                  |              |
# |    approx_kl            | 8.571716e-05 |
# |    clip_fraction        | 0.00349      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -7.09        |
# |    learning_rate        | 0.0004       |
# |    loss                 | -0.00428     |
# |    n_updates            | 2096         |
# |    policy_gradient_loss | 0.000393     |
# |    std                  | 0.916        |
# |    value_loss           | 2.68e-05     |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5359         |
# |    iterations           | 264          |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 530904       |
# | train/                  |              |
# |    approx_kl            | 0.0006144383 |
# |    clip_fraction        | 0.00154      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -11.4        |
# |    learning_rate        | 0.0004       |
# |    loss                 | -0.00271     |
# |    n_updates            | 2104         |
# |    policy_gradient_loss | -0.00099     |
# |    std                  | 0.917        |
# |    value_loss           | 1.7e-05      |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0006
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5358          |
# |    iterations           | 265           |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 532915        |
# | train/                  |               |
# |    approx_kl            | 0.00044449102 |
# |    clip_fraction        | 0.00145       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -15.2         |
# |    learning_rate        | 0.0004        |
# |    loss                 | -0.0036       |
# |    n_updates            | 2112          |
# |    policy_gradient_loss | 0.00179       |
# |    std                  | 0.918         |
# |    value_loss           | 1.18e-05      |
# -------------------------------------------
# PPO Iteration Average Reward: 0.0000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5356         |
# |    iterations           | 266          |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 534926       |
# | train/                  |              |
# |    approx_kl            | 0.0013771183 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00252     |
# |    learning_rate        | 0.0004       |
# |    loss                 | -0.00089     |
# |    n_updates            | 2120         |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.933        |
# |    value_loss           | 0.00291      |
# ------------------------------------------
# PPO Iteration Average Reward: 0.0029
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5356         |
# |    iterations           | 267          |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 536937       |
# | train/                  |              |
# |    approx_kl            | 0.0024201858 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -16.2        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0139       |
# |    n_updates            | 2128         |
# |    policy_gradient_loss | -0.00534     |
# |    std                  | 0.943        |
# |    value_loss           | 0.000126     |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 1039
#    1036     model.policy.to(torch.float32)  # Convert policy to float32
#    1038 stop_callback = StopTrainingCallback()
# -> 1039 model.learn(total_timesteps=3000000, callback=stop_callback)
#    1044 # Setup Environment
#    1045 test_env = DummyVecEnv([lambda: TradingEnv(obs, all_data_np)])
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/policies.py:645, in ActorCriticPolicy.forward(self, obs, deterministic)
#     637 """
#     638 Forward pass in all the networks (actor and critic)
#     639
#    (...)
#     642 :return: action, value and log probability of the action
#     643 """
#     644 # Preprocess the observation if needed
# --> 645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
#     647     latent_pi, latent_vf = self.mlp_extractor(features)
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/policies.py:672, in ActorCriticPolicy.extract_features(self, obs, features_extractor)
#     663 """
#     664 Preprocess the observation if needed and extract features.
#     665
#    (...)
#     669     features for the actor and the features for the critic.
#     670 """
#     671 if self.share_features_extractor:
# --> 672     return super().extract_features(obs, self.features_extractor if features_extractor is None else features_extractor)
#     673 else:
#     674     if features_extractor is not None:
#
# File /opt/homebrew/lib/python3.12/site-packages/stable_baselines3/common/policies.py:131, in BaseModel.extract_features(self, obs, features_extractor)
#     123 """
#     124 Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128 :return: The extracted features
#     129 """
#     130 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 131 return features_extractor(preprocessed_obs)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[70], line 677, in SharedStockNetwork.forward(self, observations)
#     674 daily = obs[:, i, :, :].reshape(-1, features_len)  # Ensures correct reshaping
#     676 # Apply the corresponding dense layer for this stock
# --> 677 daily_result = self.daily_stock_dense_list[i](daily)
#     679 # Reshape back to match batch and sequence dimensions
#     680 daily_results.append(daily_result.view(batch_size, sequence_len, -1))
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/modules/activation.py:828, in LeakyReLU.forward(self, input)
#     827 def forward(self, input: Tensor) -> Tensor:
# --> 828     return F.leaky_relu(input, self.negative_slope, self.inplace)
#
# File /opt/homebrew/lib/python3.12/site-packages/torch/nn/functional.py:1902, in leaky_relu(input, negative_slope, inplace)
#    1900     result = torch._C._nn.leaky_relu_(input, negative_slope)
#    1901 else:
# -> 1902     result = torch._C._nn.leaky_relu(input, negative_slope)
#    1903 return result
#
# KeyboardInterrupt:

# %%
### EXTRA LEARNING:

model.learning_rate = 0.00004
model._setup_lr_schedule()

stop_callback = StopTrainingCallback()
model.learn(total_timesteps=4000000, callback=stop_callback)

# %%
### TRAINING DATA. FIXED PORTFOLIO

env = DummyVecEnv([lambda: TradingEnv(obs, all_data_np)])
env.tickers = my_stocks

# Test Model
done = False
obs_row = env.reset()
# last_known_explianed_variance = None    
# cons_counter = 0
action_len = len(my_stocks)
if not single_stock_reward:
    action_len += 1
    

while not done:
    action = np.ones((action_len), dtype=np.float32) / (action_len)
    action = np.array([action])
    obs_row, reward, done, _ = env.step(action)
    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")


# total_pct = 0
# for i, ticker in enumerate(my_stocks):
#     pct = (all_data_np[i, -1] - all_data_np[i, 0]) / all_data_np[i, 0]
#     total_pct +=pct
#     print(f"percentage for ticker: {ticker}: {(all_data_np[i, -1] - all_data_np[i, 0]) / all_data_np[i, 0]}")
# total_pct /= len(my_stocks) + 1
# print(f"percentage if kept equal allocation all the time: {total_pct}")
# Out:
# num_features: 28
# self.action_space.shape: (1,)
# Step: 1, Action: [[1.]], Reward: [1.9841259], Last Price: [45.68592072] Position: [218.] Total Balance: 9980.083190647307 Total Reward: 1.9841258495548155, Cash Balance: 20.552474704924066, Position Balance: 9959.530715942383
# Step: 2, Action: [[1.]], Reward: [0.], Last Price: [45.87342453] Position: [218.] Total Balance: 10020.961274577307 Total Reward: 0.0, Cash Balance: 20.554727030919125, Position Balance: 10000.406547546387
# Step: 3, Action: [[1.]], Reward: [0.], Last Price: [45.87342453] Position: [218.] Total Balance: 10020.963527150132 Total Reward: 0.0, Cash Balance: 20.55697960374443, Position Balance: 10000.406547546387
# Step: 4, Action: [[1.]], Reward: [0.], Last Price: [46.6948204] Position: [218.] Total Balance: 10200.030080506924 Total Reward: 0.0, Cash Balance: 20.559232423427034, Position Balance: 10179.470848083496
# Step: 1997, Action: [[1.]], Reward: [0.], Last Price: [425.39401245] Position: [218.] Total Balance: 92761.47211306066 Total Reward: 0.0, Cash Balance: 25.577398705187523, Position Balance: 92735.89471435547
# Step: 1998, Action: [[1.]], Reward: [0.], Last Price: [430.17617798] Position: [218.] Total Balance: 93803.98700102419 Total Reward: 0.0, Cash Balance: 25.580201707785353, Position Balance: 93778.4067993164
# Step: 1999, Action: [[1.]], Reward: [0.], Last Price: [438.50769043] Position: [218.] Total Balance: 95620.25951868943 Total Reward: 0.0, Cash Balance: 25.583005017561547, Position Balance: 95594.67651367188
# Step: 2000, Action: [[1.]], Reward: [0.], Last Price: [439.02468872] Position: [218.] Total Balance: 95732.96794974784 Total Reward: 0.0, Cash Balance: 25.58580863454977, Position Balance: 95707.38214111328
# Step: 2001, Action: [[1.]], Reward: [0.], Last Price: [440.00897217] Position: [218.] Total Balance: 95947.54454517596 Total Reward: 0.0, Cash Balance: 25.588612558783694, Position Balance: 95921.95593261717
# Step: 2002, Action: [[1.]], Reward: [0.], Last Price: [445.77539062] Position: [218.] Total Balance: 97204.6265730403 Total Reward: 0.0, Cash Balance: 25.591416790296986, Position Balance: 97179.03515625
# Step: 2003, Action: [[1.]], Reward: [0.], Last Price: [443.75714111] Position: [218.] Total Balance: 96764.65098402445 Total Reward: 0.0, Cash Balance: 25.594221329123318, Position Balance: 96739.05676269533
# Step: 2004, Action: [[1.]], Reward: [0.], Last Price: [443.12084961] Position: [218.] Total Balance: 96625.94224101905 Total Reward: 0.0, Cash Balance: 25.597026175296374, Position Balance: 96600.34521484375
# Step: 2005, Action: [[1.]], Reward: [0.], Last Price: [447.17724609] Position: [218.] Total Balance: 97510.23947976634 Total Reward: 0.0, Cash Balance: 25.59983132884983, Position Balance: 97484.6396484375
# Step: 2006, Action: [[1.]], Reward: [0.], Last Price: [445.07949829] Position: [218.] Total Balance: 97052.93326423122 Total Reward: 0.0, Cash Balance: 25.602636789817375, Position Balance: 97027.3306274414
# Step: 2007, Action: [[1.]], Reward: [0.], Last Price: [448.3404541] Position: [218.] Total Balance: 97763.82443669885 Total Reward: 0.0, Cash Balance: 25.605442558232696, Position Balance: 97738.21899414062
# Step: 2008, Action: [[1.]], Reward: [0.], Last Price: [449.54345703] Position: [218.] Total Balance: 98026.08188144663 Total Reward: 0.0, Cash Balance: 25.608248634129488, Position Balance: 98000.4736328125
# Step: 2009, Action: [[1.]], Reward: [0.], Last Price: [450.22946167] Position: [218.] Total Balance: 98175.6336990605 Total Reward: 0.0, Cash Balance: 25.611055017541446, Position Balance: 98150.02264404297
# Step: 0, Action: [[1.]], Reward: [0.], Last Price: [0.] Position: [0.] Total Balance: 10000.0 Total Reward: 1.0, Cash Balance: 10000, Position Balance: 0.0

# %%
import matplotlib.pyplot as plt
# Create environment for new data
env = DummyVecEnv([lambda: TradingEnv(obs, all_data_np)])

# Test Model
done = False
obs_val_pre = env.reset()
env.current_step = 0

# Assuming you have collected these values during your loop
steps = []  # List to store step numbers
actions_list = []  # List to store action values
total_balances = []  # List to store total balances
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action, _states = model.predict(obs_val_pre, deterministic=True)
    obs_val_pre, reward, done, _ = env.step(action)

    steps.append(env.envs[0].current_step)
    actions_list.append(action.flatten())  # Flatten to make it 1D
    total_balances.append(env.envs[0].cash_balance + np.sum(env.envs[0].positions[0] * env.envs[0].last_prices[0]))

    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")

# Convert actions to a NumPy array for easier plotting
actions_array = np.array(actions_list)

# Plot Actions over Steps
plt.figure(figsize=(10, 5))
action_space = actions_array.shape[1]
if include_singular_rewards:
    action_space -= len(my_stocks)
for i in range(action_space):
    plt.plot(steps[1:-1], actions_array[1:-1, i], label=f'Action {i+1}')

plt.xlabel('Steps')
plt.ylabel('Action Values')
plt.title('Actions over Steps')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
actions_array = actions_array[:, 0:action_space]
actions_array[1:-1] = actions_array[1:-1] / actions_array[1:-1].sum(axis=1, keepdims=True)
for i in range(action_space):
    plt.plot(steps[1:-1], actions_array[1:-1, i], label=f'Action {i+1}')

plt.xlabel('Steps')
plt.ylabel('Action Values')
plt.title('Actions over Steps')
plt.legend()
plt.grid(True)
plt.show()

# Plot Total Balance over Steps
plt.figure(figsize=(10, 5))
plt.plot(steps, total_balances, marker='o', linestyle='-', alpha=0.8)
plt.xlabel('Steps')
plt.ylabel('Total Balance')
plt.title('Total Balance over Steps')
plt.grid(True)
plt.show()
# Out:
# num_features: 28
# self.action_space.shape: (1,)
# Step: 1, Action: [[0.]], Reward: [0.], Last Price: [45.68592072] Position: [0.] Total Balance: 10001.09589041096 Total Reward: 0.0, Cash Balance: 10001.09589041096, Position Balance: 0.0
# Step: 2, Action: [[0.]], Reward: [0.], Last Price: [45.87342453] Position: [0.] Total Balance: 10002.191900919497 Total Reward: 0.0, Cash Balance: 10002.191900919497, Position Balance: 0.0
# Step: 3, Action: [[0.]], Reward: [0.], Last Price: [45.87342453] Position: [0.] Total Balance: 10003.288031538776 Total Reward: 0.0, Cash Balance: 10003.288031538776, Position Balance: 0.0
# Step: 4, Action: [[0.]], Reward: [0.], Last Price: [46.6948204] Position: [0.] Total Balance: 10004.384282281959 Total Reward: 0.0, Cash Balance: 10004.384282281959, Position Balance: 0.0
# Step: 5, Action: [[0.]], Reward: [0.], Last Price: [46.95374298] Position: [0.] Total Balance: 10005.480653162209 Total Reward: 0.0, Cash Balance: 10005.480653162209, Position Balance: 0.0
# Step: 6, Action: [[0.]], Reward: [0.], Last Price: [47.50730133] Position: [0.] Total Balance: 10006.577144192692 Total Reward: 0.0, Cash Balance: 10006.577144192692, Position Balance: 0.0
# Step: 23, Action: [[0.]], Reward: [0.], Last Price: [51.23931885] Position: [0.] Total Balance: 10025.235887461191 Total Reward: 0.0, Cash Balance: 10025.235887461191, Position Balance: 0.0
# Step: 24, Action: [[0.]], Reward: [0.], Last Price: [51.74821854] Position: [0.] Total Balance: 10026.334543448858 Total Reward: 0.0, Cash Balance: 10026.334543448858, Position Balance: 0.0
# Step: 25, Action: [[0.]], Reward: [0.], Last Price: [51.83750916] Position: [0.] Total Balance: 10027.433319837182 Total Reward: 0.0, Cash Balance: 10027.433319837182, Position Balance: 0.0
# Step: 26, Action: [[0.]], Reward: [0.], Last Price: [51.9625206] Position: [0.] Total Balance: 10028.532216639356 Total Reward: 0.0, Cash Balance: 10028.532216639356, Position Balance: 0.0
# Step: 27, Action: [[0.]], Reward: [0.], Last Price: [51.80178833] Position: [0.] Total Balance: 10029.631233868577 Total Reward: 0.0, Cash Balance: 10029.631233868577, Position Balance: 0.0
# Step: 28, Action: [[0.]], Reward: [0.], Last Price: [52.05178452] Position: [0.] Total Balance: 10030.730371538042 Total Reward: 0.0, Cash Balance: 10030.730371538042, Position Balance: 0.0
# Step: 29, Action: [[0.]], Reward: [0.], Last Price: [51.7303772] Position: [0.] Total Balance: 10031.82962966095 Total Reward: 0.0, Cash Balance: 10031.82962966095, Position Balance: 0.0
# Step: 30, Action: [[0.]], Reward: [0.], Last Price: [51.8910675] Position: [0.] Total Balance: 10032.929008250501 Total Reward: 0.0, Cash Balance: 10032.929008250501, Position Balance: 0.0
# Step: 31, Action: [[0.]], Reward: [0.], Last Price: [51.6035881] Position: [0.] Total Balance: 10034.0285073199 Total Reward: 0.0, Cash Balance: 10034.0285073199, Position Balance: 0.0
# Step: 32, Action: [[0.]], Reward: [0.], Last Price: [51.71140289] Position: [0.] Total Balance: 10035.128126882346 Total Reward: 0.0, Cash Balance: 10035.128126882346, Position Balance: 0.0
# Step: 33, Action: [[0.]], Reward: [0.], Last Price: [51.74732971] Position: [0.] Total Balance: 10036.227866951045 Total Reward: 0.0, Cash Balance: 10036.227866951045, Position Balance: 0.0
# Step: 34, Action: [[0.]], Reward: [0.], Last Price: [51.76530075] Position: [0.] Total Balance: 10037.327727539205 Total Reward: 0.0, Cash Balance: 10037.327727539205, Position Balance: 0.0
# Step: 35, Action: [[0.]], Reward: [0.], Last Price: [51.81021881] Position: [0.] Total Balance: 10038.42770866003 Total Reward: 0.0, Cash Balance: 10038.42770866003, Position Balance: 0.0
# Step: 36, Action: [[0.]], Reward: [0.], Last Price: [52.00786972] Position: [0.] Total Balance: 10039.527810326734 Total Reward: 0.0, Cash Balance: 10039.527810326734, Position Balance: 0.0
# Step: 37, Action: [[0.]], Reward: [0.], Last Price: [52.06177521] Position: [0.] Total Balance: 10040.628032552522 Total Reward: 0.0, Cash Balance: 10040.628032552522, Position Balance: 0.0
# Step: 38, Action: [[0.]], Reward: [0.], Last Price: [52.25941086] Position: [0.] Total Balance: 10041.72837535061 Total Reward: 0.0, Cash Balance: 10041.72837535061, Position Balance: 0.0
# Step: 39, Action: [[0.]], Reward: [0.], Last Price: [52.13363266] Position: [0.] Total Balance: 10042.82883873421 Total Reward: 0.0, Cash Balance: 10042.82883873421, Position Balance: 0.0
# Step: 40, Action: [[0.]], Reward: [0.], Last Price: [52.1965332] Position: [0.] Total Balance: 10043.929422716537 Total Reward: 0.0, Cash Balance: 10043.929422716537, Position Balance: 0.0
# Step: 41, Action: [[0.]], Reward: [0.], Last Price: [52.00786972] Position: [0.] Total Balance: 10045.030127310807 Total Reward: 0.0, Cash Balance: 10045.030127310807, Position Balance: 0.0
# Step: 42, Action: [[0.]], Reward: [0.], Last Price: [51.62155914] Position: [0.] Total Balance: 10046.130952530239 Total Reward: 0.0, Cash Balance: 10046.130952530239, Position Balance: 0.0
# Step: 43, Action: [[0.]], Reward: [0.], Last Price: [51.7383461] Position: [0.] Total Balance: 10047.23189838805 Total Reward: 0.0, Cash Balance: 10047.23189838805, Position Balance: 0.0
# Step: 44, Action: [[0.]], Reward: [0.], Last Price: [51.81021881] Position: [0.] Total Balance: 10048.332964897463 Total Reward: 0.0, Cash Balance: 10048.332964897463, Position Balance: 0.0
# Step: 45, Action: [[0.]], Reward: [0.], Last Price: [51.75632095] Position: [0.] Total Balance: 10049.434152071699 Total Reward: 0.0, Cash Balance: 10049.434152071699, Position Balance: 0.0
# Step: 46, Action: [[0.]], Reward: [0.], Last Price: [51.80125046] Position: [0.] Total Balance: 10050.53545992398 Total Reward: 0.0, Cash Balance: 10050.53545992398, Position Balance: 0.0
# Step: 47, Action: [[0.]], Reward: [0.], Last Price: [51.59460068] Position: [0.] Total Balance: 10051.636888467534 Total Reward: 0.0, Cash Balance: 10051.636888467534, Position Balance: 0.0
# Step: 48, Action: [[0.]], Reward: [0.], Last Price: [50.4985733] Position: [0.] Total Balance: 10052.738437715585 Total Reward: 0.0, Cash Balance: 10052.738437715585, Position Balance: 0.0
# Step: 49, Action: [[0.]], Reward: [0.], Last Price: [51.25322342] Position: [0.] Total Balance: 10053.840107681362 Total Reward: 0.0, Cash Balance: 10053.840107681362, Position Balance: 0.0
# Step: 50, Action: [[0.]], Reward: [0.], Last Price: [50.78606033] Position: [0.] Total Balance: 10054.941898378094 Total Reward: 0.0, Cash Balance: 10054.941898378094, Position Balance: 0.0
# Step: 51, Action: [[0.]], Reward: [0.], Last Price: [50.54348755] Position: [0.] Total Balance: 10056.043809819012 Total Reward: 0.0, Cash Balance: 10056.043809819012, Position Balance: 0.0
# Step: 52, Action: [[0.]], Reward: [0.], Last Price: [51.3789978] Position: [0.] Total Balance: 10057.145842017348 Total Reward: 0.0, Cash Balance: 10057.145842017348, Position Balance: 0.0
# Step: 53, Action: [[0.]], Reward: [0.], Last Price: [51.43290329] Position: [0.] Total Balance: 10058.247994986335 Total Reward: 0.0, Cash Balance: 10058.247994986335, Position Balance: 0.0
# Step: 54, Action: [[0.]], Reward: [0.], Last Price: [51.14540863] Position: [0.] Total Balance: 10059.35026873921 Total Reward: 0.0, Cash Balance: 10059.35026873921, Position Balance: 0.0
# Step: 55, Action: [[0.]], Reward: [0.], Last Price: [51.03760529] Position: [0.] Total Balance: 10060.452663289208 Total Reward: 0.0, Cash Balance: 10060.452663289208, Position Balance: 0.0
# Step: 56, Action: [[0.]], Reward: [0.], Last Price: [51.8910675] Position: [0.] Total Balance: 10061.555178649569 Total Reward: 0.0, Cash Balance: 10061.555178649569, Position Balance: 0.0
# Step: 57, Action: [[0.]], Reward: [0.], Last Price: [51.94497681] Position: [0.] Total Balance: 10062.65781483353 Total Reward: 0.0, Cash Balance: 10062.65781483353, Position Balance: 0.0
# Step: 58, Action: [[0.]], Reward: [0.], Last Price: [51.59460068] Position: [0.] Total Balance: 10063.760571854335 Total Reward: 0.0, Cash Balance: 10063.760571854335, Position Balance: 0.0
# Step: 59, Action: [[0.]], Reward: [0.], Last Price: [51.11846161] Position: [0.] Total Balance: 10064.863449725222 Total Reward: 0.0, Cash Balance: 10064.863449725222, Position Balance: 0.0
# Step: 60, Action: [[0.]], Reward: [0.], Last Price: [52.06177521] Position: [0.] Total Balance: 10065.96644845944 Total Reward: 0.0, Cash Balance: 10065.96644845944, Position Balance: 0.0
# Step: 61, Action: [[0.]], Reward: [0.], Last Price: [52.13363266] Position: [0.] Total Balance: 10067.06956807023 Total Reward: 0.0, Cash Balance: 10067.06956807023, Position Balance: 0.0
# Step: 62, Action: [[0.]], Reward: [0.], Last Price: [51.56764984] Position: [0.] Total Balance: 10068.17280857084 Total Reward: 0.0, Cash Balance: 10068.17280857084, Position Balance: 0.0
# Step: 63, Action: [[0.]], Reward: [0.], Last Price: [51.74732971] Position: [0.] Total Balance: 10069.276169974519 Total Reward: 0.0, Cash Balance: 10069.276169974519, Position Balance: 0.0
# Step: 64, Action: [[0.]], Reward: [0.], Last Price: [51.58562851] Position: [0.] Total Balance: 10070.379652294516 Total Reward: 0.0, Cash Balance: 10070.379652294516, Position Balance: 0.0
# Step: 65, Action: [[0.]], Reward: [0.], Last Price: [51.42391205] Position: [0.] Total Balance: 10071.483255544083 Total Reward: 0.0, Cash Balance: 10071.483255544083, Position Balance: 0.0
# Step: 66, Action: [[0.]], Reward: [0.], Last Price: [51.7832756] Position: [0.] Total Balance: 10072.58697973647 Total Reward: 0.0, Cash Balance: 10072.58697973647, Position Balance: 0.0
# Step: 67, Action: [[0.]], Reward: [0.], Last Price: [51.87311172] Position: [0.] Total Balance: 10073.690824884934 Total Reward: 0.0, Cash Balance: 10073.690824884934, Position Balance: 0.0
# Step: 68, Action: [[0.]], Reward: [0.], Last Price: [51.92701721] Position: [0.] Total Balance: 10074.79479100273 Total Reward: 0.0, Cash Balance: 10074.79479100273, Position Balance: 0.0
# Step: 69, Action: [[0.]], Reward: [0.], Last Price: [52.14263916] Position: [0.] Total Balance: 10075.898878103115 Total Reward: 0.0, Cash Balance: 10075.898878103115, Position Balance: 0.0
# Step: 70, Action: [[0.]], Reward: [0.], Last Price: [51.3789978] Position: [0.] Total Balance: 10077.003086199345 Total Reward: 0.0, Cash Balance: 10077.003086199345, Position Balance: 0.0
# Step: 71, Action: [[0.]], Reward: [0.], Last Price: [51.30711746] Position: [0.] Total Balance: 10078.107415304683 Total Reward: 0.0, Cash Balance: 10078.107415304683, Position Balance: 0.0
# Step: 72, Action: [[0.]], Reward: [0.], Last Price: [51.1364212] Position: [0.] Total Balance: 10079.211865432388 Total Reward: 0.0, Cash Balance: 10079.211865432388, Position Balance: 0.0
# Step: 73, Action: [[0.]], Reward: [0.], Last Price: [51.58562851] Position: [0.] Total Balance: 10080.316436595722 Total Reward: 0.0, Cash Balance: 10080.316436595722, Position Balance: 0.0
# Step: 74, Action: [[0.]], Reward: [0.], Last Price: [51.40594482] Position: [0.] Total Balance: 10081.421128807951 Total Reward: 0.0, Cash Balance: 10081.421128807951, Position Balance: 0.0
# Step: 75, Action: [[0.]], Reward: [0.], Last Price: [51.80125046] Position: [0.] Total Balance: 10082.52594208234 Total Reward: 0.0, Cash Balance: 10082.52594208234, Position Balance: 0.0
# Step: 76, Action: [[0.]], Reward: [0.], Last Price: [51.68444443] Position: [0.] Total Balance: 10083.630876432158 Total Reward: 0.0, Cash Balance: 10083.630876432158, Position Balance: 0.0
# Step: 77, Action: [[0.]], Reward: [0.], Last Price: [51.43290329] Position: [0.] Total Balance: 10084.735931870671 Total Reward: 0.0, Cash Balance: 10084.735931870671, Position Balance: 0.0
# Step: 78, Action: [[0.]], Reward: [0.], Last Price: [53.59801865] Position: [0.] Total Balance: 10085.84110841115 Total Reward: 0.0, Cash Balance: 10085.84110841115, Position Balance: 0.0
# Step: 79, Action: [[0.]], Reward: [0.], Last Price: [54.80187225] Position: [0.] Total Balance: 10086.946406066867 Total Reward: 0.0, Cash Balance: 10086.946406066867, Position Balance: 0.0
# Step: 80, Action: [[0.]], Reward: [0.], Last Price: [54.7928772] Position: [0.] Total Balance: 10088.051824851094 Total Reward: 0.0, Cash Balance: 10088.051824851094, Position Balance: 0.0
# Step: 81, Action: [[0.]], Reward: [0.], Last Price: [54.46945572] Position: [0.] Total Balance: 10089.157364777106 Total Reward: 0.0, Cash Balance: 10089.157364777106, Position Balance: 0.0
# Step: 82, Action: [[0.]], Reward: [0.], Last Price: [53.99330902] Position: [0.] Total Balance: 10090.263025858178 Total Reward: 0.0, Cash Balance: 10090.263025858178, Position Balance: 0.0
# Step: 83, Action: [[0.]], Reward: [0.], Last Price: [53.78667831] Position: [0.] Total Balance: 10091.368808107587 Total Reward: 0.0, Cash Balance: 10091.368808107587, Position Balance: 0.0
# Step: 84, Action: [[0.]], Reward: [0.], Last Price: [53.83160019] Position: [0.] Total Balance: 10092.474711538613 Total Reward: 0.0, Cash Balance: 10092.474711538613, Position Balance: 0.0
# Step: 85, Action: [[0.]], Reward: [0.], Last Price: [53.72380447] Position: [0.] Total Balance: 10093.580736164535 Total Reward: 0.0, Cash Balance: 10093.580736164535, Position Balance: 0.0
# Step: 86, Action: [[0.]], Reward: [0.], Last Price: [53.39138794] Position: [0.] Total Balance: 10094.686881998636 Total Reward: 0.0, Cash Balance: 10094.686881998636, Position Balance: 0.0
# Step: 87, Action: [[0.]], Reward: [0.], Last Price: [53.19374466] Position: [0.] Total Balance: 10095.793149054198 Total Reward: 0.0, Cash Balance: 10095.793149054198, Position Balance: 0.0
# Step: 88, Action: [[0.]], Reward: [0.], Last Price: [52.74455643] Position: [0.] Total Balance: 10096.899537344505 Total Reward: 0.0, Cash Balance: 10096.899537344505, Position Balance: 0.0
# Step: 89, Action: [[0.]], Reward: [0.], Last Price: [54.28079987] Position: [0.] Total Balance: 10098.006046882843 Total Reward: 0.0, Cash Balance: 10098.006046882843, Position Balance: 0.0
# Step: 90, Action: [[0.]], Reward: [0.], Last Price: [54.32571793] Position: [0.] Total Balance: 10099.112677682502 Total Reward: 0.0, Cash Balance: 10099.112677682502, Position Balance: 0.0
# Step: 91, Action: [[0.]], Reward: [0.], Last Price: [54.05620956] Position: [0.] Total Balance: 10100.21942975677 Total Reward: 0.0, Cash Balance: 10100.21942975677, Position Balance: 0.0
# Step: 92, Action: [[0.]], Reward: [0.], Last Price: [52.735569] Position: [0.] Total Balance: 10101.326303118934 Total Reward: 0.0, Cash Balance: 10101.326303118934, Position Balance: 0.0
# Step: 93, Action: [[0.]], Reward: [0.], Last Price: [53.0230484] Position: [0.] Total Balance: 10102.43329778229 Total Reward: 0.0, Cash Balance: 10102.43329778229, Position Balance: 0.0
# Step: 94, Action: [[0.]], Reward: [0.], Last Price: [52.2144928] Position: [0.] Total Balance: 10103.540413760129 Total Reward: 0.0, Cash Balance: 10103.540413760129, Position Balance: 0.0
# Step: 95, Action: [[0.]], Reward: [0.], Last Price: [53.24558258] Position: [0.] Total Balance: 10104.647651065747 Total Reward: 0.0, Cash Balance: 10104.647651065747, Position Balance: 0.0
# Step: 96, Action: [[0.]], Reward: [0.], Last Price: [53.95105743] Position: [0.] Total Balance: 10105.755009712439 Total Reward: 0.0, Cash Balance: 10105.755009712439, Position Balance: 0.0
# Step: 97, Action: [[0.]], Reward: [0.], Last Price: [54.84647751] Position: [0.] Total Balance: 10106.862489713503 Total Reward: 0.0, Cash Balance: 10106.862489713503, Position Balance: 0.0
# Step: 98, Action: [[0.]], Reward: [0.], Last Price: [54.58418655] Position: [0.] Total Balance: 10107.97009108224 Total Reward: 0.0, Cash Balance: 10107.97009108224, Position Balance: 0.0
# Step: 99, Action: [[0.]], Reward: [0.], Last Price: [55.04545593] Position: [0.] Total Balance: 10109.077813831947 Total Reward: 0.0, Cash Balance: 10109.077813831947, Position Balance: 0.0
# Step: 100, Action: [[0.]], Reward: [0.], Last Price: [55.28062057] Position: [0.] Total Balance: 10110.18565797593 Total Reward: 0.0, Cash Balance: 10110.18565797593, Position Balance: 0.0
# Step: 101, Action: [[0.]], Reward: [0.], Last Price: [54.62940216] Position: [0.] Total Balance: 10111.293623527488 Total Reward: 0.0, Cash Balance: 10111.293623527488, Position Balance: 0.0
# Step: 102, Action: [[0.]], Reward: [0.], Last Price: [54.74698639] Position: [0.] Total Balance: 10112.40171049993 Total Reward: 0.0, Cash Balance: 10112.40171049993, Position Balance: 0.0
# Step: 103, Action: [[0.]], Reward: [0.], Last Price: [54.81934357] Position: [0.] Total Balance: 10113.509918906559 Total Reward: 0.0, Cash Balance: 10113.509918906559, Position Balance: 0.0
# Step: 104, Action: [[0.]], Reward: [0.], Last Price: [55.25347519] Position: [0.] Total Balance: 10114.618248760686 Total Reward: 0.0, Cash Balance: 10114.618248760686, Position Balance: 0.0
# Step: 105, Action: [[0.]], Reward: [0.], Last Price: [54.50278473] Position: [0.] Total Balance: 10115.726700075618 Total Reward: 0.0, Cash Balance: 10115.726700075618, Position Balance: 0.0
# Step: 106, Action: [[0.]], Reward: [0.], Last Price: [53.54405212] Position: [0.] Total Balance: 10116.835272864668 Total Reward: 0.0, Cash Balance: 10116.835272864668, Position Balance: 0.0
# Step: 107, Action: [[0.]], Reward: [0.], Last Price: [53.58927155] Position: [0.] Total Balance: 10117.943967141146 Total Reward: 0.0, Cash Balance: 10117.943967141146, Position Balance: 0.0
# Step: 108, Action: [[0.]], Reward: [0.], Last Price: [54.46661377] Position: [0.] Total Balance: 10119.052782918367 Total Reward: 0.0, Cash Balance: 10119.052782918367, Position Balance: 0.0
# Step: 109, Action: [[0.]], Reward: [0.], Last Price: [54.22239685] Position: [0.] Total Balance: 10120.161720209646 Total Reward: 0.0, Cash Balance: 10120.161720209646, Position Balance: 0.0
# Step: 110, Action: [[0.]], Reward: [0.], Last Price: [55.5067215] Position: [0.] Total Balance: 10121.270779028298 Total Reward: 0.0, Cash Balance: 10121.270779028298, Position Balance: 0.0
# Step: 111, Action: [[0.]], Reward: [0.], Last Price: [55.18111801] Position: [0.] Total Balance: 10122.379959387645 Total Reward: 0.0, Cash Balance: 10122.379959387645, Position Balance: 0.0
# Step: 112, Action: [[0.]], Reward: [0.], Last Price: [56.04940414] Position: [0.] Total Balance: 10123.489261301002 Total Reward: 0.0, Cash Balance: 10123.489261301002, Position Balance: 0.0
# Step: 113, Action: [[0.]], Reward: [0.], Last Price: [56.23029709] Position: [0.] Total Balance: 10124.598684781691 Total Reward: 0.0, Cash Balance: 10124.598684781691, Position Balance: 0.0
# Step: 114, Action: [[0.]], Reward: [0.], Last Price: [56.9629097] Position: [0.] Total Balance: 10125.708229843038 Total Reward: 0.0, Cash Balance: 10125.708229843038, Position Balance: 0.0
# Step: 115, Action: [[0.]], Reward: [0.], Last Price: [56.69158173] Position: [0.] Total Balance: 10126.817896498364 Total Reward: 0.0, Cash Balance: 10126.817896498364, Position Balance: 0.0
# Step: 116, Action: [[0.]], Reward: [0.], Last Price: [56.60113144] Position: [0.] Total Balance: 10127.927684760993 Total Reward: 0.0, Cash Balance: 10127.927684760993, Position Balance: 0.0
# Step: 117, Action: [[0.]], Reward: [0.], Last Price: [56.3478775] Position: [0.] Total Balance: 10129.037594644255 Total Reward: 0.0, Cash Balance: 10129.037594644255, Position Balance: 0.0
# Step: 150, Action: [[0.]], Reward: [0.], Last Price: [57.55984879] Position: [0.] Total Balance: 10165.73293727634 Total Reward: 0.0, Cash Balance: 10165.73293727634, Position Balance: 0.0
# Step: 151, Action: [[0.]], Reward: [0.], Last Price: [57.36991501] Position: [0.] Total Balance: 10166.846990200973 Total Reward: 0.0, Cash Balance: 10166.846990200973, Position Balance: 0.0
# Step: 152, Action: [[0.]], Reward: [0.], Last Price: [57.28851318] Position: [0.] Total Balance: 10167.961165213597 Total Reward: 0.0, Cash Balance: 10167.961165213597, Position Balance: 0.0
# Step: 153, Action: [[0.]], Reward: [0.], Last Price: [57.93972397] Position: [0.] Total Balance: 10169.075462327593 Total Reward: 0.0, Cash Balance: 10169.075462327593, Position Balance: 0.0
# Step: 154, Action: [[0.]], Reward: [0.], Last Price: [57.88546371] Position: [0.] Total Balance: 10170.189881556342 Total Reward: 0.0, Cash Balance: 10170.189881556342, Position Balance: 0.0
# Step: 155, Action: [[0.]], Reward: [0.], Last Price: [58.53667831] Position: [0.] Total Balance: 10171.304422913225 Total Reward: 0.0, Cash Balance: 10171.304422913225, Position Balance: 0.0
# Step: 156, Action: [[0.]], Reward: [0.], Last Price: [58.75506592] Position: [0.] Total Balance: 10172.419086411626 Total Reward: 0.0, Cash Balance: 10172.419086411626, Position Balance: 0.0
# Step: 157, Action: [[0.]], Reward: [0.], Last Price: [58.71865463] Position: [0.] Total Balance: 10173.533872064932 Total Reward: 0.0, Cash Balance: 10173.533872064932, Position Balance: 0.0
# Step: 158, Action: [[0.]], Reward: [0.], Last Price: [58.70955658] Position: [0.] Total Balance: 10174.64877988653 Total Reward: 0.0, Cash Balance: 10174.64877988653, Position Balance: 0.0
# Step: 159, Action: [[0.]], Reward: [0.], Last Price: [58.80056763] Position: [0.] Total Balance: 10175.763809889804 Total Reward: 0.0, Cash Balance: 10175.763809889804, Position Balance: 0.0
# Step: 160, Action: [[0.]], Reward: [0.], Last Price: [58.68226242] Position: [0.] Total Balance: 10176.878962088149 Total Reward: 0.0, Cash Balance: 10176.878962088149, Position Balance: 0.0
# Step: 161, Action: [[0.]], Reward: [0.], Last Price: [58.56396484] Position: [0.] Total Balance: 10177.994236494953 Total Reward: 0.0, Cash Balance: 10177.994236494953, Position Balance: 0.0
# Step: 162, Action: [[0.]], Reward: [0.], Last Price: [58.80056763] Position: [0.] Total Balance: 10179.10963312361 Total Reward: 0.0, Cash Balance: 10179.10963312361, Position Balance: 0.0
# Step: 163, Action: [[0.]], Reward: [0.], Last Price: [58.80056763] Position: [0.] Total Balance: 10180.225151987514 Total Reward: 0.0, Cash Balance: 10180.225151987514, Position Balance: 0.0
# Step: 164, Action: [[0.]], Reward: [0.], Last Price: [58.44569397] Position: [0.] Total Balance: 10181.34079310006 Total Reward: 0.0, Cash Balance: 10181.34079310006, Position Balance: 0.0
# Step: 165, Action: [[0.]], Reward: [0.], Last Price: [58.21819687] Position: [0.] Total Balance: 10182.456556474646 Total Reward: 0.0, Cash Balance: 10182.456556474646, Position Balance: 0.0
# Step: 166, Action: [[0.]], Reward: [0.], Last Price: [59.09173965] Position: [0.] Total Balance: 10183.57244212467 Total Reward: 0.0, Cash Balance: 10183.57244212467, Position Balance: 0.0
# Step: 167, Action: [[0.]], Reward: [0.], Last Price: [58.24549103] Position: [0.] Total Balance: 10184.688450063533 Total Reward: 0.0, Cash Balance: 10184.688450063533, Position Balance: 0.0
# Step: 168, Action: [[0.]], Reward: [0.], Last Price: [58.46387863] Position: [0.] Total Balance: 10185.804580304637 Total Reward: 0.0, Cash Balance: 10185.804580304637, Position Balance: 0.0
# Step: 169, Action: [[0.]], Reward: [0.], Last Price: [58.48209381] Position: [0.] Total Balance: 10186.920832861382 Total Reward: 0.0, Cash Balance: 10186.920832861382, Position Balance: 0.0
# Step: 170, Action: [[0.]], Reward: [0.], Last Price: [58.6003685] Position: [0.] Total Balance: 10188.037207747175 Total Reward: 0.0, Cash Balance: 10188.037207747175, Position Balance: 0.0
# Step: 171, Action: [[0.]], Reward: [0.], Last Price: [59.13723755] Position: [0.] Total Balance: 10189.15370497542 Total Reward: 0.0, Cash Balance: 10189.15370497542, Position Balance: 0.0
# Step: 172, Action: [[0.]], Reward: [0.], Last Price: [58.90065765] Position: [0.] Total Balance: 10190.270324559528 Total Reward: 0.0, Cash Balance: 10190.270324559528, Position Balance: 0.0
# Step: 173, Action: [[0.]], Reward: [0.], Last Price: [59.0826416] Position: [0.] Total Balance: 10191.387066512903 Total Reward: 0.0, Cash Balance: 10191.387066512903, Position Balance: 0.0
# Step: 174, Action: [[0.]], Reward: [0.], Last Price: [58.8824501] Position: [0.] Total Balance: 10192.50393084896 Total Reward: 0.0, Cash Balance: 10192.50393084896, Position Balance: 0.0
# Step: 175, Action: [[0.]], Reward: [0.], Last Price: [58.609478] Position: [0.] Total Balance: 10193.620917581107 Total Reward: 0.0, Cash Balance: 10193.620917581107, Position Balance: 0.0
# Step: 176, Action: [[0.]], Reward: [0.], Last Price: [58.91884613] Position: [0.] Total Balance: 10194.73802672276 Total Reward: 0.0, Cash Balance: 10194.73802672276, Position Balance: 0.0
# Step: 177, Action: [[0.]], Reward: [0.], Last Price: [58.81875229] Position: [0.] Total Balance: 10195.855258287333 Total Reward: 0.0, Cash Balance: 10195.855258287333, Position Balance: 0.0
# Step: 178, Action: [[0.]], Reward: [0.], Last Price: [59.02804565] Position: [0.] Total Balance: 10196.97261228824 Total Reward: 0.0, Cash Balance: 10196.97261228824, Position Balance: 0.0
# Step: 179, Action: [[0.]], Reward: [0.], Last Price: [59.0826416] Position: [0.] Total Balance: 10198.090088738902 Total Reward: 0.0, Cash Balance: 10198.090088738902, Position Balance: 0.0
# Step: 180, Action: [[0.]], Reward: [0.], Last Price: [58.42747498] Position: [0.] Total Balance: 10199.207687652735 Total Reward: 0.0, Cash Balance: 10199.207687652735, Position Balance: 0.0
# Step: 181, Action: [[0.]], Reward: [0.], Last Price: [59.17363739] Position: [0.] Total Balance: 10200.325409043164 Total Reward: 0.0, Cash Balance: 10200.325409043164, Position Balance: 0.0
# Step: 198, Action: [[0.]], Reward: [0.], Last Price: [59.58311462] Position: [0.] Total Balance: 10219.345424610921 Total Reward: 0.0, Cash Balance: 10219.345424610921, Position Balance: 0.0
# Step: 199, Action: [[0.]], Reward: [0.], Last Price: [59.50120544] Position: [0.] Total Balance: 10220.465352876632 Total Reward: 0.0, Cash Balance: 10220.465352876632, Position Balance: 0.0
# Step: 200, Action: [[0.]], Reward: [0.], Last Price: [59.18274307] Position: [0.] Total Balance: 10221.585403874207 Total Reward: 0.0, Cash Balance: 10221.585403874207, Position Balance: 0.0
# Step: 201, Action: [[0.]], Reward: [0.], Last Price: [59.60131836] Position: [0.] Total Balance: 10222.705577617098 Total Reward: 0.0, Cash Balance: 10222.705577617098, Position Balance: 0.0
# Step: 202, Action: [[0.]], Reward: [0.], Last Price: [60.42028427] Position: [0.] Total Balance: 10223.825874118755 Total Reward: 0.0, Cash Balance: 10223.825874118755, Position Balance: 0.0
# Step: 203, Action: [[0.]], Reward: [0.], Last Price: [61.44849777] Position: [0.] Total Balance: 10224.946293392632 Total Reward: 0.0, Cash Balance: 10224.946293392632, Position Balance: 0.0
# Step: 204, Action: [[0.]], Reward: [0.], Last Price: [61.80337906] Position: [0.] Total Balance: 10226.066835452182 Total Reward: 0.0, Cash Balance: 10226.066835452182, Position Balance: 0.0
# Step: 205, Action: [[0.]], Reward: [0.], Last Price: [61.72147751] Position: [0.] Total Balance: 10227.187500310862 Total Reward: 0.0, Cash Balance: 10227.187500310862, Position Balance: 0.0
# Step: 206, Action: [[0.]], Reward: [0.], Last Price: [62.1218605] Position: [0.] Total Balance: 10228.308287982129 Total Reward: 0.0, Cash Balance: 10228.308287982129, Position Balance: 0.0
# Step: 207, Action: [[0.]], Reward: [0.], Last Price: [62.2947464] Position: [0.] Total Balance: 10229.429198479442 Total Reward: 0.0, Cash Balance: 10229.429198479442, Position Balance: 0.0
# Step: 208, Action: [[0.]], Reward: [0.], Last Price: [63.15920258] Position: [0.] Total Balance: 10230.550231816262 Total Reward: 0.0, Cash Balance: 10230.550231816262, Position Balance: 0.0
# Step: 209, Action: [[0.]], Reward: [0.], Last Price: [63.05909729] Position: [0.] Total Balance: 10231.67138800605 Total Reward: 0.0, Cash Balance: 10231.67138800605, Position Balance: 0.0
# Step: 210, Action: [[0.]], Reward: [0.], Last Price: [62.85890961] Position: [0.] Total Balance: 10232.792667062271 Total Reward: 0.0, Cash Balance: 10232.792667062271, Position Balance: 0.0
# Step: 211, Action: [[0.]], Reward: [0.], Last Price: [62.61322403] Position: [0.] Total Balance: 10233.914068998387 Total Reward: 0.0, Cash Balance: 10233.914068998387, Position Balance: 0.0
# Step: 212, Action: [[0.]], Reward: [0.], Last Price: [62.78611374] Position: [0.] Total Balance: 10235.035593827866 Total Reward: 0.0, Cash Balance: 10235.035593827866, Position Balance: 0.0
# Step: 213, Action: [[0.]], Reward: [0.], Last Price: [62.73150635] Position: [0.] Total Balance: 10236.157241564177 Total Reward: 0.0, Cash Balance: 10236.157241564177, Position Balance: 0.0
# Step: 214, Action: [[0.]], Reward: [0.], Last Price: [62.82250214] Position: [0.] Total Balance: 10237.279012220786 Total Reward: 0.0, Cash Balance: 10237.279012220786, Position Balance: 0.0
# Step: 215, Action: [[0.]], Reward: [0.], Last Price: [63.06819153] Position: [0.] Total Balance: 10238.400905811166 Total Reward: 0.0, Cash Balance: 10238.400905811166, Position Balance: 0.0
# Step: 216, Action: [[0.]], Reward: [0.], Last Price: [62.2947464] Position: [0.] Total Balance: 10239.52292234879 Total Reward: 0.0, Cash Balance: 10239.52292234879, Position Balance: 0.0
# Step: 217, Action: [[0.]], Reward: [0.], Last Price: [62.22193527] Position: [0.] Total Balance: 10240.64506184713 Total Reward: 0.0, Cash Balance: 10240.64506184713, Position Balance: 0.0
# Step: 218, Action: [[0.]], Reward: [0.], Last Price: [62.26743698] Position: [0.] Total Balance: 10241.76732431966 Total Reward: 0.0, Cash Balance: 10241.76732431966, Position Balance: 0.0
# Step: 219, Action: [[0.]], Reward: [0.], Last Price: [63.52122116] Position: [0.] Total Balance: 10242.88970977986 Total Reward: 0.0, Cash Balance: 10242.88970977986, Position Balance: 0.0
# Step: 220, Action: [[0.]], Reward: [0.], Last Price: [61.75494003] Position: [0.] Total Balance: 10244.012218241205 Total Reward: 0.0, Cash Balance: 10244.012218241205, Position Balance: 0.0
# Step: 221, Action: [[0.]], Reward: [0.], Last Price: [61.96543503] Position: [0.] Total Balance: 10245.134849717177 Total Reward: 0.0, Cash Balance: 10245.134849717177, Position Balance: 0.0
# Step: 222, Action: [[0.]], Reward: [0.], Last Price: [61.94713974] Position: [0.] Total Balance: 10246.257604221255 Total Reward: 0.0, Cash Balance: 10246.257604221255, Position Balance: 0.0
# Step: 223, Action: [[0.]], Reward: [0.], Last Price: [62.64265823] Position: [0.] Total Balance: 10247.380481766922 Total Reward: 0.0, Cash Balance: 10247.380481766922, Position Balance: 0.0
# Step: 224, Action: [[0.]], Reward: [0.], Last Price: [62.85313416] Position: [0.] Total Balance: 10248.503482367663 Total Reward: 0.0, Cash Balance: 10248.503482367663, Position Balance: 0.0
# Step: 225, Action: [[0.]], Reward: [0.], Last Price: [62.93550873] Position: [0.] Total Balance: 10249.626606036963 Total Reward: 0.0, Cash Balance: 10249.626606036963, Position Balance: 0.0
# Step: 226, Action: [[0.]], Reward: [0.], Last Price: [63.71340179] Position: [0.] Total Balance: 10250.74985278831 Total Reward: 0.0, Cash Balance: 10250.74985278831, Position Balance: 0.0
# Step: 227, Action: [[0.]], Reward: [0.], Last Price: [64.02454376] Position: [0.] Total Balance: 10251.873222635191 Total Reward: 0.0, Cash Balance: 10251.873222635191, Position Balance: 0.0
# Step: 228, Action: [[0.]], Reward: [0.], Last Price: [64.43639374] Position: [0.] Total Balance: 10252.996715591096 Total Reward: 0.0, Cash Balance: 10252.996715591096, Position Balance: 0.0
# Step: 229, Action: [[0.]], Reward: [0.], Last Price: [63.91473007] Position: [0.] Total Balance: 10254.120331669517 Total Reward: 0.0, Cash Balance: 10254.120331669517, Position Balance: 0.0
# Step: 1955, Action: [[0.]], Reward: [0.], Last Price: [420.05303955] Position: [0.] Total Balance: 16699.3465642621 Total Reward: -0.0, Cash Balance: 16699.3465642621, Position Balance: 0.0
# Step: 1956, Action: [[0.]], Reward: [0.], Last Price: [424.68762207] Position: [0.] Total Balance: 16701.176629639005 Total Reward: -0.0, Cash Balance: 16701.176629639005, Position Balance: 0.0
# Step: 1957, Action: [[0.]], Reward: [0.], Last Price: [418.70336914] Position: [0.] Total Balance: 16703.00689557102 Total Reward: -0.0, Cash Balance: 16703.00689557102, Position Balance: 0.0
# Step: 1958, Action: [[0.]], Reward: [0.], Last Price: [410.50595093] Position: [0.] Total Balance: 16704.837362080125 Total Reward: -0.0, Cash Balance: 16704.837362080125, Position Balance: 0.0
# Step: 1959, Action: [[0.]], Reward: [0.], Last Price: [411.43881226] Position: [0.] Total Balance: 16706.6680291883 Total Reward: -0.0, Cash Balance: 16706.6680291883, Position Balance: 0.0
# Step: 1960, Action: [[0.]], Reward: [0.], Last Price: [408.71957397] Position: [0.] Total Balance: 16708.498896917525 Total Reward: -0.0, Cash Balance: 16708.498896917525, Position Balance: 0.0
# Step: 1961, Action: [[0.]], Reward: [0.], Last Price: [401.20690918] Position: [0.] Total Balance: 16710.32996528979 Total Reward: -0.0, Cash Balance: 16710.32996528979, Position Balance: 0.0
# Step: 1962, Action: [[0.]], Reward: [0.], Last Price: [396.09594727] Position: [0.] Total Balance: 16712.161234327083 Total Reward: -0.0, Cash Balance: 16712.161234327083, Position Balance: 0.0
# Step: 1963, Action: [[0.]], Reward: [0.], Last Price: [397.92199707] Position: [0.] Total Balance: 16713.992704051394 Total Reward: -0.0, Cash Balance: 16713.992704051394, Position Balance: 0.0
# Step: 1964, Action: [[0.]], Reward: [0.], Last Price: [404.48193359] Position: [0.] Total Balance: 16715.824374484713 Total Reward: -0.0, Cash Balance: 16715.824374484713, Position Balance: 0.0
# Step: 1965, Action: [[0.]], Reward: [0.], Last Price: [405.96066284] Position: [0.] Total Balance: 16717.65624564904 Total Reward: -0.0, Cash Balance: 16717.65624564904, Position Balance: 0.0
# Step: 1966, Action: [[0.]], Reward: [0.], Last Price: [396.01657104] Position: [0.] Total Balance: 16719.48831756637 Total Reward: -0.0, Cash Balance: 16719.48831756637, Position Balance: 0.0
# Step: 1967, Action: [[0.]], Reward: [0.], Last Price: [403.24139404] Position: [0.] Total Balance: 16721.320590258707 Total Reward: -0.0, Cash Balance: 16721.320590258707, Position Balance: 0.0
# Step: 1968, Action: [[0.]], Reward: [0.], Last Price: [399.20223999] Position: [0.] Total Balance: 16723.15306374805 Total Reward: -0.0, Cash Balance: 16723.15306374805, Position Balance: 0.0
# Step: 1969, Action: [[0.]], Reward: [0.], Last Price: [386.38012695] Position: [0.] Total Balance: 16724.985738056406 Total Reward: -0.0, Cash Balance: 16724.985738056406, Position Balance: 0.0
# Step: 1970, Action: [[0.]], Reward: [0.], Last Price: [391.94763184] Position: [0.] Total Balance: 16726.81861320578 Total Reward: -0.0, Cash Balance: 16726.81861320578, Position Balance: 0.0
# Step: 1971, Action: [[0.]], Reward: [0.], Last Price: [394.82559204] Position: [0.] Total Balance: 16728.651689218186 Total Reward: -0.0, Cash Balance: 16728.651689218186, Position Balance: 0.0
# Step: 1972, Action: [[0.]], Reward: [0.], Last Price: [403.57879639] Position: [0.] Total Balance: 16730.484966115633 Total Reward: -0.0, Cash Balance: 16730.484966115633, Position Balance: 0.0
# Step: 1973, Action: [[0.]], Reward: [0.], Last Price: [410.40670776] Position: [0.] Total Balance: 16732.31844392014 Total Reward: -0.0, Cash Balance: 16732.31844392014, Position Balance: 0.0
# Step: 1974, Action: [[0.]], Reward: [0.], Last Price: [406.23849487] Position: [0.] Total Balance: 16734.15212265372 Total Reward: -0.0, Cash Balance: 16734.15212265372, Position Balance: 0.0
# Step: 1975, Action: [[0.]], Reward: [0.], Last Price: [407.42944336] Position: [0.] Total Balance: 16735.98600233839 Total Reward: -0.0, Cash Balance: 16735.98600233839, Position Balance: 0.0
# Step: 1976, Action: [[0.]], Reward: [0.], Last Price: [409.19595337] Position: [0.] Total Balance: 16737.820082996182 Total Reward: -0.0, Cash Balance: 16737.820082996182, Position Balance: 0.0
# Step: 1977, Action: [[0.]], Reward: [0.], Last Price: [411.5975647] Position: [0.] Total Balance: 16739.65436464911 Total Reward: -0.0, Cash Balance: 16739.65436464911, Position Balance: 0.0
# Step: 1978, Action: [[0.]], Reward: [0.], Last Price: [410.58532715] Position: [0.] Total Balance: 16741.48884731921 Total Reward: -0.0, Cash Balance: 16741.48884731921, Position Balance: 0.0
# Step: 1979, Action: [[0.]], Reward: [0.], Last Price: [413.40380859] Position: [0.] Total Balance: 16743.323531028505 Total Reward: -0.0, Cash Balance: 16743.323531028505, Position Balance: 0.0
# Step: 1980, Action: [[0.]], Reward: [0.], Last Price: [420.63171387] Position: [0.] Total Balance: 16745.15841579903 Total Reward: -0.0, Cash Balance: 16745.15841579903, Position Balance: 0.0
# Step: 1981, Action: [[0.]], Reward: [0.], Last Price: [418.55383301] Position: [0.] Total Balance: 16746.993501652814 Total Reward: -0.0, Cash Balance: 16746.993501652814, Position Balance: 0.0
# Step: 1982, Action: [[0.]], Reward: [0.], Last Price: [417.77832031] Position: [0.] Total Balance: 16748.8287886119 Total Reward: -0.0, Cash Balance: 16748.8287886119, Position Balance: 0.0
# Step: 1983, Action: [[0.]], Reward: [0.], Last Price: [422.87866211] Position: [0.] Total Balance: 16750.664276698324 Total Reward: -0.0, Cash Balance: 16750.664276698324, Position Balance: 0.0
# Step: 1984, Action: [[0.]], Reward: [0.], Last Price: [426.55728149] Position: [0.] Total Balance: 16752.499965934127 Total Reward: -0.0, Cash Balance: 16752.499965934127, Position Balance: 0.0
# Step: 1985, Action: [[0.]], Reward: [0.], Last Price: [428.02868652] Position: [0.] Total Balance: 16754.335856341353 Total Reward: -0.0, Cash Balance: 16754.335856341353, Position Balance: 0.0
# Step: 2002, Action: [[0.]], Reward: [0.], Last Price: [445.77539062] Position: [0.] Total Balance: 16785.576793864042 Total Reward: -0.0, Cash Balance: 16785.576793864042, Position Balance: 0.0
# Step: 2003, Action: [[0.]], Reward: [0.], Last Price: [443.75714111] Position: [0.] Total Balance: 16787.416309129123 Total Reward: -0.0, Cash Balance: 16787.416309129123, Position Balance: 0.0
# Step: 2004, Action: [[0.]], Reward: [0.], Last Price: [443.12084961] Position: [0.] Total Balance: 16789.25602598492 Total Reward: -0.0, Cash Balance: 16789.25602598492, Position Balance: 0.0
# Step: 2005, Action: [[0.]], Reward: [0.], Last Price: [447.17724609] Position: [0.] Total Balance: 16791.095944453522 Total Reward: -0.0, Cash Balance: 16791.095944453522, Position Balance: 0.0
# Step: 2006, Action: [[0.]], Reward: [0.], Last Price: [445.07949829] Position: [0.] Total Balance: 16792.936064557023 Total Reward: -0.0, Cash Balance: 16792.936064557023, Position Balance: 0.0
# Step: 2007, Action: [[0.]], Reward: [0.], Last Price: [448.3404541] Position: [0.] Total Balance: 16794.776386317524 Total Reward: -0.0, Cash Balance: 16794.776386317524, Position Balance: 0.0
# Step: 2008, Action: [[0.]], Reward: [0.], Last Price: [449.54345703] Position: [0.] Total Balance: 16796.616909757122 Total Reward: -0.0, Cash Balance: 16796.616909757122, Position Balance: 0.0
# Step: 2009, Action: [[0.]], Reward: [0.], Last Price: [450.22946167] Position: [0.] Total Balance: 16798.457634897917 Total Reward: -0.0, Cash Balance: 16798.457634897917, Position Balance: 0.0
# Step: 0, Action: [[0.]], Reward: [0.], Last Price: [0.] Position: [0.] Total Balance: 10000.0 Total Reward: 1.0, Cash Balance: 10000, Position Balance: 0.0
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_2792/3710083534.py:47: RuntimeWarning: invalid value encountered in divide
#   actions_array[1:-1] = actions_array[1:-1] / actions_array[1:-1].sum(axis=1, keepdims=True)

# %%
## VALIDATION DATA
## VALIDATION DATA
## VALIDATION DATA
## VALIDATION DATA
## VALIDATION DATA
## VALIDATION DATA

# %%
epsilon = 1e-8  # Small constant to prevent division by zero
total_pct = 0
for i, ticker in enumerate(my_stocks):
    pct = (all_data_np_val[i, -1] - all_data_np_val[i, 0]) / all_data_np_val[i, 0]
    total_pct +=pct
    print(f"percentage for ticker: {ticker}: {(all_data_np_val[i, -1] - all_data_np_val[i, 0]) / all_data_np_val[i, 0]}")
total_pct /= len(my_stocks)
print(f"percentage if kept equal allocation all the time: {total_pct}")

# %%
env = DummyVecEnv([lambda: TradingEnv(obs_val, all_data_np_val)])
env.tickers = my_stocks

# Test Model
done = False
obs_row = env.reset()
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action = np.ones(action_len), dtype=np.float32) / (len(my_stocks) + 1)
    action = np.array([action])
    obs_row, reward, done, _ = env.step(action)
    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")
# Out:
#   Cell In[4], line 11
#     action = np.ones(action_len), dtype=np.float32) / (len(my_stocks) + 1)
#                                                   ^
# SyntaxError: unmatched ')'

# %%
import matplotlib.pyplot as plt
# Create environment for new data
env = DummyVecEnv([lambda: TradingEnv(obs_val, all_data_np_val)])

# Test Model
done = False
obs_val_pre = env.reset()
env.current_step = 0

# Assuming you have collected these values during your loop
steps = []  # List to store step numbers
actions_list = []  # List to store action values
total_balances = []  # List to store total balances
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action, _states = model.predict(obs_val_pre, deterministic=True)
    obs_val_pre, reward, done, _ = env.step(action)

    steps.append(env.envs[0].current_step)
    actions_list.append(action.flatten())  # Flatten to make it 1D
    total_balances.append(env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices))

    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")

# Convert actions to a NumPy array for easier plotting
actions_array = np.array(actions_list)

# Plot Actions over Steps
plt.figure(figsize=(10, 5))
action_space = actions_array.shape[1]
if include_singular_rewards:
    action_space -= len(my_stocks)
for i in range(action_space):
    plt.plot(steps[1:-1], actions_array[1:-1, i], label=f'Action {i+1}')

plt.xlabel('Steps')
plt.ylabel('Action Values')
plt.title('Actions over Steps')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
actions_array = actions_array[:, 0:action_space]
actions_array[1:-1] = actions_array[1:-1] / actions_array[1:-1].sum(axis=1, keepdims=True)
for i in range(action_space):
    plt.plot(steps[1:-1], actions_array[1:-1, i], label=f'Action {i+1}')

plt.xlabel('Steps')
plt.ylabel('Action Values')
plt.title('Actions over Steps')
plt.legend()
plt.grid(True)
plt.show()

# Plot Total Balance over Steps
plt.figure(figsize=(10, 5))
plt.plot(steps, total_balances, marker='o', linestyle='-', alpha=0.8)
plt.xlabel('Steps')
plt.ylabel('Total Balance')
plt.title('Total Balance over Steps')
plt.grid(True)
plt.show()
# Out:
# num_features: 28
# self.action_space.shape: (1,)
# Step: 1, Action: [[1.]], Reward: [0.10102858], Last Price: [456.62225342] Position: [21.] Total Balance: 9980.86479736122 Total Reward: 0.10102858293830241, Cash Balance: 391.79747558387925, Position Balance: 9589.067321777342
# Step: 2, Action: [[1.]], Reward: [0.1850777], Last Price: [458.1036377] Position: [21.] Total Balance: 10012.016803895094 Total Reward: 0.0186981369328193, Cash Balance: 391.84041229353227, Position Balance: 9620.176391601562
# Step: 152, Action: [[1.]], Reward: [0.1294408], Last Price: [408.93005371] Position: [22.] Total Balance: 9350.326549309933 Total Reward: 0.0, Cash Balance: 353.8653676693079, Position Balance: 8996.461181640625
# Step: 153, Action: [[1.]], Reward: [-0.08143047], Last Price: [411.39511108] Position: [22.] Total Balance: 9404.596591283283 Total Reward: -0.0, Cash Balance: 353.9041474356278, Position Balance: 9050.692443847656
# Step: 154, Action: [[1.]], Reward: [-0.1277504], Last Price: [410.6166687] Position: [22.] Total Balance: 9387.509642877567 Total Reward: 0.0, Cash Balance: 353.9429314517851, Position Balance: 9033.566711425781
# Step: 155, Action: [[1.]], Reward: [0.10610393], Last Price: [408.22146606] Position: [22.] Total Balance: 9334.853973136214 Total Reward: 0.0, Cash Balance: 353.9817197182456, Position Balance: 8980.872253417969
# Step: 156, Action: [[1.]], Reward: [-0.12144314], Last Price: [409.71847534] Position: [22.] Total Balance: 9367.826969755006 Total Reward: -0.0, Cash Balance: 354.020512235475, Position Balance: 9013.806457519531
# Step: 157, Action: [[1.]], Reward: [0.0974253], Last Price: [407.6126709] Position: [22.] Total Balance: 9321.538068769563 Total Reward: -0.0, Cash Balance: 354.0593090039392, Position Balance: 8967.478759765625
# Step: 158, Action: [[1.]], Reward: [0.17341454], Last Price: [408.82028198] Position: [22.] Total Balance: 9348.144313637385 Total Reward: -0.0, Cash Balance: 354.098110024104, Position Balance: 8994.046203613281
# Step: 159, Action: [[1.]], Reward: [0.12285784], Last Price: [413.94000244] Position: [22.] Total Balance: 9460.816969007374 Total Reward: -0.0, Cash Balance: 354.1369152964354, Position Balance: 9106.680053710938
# Step: 160, Action: [[1.]], Reward: [-0.20502119], Last Price: [416.13000488] Position: [22.] Total Balance: 9509.035832243275 Total Reward: 0.0, Cash Balance: 354.1757248213994, Position Balance: 9154.860107421875
# Step: 161, Action: [[1.]], Reward: [-0.16045713], Last Price: [408.20999146] Position: [22.] Total Balance: 9334.834350611181 Total Reward: -0.0, Cash Balance: 354.214538599462, Position Balance: 8980.619812011719
# Step: 162, Action: [[1.]], Reward: [-0.1868872], Last Price: [404.] Position: [22.] Total Balance: 9242.253356631089 Total Reward: 0.0, Cash Balance: 354.25335663108933, Position Balance: 8888.0
# Step: 163, Action: [[1.]], Reward: [0.11616424], Last Price: [397.8999939] Position: [22.] Total Balance: 9108.092044639403 Total Reward: 0.0, Cash Balance: 354.29217891674756, Position Balance: 8753.799865722656
# Step: 164, Action: [[1.]], Reward: [-0.20055181], Last Price: [399.73001099] Position: [22.] Total Balance: 9148.391247156122 Total Reward: -0.0, Cash Balance: 354.3310054569028, Position Balance: 8794.060241699219
# Step: 0, Action: [[1.]], Reward: [0.16679555], Last Price: [0.] Position: [0.] Total Balance: 10000.0 Total Reward: 1.0, Cash Balance: 10000, Position Balance: 0.0
# /var/folders/1n/8vt634f15059yz_p3_whxnk80000gn/T/ipykernel_2792/3721110829.py:47: RuntimeWarning: invalid value encountered in divide
#   actions_array[1:-1] = actions_array[1:-1] / actions_array[1:-1].sum(axis=1, keepdims=True)

# %%
print(len(obs_val))

# %%
to_remove = len(obs_val) - 30
print(f"to_remove: {to_remove}")
last_30_days = obs_val[to_remove:, :, :, :]
last_30_days_close = all_data_np_val[:, -30:]

# %%
## VALIDATION DATA - 30 DAYS
## VALIDATION DATA - 30 DAYS
## VALIDATION DATA - 30 DAYS
## VALIDATION DATA - 30 DAYS
## VALIDATION DATA - 30 DAYS
## VALIDATION DATA - 30 DAYS

# %%
env = DummyVecEnv([lambda: TradingEnv(last_30_days, last_30_days_close)])
env.tickers = my_stocks

# Test Model
done = False
obs_row = env.reset()
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action = np.ones(action_len), dtype=np.float32) / action_len
    action = np.array([action])
    obs_row, reward, done, _ = env.step(action)
    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")

# %%
print(f"last_30_days: {len(last_30_days)}")

import matplotlib.pyplot as plt
# Create environment for new data
env = DummyVecEnv([lambda: TradingEnv(last_30_days, last_30_days_close)])

# Test Model
done = False
obs_val_pre = env.reset()
env.current_step = 0

# Assuming you have collected these values during your loop
steps = []  # List to store step numbers
actions_list = []  # List to store action values
total_balances = []  # List to store total balances
# last_known_explianed_variance = None    
# cons_counter = 0

while not done:
    action, _states = model.predict(obs_val_pre, deterministic=True)
    obs_val_pre, reward, done, _ = env.step(action)

    steps.append(env.envs[0].current_step)
    actions_list.append(action.flatten())  # Flatten to make it 1D
    total_balances.append(env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices))

    print(f"Step: {env.envs[0].current_step}, Action: {action}, Reward: {reward}, Last Price: {env.envs[0].last_prices} Position: {env.envs[0].positions} Total Balance: {env.envs[0].cash_balance + np.sum(env.envs[0].positions * env.envs[0].last_prices)} Total Reward: {env.envs[0].total_reward}, Cash Balance: {env.envs[0].cash_balance}, Position Balance: {np.sum(env.envs[0].positions * env.envs[0].last_prices)}")

# Convert actions to a NumPy array for easier plotting
actions_array = np.array(actions_list)

# Plot Actions over Steps
plt.figure(figsize=(10, 5))
for i in range(actions_array.shape[1]):
    plt.plot(steps[1:-1], actions_array[1:-1, i], label=f'Action {i+1}')

plt.xlabel('Steps')
plt.ylabel('Action Values')
plt.title('Actions over Steps')
plt.legend()
plt.grid(True)
plt.show()

# Plot Total Balance over Steps
plt.figure(figsize=(10, 5))
plt.plot(steps, total_balances, marker='o', linestyle='-', alpha=0.8)
plt.xlabel('Steps')
plt.ylabel('Total Balance')
plt.title('Total Balance over Steps')
plt.grid(True)
plt.show()

# %%
# %run "../helpers/data_manipulator.py"
# %run "../helpers/yfinance_data_fetcher.py"
fetch_finance_data_for_tickers("BAC", "5y", refresh=True, verbose=False)

data = yf.download("BAC", period="1mo", actions=True, auto_adjust=False)
print(data)
